# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2FFeature+Store%2FBigtable&file=Bigtable+Feature+Store+-+Schema+Evolution+and+Operations.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2FFeature%2520Store%2FBigtable%2FBigtable%2520Feature%2520Store%2520-%2520Schema%2520Evolution%2520and%2520Operations.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Schema%2520Evolution%2520and%2520Operations.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Schema%2520Evolution%2520and%2520Operations.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Schema%2520Evolution%2520and%2520Operations.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Schema%2520Evolution%2520and%2520Operations.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Bigtable Feature Store — Schema Evolution & Operations
#
# A feature store in production is never "done." Features get added, deprecated, and renamed. Traffic patterns shift. Costs need optimization. This notebook covers the operational lifecycle — schema versioning, safe migrations, monitoring, and production hardening.
#
# **Prerequisites:** Run [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) first.

# %% [markdown]
# ---
# ## Configuration

# %%
PROJECT_ID = 'statmike-mlops-349915'
REGION = 'us-central1'
ZONE = 'us-central1-a'

BQ_PROJECT = PROJECT_ID
BQ_DATASET = 'bigtable_feature_store'

BT_INSTANCE = 'feature-store'
BT_TABLE = 'features'
BT_COLUMN_FAMILY = 'features'

print(f'Project:    {PROJECT_ID}')
print(f'Region:     {REGION}')
print(f'BQ Dataset: {BQ_PROJECT}.{BQ_DATASET}')
print(f'Bigtable:   {BT_INSTANCE}/{BT_TABLE}')
# Out:
# Project:    statmike-mlops-349915
# Region:     us-central1
# BQ Dataset: statmike-mlops-349915.bigtable_feature_store
# Bigtable:   feature-store/features

# %% [markdown]
# ---
# ## Packages

# %%
import subprocess, sys, shutil

def install(*packages):
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call(
            [uv, 'pip', 'install', '-q', '--prerelease=allow',
             '--python', sys.executable, *packages])
    else:
        subprocess.check_call(
            [sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install(
    'google-cloud-bigquery', 'db-dtypes',
    'google-cloud-bigtable',
    'google-cloud-monitoring',
    'pandas',
)

# %% [markdown]
# ### Authentication

# %%
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC used automatically

# %% [markdown]
# ---
# ## Prerequisites Check
#
# Verify the BigQuery dataset exists and connect to the Bigtable instance and table created in Notebook 0.

# %%
from google.cloud import bigquery
from google.cloud import bigtable
from google.cloud.bigtable.row_filters import CellsColumnLimitFilter
from google.cloud import monitoring_v3
from google.api_core.exceptions import NotFound, AlreadyExists
import pandas as pd
import json
import time
import datetime

bq = bigquery.Client(project=PROJECT_ID)
bt_client = bigtable.Client(project=PROJECT_ID, admin=True)
instance = bt_client.instance(BT_INSTANCE)
table = instance.table(BT_TABLE)

# Verify BQ dataset
try:
    dataset = bq.get_dataset(f'{BQ_PROJECT}.{BQ_DATASET}')
    print(f'BQ dataset ready:  {BQ_PROJECT}.{BQ_DATASET}')
except NotFound:
    print(f'ERROR: Dataset {BQ_PROJECT}.{BQ_DATASET} not found. Run Notebook 0 first.')

# Verify Bigtable
if table.exists():
    families = list(table.list_column_families().keys())
    print(f'Bigtable ready:    {BT_INSTANCE}/{BT_TABLE}')
    print(f'Column families:   {families}')
else:
    print(f'ERROR: Table {BT_INSTANCE}/{BT_TABLE} not found. Run Notebook 0 first.')

print(f'\nClients initialized.')
# Out:
# BQ dataset ready:  statmike-mlops-349915.bigtable_feature_store
# Bigtable ready:    feature-store/features
# Column families:   ['features', 'metadata']
#
# Clients initialized.
# Bigtable ready:    feature-store/features
# Column families:   ['features', 'metadata']
#
# Clients initialized.

# %% [markdown]
# ---
# ## 1. Schema Versioning
#
# In Notebook 1, we introduced the `#schema` metadata row — a single JSON blob that describes the feature columns, their types, and the delimiter. The serving client reads this row once at startup and builds a decoder.
#
# That works for a static schema. But in production, schemas change:
# - New features get added (a retrained model needs an extra signal)
# - Features get deprecated (an old signal is no longer predictive)
# - Types change (an INT64 becomes a FLOAT64 after reprocessing)
#
# We need **versioned schemas** so that:
# 1. The serving client always knows which schema is current
# 2. Old schemas are preserved for debugging and rollback
# 3. The transition from v1 to v2 is atomic — no partial state
#
# ### Schema Registry Pattern
#
# We use three kinds of schema rows:
#
# | Row key | Purpose |
# |---------|--------|
# | `#schema#v1` | Version 1 schema (immutable once written) |
# | `#schema#v2` | Version 2 schema (immutable once written) |
# | `#schema#current` | Pointer to the active version — this is what the serving client reads |
#
# The serving client reads `#schema#current` to discover the active version, then reads `#schema#vN` for the full schema definition. Updating the schema is a two-step process: write the new version row, then atomically update `#schema#current`.

# %%
# Define v1 schema (the original schema from Notebook 1)
# Column order matches NB1 export: 5 INT64 (feature_int_1-5) then 5 FLOAT64 (feature_float_1-5)
SCHEMA_V1 = {
    'version': 'v1',
    'columns': [
        'txn_count_5min',
        'txn_count_1hr',
        'category_count_24hr',
        'account_age_days',
        'user_lifetime_orders',
        'spending_1hr',
        'spending_30d_avg',
        'spending_ratio',
        'sale_price',
        'order_total',
    ],
    'types': {
        'txn_count_5min': 'INT64',
        'txn_count_1hr': 'INT64',
        'category_count_24hr': 'INT64',
        'account_age_days': 'INT64',
        'user_lifetime_orders': 'INT64',
        'spending_1hr': 'FLOAT64',
        'spending_30d_avg': 'FLOAT64',
        'spending_ratio': 'FLOAT64',
        'sale_price': 'FLOAT64',
        'order_total': 'FLOAT64',
    },
    'delimiter': '|',
    'created_at': datetime.datetime.now(datetime.timezone.utc).isoformat(),
    'description': 'Original behavioral fraud features from Notebook 1',
}

# Write #schema#v1
v1_json = json.dumps(SCHEMA_V1, indent=2)
row_v1 = table.direct_row('#schema#v1')
row_v1.set_cell(BT_COLUMN_FAMILY, '_schema', v1_json.encode('utf-8'))
row_v1.commit()
print(f'Wrote #schema#v1 ({len(v1_json)} bytes)')
print(f'  Columns: {len(SCHEMA_V1["columns"])}')
print(f'  Version: {SCHEMA_V1["version"]}')
# Out:
# Wrote #schema#v1 (750 bytes)
#   Columns: 10
#   Version: v1

# %%
# Define v2 schema: adds two new features for the retrained model
SCHEMA_V2 = {
    'version': 'v2',
    'columns': [
        'txn_count_5min',
        'txn_count_1hr',
        'category_count_24hr',
        'account_age_days',
        'user_lifetime_orders',
        'spending_1hr',
        'spending_30d_avg',
        'spending_ratio',
        'sale_price',
        'order_total',
        # New in v2:
        'avg_order_gap_hours',
        'distinct_devices_7d',
    ],
    'types': {
        'txn_count_5min': 'INT64',
        'txn_count_1hr': 'INT64',
        'category_count_24hr': 'INT64',
        'account_age_days': 'INT64',
        'user_lifetime_orders': 'INT64',
        'spending_1hr': 'FLOAT64',
        'spending_30d_avg': 'FLOAT64',
        'spending_ratio': 'FLOAT64',
        'sale_price': 'FLOAT64',
        'order_total': 'FLOAT64',
        'avg_order_gap_hours': 'FLOAT64',
        'distinct_devices_7d': 'INT64',
    },
    'delimiter': '|',
    'created_at': datetime.datetime.now(datetime.timezone.utc).isoformat(),
    'description': 'Added avg_order_gap_hours and distinct_devices_7d for coordinated fraud detection',
    'parent_version': 'v1',
}

# Write #schema#v2
v2_json = json.dumps(SCHEMA_V2, indent=2)
row_v2 = table.direct_row('#schema#v2')
row_v2.set_cell(BT_COLUMN_FAMILY, '_schema', v2_json.encode('utf-8'))
row_v2.commit()
print(f'Wrote #schema#v2 ({len(v2_json)} bytes)')
print(f'  Columns: {len(SCHEMA_V2["columns"])}')
print(f'  New:     avg_order_gap_hours, distinct_devices_7d')
print(f'  Parent:  v1')
# Out:
# Wrote #schema#v2 (935 bytes)
#   Columns: 12
#   New:     avg_order_gap_hours, distinct_devices_7d
#   Parent:  v1

# %%
# Write #schema#current — points to v1 initially
current_pointer = json.dumps({'current_version': 'v1'})
row_current = table.direct_row('#schema#current')
row_current.set_cell(BT_COLUMN_FAMILY, '_schema', current_pointer.encode('utf-8'))
row_current.commit()
print(f'Wrote #schema#current -> v1')

# Read it back to verify
current_row = table.read_row('#schema#current', filter_=CellsColumnLimitFilter(1))
pointer = json.loads(current_row.cells[BT_COLUMN_FAMILY][b'_schema'][0].value.decode('utf-8'))
print(f'Verified: current_version = {pointer["current_version"]}')
# Out:
# Wrote #schema#current -> v1
# Verified: current_version = v1

# %% [markdown]
# ### Schema-Aware Reader
#
# The serving client uses a two-step read: first `#schema#current` to discover the active version, then `#schema#vN` for the full schema definition. This function encapsulates the pattern.

# %%
TYPE_PARSERS = {'INT64': int, 'FLOAT64': float, 'STRING': str}

def load_current_schema(tbl, family):
    """Read #schema#current and return the active schema dict."""
    # Step 1: Read the pointer
    current_row = tbl.read_row('#schema#current', filter_=CellsColumnLimitFilter(1))
    pointer = json.loads(current_row.cells[family][b'_schema'][0].value.decode('utf-8'))
    version = pointer['current_version']
    
    # Step 2: Read the versioned schema
    schema_row = tbl.read_row(f'#schema#{version}', filter_=CellsColumnLimitFilter(1))
    schema = json.loads(schema_row.cells[family][b'_schema'][0].value.decode('utf-8'))
    return schema

def decode_features(raw_value, schema):
    """Decode a delimited feature string using the schema."""
    parts = raw_value.split(schema['delimiter'])
    result = {}
    for i, col in enumerate(schema['columns']):
        if i < len(parts):
            result[col] = TYPE_PARSERS[schema['types'][col]](parts[i])
        else:
            # Missing value — backward compatibility for new columns
            result[col] = None
    return result

# Test: load current schema and decode a feature row
active_schema = load_current_schema(table, BT_COLUMN_FAMILY)
print(f'Active schema version: {active_schema["version"]}')
print(f'Columns: {len(active_schema["columns"])}')
print(f'Description: {active_schema["description"]}')
# Out:
# Active schema version: v1
# Columns: 10
# Description: Original behavioral fraud features from Notebook 1

# %% [markdown]
# ### Switching Versions
#
# Upgrading the schema is a single row write — update `#schema#current` to point to the new version. The serving client picks up the change on its next schema refresh.

# %%
def update_current_schema(tbl, family, new_version):
    """Atomically switch #schema#current to a new version."""
    pointer = json.dumps({'current_version': new_version})
    row = tbl.direct_row('#schema#current')
    row.set_cell(family, '_schema', pointer.encode('utf-8'))
    row.commit()
    return new_version

# Upgrade to v2
update_current_schema(table, BT_COLUMN_FAMILY, 'v2')
schema_after = load_current_schema(table, BT_COLUMN_FAMILY)
print(f'Schema upgraded: v1 -> {schema_after["version"]}')
print(f'New columns: {[c for c in schema_after["columns"] if c not in SCHEMA_V1["columns"]]}')

# Roll back to v1 for the rest of the notebook (since data rows are v1 format)
update_current_schema(table, BT_COLUMN_FAMILY, 'v1')
print(f'\nRolled back to v1 for compatibility with existing data rows.')
# Out:
# Schema upgraded: v1 -> v2
# New columns: ['avg_order_gap_hours', 'distinct_devices_7d']
#
# Rolled back to v1 for compatibility with existing data rows.

# %% [markdown]
# ### Interpreting Schema Versioning
#
# The versioned schema pattern gives you three properties:
#
# 1. **Immutable history.** Each `#schema#vN` row is written once and never modified. You can always see what the schema looked like at any point in time.
#
# 2. **Atomic switch.** Updating `#schema#current` is a single Bigtable row write — atomic and fast. There is no window where the schema is "half-upgraded."
#
# 3. **Instant rollback.** If the new schema causes issues, point `#schema#current` back to the previous version. The data rows are unchanged.
#
# The trade-off is that your decoder must handle rows written under any schema version — old rows may have fewer fields than the current schema expects. We address that next.

# %% [markdown]
# ---
# ## 2. Adding Features (Non-Breaking)
#
# Adding a new column qualifier to Bigtable is effortless — just start writing it. There is no `ALTER TABLE ADD COLUMN`. Bigtable is schemaless at the storage level; columns are created on first write.
#
# The challenge is on the **read side**: old rows do not have the new qualifier. Your decoder must handle missing values gracefully.
#
# ### Pattern: Append to Delimited Payload
#
# For the concatenated `_values` payload, new features are appended to the end of the delimiter-separated string. Old decoders that only know about the first N fields still work — they parse the fields they know and ignore the rest. New decoders parse all fields.
#
# For rows that haven't been backfilled yet, the new fields are simply missing from the string. The decoder returns `None` for those fields.

# %%
# Demo: Write some rows with the v1 format (10 features)
# and some with the v2 format (12 features, 2 new appended)

import random
random.seed(42)

# Write 5 rows in v1 format (5 INT64 then 5 FLOAT64, matching export order)
v1_rows = []
for i in range(5):
    row_key = f'demo_v1_{i}'
    values = [
        str(random.randint(0, 3)),       # txn_count_5min (INT64)
        str(random.randint(0, 10)),      # txn_count_1hr (INT64)
        str(random.randint(0, 5)),       # category_count_24hr (INT64)
        str(random.randint(30, 3000)),   # account_age_days (INT64)
        str(random.randint(1, 50)),      # user_lifetime_orders (INT64)
        f'{random.uniform(0, 500):.2f}', # spending_1hr (FLOAT64)
        f'{random.uniform(20, 100):.2f}',# spending_30d_avg (FLOAT64)
        f'{random.uniform(0.1, 5):.4f}', # spending_ratio (FLOAT64)
        f'{random.uniform(10, 300):.2f}',# sale_price (FLOAT64)
        f'{random.uniform(10, 300):.2f}',# order_total (FLOAT64)
    ]
    payload = '|'.join(values)
    row = table.direct_row(row_key)
    row.set_cell(BT_COLUMN_FAMILY, '_values', payload.encode('utf-8'))
    row.commit()
    v1_rows.append(row_key)

# Write 5 rows in v2 format (v1 fields + 2 new fields appended)
v2_rows = []
for i in range(5):
    row_key = f'demo_v2_{i}'
    values = [
        str(random.randint(0, 3)),
        str(random.randint(0, 10)),
        str(random.randint(0, 5)),
        str(random.randint(30, 3000)),
        str(random.randint(1, 50)),
        f'{random.uniform(0, 500):.2f}',
        f'{random.uniform(20, 100):.2f}',
        f'{random.uniform(0.1, 5):.4f}',
        f'{random.uniform(10, 300):.2f}',
        f'{random.uniform(10, 300):.2f}',
        # New v2 fields:
        f'{random.uniform(1, 720):.1f}',  # avg_order_gap_hours (FLOAT64)
        str(random.randint(1, 5)),         # distinct_devices_7d (INT64)
    ]
    payload = '|'.join(values)
    row = table.direct_row(row_key)
    row.set_cell(BT_COLUMN_FAMILY, '_values', payload.encode('utf-8'))
    row.commit()
    v2_rows.append(row_key)

print(f'Wrote {len(v1_rows)} v1 rows (10 fields) and {len(v2_rows)} v2 rows (12 fields)')
# Out:
# Wrote 5 v1 rows (10 fields) and 5 v2 rows (12 fields)

# %%
# Read all demo rows using the v2 schema — the decoder handles missing fields
v2_schema = load_current_schema(table, BT_COLUMN_FAMILY)
# Temporarily use v2 for decoding
update_current_schema(table, BT_COLUMN_FAMILY, 'v2')
v2_schema = load_current_schema(table, BT_COLUMN_FAMILY)

print(f'Decoding all demo rows with v2 schema ({len(v2_schema["columns"])} columns):\n')

all_demo_keys = v1_rows + v2_rows
for key in all_demo_keys:
    row = table.read_row(key, filter_=CellsColumnLimitFilter(1))
    if row and b'_values' in row.cells.get(BT_COLUMN_FAMILY, {}):
        raw = row.cells[BT_COLUMN_FAMILY][b'_values'][0].value.decode('utf-8')
        features = decode_features(raw, v2_schema)
        new_fields = {
            'avg_order_gap_hours': features.get('avg_order_gap_hours'),
            'distinct_devices_7d': features.get('distinct_devices_7d'),
        }
        print(f'  {key:<12s}  new_fields={new_fields}')

# Restore to v1
update_current_schema(table, BT_COLUMN_FAMILY, 'v1')
print(f'\nRows with v1 data return None for new fields — backward compatible.')
# Out:
# Decoding all demo rows with v2 schema (12 columns):
#
#   demo_v1_0     new_fields={'avg_order_gap_hours': None, 'distinct_devices_7d': None}
#   demo_v1_1     new_fields={'avg_order_gap_hours': None, 'distinct_devices_7d': None}
#   demo_v1_2     new_fields={'avg_order_gap_hours': None, 'distinct_devices_7d': None}
#   demo_v1_3     new_fields={'avg_order_gap_hours': None, 'distinct_devices_7d': None}
#   demo_v1_4     new_fields={'avg_order_gap_hours': None, 'distinct_devices_7d': None}
#   demo_v2_0     new_fields={'avg_order_gap_hours': 458.1, 'distinct_devices_7d': 3}
#   demo_v2_1     new_fields={'avg_order_gap_hours': 525.2, 'distinct_devices_7d': 2}
#   demo_v2_2     new_fields={'avg_order_gap_hours': 24.1, 'distinct_devices_7d': 3}
#   demo_v2_3     new_fields={'avg_order_gap_hours': 330.9, 'distinct_devices_7d': 3}
#   demo_v2_4     new_fields={'avg_order_gap_hours': 718.2, 'distinct_devices_7d': 5}
#
# Rows with v1 data return None for new fields — backward compatible.

# %% [markdown]
# ### Handling Default Values
#
# When the decoder returns `None` for a missing feature, the serving application needs a policy:
#
# | Strategy | When to use |
# |----------|------------|
# | **Default value** (e.g., 0, -1, mean) | The model tolerates a sentinel value without degrading predictions |
# | **Skip the feature** | The model can handle missing inputs (e.g., tree models with `enable_missing=True`) |
# | **Block serving** | The feature is critical and rows without it must not be scored |
# | **Lazy backfill** | On read, compute the missing feature on-the-fly and write it back |
#
# For our fraud model, `avg_order_gap_hours` defaults to a high value (infrequent ordering) and `distinct_devices_7d` defaults to 1. These are conservative defaults that reduce false positives during the backfill window.

# %% [markdown]
# ---
# ## 3. Removing and Renaming Features
#
# Removing a feature from a Bigtable table is different from removing a column in a relational database. There is no `DROP COLUMN` — old data retains the column qualifier until you explicitly delete it or GC policies reclaim it.
#
# ### Deprecation Pattern
#
# Rather than immediately deleting data, we use a **deprecation workflow**:
#
# 1. **Mark as deprecated in schema metadata.** The schema row records which features are deprecated and when.
# 2. **Stop writing the feature.** New exports/updates omit it.
# 3. **Update readers.** The decoder ignores deprecated columns.
# 4. **Eventually clean up.** Backfill to remove old data, or let GC policies expire it.

# %%
# Demonstrate deprecation: mark spending_ratio as deprecated in v3
SCHEMA_V3 = {
    'version': 'v3',
    'columns': [
        'txn_count_5min',
        'txn_count_1hr',
        'category_count_24hr',
        'account_age_days',
        'user_lifetime_orders',
        'spending_1hr',
        'spending_30d_avg',
        'spending_ratio',          # still in the column list for backward compat
        'sale_price',
        'order_total',
    ],
    'types': {
        'txn_count_5min': 'INT64',
        'txn_count_1hr': 'INT64',
        'category_count_24hr': 'INT64',
        'account_age_days': 'INT64',
        'user_lifetime_orders': 'INT64',
        'spending_1hr': 'FLOAT64',
        'spending_30d_avg': 'FLOAT64',
        'spending_ratio': 'FLOAT64',
        'sale_price': 'FLOAT64',
        'order_total': 'FLOAT64',
    },
    'delimiter': '|',
    'created_at': datetime.datetime.now(datetime.timezone.utc).isoformat(),
    'description': 'Deprecated spending_ratio — redundant with spending_1hr/spending_30d_avg',
    'parent_version': 'v1',
    'deprecated': ['spending_ratio'],
    'deprecated_date': datetime.date.today().isoformat(),
}

# Write #schema#v3
v3_json = json.dumps(SCHEMA_V3, indent=2)
row_v3 = table.direct_row('#schema#v3')
row_v3.set_cell(BT_COLUMN_FAMILY, '_schema', v3_json.encode('utf-8'))
row_v3.commit()

print(f'Wrote #schema#v3 ({len(v3_json)} bytes)')
print(f'  Deprecated: {SCHEMA_V3["deprecated"]}')
print(f'  Date:       {SCHEMA_V3["deprecated_date"]}')
# Out:
# Wrote #schema#v3 (882 bytes)
#   Deprecated: ['spending_ratio']
#   Date:       2026-05-09

# %%
# Deprecation-aware decoder
def decode_features_v2(raw_value, schema):
    """Decode features, excluding deprecated columns."""
    parts = raw_value.split(schema['delimiter'])
    deprecated = set(schema.get('deprecated', []))
    result = {}
    for i, col in enumerate(schema['columns']):
        if col in deprecated:
            continue  # Skip deprecated features
        if i < len(parts):
            result[col] = TYPE_PARSERS[schema['types'][col]](parts[i])
        else:
            result[col] = None
    return result

# Test: decode a demo row with v3 schema (spending_ratio excluded)
row = table.read_row('demo_v1_0', filter_=CellsColumnLimitFilter(1))
raw = row.cells[BT_COLUMN_FAMILY][b'_values'][0].value.decode('utf-8')

features_full = decode_features(raw, SCHEMA_V3)
features_no_deprecated = decode_features_v2(raw, SCHEMA_V3)

print('Full decode (all columns):')
for k, v in features_full.items():
    marker = ' [DEPRECATED]' if k in SCHEMA_V3.get('deprecated', []) else ''
    print(f'  {k:<25s} = {v}{marker}')

print(f'\nDeprecation-aware decode ({len(features_no_deprecated)} columns):')
for k, v in features_no_deprecated.items():
    print(f'  {k:<25s} = {v}')
# Out:
# Full decode (all columns):
#   txn_count_5min            = 0
#   txn_count_1hr             = 0
#   category_count_24hr       = 5
#   account_age_days          = 1156
#   user_lifetime_orders      = 16
#   spending_1hr              = 111.61
#   spending_30d_avg          = 78.92
#   spending_ratio            = 3.4158 [DEPRECATED]
#   sale_price                = 268.73
#   order_total               = 35.21
#
# Deprecation-aware decode (9 columns):
#   txn_count_5min            = 0
#   txn_count_1hr             = 0
#   category_count_24hr       = 5
#   account_age_days          = 1156
#   user_lifetime_orders      = 16
#   spending_1hr              = 111.61
#   spending_30d_avg          = 78.92
#   sale_price                = 268.73
#   order_total               = 35.21

# %% [markdown]
# ### Renaming Features
#
# Renaming is effectively a deprecation of the old name plus addition of the new name. During the transition period, **both** exist in the data:
#
# 1. Write the new qualifier with the new name
# 2. Update the schema: add the new name, mark the old as deprecated
# 3. Run a backfill to copy old-name values to new-name values
# 4. Once all rows have the new name, remove the old name from the schema
#
# This is inherently a multi-step process. The schema metadata tracks where you are in the transition:
#
# ```json
# {
#     "renames": {
#         "spending_ratio": "price_to_avg_ratio"
#     },
#     "rename_status": "in_progress"
# }
# ```
#
# The serving client can use either name during the transition, falling back to the old name if the new one is not yet present.

# %% [markdown]
# ---
# ## 4. Backfilling Without Downtime
#
# When you add a new feature or recompute existing values, you need to update potentially hundreds of thousands of rows. The key constraint: **readers must continue serving during the backfill.** No downtime, no inconsistent reads.
#
# ### Backfill Strategies
#
# | Pattern | How it works | Best for |
# |---------|-------------|----------|
# | **Write-alongside** | Write new values in a new qualifier; reader switches once backfill completes | Adding a feature to existing rows |
# | **Batch MutateRows** | Update rows in batches using `mutate_rows()` | Recomputing values in-place |
# | **EXPORT DATA overwrite** | Re-export the entire table from BigQuery with `overwrite=true` | Full table refresh |
#
# ### Demo: Batch Backfill with MutateRows
#
# Let's backfill the `avg_order_gap_hours` and `distinct_devices_7d` features onto 1000 rows. We use `mutate_rows()` for efficient batching.

# %%
# Create dedicated backfill demo rows using real feature data from BigQuery
# This avoids modifying shared data rows that other notebooks depend on
backfill_data = bq.query(f'''
    SELECT
        entity_group, entity_id,
        feature_int_1, feature_int_2, feature_int_3, feature_int_4, feature_int_5,
        feature_float_1, feature_float_2, feature_float_3, feature_float_4, feature_float_5
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    WHERE entity_group = 'A'
    ORDER BY entity_id
    LIMIT 200
''').to_dataframe()

# Write as backfill demo rows with v1 format (_values = pipe-delimited)
backfill_keys = []
rows_to_write = []
for _, r in backfill_data.iterrows():
    key = f'backfill_{r["entity_group"]}#{r["entity_id"]}'
    values = '|'.join([
        str(r['feature_int_1']), str(r['feature_int_2']), str(r['feature_int_3']),
        str(r['feature_int_4']), str(r['feature_int_5']),
        str(r['feature_float_1']), str(r['feature_float_2']),
        str(r['feature_float_3']), str(r['feature_float_4']), str(r['feature_float_5']),
    ])
    bt_row = table.direct_row(key)
    bt_row.set_cell(BT_COLUMN_FAMILY, '_values', values.encode('utf-8'))
    rows_to_write.append(bt_row)
    backfill_keys.append(key)

# Write in batches
for i in range(0, len(rows_to_write), 100):
    batch = rows_to_write[i:i+100]
    table.mutate_rows(batch)

print(f'Created {len(backfill_keys)} backfill demo rows (real data from dense_features)')
print(f'  Keys: {backfill_keys[0]} ... {backfill_keys[-1]}')
# Out:
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Created 200 backfill demo rows (real data from dense_features)
#   Keys: backfill_A#000001 ... backfill_A#000200

# %%
# Backfill: append two new features to each row's _values payload
import random
random.seed(123)

BATCH_SIZE = 100
total_updated = 0
total_errors = 0
start_time = time.time()

for batch_start in range(0, len(backfill_keys), BATCH_SIZE):
    batch_keys = backfill_keys[batch_start:batch_start + BATCH_SIZE]
    rows_to_mutate = []
    
    for key in batch_keys:
        # Read current value
        existing = table.read_row(key, filter_=CellsColumnLimitFilter(1))
        if existing and b'_values' in existing.cells.get(BT_COLUMN_FAMILY, {}):
            old_value = existing.cells[BT_COLUMN_FAMILY][b'_values'][0].value.decode('utf-8')
            
            # Compute new feature values (in production, these come from BigQuery or a pipeline)
            avg_gap = f'{random.uniform(1, 720):.1f}'
            devices = str(random.randint(1, 5))
            
            # Append new fields to the existing payload
            new_value = f'{old_value}|{avg_gap}|{devices}'
            
            row = table.direct_row(key)
            row.set_cell(BT_COLUMN_FAMILY, '_values', new_value.encode('utf-8'))
            rows_to_mutate.append(row)
    
    # Write batch
    if rows_to_mutate:
        statuses = table.mutate_rows(rows_to_mutate)
        batch_errors = sum(1 for s in statuses if s.code != 0)
        total_updated += len(rows_to_mutate) - batch_errors
        total_errors += batch_errors
    
    # Progress report
    elapsed = time.time() - start_time
    done = min(batch_start + BATCH_SIZE, len(backfill_keys))
    rate = done / elapsed if elapsed > 0 else 0
    remaining = (len(backfill_keys) - done) / rate if rate > 0 else 0
    print(f'  Batch {batch_start // BATCH_SIZE + 1}: '
          f'{done}/{len(backfill_keys)} rows '
          f'({elapsed:.1f}s elapsed, ~{remaining:.0f}s remaining)')

total_time = time.time() - start_time
print(f'\nBackfill complete:')
print(f'  Updated: {total_updated} rows')
print(f'  Errors:  {total_errors} rows')
print(f'  Time:    {total_time:.1f}s')
print(f'  Rate:    {total_updated / total_time:.0f} rows/sec')
# Out:
#   Batch 1: 100/200 rows (0.6s elapsed, ~1s remaining)
#   Batch 2: 200/200 rows (1.1s elapsed, ~0s remaining)
#
# Backfill complete:
#   Updated: 200 rows
#   Errors:  0 rows
#   Time:    1.1s
#   Rate:    183 rows/sec

# %%
# Verify: read a backfilled row and decode with v2 schema
sample_key = backfill_keys[0]
row = table.read_row(sample_key, filter_=CellsColumnLimitFilter(1))
raw = row.cells[BT_COLUMN_FAMILY][b'_values'][0].value.decode('utf-8')

# Decode with v2 schema
features = decode_features(raw, SCHEMA_V2)

print(f'Verified backfilled row: {sample_key}')
print(f'  Raw: {raw}')
print(f'  Fields: {len(features)}')
print(f'  avg_order_gap_hours: {features.get("avg_order_gap_hours")}')
print(f'  distinct_devices_7d: {features.get("distinct_devices_7d")}')
# Out:
# Verified backfilled row: backfill_A#000001
#   Raw: 29|4136|91|787331|25|21.3848|227.0087|20.2679|6.2978|0.393542|38.6|1
#   Fields: 12
#   avg_order_gap_hours: 38.6
#   distinct_devices_7d: 1

# %% [markdown]
# ### Zero-Downtime Backfill Flow
#
# The key insight is that **readers and writers operate on different schema versions simultaneously**:
#
# ```
# Time →
#
# 1. Write #schema#v2 (new version with new features)
# 2. Start backfill (batch MutateRows, appending new fields)
#    ├─ Readers still using v1 schema — they ignore extra fields
#    ├─ New rows being written with v2 format by the export pipeline
#    └─ Old rows being updated one batch at a time
# 3. Backfill complete — all rows have v2 data
# 4. Update #schema#current -> v2 (atomic switch)
#    └─ Readers now decode v2 fields
# ```
#
# At no point during this process do readers see inconsistent data. They either read with the old schema (missing new fields default to `None`) or the new schema (all fields present).
#
# ### EXPORT DATA Alternative
#
# For a full table refresh, [`EXPORT DATA`](https://cloud.google.com/bigquery/docs/export-to-bigtable) `... overwrite = true` from BigQuery replaces all rows atomically. This is simpler than batch mutations when:
# - You are adding many features at once
# - The export query computes all features (old and new) from the source table
# - The table is small enough that a full re-export is faster than row-by-row updates
#
# For our ~130K-row feature store, a full EXPORT DATA takes about 15-20 seconds. The trade-off is that `overwrite = true` briefly deletes old data before writing new data — there is a short window where reads may return empty. For truly zero-downtime refreshes, use batch mutations.

# %% [markdown]
# ### Production Schema Migration During Live Serving
#
# The isolated backfill demo above shows the mechanics — versioned schemas, backward-compatible decoders, and batch mutations. But in production, the hardest part is **coordination**: evolving the schema while a serving endpoint is actively reading features. What happens when the schema says "v2" but some rows still have v1 data?
#
# For a complete demonstration with a running serving endpoint — including mixed v1/v2 rows during the transition, latency measurement across all phases, and zero-error verification — see [Notebook 8: Serving Integration](./Bigtable%20Feature%20Store%20-%20Serving%20Integration.ipynb), Section 6.

# %% [markdown]
# ---
# ## 5. Feature Registry
#
# The `#schema` row from Section 1 tells decoders *how* to parse features — column names, types, delimiter. But production teams need more: *who owns this feature? When was it last updated? What's the freshness SLA? Is it still active?*
#
# A **feature registry** extends the schema row pattern into a centralized catalog. Instead of just listing columns, it stores per-feature metadata — descriptions, owners, lineage, and status — in a dedicated `#registry` row.
#
# ### Why a Registry Matters
#
# | Without Registry | With Registry |
# |-----------------|---------------|
# | "What features exist?" → read code/docs | Query the `#registry` row |
# | "Who owns feature_float_3?" → ask around | `registry['features']['feature_float_3']['owner']` |
# | "Is this feature deprecated?" → check git blame | `status: 'deprecated'` with date |
# | "Where does this feature come from?" → trace pipelines | `source_table` and `depends_on` fields |
#
# This builds directly on the `#schema` row pattern from Section 1 — same storage mechanism (metadata row in Bigtable), richer content.

# %%
# Build and write a feature registry row
import datetime

REGISTRY = {
    'version': '1',
    'last_updated': datetime.datetime.now(datetime.timezone.utc).isoformat(),
    'features': {
        'feature_int_1': {
            'type': 'INT64',
            'description': 'Transaction count in 5-minute window',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '1 hour',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_int_2': {
            'type': 'INT64',
            'description': 'Transaction count in 1-hour window',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '1 hour',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_int_3': {
            'type': 'INT64',
            'description': 'Distinct category count in 24 hours',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '6 hours',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_int_4': {
            'type': 'INT64',
            'description': 'Account age in days',
            'owner': 'identity-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '24 hours',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_int_5': {
            'type': 'INT64',
            'description': 'Lifetime order count',
            'owner': 'identity-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '24 hours',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_float_1': {
            'type': 'FLOAT64',
            'description': 'Spending amount in last hour',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '1 hour',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_float_2': {
            'type': 'FLOAT64',
            'description': '30-day average spending',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '6 hours',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_float_3': {
            'type': 'FLOAT64',
            'description': 'Spending vs average ratio',
            'owner': 'fraud-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '1 hour',
            'created': '2026-01-15',
            'status': 'deprecated',
            'deprecated_date': '2026-04-01',
            'deprecated_reason': 'Replaced by feature_float_6 with better normalization',
        },
        'feature_float_4': {
            'type': 'FLOAT64',
            'description': 'Sale price of current item',
            'owner': 'pricing-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '15 minutes',
            'created': '2026-01-15',
            'status': 'active',
        },
        'feature_float_5': {
            'type': 'FLOAT64',
            'description': 'Order total amount',
            'owner': 'pricing-team',
            'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
            'freshness_sla': '15 minutes',
            'created': '2026-01-15',
            'status': 'active',
        },
    }
}

# Write to Bigtable
registry_row = table.direct_row('#registry')
registry_row.set_cell(BT_COLUMN_FAMILY, '_registry', json.dumps(REGISTRY).encode('utf-8'))
registry_row.commit()

# Read it back and display
reg_row = table.read_row('#registry', filter_=CellsColumnLimitFilter(1))
reg_data = json.loads(reg_row.cells[BT_COLUMN_FAMILY][b'_registry'][0].value.decode('utf-8'))

print(f'Feature Registry v{reg_data["version"]} ({len(reg_data["features"])} features)')
print(f'Last updated: {reg_data["last_updated"]}')
print()
print(f'{"Feature":<20} {"Type":<10} {"Owner":<16} {"Status":<12} {"Freshness SLA":<15}')
print('-' * 73)
for name, meta in reg_data['features'].items():
    print(f'{name:<20} {meta["type"]:<10} {meta["owner"]:<16} {meta["status"]:<12} {meta["freshness_sla"]:<15}')

# Discovery queries
print(f'\n--- Discovery Queries ---')
print(f'\nFeatures owned by fraud-team:')
for name, meta in reg_data['features'].items():
    if meta['owner'] == 'fraud-team':
        print(f'  {name}: {meta["description"]}')

print(f'\nDeprecated features:')
for name, meta in reg_data['features'].items():
    if meta['status'] == 'deprecated':
        print(f'  {name}: deprecated {meta.get("deprecated_date", "unknown")} — {meta.get("deprecated_reason", "")}')
# Out:
# Feature Registry v1 (10 features)
# Last updated: 2026-05-09T21:47:01.029543+00:00
#
# Feature              Type       Owner            Status       Freshness SLA
# -------------------------------------------------------------------------
# feature_int_1        INT64      fraud-team       active       1 hour
# feature_int_2        INT64      fraud-team       active       1 hour
# feature_int_3        INT64      fraud-team       active       6 hours
# feature_int_4        INT64      identity-team    active       24 hours
# feature_int_5        INT64      identity-team    active       24 hours
# feature_float_1      FLOAT64    fraud-team       active       1 hour
# feature_float_2      FLOAT64    fraud-team       active       6 hours
# feature_float_3      FLOAT64    fraud-team       deprecated   1 hour
# feature_float_4      FLOAT64    pricing-team     active       15 minutes
# feature_float_5      FLOAT64    pricing-team     active       15 minutes
#
# --- Discovery Queries ---
#
# ...

# %%
# Feature lineage: track dependencies and consumers
LINEAGE = {
    'feature_int_1': {
        'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
        'source_column': 'feature_int_1',
        'transforms': ['CAST AS STRING'],
        'used_by': ['fraud_model_v2', 'risk_score_pipeline'],
        'sync_method': 'EXPORT DATA (NB3)',
    },
    'feature_float_1': {
        'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
        'source_column': 'feature_float_1',
        'transforms': ['ROUND(x, 4)', 'CAST AS STRING'],
        'used_by': ['fraud_model_v2', 'spending_monitor'],
        'sync_method': 'EXPORT DATA (NB3)',
    },
    'feature_float_3': {
        'source_table': f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
        'source_column': 'feature_float_3',
        'transforms': ['COALESCE(x, 0.0)', 'ROUND(x, 4)', 'CAST AS STRING'],
        'used_by': [],
        'sync_method': 'EXPORT DATA (NB3)',
        'note': 'DEPRECATED — no active consumers',
    },
}

print('Feature Lineage (sample):')
print()
for feature, info in LINEAGE.items():
    status = REGISTRY['features'][feature]['status']
    print(f'{feature} [{status}]')
    print(f'  Source:     {info["source_column"]} from {info["source_table"].split(".")[-1]}')
    print(f'  Transforms: {" → ".join(info["transforms"])}')
    print(f'  Sync:       {info["sync_method"]}')
    consumers = info['used_by'] if info['used_by'] else ['(none)']  
    print(f'  Used by:    {", ".join(consumers)}')
    if 'note' in info:
        print(f'  Note:       {info["note"]}')
    print()
# Out:
# Feature Lineage (sample):
#
# feature_int_1 [active]
#   Source:     feature_int_1 from dense_features
#   Transforms: CAST AS STRING
#   Sync:       EXPORT DATA (NB3)
#   Used by:    fraud_model_v2, risk_score_pipeline
#
# feature_float_1 [active]
#   Source:     feature_float_1 from dense_features
#   Transforms: ROUND(x, 4) → CAST AS STRING
#   Sync:       EXPORT DATA (NB3)
#   Used by:    fraud_model_v2, spending_monitor
#
# feature_float_3 [deprecated]
#   Source:     feature_float_3 from dense_features
#   Transforms: COALESCE(x, 0.0) → ROUND(x, 4) → CAST AS STRING
#   Sync:       EXPORT DATA (NB3)
#   Used by:    (none)
#   Note:       DEPRECATED — no active consumers

# %% [markdown]
# ### Registry Patterns Comparison
#
# | Approach | Storage | Strengths | Limitations |
# |----------|---------|-----------|-------------|
# | **Metadata row in Bigtable** (what we built) | `#registry` row in the feature table | Zero additional infrastructure, co-located with data, single read to get metadata | No search API, no lineage graph, manual updates |
# | **[Dataplex Catalog](https://cloud.google.com/dataplex/docs/catalog-overview)** | Managed metadata service | Discovery API, tagging, lineage integration, cross-service | Separate service to manage, may not reflect Bigtable schema changes automatically |
# | **Custom database** (PostgreSQL, Firestore) | Dedicated metadata store | Full query flexibility, custom UI, API | Another system to maintain, sync with Bigtable schema |
#
# **Recommendation:** Start with the metadata row approach — it requires no additional infrastructure and scales with your Bigtable instance. Graduate to Dataplex Catalog when you need cross-service discovery ("what features exist across Bigtable, BigQuery, and Vertex AI?") or when the number of features exceeds what a single JSON blob can reasonably hold (~1,000+ features).

# %% [markdown]
# ---
# ## 6. Monitoring with Cloud Monitoring
#
# Bigtable automatically emits metrics to [Cloud Monitoring](https://cloud.google.com/bigtable/docs/monitoring-instance). These metrics are essential for operating a feature store:
#
# | Metric | What it tells you | Alert threshold |
# |--------|------------------|----------------|
# | `bigtable.googleapis.com/server/latencies` | Read/write latency (p50, p99) | p99 > 50ms for reads |
# | `bigtable.googleapis.com/server/request_count` | QPS by method (Read, Write) | Unexpected drops = pipeline failure |
# | `bigtable.googleapis.com/cluster/cpu_load` | CPU utilization across nodes | > 70% sustained = add nodes |
# | `bigtable.googleapis.com/cluster/storage_utilization` | Disk usage vs capacity | > 70% = plan expansion |
# | `bigtable.googleapis.com/disk/bytes_used` | Storage per table | Unexpected growth = data leak |
#
# ### Query Metrics via API
#
# The Cloud Monitoring API lets you query these metrics programmatically — useful for dashboards, alerting, and capacity planning.

# %%
# Query Bigtable read latencies from the last hour
monitoring_client = monitoring_v3.MetricServiceClient()
project_name = f'projects/{PROJECT_ID}'

now = time.time()
seconds_ago = int(now) - 3600  # 1 hour ago

# Build the time interval
interval = monitoring_v3.TimeInterval({
    'end_time': {'seconds': int(now)},
    'start_time': {'seconds': seconds_ago},
})

# Query server request count
try:
    results = monitoring_client.list_time_series(
        request={
            'name': project_name,
            'filter': (
                'metric.type = "bigtable.googleapis.com/server/request_count" '
                f'AND resource.labels.instance = "{BT_INSTANCE}"'
            ),
            'interval': interval,
            'view': monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )
    
    total_requests = 0
    methods = {}
    for ts in results:
        method = ts.metric.labels.get('method', 'unknown')
        for point in ts.points:
            count = point.value.int64_value
            total_requests += count
            methods[method] = methods.get(method, 0) + count
    
    print(f'Bigtable request count (last hour):')
    print(f'  Instance: {BT_INSTANCE}')
    print(f'  Total:    {total_requests:,} requests')
    for method, count in sorted(methods.items(), key=lambda x: -x[1]):
        print(f'  {method:<25s} {count:>8,}')

except Exception as e:
    print(f'Monitoring query returned no data (expected if instance is new or idle).')
    print(f'Detail: {e}')
# Out:
# Bigtable request count (last hour):
#   Instance: feature-store
#   Total:    1,740 requests
#   Bigtable.MutateRows          1,373
#   Bigtable.ReadRows              365
#   Bigtable.SampleRowKeys           2

# %%
# Query CPU load
try:
    cpu_results = monitoring_client.list_time_series(
        request={
            'name': project_name,
            'filter': (
                'metric.type = "bigtable.googleapis.com/cluster/cpu_load" '
                f'AND resource.labels.instance = "{BT_INSTANCE}"'
            ),
            'interval': interval,
            'view': monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )
    
    cpu_values = []
    for ts in cpu_results:
        for point in ts.points:
            cpu_values.append(point.value.double_value)
    
    if cpu_values:
        print(f'Bigtable CPU load (last hour):')
        print(f'  Min:  {min(cpu_values):.1%}')
        print(f'  Max:  {max(cpu_values):.1%}')
        print(f'  Avg:  {sum(cpu_values)/len(cpu_values):.1%}')
    else:
        print('No CPU load data available (development instances may not report CPU metrics).')

except Exception as e:
    print(f'CPU metric query: no data available.')
    print(f'Detail: {e}')
# Out:
# Bigtable CPU load (last hour):
#   Min:  0.9%
#   Max:  2.3%
#   Avg:  1.1%

# %%
# Query storage utilization
try:
    storage_results = monitoring_client.list_time_series(
        request={
            'name': project_name,
            'filter': (
                'metric.type = "bigtable.googleapis.com/disk/bytes_used" '
                f'AND resource.labels.instance = "{BT_INSTANCE}"'
            ),
            'interval': interval,
            'view': monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )
    
    storage_bytes = []
    for ts in storage_results:
        for point in ts.points:
            storage_bytes.append(point.value.int64_value)
    
    if storage_bytes:
        latest = storage_bytes[0]
        print(f'Bigtable storage (latest reading):')
        print(f'  Bytes used: {latest:,} ({latest / 1e6:.1f} MB)')
    else:
        print('No storage data available (metrics may take a few minutes to populate).')

except Exception as e:
    print(f'Storage metric query: no data available.')
    print(f'Detail: {e}')
# Out:
# Bigtable storage (latest reading):
#   Bytes used: 35,997,725 (36.0 MB)

# %% [markdown]
# ### Feature Distribution Monitoring
#
# Infrastructure metrics (latency, CPU, storage) tell you if the system is healthy. **Feature distribution monitoring** tells you if the *data* is healthy. Feature drift — a statistical change in feature values between training and serving — can silently degrade model performance even when the infrastructure is running perfectly.
#
# | Drift Type | What Changed | Example |
# |-----------|-------------|---------|
# | **Data drift** | Input feature distribution shifted | User age distribution skewed younger after a marketing campaign |
# | **Concept drift** | Relationship between features and target changed | Purchase patterns shifted during a holiday season |
# | **Schema drift** | Feature schema changed | A column switched from INT64 to FLOAT64 after an upstream change |
#
# Catching drift early lets you retrain before model performance degrades.

# %%
# Feature drift detection: compare Bigtable serving values to BigQuery baseline
from google.cloud.bigtable.row_filters import CellsColumnLimitFilter
import json
import numpy as np

# Step 1: Compute baseline statistics from BigQuery (training data)
print('Computing baseline statistics from BigQuery...')
baseline_df = bq.query(f'''
    SELECT
        AVG(feature_float_1) AS mean_f1,
        STDDEV(feature_float_1) AS std_f1,
        AVG(feature_float_2) AS mean_f2,
        STDDEV(feature_float_2) AS std_f2,
        AVG(feature_float_3) AS mean_f3,
        STDDEV(feature_float_3) AS std_f3,
        AVG(CAST(feature_int_1 AS FLOAT64)) AS mean_i1,
        STDDEV(CAST(feature_int_1 AS FLOAT64)) AS std_i1,
        AVG(CAST(feature_int_2 AS FLOAT64)) AS mean_i2,
        STDDEV(CAST(feature_int_2 AS FLOAT64)) AS std_i2,
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
''').to_dataframe()

# Step 2: Sample features from Bigtable (serving data)
print('Sampling features from Bigtable...')
schema_row = table.read_row('#schema', filter_=CellsColumnLimitFilter(1))
if schema_row is None:
    print('No #schema row — run Notebook 1 first to export features')
else:
    schema_data = json.loads(
        schema_row.cells[BT_COLUMN_FAMILY][b'_schema'][0].value.decode('utf-8')
    )
    separator = schema_data.get('separator', schema_data.get('delimiter', '|'))
    columns = schema_data['columns']

    # Read a sample of rows
    partial_rows = table.read_rows(filter_=CellsColumnLimitFilter(1))
    sample_values = {col: [] for col in ['feature_float_1', 'feature_float_2', 'feature_float_3',
                                          'feature_int_1', 'feature_int_2']}
    count = 0
    for row in partial_rows:
        key = row.row_key.decode()
        if key.startswith('#'):
            continue
        raw = row.cells[BT_COLUMN_FAMILY][b'_values'][0].value.decode('utf-8')
        parts = raw.split(separator)
        for col in sample_values:
            if col in columns:
                idx = columns.index(col)
                if idx < len(parts):
                    try:
                        sample_values[col].append(float(parts[idx]))
                    except (ValueError, TypeError):
                        pass
        count += 1
        if count >= 500:
            break

    # Step 3: Compare distributions
    print(f'\n=== Feature Drift Report ({count} sampled rows) ===\n')
    print(f'{"Feature":<20} {"BQ Mean":>10} {"BQ Std":>10} {"BT Mean":>10} {"BT Std":>10} {"Shift (σ)":>10} {"Status":<8}')
    print('-' * 78)

    features_to_check = [
        ('feature_float_1', 'mean_f1', 'std_f1'),
        ('feature_float_2', 'mean_f2', 'std_f2'),
        ('feature_float_3', 'mean_f3', 'std_f3'),
        ('feature_int_1', 'mean_i1', 'std_i1'),
        ('feature_int_2', 'mean_i2', 'std_i2'),
    ]

    drift_detected = False
    for feat_name, mean_col, std_col in features_to_check:
        bq_mean = baseline_df[mean_col].iloc[0]
        bq_std = baseline_df[std_col].iloc[0]
        bt_values = sample_values.get(feat_name, [])
        
        if not bt_values or bq_std == 0:
            print(f'{feat_name:<20} {"N/A":>10} {"N/A":>10} {"N/A":>10} {"N/A":>10} {"N/A":>10} {"SKIP":<8}')
            continue
        
        bt_mean = np.mean(bt_values)
        bt_std = np.std(bt_values)
        shift = abs(bt_mean - bq_mean) / bq_std  # Z-score of mean shift
        
        status = 'OK' if shift < 2.0 else 'DRIFT'
        if shift >= 2.0:
            drift_detected = True
        
        print(f'{feat_name:<20} {bq_mean:>10.3f} {bq_std:>10.3f} {bt_mean:>10.3f} {bt_std:>10.3f} {shift:>10.2f} {status:<8}')

    print(f'\n{"⚠ Drift detected — consider retraining" if drift_detected else "All features within normal range"}')
# Out:
# Computing baseline statistics from BigQuery...
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Sampling features from Bigtable...
#
# === Feature Drift Report (500 sampled rows) ===
#
# Feature                 BQ Mean     BQ Std    BT Mean     BT Std  Shift (σ) Status
# ------------------------------------------------------------------------------
# feature_float_1          50.110     28.871     49.490     29.454       0.02 OK
# feature_float_2         500.301    288.328    507.895    295.017       0.03 OK
# feature_float_3           0.031     14.440     -0.424     14.045       0.03 OK
# feature_int_1           499.762    287.935    486.256    277.853       0.05 OK
# feature_int_2          5002.555   2887.203   4998.100   2884.020       0.00 OK
#
# All features within normal range

# %% [markdown]
# ### Automated Drift Detection
#
# In production, run drift checks on a schedule using [Cloud Scheduler](https://cloud.google.com/scheduler/docs/overview) + [Cloud Functions](https://cloud.google.com/functions/docs/concepts/overview):
#
# 1. **Cloud Scheduler** triggers a Cloud Function every hour
# 2. **Cloud Function** reads a sample from Bigtable, computes statistics, compares to stored baselines
# 3. If drift exceeds threshold → write a [custom metric](https://cloud.google.com/monitoring/custom-metrics/creating-metrics) to Cloud Monitoring
# 4. **Cloud Monitoring alert** fires when the custom metric crosses the threshold
#
# ```python
# # Custom metric for drift monitoring (reference pattern)
# from google.cloud import monitoring_v3
#
# metric_client = monitoring_v3.MetricServiceClient()
#
# # Create a custom metric descriptor for feature drift
# descriptor = monitoring_v3.MetricDescriptor(
#     type='custom.googleapis.com/bigtable/feature_drift_zscore',
#     metric_kind=monitoring_v3.MetricDescriptor.MetricKind.GAUGE,
#     value_type=monitoring_v3.MetricDescriptor.ValueType.DOUBLE,
#     description='Z-score of mean shift between training and serving distributions',
#     labels=[
#         monitoring_v3.LabelDescriptor(
#             key='feature_name',
#             value_type=monitoring_v3.LabelDescriptor.ValueType.STRING,
#         ),
#     ],
# )
# ```
#
# This creates a feedback loop: data drift triggers an alert → data scientist investigates → retrains model → updates features → drift resolves.

# %% [markdown]
# ### BigQuery ML Data Validation Functions
#
# The manual approach above works for understanding drift detection. For production, BigQuery ML provides purpose-built functions that handle the statistics, comparison, and anomaly detection automatically:
#
# | Function | Purpose | Use Case |
# |----------|---------|----------|
# | [`ML.DESCRIBE_DATA`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-describe-data) | Compute descriptive statistics for training or serving data | Baseline computation |
# | [`ML.VALIDATE_DATA_SKEW`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-validate-data-skew) | Compare serving data statistics against training data statistics | Training-serving skew detection |
# | [`ML.VALIDATE_DATA_DRIFT`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-validate-data-drift) | Compare two sets of serving data to identify anomalous differences | Drift over time |
# | [`ML.TFDV_DESCRIBE`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-tfdv-describe) | Fine-grained statistics (same as TensorFlow `tfdv.generate_statistics_from_csv`) | Detailed statistical profiling |
# | [`ML.TFDV_VALIDATE`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-tfdv-validate) | Compare training vs serving or serving vs serving (same as TensorFlow `validate_statistics`) | Schema and distribution validation |
#
# These functions integrate naturally with a Bigtable feature store workflow: the offline store (BigQuery) validates data quality, and any skew or drift it detects tells you whether the online store (Bigtable) is serving stale or shifted feature values.

# %%
# BigQuery ML data validation — production-grade drift detection
#
# ML.DESCRIBE_DATA computes baseline statistics from training data.
# ML.VALIDATE_DATA_SKEW compares serving data against a trained model's training data.
# ML.VALIDATE_DATA_DRIFT compares two sets of serving data over time.

# Step 1: Describe training data (compute baseline statistics)
describe_query = f'''
SELECT * FROM ML.DESCRIBE_DATA(
    (SELECT
        feature_float_1, feature_float_2, feature_float_3,
        feature_int_1, feature_int_2
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    LIMIT 50000)
)
'''

try:
    describe_df = bq.query(describe_query).to_dataframe()
    print('ML.DESCRIBE_DATA — Training data statistics:')
    print(describe_df.to_string())
except Exception as e:
    print(f'ML.DESCRIBE_DATA: {e}')

# Step 2: Validate data skew (training vs serving)
# ML.VALIDATE_DATA_SKEW requires a trained BQML model as the first argument —
# it compares serving data against the training data statistics stored in the model.
# In a full pipeline, you would train a model and then validate like this:
#
#   SELECT * FROM ML.VALIDATE_DATA_SKEW(
#       MODEL `project.dataset.my_model`,
#       (SELECT feature_float_1, ... FROM serving_table),
#       STRUCT(0.3 AS numerical_default_threshold)
#   )
#
# Since we don't have a trained BQML model in this notebook, we skip this step.
# See: https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-validate-data-skew
print('\nML.VALIDATE_DATA_SKEW — requires a trained BQML model (reference pattern above)')

# Step 3: Validate data drift (serving at time T1 vs serving at time T2)
drift_query = f'''
SELECT * FROM ML.VALIDATE_DATA_DRIFT(
    -- Serving data at time T1 (earlier window)
    (SELECT feature_float_1, feature_float_2, feature_float_3
     FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
     WHERE entity_group IN ('A', 'B', 'C')),
    -- Serving data at time T2 (later window)
    (SELECT feature_float_1, feature_float_2, feature_float_3
     FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
     WHERE entity_group IN ('D', 'E', 'F')),
    STRUCT(0.3 AS numerical_default_threshold)
)
'''

try:
    drift_df = bq.query(drift_query).to_dataframe()
    print('\nML.VALIDATE_DATA_DRIFT — Serving data over time:')
    print(drift_df.to_string())
except Exception as e:
    print(f'\nML.VALIDATE_DATA_DRIFT: {e}')
# Out:
# ML.DESCRIBE_DATA — Training data statistics:
#               name  num_rows  num_nulls  num_zeros       min       max         mean       stddev     median                     quantiles  unique  avg_string_length  num_values top_values  min_array_length  max_array_length  avg_array_length  total_array_length array_length_quantiles  dimension
# 0  feature_float_1     50000          0          0    0.0012   99.9991    50.240095    28.872696    50.3840     [0.0012, 50.384, 99.9991]    <NA>                NaN       50000         []              <NA>              <NA>               NaN                <NA>                     []       <NA>
# 1  feature_float_2     50000          0          0    0.0117  999.9914   500.139788   287.988079   498.4095  [0.0117, 498.4095, 999.9914]    <NA>                NaN       50000         []              <NA>              <NA>               NaN                <NA>                     []       <NA>
# ...

# %% [markdown]
# ### Putting It Together: Bigtable + BigQuery ML Monitoring
#
# The two approaches complement each other:
#
# | Layer | Tool | What It Catches | When to Use |
# |-------|------|-----------------|-------------|
# | **Online (Bigtable)** | Manual sampling + Z-scores | Real-time serving drift — are features in Bigtable still matching training? | Continuous monitoring, alerts |
# | **Offline (BigQuery)** | `ML.VALIDATE_DATA_SKEW` | Training-serving skew — did the export pipeline change the data? | After each export or sync |
# | **Offline (BigQuery)** | `ML.VALIDATE_DATA_DRIFT` | Temporal drift — are feature distributions shifting over time? | Periodic (daily/weekly) checks |
# | **Offline (BigQuery)** | `ML.DESCRIBE_DATA` | Baseline profiling — what does the training data look like? | At training time, stored as reference |
#
# A typical production workflow:
# 1. At training time, run `ML.DESCRIBE_DATA` and save the statistics
# 2. After each EXPORT DATA sync, run `ML.VALIDATE_DATA_SKEW` against training baselines
# 3. Weekly, run `ML.VALIDATE_DATA_DRIFT` comparing this week's serving data to last week's
# 4. Continuously, sample Bigtable features and compare to baselines (the manual approach above)
# 5. Alert on any anomalies — retrain if drift is confirmed

# %% [markdown]
# ### Creating Alerting Policies
#
# In production, you would create alerting policies for key thresholds. Here is the pattern using the Cloud Monitoring API:
#
# ```python
# from google.cloud import monitoring_v3
#
# alert_client = monitoring_v3.AlertPolicyServiceClient()
#
# # Alert when p99 read latency exceeds 50ms for 5 minutes
# policy = monitoring_v3.AlertPolicy({
#     'display_name': 'Feature Store Read Latency P99',
#     'conditions': [{
#         'display_name': 'Read latency p99 > 50ms',
#         'condition_threshold': {
#             'filter': (
#                 'metric.type = "bigtable.googleapis.com/server/latencies" '
#                 f'AND resource.labels.instance = "{BT_INSTANCE}" '
#                 'AND metric.labels.method = "ReadRows"'
#             ),
#             'comparison': monitoring_v3.ComparisonType.COMPARISON_GT,
#             'threshold_value': 50.0,  # milliseconds
#             'duration': {'seconds': 300},  # 5 minutes
#             'aggregations': [{
#                 'alignment_period': {'seconds': 60},
#                 'per_series_aligner': monitoring_v3.Aggregation.Aligner.ALIGN_PERCENTILE_99,
#             }],
#         },
#     }],
#     'notification_channels': [],  # Add channel IDs for email/PagerDuty/Slack
#     'combiner': monitoring_v3.AlertPolicy.ConditionCombinerType.AND,
# })
#
# # alert_client.create_alert_policy(name=project_name, alert_policy=policy)
# ```
#
# Key alerts for a feature store:
#
# | Alert | Condition | Why it matters |
# |-------|----------|---------------|
# | Read latency p99 | > 50ms for 5 min | Serving SLA breach |
# | CPU utilization | > 70% for 10 min | Cluster needs scaling |
# | Request rate drop | < 50% of baseline for 5 min | Pipeline failure |
# | Storage growth | > 10% increase in 24h | Data leak or runaway writes |

# %% [markdown]
# ---
# ## 7. App Profiles
#
# [App profiles](https://cloud.google.com/bigtable/docs/app-profiles) control how Bigtable routes and prioritizes requests. Different traffic patterns need different routing:
#
# | Profile | Routing | Priority | Use case |
# |---------|---------|----------|----------|
# | `default` | Multi-cluster (any) | HIGH | General access |
# | `serving-profile` | Multi-cluster | HIGH | Real-time ML serving |
# | `bq-export` | Single-cluster | LOW | BigQuery EXPORT DATA |
# | `batch-reads` | Multi-cluster | MEDIUM | Batch feature extraction |
#
# ### Routing Types
#
# - **Single-cluster routing** sends all requests to one specific cluster. Required for `EXPORT DATA` (which needs consistent write ordering) and strongly-consistent reads.
# - **Multi-cluster routing** distributes requests across all clusters for high availability. Reads may be eventually consistent but benefit from geographic proximity and failover.
#
# ### Priority Levels
#
# - **PRIORITY_HIGH** — latency-sensitive serving traffic gets first access to resources
# - **PRIORITY_MEDIUM** — batch reads that can tolerate some queuing
# - **PRIORITY_LOW** — background jobs (exports, backfills) that should yield to serving
#
# Using different priorities prevents a large EXPORT DATA job from starving real-time serving reads.

# %%
# List existing app profiles
result = subprocess.run(
    ['gcloud', 'bigtable', 'app-profiles', 'list',
     '--instance', BT_INSTANCE,
     '--project', PROJECT_ID,
     '--format', 'table(name.basename(), routingPolicy, priority, description)'],
    capture_output=True, text=True,
)

if result.returncode == 0:
    print('Existing app profiles:')
    print(result.stdout)
else:
    print(f'Could not list profiles: {result.stderr.strip()}')
# Out:
# Existing app profiles:
# NAME       ROUTING_POLICY  PRIORITY  DESCRIPTION
# bq-export                            BigQuery EXPORT DATA - single cluster, LOW
#                                      priority
# default                              Default application profile for this
#                                      instance. This profile is used if you do
#                                      not supply a different profile ID at
#                                      connection time.

# %%
# Create a serving profile with HIGH priority
# Get cluster ID first
cluster_result = subprocess.run(
    ['gcloud', 'bigtable', 'clusters', 'list',
     '--instances', BT_INSTANCE,
     '--project', PROJECT_ID,
     '--format', 'value(name.basename())'],
    capture_output=True, text=True,
)
cluster_id = cluster_result.stdout.strip().split('\n')[0] if cluster_result.returncode == 0 else f'{BT_INSTANCE}-c1'
print(f'Cluster ID: {cluster_id}')

# Create the serving profile
result = subprocess.run(
    ['gcloud', 'bigtable', 'app-profiles', 'create', 'serving-profile',
     '--instance', BT_INSTANCE,
     '--project', PROJECT_ID,
     '--route-to', cluster_id,
     '--priority', 'PRIORITY_HIGH',
     '--description', 'Real-time ML serving - HIGH priority',
     '--force'],
    capture_output=True, text=True,
)

if result.returncode == 0:
    print(f'Created app profile: serving-profile')
elif 'already exists' in result.stderr.lower():
    print(f'App profile already exists: serving-profile')
else:
    print(f'Note: {result.stderr.strip()}')
# Out:
# Cluster ID: feature-store-c1
# Created app profile: serving-profile

# %%
# Create a batch-reads profile with MEDIUM priority
result = subprocess.run(
    ['gcloud', 'bigtable', 'app-profiles', 'create', 'batch-reads',
     '--instance', BT_INSTANCE,
     '--project', PROJECT_ID,
     '--route-to', cluster_id,
     '--priority', 'PRIORITY_MEDIUM',
     '--description', 'Batch feature extraction - MEDIUM priority',
     '--force'],
    capture_output=True, text=True,
)

if result.returncode == 0:
    print(f'Created app profile: batch-reads')
elif 'already exists' in result.stderr.lower():
    print(f'App profile already exists: batch-reads')
else:
    print(f'Note: {result.stderr.strip()}')
# Out:
# Created app profile: batch-reads

# %%
# List all profiles after creation
result = subprocess.run(
    ['gcloud', 'bigtable', 'app-profiles', 'list',
     '--instance', BT_INSTANCE,
     '--project', PROJECT_ID,
     '--format', 'table(name.basename(), routingPolicy, priority, description)'],
    capture_output=True, text=True,
)

if result.returncode == 0:
    print('All app profiles:')
    print(result.stdout)
# Out:
# All app profiles:
# NAME             ROUTING_POLICY  PRIORITY  DESCRIPTION
# batch-reads                                Batch feature extraction - MEDIUM
#                                            priority
# bq-export                                  BigQuery EXPORT DATA - single
#                                            cluster, LOW priority
# default                                    Default application profile for this
#                                            instance. This profile is used if you
#                                            do not supply a different profile ID
#                                            at connection time.
# serving-profile                            Real-time ML serving - HIGH priority

# %% [markdown]
# ### Using App Profiles in Code
#
# To use a specific app profile, pass it when opening the table:
#
# ```python
# # Serving reads use HIGH priority
# serving_table = instance.table(BT_TABLE, app_profile_id='serving-profile')
# row = serving_table.read_row(user_id)
#
# # Batch reads use MEDIUM priority
# batch_table = instance.table(BT_TABLE, app_profile_id='batch-reads')
# rows = batch_table.read_rows(start_key=start, end_key=end)
#
# # EXPORT DATA uses LOW priority (in the Bigtable URI)
# # https://bigtable.googleapis.com/projects/.../appProfiles/bq-export/tables/...
# ```
#
# The serving pipeline should always use the HIGH-priority profile. Background jobs (backfills, exports, analytics) use MEDIUM or LOW so they never starve serving traffic.

# %% [markdown]
# ---
# ## 8. Cost Optimization
#
# Bigtable pricing has three components: **nodes** (compute), **storage** (SSD or HDD), and **network** (egress). For a feature store, nodes dominate the cost. See the [Bigtable pricing page](https://cloud.google.com/bigtable/pricing) for current rates.
#
# ### Storage Types
#
# | Storage type | Read latency | Use case |
# |-------------|-------------|----------|
# | **SSD** | Single-digit ms | Feature stores, serving (required for low-latency reads) |
# | **HDD** | 200ms+ | Archival, analytics, cold storage |
#
# For ML feature stores, **SSD is required**. The entire value proposition is single-digit millisecond reads — HDD's 200ms+ latency defeats the purpose.
#
# ### Instance Types and Node Scaling
#
# | Instance type | Min nodes | SLA | Use case |
# |--------------|-----------|-----|----------|
# | Development | 1 (fixed) | None | Labs, prototyping |
# | Production | 3+ | 99.99% | Production workloads |
# | Production + autoscaling | 3-30 (auto) | 99.99% | Variable traffic |
#
# ### Understanding Cost Drivers
#
# For a typical feature store:
# - **Nodes** are the dominant cost — compute is billed per node-hour, and you need at least 3 for production SLA
# - **Storage** is comparatively cheap — even millions of feature rows use modest storage
# - **Network** is free within the same region; egress charges apply for cross-region reads
#
# The key decision is **how many nodes** — enough to handle your QPS with headroom, but not so many that you're paying for idle capacity. Autoscaling (below) addresses this directly.

# %%
# Cost structure — conceptual breakdown
#
# Use the Bigtable pricing calculator to estimate costs for your workload:
# https://cloud.google.com/products/calculator

NUM_ENTITIES = 130_000
AVG_ROW_SIZE_BYTES = 150  # 10 features, pipe-delimited, ~15 bytes each

total_storage_mb = (NUM_ENTITIES * AVG_ROW_SIZE_BYTES) / (1024 ** 2)
total_storage_gb = total_storage_mb / 1024

print(f'Feature store storage footprint:')
print(f'  Entities:     {NUM_ENTITIES:,}')
print(f'  Row size:     ~{AVG_ROW_SIZE_BYTES} bytes')
print(f'  Total data:   {total_storage_mb:.1f} MB ({total_storage_gb:.4f} GB)')
print()
print('Cost components (see https://cloud.google.com/bigtable/pricing for current rates):')
print('  1. Nodes:    Per node-hour — the dominant cost for most feature stores')
print('  2. Storage:  Per GB/month (SSD) — minimal for this dataset size')
print('  3. Network:  Free within same region; per-GB egress for cross-region')
print()
print('Scaling scenarios:')
print(f'{"Scenario":<45s} {"Nodes":>5s} {"Cost driver":>20s}')
print('-' * 72)
scenarios = [
    ('Development (1 node, no SLA)', 1, '1 node-hour/hr'),
    ('Production minimum (3 nodes)', 3, '3 node-hours/hr'),
    ('Production with headroom (5 nodes)', 5, '5 node-hours/hr'),
    ('Production + autoscaling (3-10 nodes)', '3-10', 'variable node-hours/hr'),
]
for name, nodes, driver in scenarios:
    print(f'{name:<45s} {str(nodes):>5s} {driver:>20s}')

print(f'\nStorage at {total_storage_mb:.1f} MB is negligible — nodes are >99% of the bill.')
# Out:
# Feature store storage footprint:
#   Entities:     130,000
#   Row size:     ~150 bytes
#   Total data:   18.6 MB (0.0182 GB)
#
# Cost components (see https://cloud.google.com/bigtable/pricing for current rates):
#   1. Nodes:    Per node-hour — the dominant cost for most feature stores
#   2. Storage:  Per GB/month (SSD) — minimal for this dataset size
#   3. Network:  Free within same region; per-GB egress for cross-region
#
# Scaling scenarios:
# Scenario                                      Nodes          Cost driver
# ------------------------------------------------------------------------
# Development (1 node, no SLA)                      1       1 node-hour/hr
# Production minimum (3 nodes)                      3      3 node-hours/hr
# Production with headroom (5 nodes)                5      5 node-hours/hr
# Production + autoscaling (3-10 nodes)          3-10 variable node-hours/hr
#
# Storage at 18.6 MB is negligible — nodes are >99% of the bill.

# %% [markdown]
# ### Committed Use Discounts
#
# For predictable workloads, [Committed Use Discounts (CUDs)](https://cloud.google.com/bigtable/pricing#committed-use-discounts) reduce node costs significantly:
#
# | Commitment | Approximate Discount |
# |-----------|---------------------|
# | None (on-demand) | 0% |
# | 1-year | ~25% |
# | 3-year | ~50% |
#
# CUDs apply to node-hours. Storage and network are not discountable. For a production feature store that runs 24/7, a 1-year commitment is almost always worth it.
#
# ### Autoscaling and Capacity Planning
#
# Bigtable [autoscaling](https://cloud.google.com/bigtable/docs/autoscaling) adjusts node count based on CPU utilization. It requires a **Production** instance (Development instances like the one in this tutorial are fixed at 1 node and cannot autoscale).
#
# **Capacity planning guidelines:**
#
# | Factor | Guideline |
# |--------|-----------|
# | CPU target | Keep below 70% — above this, latency increases non-linearly |
# | Reads per node | ~10,000 reads/sec at 1 KB row size per SSD node |
# | Writes per node | ~10,000 writes/sec at 1 KB row size per SSD node |
# | Min nodes | At least 3 for production SLA (99.99%) |
# | Max nodes | Set based on budget ceiling — autoscaling won't exceed this |
#
# **Estimating node count for a feature store:**
#
# ```
# Required nodes = (peak_QPS × avg_row_size_KB) / 10,000 reads_per_node
# ```
#
# For example, 50,000 QPS at 150 bytes/row ≈ 5,000 / 10,000 = 1 node of raw capacity. With the 70% CPU headroom target and production minimum of 3 nodes, you'd set `min=3, max=5`.
#
# **Reference: autoscaling configuration**
#
# ```bash
# # Production instance autoscaling (not available on Development instances)
# gcloud bigtable clusters update CLUSTER_ID \
#     --instance=INSTANCE_ID \
#     --autoscaling-min-nodes=3 \
#     --autoscaling-max-nodes=10 \
#     --autoscaling-cpu-target=60 \
#     --autoscaling-storage-target=2560  # GB per node
# ```
#
# For feature stores with variable traffic (e.g., e-commerce with peak hours), autoscaling prevents over-provisioning during off-peak while ensuring capacity during peaks. Combine with CUDs: commit to the minimum node count and let autoscaling handle the burst.

# %% [markdown]
# ---
# ## 9. Security and IAM
#
# [IAM roles](https://cloud.google.com/bigtable/docs/access-control) control who can read, write, and administer your Bigtable feature store. The principle of least privilege is especially important here because feature data often contains sensitive user signals.
#
# ### Bigtable IAM Roles for Feature Stores
#
# | Role | Permissions | Assign to |
# |------|------------|-----------|
# | `roles/bigtable.reader` | Read rows, list tables | Serving endpoints, read-only dashboards |
# | `roles/bigtable.user` | Read + write rows, manage column families | Feature pipelines, backfill jobs, EXPORT DATA service accounts |
# | `roles/bigtable.admin` | Full control — create/delete tables, manage instances | Ops team, schema migration tooling |
#
# **Key principle:** Serving endpoints should never have write access. If a serving endpoint is compromised, an attacker with `bigtable.reader` can read feature data but cannot modify it — no data corruption, no schema tampering, no row deletion.

# %%
# View current IAM policy for the Bigtable instance (read-only)
result = subprocess.run(
    ['gcloud', 'bigtable', 'instances', 'get-iam-policy', BT_INSTANCE,
     '--project', PROJECT_ID, '--format', 'yaml'],
    capture_output=True, text=True,
)

if result.returncode == 0 and result.stdout.strip():
    print(f'IAM policy for instance "{BT_INSTANCE}":\n')
    print(result.stdout)
else:
    print(f'IAM policy for instance "{BT_INSTANCE}":')
    print('  No explicit bindings (access inherited from project-level IAM)')

# Reference: least-privilege role assignments for a feature store
print('\n--- Reference: gcloud commands for least-privilege access ---\n')

print(f'# Serving endpoint — read-only access:')
print(f'gcloud bigtable instances add-iam-policy-binding {BT_INSTANCE} \\')
print(f'    --member="serviceAccount:serving-sa@{PROJECT_ID}.iam.gserviceaccount.com" \\')
print(f'    --role="roles/bigtable.reader"')

print(f'\n# Feature pipeline — read + write:')
print(f'gcloud bigtable instances add-iam-policy-binding {BT_INSTANCE} \\')
print(f'    --member="serviceAccount:pipeline-sa@{PROJECT_ID}.iam.gserviceaccount.com" \\')
print(f'    --role="roles/bigtable.user"')

print(f'\n# Ops/admin — full control (schema changes, table creation):')
print(f'gcloud bigtable instances add-iam-policy-binding {BT_INSTANCE} \\')
print(f'    --member="serviceAccount:admin-sa@{PROJECT_ID}.iam.gserviceaccount.com" \\')
print(f'    --role="roles/bigtable.admin"')
# Out:
# IAM policy for instance "feature-store":
#
# etag: ACAB
#
#
# --- Reference: gcloud commands for least-privilege access ---
#
# # Serving endpoint — read-only access:
# gcloud bigtable instances add-iam-policy-binding feature-store \
#     --member="serviceAccount:serving-sa@statmike-mlops-349915.iam.gserviceaccount.com" \
#     --role="roles/bigtable.reader"
#
# # Feature pipeline — read + write:
# gcloud bigtable instances add-iam-policy-binding feature-store \
#     --member="serviceAccount:pipeline-sa@statmike-mlops-349915.iam.gserviceaccount.com" \
#     --role="roles/bigtable.user"
#
# # Ops/admin — full control (schema changes, table creation):
# gcloud bigtable instances add-iam-policy-binding feature-store \
#     --member="serviceAccount:admin-sa@statmike-mlops-349915.iam.gserviceaccount.com" \
#     --role="roles/bigtable.admin"

# %% [markdown]
# ### Network Security
#
# For production deployments, Bigtable integrates with Google Cloud's network security controls:
#
# | Control | Purpose | Documentation |
# |---------|---------|---------------|
# | **[VPC Service Controls](https://cloud.google.com/bigtable/docs/vpc-service-controls)** | Define a security perimeter around Bigtable to prevent data exfiltration | Prevents unauthorized access from outside the perimeter |
# | **[CMEK](https://cloud.google.com/bigtable/docs/cmek)** | Customer-managed encryption keys via Cloud KMS | Required when your organization mandates key ownership |
# | **Private Google Access** | Access Bigtable from VPC without public IP addresses | Standard for production VPC configurations |
#
# These are infrastructure-level controls typically managed by your platform team. From the feature store perspective, the main implication is that serving endpoints must run within the VPC Service Controls perimeter if one is configured.

# %% [markdown]
# ---
# ## 10. Authorized Views
#
# IAM roles (Section 9) control *who* can access your Bigtable instance. But what if different teams need access to the same table with different visibility?
#
# - The ML team needs feature columns but should not see PII in the `metadata` family
# - Team A should only see entities in their entity group (`A#*` row prefix)
# - An external partner needs a subset of features for a specific integration
#
# [Authorized views](https://cloud.google.com/bigtable/docs/authorized-views-overview) solve this by creating filtered, read-only projections of a table. Each view defines which row prefixes and column families/qualifiers are visible — without duplicating any data.
#
# ### How Authorized Views Work
#
# ```
# Table: features
# ├── All rows, all column families      ← full access (bigtable.admin)
# │
# ├── Authorized View: features-ml-view
# │   ├── Rows: all
# │   └── Columns: features family only   ← ML team (no metadata/PII)
# │
# └── Authorized View: features-team-a
#     ├── Rows: prefix 'A#' only
#     └── Columns: all families            ← Team A (their entities only)
# ```
#
# Readers are granted IAM permissions on the *view*, not the table. They use the view ID in their client code — the filtering is enforced server-side.

# %%
# Authorized view creation (reference pattern — not executed)
#
# Authorized views are created via gcloud or the Admin API.
# The view definition specifies allowed row prefixes and column families.

print('=== Authorized View: ML Team (features only, no PII) ===')
print()

ml_view_definition = {
    'subsetView': {
        'rowPrefixes': [],  # empty = all rows
        'familySubsets': {
            'features': {}  # empty = all qualifiers in this family
        }
    }
}
print('View definition (features-ml-view):')
print(json.dumps(ml_view_definition, indent=2))
print()
print(f'gcloud bigtable authorized-views create features-ml-view \\\\')
print(f'  --table={BT_TABLE} --instance={BT_INSTANCE} \\\\')
print(f'  --project={PROJECT_ID} \\\\')
print(f'  --definition-file=ml-view-definition.json')

print()
print('=== Authorized View: Team A (their entities only) ===')
print()

import base64
team_a_prefix = base64.b64encode(b'A#').decode('utf-8')

team_a_view_definition = {
    'subsetView': {
        'rowPrefixes': [team_a_prefix],  # base64-encoded 'A#'
        'familySubsets': {
            'features': {},
            'metadata': {}
        }
    }
}
print('View definition (features-team-a):')
print(json.dumps(team_a_view_definition, indent=2))
print(f'  (rowPrefixes value {team_a_prefix} = base64 of "A#")')
print()
print(f'gcloud bigtable authorized-views create features-team-a \\\\')
print(f'  --table={BT_TABLE} --instance={BT_INSTANCE} \\\\')
print(f'  --project={PROJECT_ID} \\\\')
print(f'  --definition-file=team-a-view-definition.json')

print()
print('=== Reading through an Authorized View ===')
print()
print('Python client pattern:')
print(f"""""")
print(f'  from google.cloud import bigtable')
print(f'  client = bigtable.Client(project="{PROJECT_ID}")')
print(f'  instance = client.instance("{BT_INSTANCE}")')
print(f'  # Read through the authorized view instead of the table')
print(f'  view_table = instance.table("{BT_TABLE}")  # same table')
print(f'  # Grant the reader bigtable.authorizedViews.get on the view,')
print(f'  # not bigtable.tables.readRows on the table')
print(f"""""")
# Out:
# === Authorized View: ML Team (features only, no PII) ===
#
# View definition (features-ml-view):
# {
#   "subsetView": {
#     "rowPrefixes": [],
#     "familySubsets": {
#       "features": {}
#     }
#   }
# }
#
# gcloud bigtable authorized-views create features-ml-view \\
#   --table=features --instance=feature-store \\
#   --project=statmike-mlops-349915 \\
#   --definition-file=ml-view-definition.json
#
# === Authorized View: Team A (their entities only) ===
#
# View definition (features-team-a):
# {
#   "subsetView": {
#     "rowPrefixes": [
#       "QSM="
#     ],
#     "familySubsets": {
#       "features": {},
#       "metadata": {}
#     }
#   }
# }
#   (rowPrefixes value QSM= = base64 of "A#")
#
# gcloud bigtable authorized-views create features-team-a \\
#   --table=features --instance=feature-store \\
#   --project=statmike-mlops-349915 \\
#   --definition-file=team-a-view-definition.json
#
# === Reading through an Authorized View ===
#
# Python client pattern:
#
# ...

# %% [markdown]
# ### Access Control Patterns
#
# | Pattern | Granularity | Data Duplication | Maintenance | Best For |
# |---------|------------|-----------------|-------------|----------|
# | **IAM roles** | Instance or table level | None | Low | Broad access control — admin vs reader |
# | **Authorized views** | Row prefix + column family | None | Medium | Team-level isolation, PII filtering |
# | **Separate tables** | Full table isolation | Yes (full copies) | High | Regulatory requirements, complete isolation |
# | **Application-level filtering** | Custom logic in serving code | None | High | Complex rules that don't map to prefixes |
#
# **Recommendation:** Start with IAM roles for basic access control. Add authorized views when teams need different feature subsets from the same table — this avoids the storage cost and sync complexity of maintaining separate copies. Only use separate tables when regulatory or compliance requirements mandate physical isolation.
#
# See [Authorized views documentation](https://cloud.google.com/bigtable/docs/authorized-views-overview) for setup details and IAM permissions.

# %% [markdown]
# ---
# ## 11. Production Readiness Checklist
#
# Before promoting a Bigtable feature store to production, verify each item:
#
# ### Schema & Data
# - [ ] Schema metadata row written and versioned (`#schema#v1`, `#schema#current`)
# - [ ] Decoder handles missing features gracefully (default values for new columns)
# - [ ] Decoder handles extra features gracefully (ignores unknown trailing fields)
# - [ ] Deprecated features tracked in schema metadata with deprecation dates
# - [ ] GC policies set per column family (e.g., `MaxVersionsGCRule(1)` for latest-only)
#
# ### Infrastructure
# - [ ] App profiles configured: `serving-profile` (HIGH), `bq-export` (LOW), `batch-reads` (MEDIUM)
# - [ ] Production instance type (not Development) with minimum 3 nodes for HA
# - [ ] SSD storage (not HDD) for sub-10ms read latency
# - [ ] [Autoscaling](https://cloud.google.com/bigtable/docs/autoscaling) configured with appropriate min/max nodes and CPU target (Section 7)
# - [ ] [Replication](https://cloud.google.com/bigtable/docs/replication-overview) configured for multi-region availability if required
#
# ### Security
# - [ ] [IAM](https://cloud.google.com/bigtable/docs/access-control): least-privilege roles — `bigtable.reader` for serving, `bigtable.user` for pipelines, `bigtable.admin` only for ops (Section 8)
# - [ ] VPC Service Controls perimeter if required by compliance
# - [ ] CMEK configured if customer-managed encryption is required
#
# ### Monitoring & Alerting
# - [ ] Cloud Monitoring dashboard with key Bigtable metrics
# - [ ] Alert: read latency p99 > 50ms for 5 minutes
# - [ ] Alert: CPU utilization > 70% sustained for 10 minutes
# - [ ] Alert: request rate drops below 50% of baseline
# - [ ] Alert: storage growth exceeds 10% in 24 hours
#
# ### Operational
# - [ ] Backup strategy: managed backups or EXPORT DATA to GCS on schedule
# - [ ] Load testing completed: verified throughput at expected QPS
# - [ ] Key design reviewed: no hotspot risk (sequential keys, timestamps, monotonic IDs)
# - [ ] Reservation cleanup: no orphaned Enterprise reservations running
#
# ### Deployment
# - [ ] Schema migration runbook documented (versioning, backfill, switch)
# - [ ] Rollback procedure tested (revert `#schema#current` to previous version)
# - [ ] Feature freshness SLA defined (how stale can features be before alerts fire?)
# - [ ] On-call playbook for common issues (latency spike, pipeline failure, storage growth)

# %% [markdown]
# ### Infrastructure as Code
#
# Managing Bigtable resources through [Terraform](https://registry.terraform.io/providers/hashicorp/google/latest/docs/resources/bigtable_instance) ensures reproducibility across environments (dev, staging, prod) and enables code-reviewed infrastructure changes.
#
# **Terraform configuration for a feature store:**
#
# ```hcl
# # bigtable.tf — Feature store infrastructure
#
# resource "google_bigtable_instance" "feature_store" {
#   name                = "feature-store"
#   deletion_protection = true
#
#   cluster {
#     cluster_id   = "feature-store-c1"
#     zone         = "us-central1-a"
#     storage_type = "SSD"
#
#     autoscaling_config {
#       min_nodes  = 3
#       max_nodes  = 10
#       cpu_target = 60
#     }
#   }
# }
#
# resource "google_bigtable_table" "features" {
#   name          = "features"
#   instance_name = google_bigtable_instance.feature_store.name
#
#   column_family { family = "features" }
#   column_family { family = "metadata" }
# }
#
# resource "google_bigtable_gc_policy" "features_gc" {
#   instance_name = google_bigtable_instance.feature_store.name
#   table         = google_bigtable_table.features.name
#   column_family = "features"
#
#   max_version { number = 1 }
# }
#
# # IAM: serving endpoint gets read-only access
# resource "google_bigtable_instance_iam_member" "serving_reader" {
#   instance = google_bigtable_instance.feature_store.name
#   role     = "roles/bigtable.reader"
#   member   = "serviceAccount:serving-sa@${var.project_id}.iam.gserviceaccount.com"
# }
#
# # IAM: pipeline gets read-write access
# resource "google_bigtable_instance_iam_member" "pipeline_user" {
#   instance = google_bigtable_instance.feature_store.name
#   role     = "roles/bigtable.user"
#   member   = "serviceAccount:pipeline-sa@${var.project_id}.iam.gserviceaccount.com"
# }
# ```
#
# This configuration covers the key items from the production checklist: SSD storage, autoscaling, GC policies, and least-privilege IAM. The `deletion_protection = true` flag prevents accidental instance deletion via `terraform destroy`.

# %% [markdown]
# ### CI/CD Testing Patterns
#
# Feature store pipelines need integration tests that verify data correctness end-to-end — not just that code runs, but that features arrive in Bigtable with the right values, types, and row keys.
#
# **Testing strategy:**
#
# | Layer | What to test | How |
# |-------|-------------|-----|
# | **Unit** | Serialization/deserialization, schema decoder, feature transforms | Standard pytest — no infrastructure needed |
# | **Integration** | EXPORT DATA writes correct rows, backfill updates values, GC policies apply | Bigtable emulator or dedicated test instance |
# | **End-to-end** | Full pipeline: BQ query → export → Bigtable → serving read → prediction | Dedicated test instance with production-like data |
#
# **Integration test pattern:**
#
# ```python
# # test_feature_export.py
# import pytest
# from google.cloud import bigtable
#
# @pytest.fixture(scope="module")
# def bt_table():
#     """Connect to test Bigtable instance (emulator or dedicated test instance)."""
#     client = bigtable.Client(project="test-project", admin=True)
#     instance = client.instance("test-instance")
#     table = instance.table("features")
#     yield table
#
# def test_export_row_count(bt_table):
#     """Verify EXPORT DATA wrote the expected number of rows."""
#     rows = list(bt_table.read_rows())
#     data_rows = [r for r in rows if not r.row_key.decode().startswith('#')]
#     assert len(data_rows) == EXPECTED_COUNT, f"Expected {EXPECTED_COUNT}, got {len(data_rows)}"
#
# def test_schema_row_exists(bt_table):
#     """Verify the schema metadata row was written."""
#     schema_row = bt_table.read_row('#schema')
#     assert schema_row is not None, "Missing #schema row"
#
# def test_feature_values_match_source(bt_table, bq_client):
#     """Spot-check: Bigtable values match BigQuery source for a sample entity."""
#     # Read from Bigtable
#     row = bt_table.read_row('A#000001'.encode())
#     bt_values = decode_features(row)
#     # Read from BigQuery
#     bq_row = bq_client.query("SELECT * FROM dataset.dense_features WHERE entity_id = '000001' LIMIT 1")
#     # Compare
#     for col in ['feature_float_1', 'feature_int_1']:
#         assert bt_values[col] == pytest.approx(bq_row[col], rel=1e-4)
# ```
#
# **Bigtable emulator for local tests:**
#
# ```bash
# # Start the emulator (no GCP credentials needed)
# gcloud beta emulators bigtable start --host-port=localhost:8086 &
#
# # Point client to emulator
# export BIGTABLE_EMULATOR_HOST=localhost:8086
#
# # Run tests against emulator
# pytest tests/test_feature_export.py -v
#
# # Stop emulator
# kill %1 && unset BIGTABLE_EMULATOR_HOST
# ```
#
# The emulator supports core operations (read, write, scan, GC policies) but not admin features like IAM, app profiles, or autoscaling. Use a dedicated test instance for those. See the [emulator documentation](https://cloud.google.com/bigtable/docs/emulator) for details.

# %% [markdown]
# ---
# ## Cleanup
#
# Remove the demo rows and schema versions we created for this notebook. The original data rows and `#schema` row from Notebook 1 are left intact.

# %%
# Clean up demo rows, backfill rows, and schema versions
cleanup_keys = (
    [f'demo_v1_{i}' for i in range(5)] +
    [f'demo_v2_{i}' for i in range(5)] +
    backfill_keys +
    ['#schema#v1', '#schema#v2', '#schema#v3', '#schema#current', '#registry']
)

cleaned = 0
batch = []
for key in cleanup_keys:
    row = table.direct_row(key)
    row.delete()
    batch.append(row)
    if len(batch) >= 100:
        table.mutate_rows(batch)
        cleaned += len(batch)
        batch = []
if batch:
    table.mutate_rows(batch)
    cleaned += len(batch)

print(f'Cleaned up {cleaned} rows (demo + backfill + versioned schema rows)')

# Clean up app profiles (optional — comment out to keep them)
for profile in ['serving-profile', 'batch-reads']:
    result = subprocess.run(
        ['gcloud', 'bigtable', 'app-profiles', 'delete', profile,
         '--instance', BT_INSTANCE,
         '--project', PROJECT_ID,
         '--force', '--quiet'],
        capture_output=True, text=True,
    )
    if result.returncode == 0:
        print(f'Deleted app profile: {profile}')
    else:
        print(f'App profile {profile}: {result.stderr.strip() or "already deleted"}')

print('\nCleanup complete. Original feature data and #schema row remain.')
# Out:
# Cleaned up 215 rows (demo + backfill + versioned schema rows)
# Deleted app profile: serving-profile
# Deleted app profile: batch-reads
#
# Cleanup complete. Original feature data and #schema row remain.

# %% [markdown]
# ---
# ## Summary
#
# | What we covered | Key takeaway |
# |-----------------|-------------|
# | **Schema versioning** | Immutable `#schema#vN` rows + a `#schema#current` pointer enable atomic upgrades and instant rollback |
# | **Adding features** | Append to delimited payload; decoder returns `None` for missing fields during backfill |
# | **Deprecation** | Schema metadata tracks deprecated features and dates; decoder skips them |
# | **Backfilling** | Batch `mutate_rows()` updates rows without downtime; readers use old schema until switch |
# | **Monitoring** | Cloud Monitoring API queries latency, QPS, CPU, and storage metrics programmatically |
# | **App profiles** | Different priorities for serving (HIGH), batch (MEDIUM), and export (LOW) traffic |
# | **Cost optimization** | SSD required; nodes dominate cost; CUDs for predictable workloads |
# | **Autoscaling** | CPU-based node scaling for variable traffic; capacity planning based on QPS and row size |
# | **Security & IAM** | Least-privilege roles (`reader`/`user`/`admin`), VPC Service Controls, CMEK |
# | **Infrastructure as Code** | Terraform configuration for reproducible Bigtable provisioning across environments |
# | **CI/CD testing** | Emulator for local tests; integration tests verify export correctness end-to-end |
# | **Production checklist** | 20+ items covering schema, infrastructure, security, monitoring, and operations |
#
# ### What's next
#
# [**Notebook 8: Serving Integration**](./Bigtable%20Feature%20Store%20-%20Serving%20Integration.ipynb) brings the series full circle — training a model on BigQuery features, serving predictions from Bigtable at single-digit millisecond latency, and demonstrating **schema evolution during live serving** (Section 6): backfilling rows and switching schema versions while the endpoint is active, with zero errors and no latency degradation.

# %% [markdown]
# ### Cleanup Reminder
#
# When you are done with the Bigtable Feature Store series, return to [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) and follow the **Cleanup** section to delete the Bigtable instance, BigQuery dataset, and any other billable resources.
