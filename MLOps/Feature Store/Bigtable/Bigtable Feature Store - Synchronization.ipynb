# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2FFeature+Store%2FBigtable&file=Bigtable+Feature+Store+-+Synchronization.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2FFeature%2520Store%2FBigtable%2FBigtable%2520Feature%2520Store%2520-%2520Synchronization.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Synchronization.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Synchronization.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Synchronization.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Synchronization.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Synchronization.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Bigtable Feature Store — Synchronization
#
# Features computed in BigQuery are only useful for real-time serving if they reach Bigtable fast enough. This notebook explores the spectrum of sync strategies — from one-time backfill to sub-minute continuous updates — and measures the freshness tradeoffs.
#
# **Prerequisites:** Run [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) first.

# %% [markdown]
# ---
# ## Configuration

# %%
PROJECT_ID = 'statmike-mlops-349915'
REGION = 'us-central1'
ZONE = 'us-central1-a'

BQ_PROJECT = PROJECT_ID
BQ_DATASET = 'bigtable_feature_store'

BT_INSTANCE = 'feature-store'
BT_TABLE = 'features'
BT_COLUMN_FAMILY = 'features'
APP_PROFILE_ID = 'bq-export'

RESERVATION_ID = 'feature-store-export'
RESERVATION_SLOTS = 100

LOCATION = 'US'

print(f'Project:      {PROJECT_ID}')
print(f'BQ Dataset:   {BQ_PROJECT}.{BQ_DATASET}')
print(f'Bigtable:     {BT_INSTANCE}/{BT_TABLE}')
print(f'App Profile:  {APP_PROFILE_ID}')
print(f'Reservation:  {RESERVATION_ID} ({RESERVATION_SLOTS} slots)')
# Out:
# Project:      statmike-mlops-349915
# BQ Dataset:   statmike-mlops-349915.bigtable_feature_store
# Bigtable:     feature-store/features
# App Profile:  bq-export
# Reservation:  feature-store-export (100 slots)

# %% [markdown]
# ---
# ## Prerequisites Check
#
# Verify the BigQuery dataset and Bigtable table exist (created in Notebook 0).

# %%
import subprocess, sys, shutil

def install(*packages):
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call(
            [uv, 'pip', 'install', '-q', '--prerelease=allow',
             '--python', sys.executable, *packages])
    else:
        subprocess.check_call(
            [sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install(
    'google-cloud-bigquery', 'db-dtypes',
    'google-cloud-bigtable',
    'google-cloud-bigquery-reservation',
    'google-cloud-bigquery-datatransfer',
    'pandas',
)

# %%
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC used automatically

# %%
from google.cloud import bigquery
from google.cloud import bigtable
from google.cloud.bigtable.row_filters import CellsColumnLimitFilter
from google.cloud import bigquery_reservation_v1
from google.api_core.exceptions import AlreadyExists, NotFound
import pandas as pd
import time
import json

bq = bigquery.Client(project=PROJECT_ID)
bt_client = bigtable.Client(project=PROJECT_ID, admin=True)
instance = bt_client.instance(BT_INSTANCE)
table = instance.table(BT_TABLE)
reservation_client = bigquery_reservation_v1.ReservationServiceClient()

print('Clients initialized:')
print(f'  BigQuery:      {bq.project}')
print(f'  Bigtable:      {BT_INSTANCE}/{BT_TABLE}')
print(f'  Reservations:  ready')
# Out:
# Clients initialized:
#   BigQuery:      statmike-mlops-349915
#   Bigtable:      feature-store/features
#   Reservations:  ready

# %%
# Verify BQ dataset exists
try:
    dataset = bq.get_dataset(f'{BQ_PROJECT}.{BQ_DATASET}')
    print(f'BigQuery dataset found: {dataset.full_dataset_id}')
except NotFound:
    raise RuntimeError(
        f'Dataset {BQ_PROJECT}.{BQ_DATASET} not found. '
        'Run Notebook 0 (Environment) first.'
    )

# Verify Bigtable table is accessible
if table.exists():
    print(f'Bigtable table found: {BT_INSTANCE}/{BT_TABLE}')
else:
    raise RuntimeError(
        f'Bigtable table {BT_INSTANCE}/{BT_TABLE} not found. '
        'Run Notebook 0 (Environment) first.'
    )

# List tables in dataset for context
tables = list(bq.list_tables(f'{BQ_PROJECT}.{BQ_DATASET}'))
print(f'\nTables in {BQ_DATASET}:')
for t in tables:
    print(f'  {t.table_id}')
# Out:
# BigQuery dataset found: statmike-mlops-349915:bigtable_feature_store
# Bigtable table found: feature-store/features
#
# Tables in bigtable_feature_store:
#   dense_features
#   sparse_events

# %% [markdown]
# ---
# ## Section 1: One-Time Export (EXPORT DATA)
#
# The simplest synchronization pattern is a one-time snapshot: compute all features in BigQuery, export them to Bigtable, done. This is ideal for:
#
# - **Initial backfill** — populating the feature store for the first time
# - **Full refresh** — replacing all features after a model retrain or schema change
# - **Ad-hoc updates** — manually refreshing features when data quality issues are fixed
#
# The mechanism is BigQuery's [EXPORT DATA](https://cloud.google.com/bigquery/docs/reference/standard-sql/other-statements#export_data_statement) statement with `format = 'CLOUD_BIGTABLE'`. This writes query results directly to Bigtable without any intermediate storage.
#
# ### EXPORT DATA Options
#
# | Option | Value | Purpose |
# |--------|-------|--------|
# | `format` | `'CLOUD_BIGTABLE'` | Target format — writes to Bigtable instead of GCS |
# | `uri` | Bigtable URI with app profile | Target table and routing config |
# | `overwrite` | `true` or `false` | `true` = delete existing rows first (full replace); `false` = upsert (insert or update matching row keys) |
#
# The URI includes the app profile, which controls cluster routing and request priority:
#
# ```
# https://bigtable.googleapis.com/projects/{PROJECT}/instances/{INSTANCE}/appProfiles/{PROFILE}/tables/{TABLE}
# ```
#
# ### Infrastructure Requirements
#
# EXPORT DATA to Bigtable requires two pieces of infrastructure:
#
# 1. **Enterprise reservation** — BigQuery Enterprise edition is required. We create a reservation with slots and a QUERY-type assignment. Slots are billed per-second at on-demand Enterprise rates.
#
# 2. **Bigtable app profile** — configured with single-cluster routing and LOW request priority so export traffic does not compete with latency-sensitive serving reads.

# %% [markdown]
# ### Create Enterprise Reservation
#
# No capacity commitment needed — on-demand edition billing. Slots are billed per-second while the reservation exists.

# %%
# Create Enterprise reservation for EXPORT DATA
parent = f'projects/{PROJECT_ID}/locations/{LOCATION}'

created = False
try:
    reservation = reservation_client.create_reservation(
        parent=parent,
        reservation_id=RESERVATION_ID,
        reservation=bigquery_reservation_v1.Reservation(
            slot_capacity=RESERVATION_SLOTS,
            edition=bigquery_reservation_v1.Edition.ENTERPRISE,
        ),
    )
    created = True
    print(f'Created reservation: {reservation.name}')
    print(f'  Slots:   {reservation.slot_capacity}')
    print(f'  Edition: ENTERPRISE')
except AlreadyExists:
    reservation = reservation_client.get_reservation(
        name=f'{parent}/reservations/{RESERVATION_ID}'
    )
    print(f'Reservation exists: {reservation.name}')
# Out:
# Created reservation: projects/statmike-mlops-349915/locations/US/reservations/feature-store-export
#   Slots:   100
#   Edition: ENTERPRISE

# %%
# QUERY assignment — routes query jobs through the reservation
try:
    assignment = reservation_client.create_assignment(
        parent=reservation.name,
        assignment=bigquery_reservation_v1.Assignment(
            job_type=bigquery_reservation_v1.Assignment.JobType.QUERY,
            assignee=f'projects/{PROJECT_ID}',
        ),
    )
    print(f'Created assignment: {assignment.name}')
    print(f'  Job type: QUERY')
    print(f'  Assignee: {PROJECT_ID}')
    created = True
except AlreadyExists:
    assignments = list(reservation_client.list_assignments(parent=reservation.name))
    assignment = assignments[0]
    print(f'Assignment exists: {assignment.name}')

print(f'\nReservation ready:')
print(f'  Reservation: {RESERVATION_ID} ({RESERVATION_SLOTS} slots, Enterprise)')
print(f'  Assignment:  QUERY → {PROJECT_ID}')

if created:
    print(f'\nWaiting 180s for assignment to propagate...')
    time.sleep(180)
    print('Ready.')
else:
    print('\nReservation and assignment already exist — no wait needed.')
# Out:
# Created assignment: projects/statmike-mlops-349915/locations/US/reservations/feature-store-export/assignments/6618466362019364446
#   Job type: QUERY
#   Assignee: statmike-mlops-349915
#
# Reservation ready:
#   Reservation: feature-store-export (100 slots, Enterprise)
#   Assignment:  QUERY → statmike-mlops-349915
#
# Waiting 180s for assignment to propagate...
# Ready.

# %% [markdown]
# ### Create Bigtable App Profile
#
# The [app profile](https://cloud.google.com/bigtable/docs/app-profiles) controls how requests are routed to clusters. EXPORT DATA requires:
# - **Single-cluster routing** — writes go to exactly one cluster (no multi-cluster replication conflicts)
# - **LOW request priority** — export traffic yields to serving reads
#
# We use `gcloud` to create the profile since the Python client's app profile API requires more boilerplate.

# %%
# Create app profile for EXPORT DATA
import subprocess

result = subprocess.run([
    'gcloud', 'bigtable', 'app-profiles', 'create', APP_PROFILE_ID,
    '--instance', BT_INSTANCE,
    '--project', PROJECT_ID,
    '--route-to', f'{BT_INSTANCE}-c1',
    '--priority', 'PRIORITY_LOW',
    '--standard',
    '--description', 'BigQuery EXPORT DATA - single cluster, LOW priority',
    '--force',
], capture_output=True, text=True)

if result.returncode == 0:
    print(f'Created app profile: {APP_PROFILE_ID}')
elif 'already exists' in result.stderr.lower():
    print(f'App profile exists: {APP_PROFILE_ID}')
else:
    print(f'Error: {result.stderr.strip()}')
    # Try without --standard flag (older gcloud versions)
    result2 = subprocess.run([
        'gcloud', 'bigtable', 'app-profiles', 'create', APP_PROFILE_ID,
        '--instance', BT_INSTANCE,
        '--project', PROJECT_ID,
        '--route-to', f'{BT_INSTANCE}-c1',
        '--description', 'BigQuery EXPORT DATA - single cluster routing',
        '--force',
    ], capture_output=True, text=True)
    if result2.returncode == 0:
        print(f'Created app profile: {APP_PROFILE_ID} (without priority flag)')
    elif 'already exists' in result2.stderr.lower():
        print(f'App profile exists: {APP_PROFILE_ID}')
    else:
        print(f'Error: {result2.stderr.strip()}')

# Verify
result = subprocess.run([
    'gcloud', 'bigtable', 'app-profiles', 'describe', APP_PROFILE_ID,
    '--instance', BT_INSTANCE,
    '--project', PROJECT_ID,
], capture_output=True, text=True)
if result.returncode == 0:
    print(f'\nProfile details:')
    for line in result.stdout.strip().split('\n'):
        print(f'  {line}')
# Out:
# App profile exists: bq-export
#
# Profile details:
#   createTime: '2026-05-09T19:00:02.534366Z'
#   description: BigQuery EXPORT DATA - single cluster, LOW priority
#   name: projects/statmike-mlops-349915/instances/feature-store/appProfiles/bq-export
#   singleClusterRouting:
#     clusterId: feature-store-c1
#   standardIsolation:
#     priority: PRIORITY_LOW
#   state: READY
#   updateTime: '2026-05-09T19:00:02.534366Z'

# %% [markdown]
# ### Build and Execute the Export
#
# The export query selects a subset of features from the `dense_features` table (created in Notebook 0) and writes them to Bigtable. The query uses the STRUCT pattern to map columns to Bigtable's column family and qualifiers:
#
# - The first column (`rowkey`) becomes the **Bigtable row key**
# - The STRUCT name (`features`) becomes the **column family**
# - Each STRUCT field becomes a **column qualifier**

# %%
# Bigtable URI for EXPORT DATA (includes app profile)
BIGTABLE_URI = (
    f'https://bigtable.googleapis.com/projects/{PROJECT_ID}'
    f'/instances/{BT_INSTANCE}'
    f'/appProfiles/{APP_PROFILE_ID}'
    f'/tables/{BT_TABLE}'
)

print(f'Target URI: {BIGTABLE_URI}')
# Out:
# Target URI: https://bigtable.googleapis.com/projects/statmike-mlops-349915/instances/feature-store/appProfiles/bq-export/tables/features

# %%
# Build the EXPORT DATA query
# Export a subset of dense_features to Bigtable
EXPORT_SQL = f'''
EXPORT DATA OPTIONS (
    format = 'CLOUD_BIGTABLE',
    uri = '{BIGTABLE_URI}',
    overwrite = true
) AS
SELECT
    CONCAT(entity_group, '#', entity_id) AS rowkey,
    STRUCT(
        CONCAT(
            CAST(feature_int_1 AS STRING), '|',
            CAST(feature_int_2 AS STRING), '|',
            CAST(feature_int_3 AS STRING), '|',
            CAST(feature_int_4 AS STRING), '|',
            CAST(feature_int_5 AS STRING), '|',
            CAST(ROUND(feature_float_1, 4) AS STRING), '|',
            CAST(ROUND(feature_float_2, 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_3, 0.0), 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_4, 0.0), 4) AS STRING), '|',
            CAST(ROUND(feature_float_5, 4) AS STRING)
        ) AS _values
    ) AS {BT_COLUMN_FAMILY}
FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
'''

print('EXPORT DATA query:')
print(EXPORT_SQL)
# Out:
# EXPORT DATA query:
#
# EXPORT DATA OPTIONS (
#     format = 'CLOUD_BIGTABLE',
#     uri = 'https://bigtable.googleapis.com/projects/statmike-mlops-349915/instances/feature-store/appProfiles/bq-export/tables/features',
#     overwrite = true
# ) AS
# SELECT
#     CONCAT(entity_group, '#', entity_id) AS rowkey,
#     STRUCT(
#         CONCAT(
#             CAST(feature_int_1 AS STRING), '|',
#             CAST(feature_int_2 AS STRING), '|',
#             CAST(feature_int_3 AS STRING), '|',
#             CAST(feature_int_4 AS STRING), '|',
#             CAST(feature_int_5 AS STRING), '|',
#             CAST(ROUND(feature_float_1, 4) AS STRING), '|',
#             CAST(ROUND(feature_float_2, 4) AS STRING), '|',
#             CAST(ROUND(COALESCE(feature_float_3, 0.0), 4) AS STRING), '|',
#             CAST(ROUND(COALESCE(feature_float_4, 0.0), 4) AS STRING), '|',
#             CAST(ROUND(feature_float_5, 4) AS STRING)
#         ) AS _values
#     ) AS features
# ...

# %%
# Execute the export
print('Exporting features to Bigtable...')
print(f'  Source: {BQ_PROJECT}.{BQ_DATASET}.dense_features')
print(f'  Target: {BT_INSTANCE}/{BT_TABLE}')
print(f'  Mode:   overwrite = true (full replace)')
print()

start = time.perf_counter()
job = bq.query(EXPORT_SQL)
job.result()  # Wait for completion
export_time = time.perf_counter() - start

print(f'Export complete in {export_time:.1f}s')
print(f'  Job ID:          {job.job_id}')
print(f'  Bytes processed: {job.total_bytes_processed:,}')
if job.slot_millis:
    print(f'  Slot time:       {job.slot_millis:,} ms')
    print(f'  Slot seconds:    {job.slot_millis / 1000:.1f}s')
# Out:
# Exporting features to Bigtable...
#   Source: statmike-mlops-349915.bigtable_feature_store.dense_features
#   Target: feature-store/features
#   Mode:   overwrite = true (full replace)
# Export complete in 18.0s
#   Job ID:          d9cb8ded-4ce8-495e-a267-fb716df71968
#   Bytes processed: 11,726,893
#   Slot time:       43,866 ms
#   Slot seconds:    43.9s

# %%
# Verify: read a sample of rows from Bigtable
partial_rows = table.read_rows(
    filter_=CellsColumnLimitFilter(1),
    limit=10,
)
partial_rows.consume_all()

print(f'Sample rows from Bigtable ({len(partial_rows.rows)} rows):')
for key, row in list(partial_rows.rows.items())[:5]:
    cells = row.cells.get(BT_COLUMN_FAMILY, {})
    values = {}
    for col_name, col_cells in cells.items():
        values[col_name.decode('utf-8')] = col_cells[0].value.decode('utf-8')
    print(f'  {key.decode("utf-8"):>10s}: {values}')
# Out:
# Sample rows from Bigtable (10 rows):
#      #schema: {'_schema': '{\n  "columns": [\n    "feature_int_1",\n    "feature_int_2",\n    "feature_int_3",\n    "feature_int_4",\n    "feature_int_5",\n    "feature_float_1",\n    "feature_float_2",\n    "feature_float_3",\n    "feature_float_4",\n    "feature_float_5"\n  ],\n  "types": {\n    "feature_int_1": "INT64",\n    "feature_int_2": "INT64",\n    "feature_int_3": "INT64",\n    "feature_int_4": "INT64",\n    "feature_int_5": "INT64",\n    "feature_float_1": "FLOAT64",\n    "feature_float_2": "FLOAT64",\n    "feature_float_3": "FLOAT64",\n    "feature_float_4": "FLOAT64",\n    "feature_float_5": "FLOAT64"\n  },\n  "delimiter": "|",\n  "version": "v1",\n  "source_table": "statmike-mlops-349915.bigtable_feature_store.dense_features",\n  "description": "Dense features \\u2014 5 INT64 + 5 FLOAT64 features per entity"\n}'}
#     A#000001: {'_values': '29|4136|91|787331|25|21.3848|227.0087|20.2679|6.2978|0.3935'}
# ...

# %% [markdown]
# ### Post-Export Validation
#
# After any export, verify data integrity: row count matches, values are correct, and the schema is consistent. This is especially important for scheduled exports where silent failures can go unnoticed.

# %%
# Post-export validation: compare BigQuery source to Bigtable target
from google.cloud.bigtable.row_set import RowSet, RowRange
from google.cloud.bigtable.row_filters import CellsColumnLimitFilter
import random

print('=== Post-Export Validation ===\n')

# Check 1: Row count comparison
bq_count = bq.query(f'''
    SELECT COUNT(*) as cnt FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
''').to_dataframe()['cnt'][0]

bt_rows = list(table.read_rows(filter_=CellsColumnLimitFilter(1)))
bt_data_rows = [r for r in bt_rows if not r.row_key.decode().startswith('#')]
bt_count = len(bt_data_rows)

count_match = bt_count >= bq_count * 0.99  # Allow 1% tolerance for timing
print(f'1. Row count:  BQ={bq_count:,}  BT={bt_count:,}  {"PASS" if count_match else "WARN — counts differ"}')

# Check 2: Sample verification (10 random entities)
sample_df = bq.query(f'''
    SELECT entity_group, entity_id, feature_float_1
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    ORDER BY RAND()
    LIMIT 10
''').to_dataframe()

sample_match = 0
for _, row_data in sample_df.iterrows():
    key = f'{row_data["entity_group"]}#{row_data["entity_id"]}'
    bt_row = table.read_row(key.encode(), filter_=CellsColumnLimitFilter(1))
    if bt_row and BT_COLUMN_FAMILY in bt_row.cells:
        sample_match += 1

print(f'2. Sample check: {sample_match}/{len(sample_df)} entities found in Bigtable  {"PASS" if sample_match == len(sample_df) else "WARN"}')

# Check 3: Schema consistency
schema_row = table.read_row('#schema'.encode(), filter_=CellsColumnLimitFilter(1))
if schema_row:
    schema_json = json.loads(schema_row.cells[BT_COLUMN_FAMILY][b'_schema'][0].value.decode())
    print(f'3. Schema row:  {len(schema_json.get("columns", []))} columns defined  PASS')
else:
    print(f'3. Schema row:  NOT FOUND — run the schema write cell first')

print(f'\n{"All checks passed!" if count_match and sample_match == len(sample_df) else "Review warnings above."}')
# Out:
# === Post-Export Validation ===
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 1. Row count:  BQ=130,002  BT=130,001  PASS
# 2. Sample check: 10/10 entities found in Bigtable  PASS
# 3. Schema row:  10 columns defined  PASS
#
# All checks passed!

# %% [markdown]
# ### Full Replace vs Empty Table Check
#
# The `overwrite` option in [`EXPORT DATA`](https://cloud.google.com/bigquery/docs/export-to-bigtable) controls how exported rows interact with existing data in Bigtable:
#
# | | `overwrite = true` (Full Replace) | `overwrite = false` (Empty Table Required) |
# |---|---|---|
# | **Behavior** | Deletes all existing rows in the table, then writes the exported rows | Writes to the table only if it is currently empty — fails otherwise |
# | **Data during export** | Brief window where Bigtable has **zero rows** (between delete and re-insert) | No risk of overwriting — the table must be empty to begin with |
# | **Use case** | Initial backfill, schema migration, full refresh after model retrain | First-time population of a brand new or manually cleared table |
# | **Risk** | Serving applications see empty results during the delete/re-insert window | Export fails if any rows exist — no partial writes, no silent overwrites |
#
# > **There is no upsert mode for EXPORT DATA.** Unlike database MERGE statements, `EXPORT DATA` to Bigtable does not support "insert or update matching row keys." Each export is either a full replace (`overwrite = true`) or requires an empty target (`overwrite = false`). For incremental updates, use direct writes via the Bigtable client library (Section 4) or [continuous queries](https://cloud.google.com/bigquery/docs/continuous-queries-introduction) which have their own upsert semantics.
#
# **Which to use:**
#
# ```
# Is this the first time populating the table?
# │
# ├─ Yes ──→ overwrite = true  (clean start, works regardless of table state)
# │
# └─ No
#     │
#     └─ Need to refresh features? ──→ overwrite = true  (full replace)
# ```
#
# > **Continuous queries** (Section 3) operate differently — they use upsert semantics built into the continuous query runtime, re-exporting features only for entities with new activity while leaving all other rows untouched. This is the most efficient pattern for keeping features fresh because it only writes what changed.

# %% [markdown]
# ### One-Time Export: Summary
#
# The one-time export is the simplest synchronization pattern. It works well for:
#
# | Use Case | Why it Works |
# |----------|-------------|
# | **Initial backfill** | Populate the entire feature store from historical data |
# | **Full refresh after retrain** | Replace all features with newly computed values |
# | **Schema migration** | Export with new column layout after schema changes |
#
# The limitation is obvious: features are frozen at export time. Any new data that arrives after the export is invisible to serving. For features that change slowly (user demographics, lifetime aggregates), this may be acceptable. For features that change quickly (velocity counts, recent spending), we need something better.

# %% [markdown]
# ---
# ## Section 2: Scheduled Sync
#
# The next step up from one-time export is **scheduled sync**: run the same EXPORT DATA statement on a recurring schedule. This gives predictable freshness without the complexity of continuous queries.
#
# BigQuery provides two mechanisms for this:
#
# 1. **Scheduled Queries** (via [BigQuery Data Transfer Service](https://cloud.google.com/bigquery/docs/scheduling-queries)) — native, no additional infrastructure
# 2. **Cloud Scheduler + Cloud Functions** — more flexible, supports custom logic before/after the export
#
# ### Freshness vs. Complexity Tradeoff
#
# | Schedule Interval | Feature Freshness | Cost Implication |
# |-------------------|-------------------|------------------|
# | Every 24 hours | Features up to 1 day stale | Lowest — one job per day |
# | Every 1 hour | Features up to 1 hour stale | Moderate — 24 jobs per day |
# | Every 15 minutes | Features up to 15 min stale | Higher — 96 jobs per day |
# | Every 5 minutes | Features up to 5 min stale | Highest for scheduled — 288 jobs per day |
#
# Each job incurs the reservation slot cost for its duration. For small feature tables, each export may only take 10-30 seconds, so even frequent schedules are inexpensive.
#
# ### Scheduled Query via Python API
#
# The [BigQuery Data Transfer Service](https://cloud.google.com/bigquery/docs/scheduling-queries) supports scheduling any SQL statement, including EXPORT DATA. Here is the API pattern for creating a scheduled export.

# %%
# Scheduled query pattern using BigQuery Data Transfer Service
# This cell shows the API call pattern but does NOT create a live schedule.

from google.cloud import bigquery_datatransfer_v1
from google.protobuf.struct_pb2 import Struct

# The EXPORT DATA SQL to run on schedule
# Uses overwrite=true because EXPORT DATA to Bigtable does not support upsert.
# Each scheduled run does a full replace of all features.
SCHEDULED_EXPORT_SQL = f'''
EXPORT DATA OPTIONS (
    format = 'CLOUD_BIGTABLE',
    uri = '{BIGTABLE_URI}',
    overwrite = true
) AS
SELECT
    CONCAT(entity_group, '#', entity_id) AS rowkey,
    STRUCT(
        CONCAT(
            CAST(feature_int_1 AS STRING), '|',
            CAST(feature_int_2 AS STRING), '|',
            CAST(feature_int_3 AS STRING), '|',
            CAST(feature_int_4 AS STRING), '|',
            CAST(feature_int_5 AS STRING), '|',
            CAST(ROUND(feature_float_1, 4) AS STRING), '|',
            CAST(ROUND(feature_float_2, 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_3, 0.0), 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_4, 0.0), 4) AS STRING), '|',
            CAST(ROUND(feature_float_5, 4) AS STRING)
        ) AS _values
    ) AS {BT_COLUMN_FAMILY}
FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
'''

# Build the transfer config (NOT executed — for reference)
transfer_config_params = Struct()
transfer_config_params.update({
    'query': SCHEDULED_EXPORT_SQL,
})

transfer_config = bigquery_datatransfer_v1.TransferConfig(
    display_name='Feature Store Sync — Every Hour',
    data_source_id='scheduled_query',
    schedule='every 1 hours',  # Options: 'every 15 minutes', 'every 6 hours', 'every day 02:00'
    params=transfer_config_params,
    destination_dataset_id=BQ_DATASET,  # Required by API even for EXPORT DATA
)

print('Scheduled query configuration (reference only):')
print(f'  Display name: {transfer_config.display_name}')
print(f'  Schedule:     {transfer_config.schedule}')
print(f'  Data source:  {transfer_config.data_source_id}')
print(f'  overwrite:    true (full replace — EXPORT DATA does not support upsert)')
print()
print('To create this schedule, uncomment and run:')
print('  transfer_client = bigquery_datatransfer_v1.DataTransferServiceClient()')
print(f'  transfer_client.create_transfer_config(')
print(f'      parent="projects/{PROJECT_ID}/locations/{LOCATION}",')
print(f'      transfer_config=transfer_config,')
print(f'  ')
# Out:
# Scheduled query configuration (reference only):
#   Display name: Feature Store Sync — Every Hour
#   Schedule:     every 1 hours
#   Data source:  scheduled_query
#   overwrite:    true (full replace — EXPORT DATA does not support upsert)
#
# To create this schedule, uncomment and run:
#   transfer_client = bigquery_datatransfer_v1.DataTransferServiceClient()
#   transfer_client.create_transfer_config(
#       parent="projects/statmike-mlops-349915/locations/US",
#       transfer_config=transfer_config,

# %% [markdown]
# ### Key Design Decisions for Scheduled Sync
#
# **`overwrite = true` (full replace):** Since EXPORT DATA to Bigtable does not support upsert, each scheduled run replaces all features. This is straightforward but means a brief window during each export where serving reads may see stale or missing data. For small feature tables (< 1 GB), this window is seconds; for large tables, consider whether the serving application can tolerate it.
#
# **Schedule interval:** Match the freshness requirement of your features. Slowly-changing features (user demographics, lifetime aggregates) can sync daily. Velocity features (transaction counts, spending rates) need more frequent updates — but if you need sub-minute freshness, skip ahead to continuous queries (which support upsert semantics natively).
#
# ### Alternative: Cloud Scheduler + Cloud Functions
#
# For more control over the sync process, you can use [Cloud Scheduler](https://cloud.google.com/scheduler/docs/overview) to trigger a [Cloud Function](https://cloud.google.com/functions/docs/concepts/overview) that runs the EXPORT DATA query:
#
# ```
# Cloud Scheduler (cron) → Cloud Functions (Python) → BigQuery EXPORT DATA → Bigtable
# ```
#
# This adds flexibility:
# - **Pre-export validation** — check data quality before exporting
# - **Post-export notifications** — send Slack/email alerts on completion or failure
# - **Conditional exports** — only run if upstream data has actually changed
# - **Multi-step pipelines** — compute features in one step, export in another
#
# The tradeoff is more infrastructure to manage. For most cases, the native Scheduled Query is sufficient.
#
# ### Orchestration Alternatives
#
# While BigQuery's built-in scheduled queries are the simplest approach, production teams often need more control over dependencies, retries, and multi-step pipelines:
#
# | Orchestrator | When to Use | Documentation |
# |-------------|------------|---------------|
# | **BQ Scheduled Queries** | Simple single-query schedules, no external dependencies | [Scheduled queries](https://cloud.google.com/bigquery/docs/scheduling-queries) |
# | **Cloud Composer (Airflow)** | Multi-step DAGs: validate data → export → verify → notify. Handles dependencies between BQ, Bigtable, and other systems. | [Cloud Composer](https://cloud.google.com/composer/docs/concepts/overview) |
# | **Cloud Scheduler + Cloud Functions** | Lightweight: trigger an EXPORT DATA job on a cron schedule without a full orchestration layer | [Cloud Scheduler](https://cloud.google.com/scheduler/docs/overview) |
# | **Cloud Workflows** | Serverless orchestration for simple multi-step pipelines without managing Airflow infrastructure | [Workflows](https://cloud.google.com/workflows/docs/overview) |
#
# > **Airflow pattern:** A typical Composer DAG would: (1) run a BQ query to identify changed entities, (2) run `EXPORT DATA` for those entities, (3) validate row counts in Bigtable, (4) send a Pub/Sub notification or Slack alert on completion/failure.

# %% [markdown]
# ---
# ## Section 3: Continuous Queries
#
# > **Reference pattern** — the code in this section shows the continuous query SQL and reservation configuration but does **not** execute the continuous query. The CONTINUOUS reservation type may not be available in all environments and runs indefinitely (consuming slots continuously).
#
# BigQuery [continuous queries](https://cloud.google.com/bigquery/docs/continuous-queries-introduction) bridge the gap between scheduled batch exports and full streaming pipelines. A continuous query watches for new rows via the `APPENDS()` function and re-exports affected features within seconds of data arrival.
#
# ### How It Works
#
# | Component | One-Time Export | Continuous Query |
# |-----------|----------------|------------------|
# | **Source** | Full table scan | `APPENDS(TABLE, timestamp)` — only new rows |
# | **Reservation type** | QUERY assignment | CONTINUOUS assignment |
# | **Lifecycle** | Runs once, completes | Runs indefinitely |
# | **Freshness** | Snapshot at export time | Seconds after new rows arrive |
# | **Cost** | Pay for one job | Pay for continuous slot allocation |
#
# ### Reservation Type Change
#
# Continuous queries require a CONTINUOUS assignment (not QUERY). The CONTINUOUS assignment type has different constraints:
# - Maximum 500 slots per reservation
# - Cannot share a reservation with QUERY assignments
# - Slots are allocated (and billed) as long as the reservation exists

# %%
# Reservation type change pattern (reference only — not executed)
#
# To switch from QUERY to CONTINUOUS:
#
# Step 1: Delete the existing QUERY assignment
# reservation_client.delete_assignment(name=assignment.name)
#
# Step 2: Create a CONTINUOUS assignment
# continuous_assignment = reservation_client.create_assignment(
#     parent=reservation.name,
#     assignment=bigquery_reservation_v1.Assignment(
#         job_type=bigquery_reservation_v1.Assignment.JobType.CONTINUOUS,
#         assignee=f'projects/{PROJECT_ID}',
#     ),
# )
#
# Note: You may need a separate reservation for CONTINUOUS assignments
# since QUERY and CONTINUOUS cannot share the same reservation.

print('Reservation type change pattern:')
print('  1. Delete QUERY assignment')
print('  2. Create CONTINUOUS assignment (same or new reservation)')
print('  3. CONTINUOUS max: 500 slots per reservation')
print('  4. Cannot mix QUERY and CONTINUOUS in one reservation')
# Out:
# Reservation type change pattern:
#   1. Delete QUERY assignment
#   2. Create CONTINUOUS assignment (same or new reservation)
#   3. CONTINUOUS max: 500 slots per reservation
#   4. Cannot mix QUERY and CONTINUOUS in one reservation

# %% [markdown]
# ### The Continuous Query SQL
#
# The key change is the `APPENDS()` function. It watches a table for newly inserted rows and triggers the query each time new data arrives. The query then re-computes features only for entities (users) that have new activity.
#
# ```sql
# APPENDS(TABLE `project.dataset.table`, start_timestamp)
# ```
#
# - `TABLE` — the source table to watch
# - `start_timestamp` — only consider rows inserted after this time
#
# The continuous query identifies entities with new rows, re-computes their features against the full history, and exports the updated features to Bigtable. This is efficient: only affected entities are reprocessed, but their features reflect the complete historical context.

# %%
# Continuous query SQL (reference only — NOT executed)
# This query would run indefinitely, re-exporting features
# whenever new rows appear in the source table.
#
# Note: Continuous queries use upsert semantics — they update matching row keys
# and leave non-matching rows untouched. This is different from regular EXPORT DATA
# which only supports full replace (overwrite=true) or empty table (overwrite=false).

CONTINUOUS_SQL = f"""
-- =================================================================
-- CONTINUOUS QUERY VERSION
-- Triggered by APPENDS() — runs whenever new rows arrive.
-- Re-computes features for entities with new activity.
-- Continuous queries use upsert semantics (no overwrite option needed).
-- =================================================================
EXPORT DATA OPTIONS (
    format = 'CLOUD_BIGTABLE',
    uri = '{BIGTABLE_URI}'
) AS
WITH
-- Identify entities with new activity
new_activity AS (
    SELECT DISTINCT entity_id, entity_group
    FROM APPENDS(
        TABLE `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`,
        CURRENT_TIMESTAMP() - INTERVAL 10 MINUTE
    )
),

-- Re-compute features for active entities from full history
recomputed AS (
    SELECT
        d.entity_group,
        d.entity_id,
        d.feature_int_1,
        d.feature_int_2,
        d.feature_int_3,
        d.feature_int_4,
        d.feature_int_5,
        d.feature_float_1,
        d.feature_float_2,
        d.feature_float_3,
        d.feature_float_4,
        d.feature_float_5,
        ROW_NUMBER() OVER (
            PARTITION BY d.entity_id ORDER BY d.entity_id DESC
        ) AS rn
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features` d
    WHERE d.entity_id IN (SELECT entity_id FROM new_activity)
),

latest_per_entity AS (
    SELECT * FROM recomputed WHERE rn = 1
)

SELECT
    CONCAT(entity_group, '#', entity_id) AS rowkey,
    STRUCT(
        CONCAT(
            CAST(feature_int_1 AS STRING), '|',
            CAST(feature_int_2 AS STRING), '|',
            CAST(feature_int_3 AS STRING), '|',
            CAST(feature_int_4 AS STRING), '|',
            CAST(feature_int_5 AS STRING), '|',
            CAST(ROUND(feature_float_1, 4) AS STRING), '|',
            CAST(ROUND(feature_float_2, 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_3, 0.0), 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_4, 0.0), 4) AS STRING), '|',
            CAST(ROUND(feature_float_5, 4) AS STRING)
        ) AS _values
    ) AS {BT_COLUMN_FAMILY}
FROM latest_per_entity
"""

print('Continuous query SQL (reference only — not executed):')
print(CONTINUOUS_SQL)
# Out:
# Continuous query SQL (reference only — not executed):
#
# -- =================================================================
# -- CONTINUOUS QUERY VERSION
# -- Triggered by APPENDS() — runs whenever new rows arrive.
# -- Re-computes features for entities with new activity.
# -- Continuous queries use upsert semantics (no overwrite option needed).
# -- =================================================================
# EXPORT DATA OPTIONS (
#     format = 'CLOUD_BIGTABLE',
#     uri = 'https://bigtable.googleapis.com/projects/statmike-mlops-349915/instances/feature-store/appProfiles/bq-export/tables/features'
# ) AS
# WITH
# -- Identify entities with new activity
# new_activity AS (
#     SELECT DISTINCT entity_id, entity_group
#     FROM APPENDS(
#         TABLE `statmike-mlops-349915.bigtable_feature_store.sparse_events`,
#         CURRENT_TIMESTAMP() - INTERVAL 10 MINUTE
#     )
# ),
#
# -- Re-compute features for active entities from full history
# recomputed AS (
#     SELECT
# ...

# %% [markdown]
# ### How the Continuous Query Processes Data
#
# ```
# Timeline:
#   t=0    New row inserted into sparse_events for entity_42
#   t=1s   APPENDS() detects the new row
#   t=2s   CTE identifies entity_42 as having new activity
#   t=3s   Features re-computed for entity_42 from full dense_features history
#   t=5s   Updated features exported to Bigtable via EXPORT DATA
#   t=5s   Bigtable now serves fresh features for entity_42
# ```
#
# ### When to Use Continuous Queries
#
# | Scenario | Recommendation |
# |----------|---------------|
# | Features change hourly or slower | Scheduled query (cheaper) |
# | Features need sub-minute freshness | Continuous query |
# | Features need sub-second freshness | Streaming pipeline (Section 4) |
# | Feature computation is simple (pass-through) | Continuous query works great |
# | Feature computation is expensive (full window aggregation) | Continuous query works but uses more slots |
#
# ### Why We Don't Execute It Here
#
# Continuous queries run indefinitely and consume reservation slots the entire time. For a learning exercise, the one-time export in Section 1 demonstrates the same EXPORT DATA mechanics. The upgrade path from one-time to continuous is:
# 1. Change reservation assignment from QUERY to CONTINUOUS
# 2. Wrap the source with `APPENDS()`
# 3. Add entity filtering in the CTE
# 4. Execute — the query runs until cancelled

# %% [markdown]
# ---
# ## Section 4: Streaming Pipeline (Pub/Sub → Dataflow → Bigtable)
#
# For the lowest possible latency, bypass BigQuery entirely for incoming events. A streaming pipeline computes features on the fly and writes directly to Bigtable.
#
# In production, this pattern uses [Dataflow](https://cloud.google.com/dataflow/docs/overview) with the [Bigtable I/O connector](https://cloud.google.com/bigtable/docs/dataflow-bigtable). Below, we run an executable demo using a simpler Pub/Sub subscriber pattern in-notebook to illustrate the core event-processing logic — the same logic you would place inside a Dataflow `DoFn` or a Cloud Function.
#
# ### Architecture
#
# ```
#                                         ┌─────────────────────────────┐
#                                         │  Bigtable (feature serving) │
#                                    ┌──→ │  - sub-second writes        │
#                                    │    │  - millisecond reads         │
#                                    │    └─────────────────────────────┘
#                                    │
# Events → Pub/Sub → Dataflow ───────┼────
#                                    │
#                                    │    ┌─────────────────────────────┐
#                                    └──→ │  BigQuery (analytics)       │
#                                         │  - historical analysis       │
#                                         │  - model retraining          │
#                                         └─────────────────────────────┘
# ```
#
# ### Dual-Write Pattern
#
# The streaming pipeline writes to **two** destinations:
# - **Bigtable** — for real-time feature serving (millisecond reads)
# - **BigQuery** — for analytics, monitoring, and model retraining (via streaming insert or Storage Write API)
#
# This avoids the latency of going through BigQuery first. Events hit Bigtable within seconds of arriving in Pub/Sub.

# %% [markdown]
# ### Executable Demo: Pub/Sub → Bigtable
#
# In production, streaming pipelines typically use [Dataflow](https://cloud.google.com/dataflow/docs/overview) with the [Bigtable I/O connector](https://cloud.google.com/bigtable/docs/dataflow-bigtable). Here, we demonstrate the core pattern using a Pub/Sub subscriber that writes directly to Bigtable — the same event-processing logic you'd put inside a Dataflow `DoFn` or a Cloud Function.

# %%
# Create Pub/Sub topic and subscription for the streaming demo
from google.cloud import pubsub_v1

publisher = pubsub_v1.PublisherClient()
subscriber_client = pubsub_v1.SubscriberClient()

STREAM_TOPIC = 'feature-stream-demo'
STREAM_SUB = 'feature-stream-demo-sub'
topic_path = publisher.topic_path(PROJECT_ID, STREAM_TOPIC)
sub_path = subscriber_client.subscription_path(PROJECT_ID, STREAM_SUB)

try:
    publisher.create_topic(request={'name': topic_path})
    print(f'Created topic: {topic_path}')
except AlreadyExists:
    print(f'Topic exists: {topic_path}')

try:
    subscriber_client.create_subscription(
        request={'name': sub_path, 'topic': topic_path}
    )
    print(f'Created subscription: {sub_path}')
except AlreadyExists:
    print(f'Subscription exists: {sub_path}')
# Out:
# Created topic: projects/statmike-mlops-349915/topics/feature-stream-demo
# Created subscription: projects/statmike-mlops-349915/subscriptions/feature-stream-demo-sub

# %%
# Publish 20 sample events (simulating a stream of feature updates)
import json, time, random

events = []
publish_start = time.perf_counter()

for i in range(20):
    event = {
        'entity_group': random.choice(['A', 'B', 'C']),
        'entity_id': str(random.randint(1, 100)).zfill(6),
        'event_type': random.choice(['purchase', 'click', 'view']),
        'metric_1': round(random.uniform(0, 100), 2),
        'metric_2': round(random.uniform(0, 50), 2),
        'timestamp': time.time(),
        'event_id': f'stream-evt-{i:03d}',
    }
    future = publisher.publish(topic_path, json.dumps(event).encode('utf-8'))
    future.result()
    events.append(event)

publish_time = (time.perf_counter() - publish_start) * 1000
print(f'Published {len(events)} events in {publish_time:.0f}ms ({publish_time/len(events):.1f}ms per event)')
# Out:
# Published 20 events in 1141ms (57.1ms per event)

# %%
# Consume events and write each to Bigtable
consume_start = time.perf_counter()

response = subscriber_client.pull(
    request={'subscription': sub_path, 'max_messages': 50}
)
messages = response.received_messages
print(f'Pulled {len(messages)} messages')

# Write each event as a Bigtable row
STREAM_PREFIX = 'stream_demo#'
written_keys = []

for msg in messages:
    event = json.loads(msg.message.data.decode('utf-8'))
    
    # Row key: stream_demo#{entity_group}#{entity_id}#{event_id}
    row_key = f'{STREAM_PREFIX}{event["entity_group"]}#{event["entity_id"]}#{event["event_id"]}'
    
    row = table.direct_row(row_key.encode('utf-8'))
    row.set_cell(BT_COLUMN_FAMILY, 'event_type', event['event_type'].encode())
    row.set_cell(BT_COLUMN_FAMILY, 'metric_1', str(event['metric_1']).encode())
    row.set_cell(BT_COLUMN_FAMILY, 'metric_2', str(event['metric_2']).encode())
    row.set_cell(BT_COLUMN_FAMILY, 'timestamp', str(event['timestamp']).encode())
    row.commit()
    written_keys.append(row_key)

# Acknowledge messages
ack_ids = [msg.ack_id for msg in messages]
if ack_ids:
    subscriber_client.acknowledge(request={'subscription': sub_path, 'ack_ids': ack_ids})

consume_time = (time.perf_counter() - consume_start) * 1000
print(f'Wrote {len(written_keys)} rows to Bigtable in {consume_time:.0f}ms')
print(f'End-to-end: {publish_time + consume_time:.0f}ms (publish + consume + write)')
# Out:
# Pulled 20 messages
# Wrote 20 rows to Bigtable in 2014ms
# End-to-end: 3155ms (publish + consume + write)

# %%
# Verify: read back the streamed rows from Bigtable
from google.cloud.bigtable.row_set import RowSet, RowRange
from google.cloud.bigtable.row_filters import CellsColumnLimitFilter

row_set = RowSet()
row_set.add_row_range(RowRange(
    start_key=STREAM_PREFIX.encode(),
    end_key=f'{STREAM_PREFIX}\xff'.encode(),
))

verify_rows = list(table.read_rows(
    row_set=row_set,
    filter_=CellsColumnLimitFilter(1),
))

print(f'Verified: {len(verify_rows)} rows in Bigtable (expected {len(written_keys)})')
if verify_rows:
    sample = verify_rows[0]
    print(f'\nSample row: {sample.row_key.decode()}')
    for col, cells in sample.cells.get(BT_COLUMN_FAMILY, {}).items():
        print(f'  {col.decode()}: {cells[0].value.decode()}')
# Out:
# Verified: 20 rows in Bigtable (expected 20)
#
# Sample row: stream_demo#A#000033#stream-evt-006
#   event_type: purchase
#   metric_1: 92.28
#   metric_2: 29.33
#   timestamp: 1778363542.5625012

# %%
# Cleanup: delete Pub/Sub resources and demo rows
try:
    subscriber_client.delete_subscription(request={'subscription': sub_path})
    print(f'Deleted subscription: {sub_path}')
except Exception as e:
    print(f'Subscription cleanup: {e}')

try:
    publisher.delete_topic(request={'topic': topic_path})
    print(f'Deleted topic: {topic_path}')
except Exception as e:
    print(f'Topic cleanup: {e}')

# Delete demo rows from Bigtable
deleted = 0
for row_key in written_keys:
    row = table.direct_row(row_key.encode('utf-8'))
    row.delete()
    row.commit()
    deleted += 1
print(f'Deleted {deleted} demo rows from Bigtable')
# Out:
# Deleted subscription: projects/statmike-mlops-349915/subscriptions/feature-stream-demo-sub
# Deleted topic: projects/statmike-mlops-349915/topics/feature-stream-demo
# Deleted 20 demo rows from Bigtable

# %% [markdown]
# ### Streaming Pipeline: When to Use
#
# | Aspect | Continuous Query | Streaming Pipeline |
# |--------|-----------------|-------------------|
# | **Latency** | Seconds (BQ processing time) | Sub-second (direct writes) |
# | **Feature logic** | Full SQL (windows, joins, UDFs) | Beam transforms (limited vs. SQL) |
# | **Infrastructure** | BQ reservation only | Pub/Sub + Dataflow + Bigtable |
# | **Operational complexity** | Low (managed by BQ) | High (pipeline monitoring, scaling, failures) |
# | **Cost model** | Slot-hours | Dataflow worker-hours + Pub/Sub throughput |
# | **Best for** | SQL-expressible features | Custom logic, lowest latency, dual-write patterns |
#
# Most feature stores start with EXPORT DATA (Section 1) and only graduate to streaming when sub-second freshness is a hard requirement. The continuous query (Section 3) handles the middle ground well.

# %% [markdown]
# ---
# ## Section 5: The Propagation Race
#
# We have discussed three freshness levels. Let's measure the actual propagation delay for the simplest pattern: insert new data into BigQuery, then run EXPORT DATA and time the end-to-end journey from insert to Bigtable availability.
#
# ### Test Plan
#
# 1. Insert a new row into BigQuery via streaming insert
# 2. Verify it is visible in BigQuery
# 3. Run a one-time EXPORT DATA
# 4. Verify the row appears in Bigtable
# 5. Measure the total wall-clock time

# %%
# Step 1: Check what tables and columns are available for the test
tables_df = bq.query(f'''
    SELECT table_name
    FROM `{BQ_PROJECT}.{BQ_DATASET}.INFORMATION_SCHEMA.TABLES`
    ORDER BY table_name
''').to_dataframe()

print('Available tables:')
for _, row in tables_df.iterrows():
    print(f'  {row["table_name"]}')
# Out:
# Available tables:
#   dense_features
#   sparse_events
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
# Step 2: Pick a test entity that does not exist yet
TEST_ENTITY_GROUP = 'TEST'
TEST_ENTITY_ID = 'sync_test_001'
TEST_ROW_KEY = f'{TEST_ENTITY_GROUP}#{TEST_ENTITY_ID}'

# Check if it already exists in Bigtable
existing_row = table.read_row(
    TEST_ROW_KEY.encode('utf-8'),
    filter_=CellsColumnLimitFilter(1),
)
if existing_row:
    print(f'Entity {TEST_ROW_KEY} already exists in Bigtable — will be overwritten')
else:
    print(f'Entity {TEST_ROW_KEY} does not exist in Bigtable — good for testing')
# Out:
# Entity TEST#sync_test_001 already exists in Bigtable — will be overwritten

# %%
# Step 3: Insert a test row into BigQuery via streaming insert

# Insert into dense_features (the source for our export)
test_rows = [{
    'entity_group': TEST_ENTITY_GROUP,
    'entity_id': TEST_ENTITY_ID,
    'feature_int_1': 999,
    'feature_int_2': 888,
    'feature_int_3': 777,
    'feature_int_4': 666,
    'feature_int_5': 555,
    'feature_float_1': 99.99,
    'feature_float_2': 88.88,
    'feature_float_3': 77.77,
    'feature_float_4': 66.66,
    'feature_float_5': 55.55,
}]

insert_start = time.perf_counter()

errors = bq.insert_rows_json(
    f'{BQ_PROJECT}.{BQ_DATASET}.dense_features',
    test_rows,
)

insert_time = time.perf_counter() - insert_start

if errors:
    print(f'Insert errors: {errors}')
else:
    print(f'Inserted test row in {insert_time:.3f}s')
    print(f'  row key:  {TEST_ROW_KEY}')
    print(f'  ints:     999 | 888 | 777 | 666 | 555')
    print(f'  floats:   99.99 | 88.88 | 77.77 | 66.66 | 55.55')
# Out:
# Inserted test row in 0.255s
#   row key:  TEST#sync_test_001
#   ints:     999 | 888 | 777 | 666 | 555
#   floats:   99.99 | 88.88 | 77.77 | 66.66 | 55.55

# %%
# Step 4: Verify the row is visible in BigQuery
# Streaming inserts are available for queries almost immediately
time.sleep(5)  # Brief wait for streaming buffer

verify_df = bq.query(f'''
    SELECT entity_group, entity_id, feature_int_1, feature_float_1
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    WHERE entity_group = '{TEST_ENTITY_GROUP}' AND entity_id = '{TEST_ENTITY_ID}'
''').to_dataframe()

if len(verify_df) > 0:
    print(f'Row visible in BigQuery:')
    print(verify_df.to_string(index=False))
else:
    print('Row not yet visible in BigQuery — streaming buffer may need more time')
# Out:
# Row visible in BigQuery:
# entity_group     entity_id  feature_int_1  feature_float_1
#         TEST sync_test_001            999            99.99
#         TEST sync_test_001            999            99.99
#         TEST sync_test_001            999            99.99

# %%
# Step 5: Run EXPORT DATA and time it
# Export only the test entity to minimize export time
# Note: overwrite=true is required because the table already has data from the
# initial export. EXPORT DATA to Bigtable does not support upsert — overwrite=false
# requires the target table to be empty.
EXPORT_TEST_SQL = f'''
EXPORT DATA OPTIONS (
    format = 'CLOUD_BIGTABLE',
    uri = '{BIGTABLE_URI}',
    overwrite = true
) AS
SELECT
    CONCAT(entity_group, '#', entity_id) AS rowkey,
    STRUCT(
        CONCAT(
            CAST(feature_int_1 AS STRING), '|',
            CAST(feature_int_2 AS STRING), '|',
            CAST(feature_int_3 AS STRING), '|',
            CAST(feature_int_4 AS STRING), '|',
            CAST(feature_int_5 AS STRING), '|',
            CAST(ROUND(feature_float_1, 4) AS STRING), '|',
            CAST(ROUND(feature_float_2, 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_3, 0.0), 4) AS STRING), '|',
            CAST(ROUND(COALESCE(feature_float_4, 0.0), 4) AS STRING), '|',
            CAST(ROUND(feature_float_5, 4) AS STRING)
        ) AS _values
    ) AS {BT_COLUMN_FAMILY}
FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
WHERE entity_group = '{TEST_ENTITY_GROUP}' AND entity_id = '{TEST_ENTITY_ID}'
'''

print('Exporting test entity to Bigtable...')
export_start = time.perf_counter()
job = bq.query(EXPORT_TEST_SQL)
job.result()
export_elapsed = time.perf_counter() - export_start

print(f'Export complete in {export_elapsed:.1f}s')
print(f'  Job ID: {job.job_id}')
# Out:
# Exporting test entity to Bigtable...
# Export complete in 1.6s
#   Job ID: f35b71a7-2445-417d-b7d6-7cc5c0cd11e3

# %%
# Step 6: Verify the row in Bigtable
bt_row = table.read_row(
    TEST_ROW_KEY.encode('utf-8'),
    filter_=CellsColumnLimitFilter(1),
)

total_propagation = time.perf_counter() - insert_start

if bt_row:
    cells = bt_row.cells.get(BT_COLUMN_FAMILY, {})
    values = {}
    for col_name, col_cells in cells.items():
        values[col_name.decode('utf-8')] = col_cells[0].value.decode('utf-8')
    print(f'Row found in Bigtable:')
    print(f'  row key: {TEST_ROW_KEY}')
    for k, v in values.items():
        print(f'  {k}: {v}')
else:
    print(f'Row NOT found in Bigtable for key {TEST_ROW_KEY}')

print(f'\n--- Propagation Timeline ---')
print(f'  BQ streaming insert:  {insert_time:.3f}s')
print(f'  EXPORT DATA job:      {export_elapsed:.1f}s')
print(f'  Total wall clock:     {total_propagation:.1f}s')
print(f'\nThe EXPORT DATA job dominates the propagation time.')
print(f'A continuous query would reduce this to seconds.')
print(f'A streaming pipeline would reduce this to sub-second.')
# Out:
# Row found in Bigtable:
#   row key: TEST#sync_test_001
#   _values: 999|888|777|666|555|99.99|88.88|77.77|66.66|55.55
#
# --- Propagation Timeline ---
#   BQ streaming insert:  0.255s
#   EXPORT DATA job:      1.6s
#   Total wall clock:     7.8s
#
# The EXPORT DATA job dominates the propagation time.
# A continuous query would reduce this to seconds.
# A streaming pipeline would reduce this to sub-second.

# %% [markdown]
# ### Propagation Summary
#
# The timeline for a single feature update via one-time export:
#
# ```
# t=0s    │ Event occurs
# t<1s    │ BQ streaming insert completes
# t~5s    │ Row visible in BQ (streaming buffer)
# t~20s   │ EXPORT DATA job completes (job scheduling + execution)
# t~20s   │ Feature available in Bigtable
# ```
#
# The EXPORT DATA job scheduling and execution dominates. For comparison:
#
# | Pattern | Typical Propagation | Bottleneck |
# |---------|--------------------|-----------|
# | One-time EXPORT DATA | 10-30 seconds | Job scheduling + execution |
# | Scheduled query | Schedule interval + job time | Waiting for next schedule |
# | Continuous query | 2-10 seconds | APPENDS() detection + BQ processing |
# | Streaming pipeline | < 1 second | Network + Dataflow processing |

# %% [markdown]
# ---
# ## Section 6: Reservation Management
#
# BigQuery Enterprise edition uses [reservations](https://cloud.google.com/bigquery/docs/reservations-intro) to allocate compute capacity. Understanding reservation management is critical for controlling costs and ensuring feature export jobs have the resources they need.
#
# ### Key Concepts
#
# | Concept | Description |
# |---------|------------|
# | **Reservation** | A pool of BigQuery slots (compute units) |
# | **Assignment** | Maps a reservation to a project/folder/org and a job type (QUERY, CONTINUOUS, etc.) |
# | **Slot** | A unit of BigQuery compute capacity |
# | **Edition** | Enterprise, Enterprise Plus, or Standard — determines features and pricing |
#
# ### QUERY vs. CONTINUOUS Assignments
#
# | Aspect | QUERY | CONTINUOUS |
# |--------|-------|------------|
# | **Purpose** | Ad-hoc queries, EXPORT DATA | Long-running continuous queries |
# | **Lifecycle** | Jobs start and finish | Jobs run indefinitely |
# | **Max slots** | Up to reservation capacity | 500 slots max per reservation |
# | **Mixing** | Cannot share reservation with CONTINUOUS | Cannot share reservation with QUERY |
# | **Cost** | Slots billed while reservation exists | Slots billed while reservation exists |
#
# ### Slot Capacity Planning
#
# For EXPORT DATA to Bigtable:
# - **Small tables** (< 1 GB): 100 slots is sufficient
# - **Medium tables** (1-100 GB): 200-500 slots for reasonable export times
# - **Large tables** (> 100 GB): 500-1000+ slots, consider partitioned exports
#
# ### Cost Implications
#
# Enterprise edition on-demand pricing (as of 2024):
# - Slots are billed per-second while the reservation exists
# - Create the reservation, run the export, delete immediately — minimizes cost
# - For continuous queries: slots are billed 24/7 since the reservation must stay active

# %%
# List current reservations
parent = f'projects/{PROJECT_ID}/locations/{LOCATION}'

print('Current reservations:')
reservations = list(reservation_client.list_reservations(parent=parent))
if not reservations:
    print('  (none)')
else:
    for r in reservations:
        print(f'  {r.name}')
        print(f'    Slots:   {r.slot_capacity}')
        print(f'    Edition: {bigquery_reservation_v1.Edition(r.edition).name}')
        
        # List assignments for this reservation
        assignments = list(reservation_client.list_assignments(parent=r.name))
        for a in assignments:
            print(f'    Assignment: {a.job_type.name} → {a.assignee}')
# Out:
# Current reservations:
#   projects/statmike-mlops-349915/locations/US/reservations/default
#     Slots:   0
#     Edition: ENTERPRISE
#   projects/statmike-mlops-349915/locations/US/reservations/feature-store-export
#     Slots:   100
#     Edition: ENTERPRISE
#     Assignment: QUERY → projects/statmike-mlops-349915

# %% [markdown]
# ### The Sync Strategy Decision Tree
#
# ```
# How fresh do features need to be?
# │
# ├─ Hours to days ─────────→ Scheduled Query (Section 2)
# │                           Simple, low cost, predictable
# │
# ├─ Minutes ──────────────→ Continuous Query (Section 3)
# │                           BQ-native, SQL features, moderate cost
# │
# └─ Sub-second ───────────→ Streaming Pipeline (Section 4)
#                             Lowest latency, highest complexity
#
# One-time export (Section 1) is always the starting point for initial backfill.
# ```

# %% [markdown]
# ---
# ## Section 7: Data Boost for Batch Reads
#
# Sections 1–4 covered moving data INTO Bigtable. But feature stores also need to read data OUT — for training data extraction, backfill validation, and analytics. These batch reads can compete with serving traffic for node CPU.
#
# [Data Boost](https://cloud.google.com/bigtable/docs/data-boost-overview) solves this by routing batch reads through serverless compute that is completely isolated from your Bigtable nodes. Serving latency is unaffected no matter how large the scan.
#
# ### Key Characteristics
#
# | Aspect | Details |
# |--------|---------|
# | **Read types** | Scans only — not point reads (single-row lookups) |
# | **Write support** | None — read-only |
# | **Data freshness** | Up to 35 minutes behind latest writes |
# | **Impact on serving** | Zero — uses separate serverless compute |
# | **Cost** | Separate per-byte charge (not included in node cost) |
# | **Instance types** | Production instances only (not Development) |
#
# ### When to Use Data Boost
#
# | Use case | Why Data Boost fits |
# |----------|-------------------|
# | **Training data extraction** | Scan all features for model training without degrading serving |
# | **Backfill validation** | Read back exported rows to compare against BigQuery source |
# | **Analytics / auditing** | Run full-table scans for data quality checks |
# | **Feature distribution monitoring** | Compute statistics across all entities |
#
# ### When NOT to Use Data Boost
#
# - **Real-time serving** — use standard app profiles for point reads
# - **Low-latency reads** — Data Boost adds overhead for scan setup
# - **Writes** — Data Boost is read-only
# - **Data that just changed** — 35-minute lag means recent writes may not be visible

# %%
# Data Boost app profile creation (reference pattern)
#
# Data Boost requires a Production instance — our Development instance
# does not support this feature. The commands below show the pattern.

print('=== Data Boost App Profile (Reference) ===')
print()
print('Create a Data Boost app profile:')
print(f'''  gcloud bigtable app-profiles create data-boost-reads \\''')
print(f'''    --instance={BT_INSTANCE} \\''')
print(f'''    --project={PROJECT_ID} \\''')
print(f'''    --data-boost-compute-billing-owner=HOST_PAYS \\''')
print(f'''    --description="Data Boost for batch reads and training export"''')
print()
print('Read using the Data Boost profile in Python:')
print('''
  # Create client with Data Boost app profile
  from google.cloud import bigtable
  from google.cloud.bigtable.row_filters import CellsColumnLimitFilter

  client = bigtable.Client(project=PROJECT_ID)
  instance = client.instance(BT_INSTANCE)
  table = instance.table(BT_TABLE, app_profile_id='data-boost-reads')

  # Scan all rows — runs on serverless compute, zero impact on serving nodes
  rows = list(table.read_rows(filter_=CellsColumnLimitFilter(1)))
  print(f'Read {len(rows)} rows via Data Boost')
''')
print('Data Boost with GoogleSQL:')
print(f'''  SELECT _key, features['_values']''')
print(f'''  FROM `{BT_TABLE}`''')
print(f'''  -- Run in Bigtable Studio with Data Boost app profile selected''')
print()
print('Note: Our Development instance does not support Data Boost.')
print('Upgrade to a Production instance to use this feature.')
# Out:
# === Data Boost App Profile (Reference) ===
#
# Create a Data Boost app profile:
#   gcloud bigtable app-profiles create data-boost-reads \
#     --instance=feature-store \
#     --project=statmike-mlops-349915 \
#     --data-boost-compute-billing-owner=HOST_PAYS \
#     --description="Data Boost for batch reads and training export"
#
# Read using the Data Boost profile in Python:
#
#   # Create client with Data Boost app profile
#   from google.cloud import bigtable
#   from google.cloud.bigtable.row_filters import CellsColumnLimitFilter
#
#   client = bigtable.Client(project=PROJECT_ID)
#   instance = client.instance(BT_INSTANCE)
#   table = instance.table(BT_TABLE, app_profile_id='data-boost-reads')
#
#   # Scan all rows — runs on serverless compute, zero impact on serving nodes
#   rows = list(table.read_rows(filter_=CellsColumnLimitFilter(1)))
#   print(f'Read {len(rows)} rows via Data Boost')
#
# Data Boost with GoogleSQL:
#   SELECT _key, features['_values']
# ...

# %% [markdown]
# ### Data Boost vs Regular App Profiles
#
# | Aspect | Regular App Profile | Data Boost |
# |--------|-------------------|------------|
# | **Impact on serving** | Shares node CPU — batch reads can increase serving latency | Zero impact — uses separate serverless compute |
# | **Read types** | Point reads + scans | Scans only (not point reads) |
# | **Data freshness** | Real-time (reads latest committed data) | Up to 35 minutes behind latest writes |
# | **Cost** | Included in node-hour pricing | Separate per-byte charge |
# | **Best for** | Real-time serving, small batch reads | Large scans: training export, backfill, analytics |
# | **Instance requirement** | All instance types | Production instances only |
#
# ### Data Boost in the Sync Pipeline
#
# Data Boost completes the data flow circle:
#
# ```
# BigQuery ──EXPORT DATA──→ Bigtable ──Data Boost──→ Training Pipeline
#   (offline store)            (online store)          (model retraining)
# ```
#
# Without Data Boost, reading features back from Bigtable for training competes with serving traffic. With Data Boost, the training pipeline can scan the entire feature store without any impact on prediction latency. See [Data Boost documentation](https://cloud.google.com/bigtable/docs/data-boost-overview) for pricing and configuration details.

# %% [markdown]
# ---
# ## Section 8: Continuous Materialized Views
#
# > **Preview feature** (as of May 2026). Continuous materialized views are a pre-GA offering subject to the "Pre-GA Offerings Terms" in the General Service Terms. Check the [current status](https://cloud.google.com/bigtable/docs/continuous-materialized-views) before using in production. This section was written on 2026-05-09.
#
# Sections 1–4 move data from BigQuery INTO Bigtable. Section 7 (Data Boost) reads data OUT. Continuous materialized views work *within* Bigtable itself — pre-computing aggregations that stay fresh automatically as source data changes.
#
# A [continuous materialized view](https://cloud.google.com/bigtable/docs/continuous-materialized-views) is a fully-managed, pre-computed result of a GoogleSQL query. When rows are written, updated, or garbage-collected in the source table, the view updates automatically in the background.
#
# ### Key Characteristics
#
# | Aspect | Details |
# |--------|----------|
# | **Consistency** | Eventually consistent — updates may lag source writes |
# | **Limit** | Up to 5 materialized views per table |
# | **Query syntax** | GoogleSQL `SELECT ... GROUP BY` (aggregations) or `SELECT ... ORDER BY` (secondary indexes) |
# | **GC sync** | Automatically reflects garbage collection policy changes on source table |
# | **Serving impact** | Minimal — background processing, negligible impact on reads/writes |
# | **Maintenance** | Fully managed — no manual refresh or scheduling |
# | **Modification** | Cannot modify the query — must delete and recreate |
#
# ### How They Differ from BigQuery Continuous Queries (Section 3)
#
# BigQuery continuous queries (Section 3) export data *from BigQuery to Bigtable* using `APPENDS()`. Continuous materialized views compute *within Bigtable itself* — no BigQuery reservation, no external orchestration.
#
# ### Feature Store Use Cases
#
# | Use Case | Example |
# |----------|----------|
# | **Pre-computed aggregations** | Count of entities per group, average feature value by category |
# | **Secondary indexes** | Look up entities by category instead of by row key |
# | **Running statistics** | Sum, count, min, max across entity groups — always fresh |
# | **Denormalized views** | Flatten nested features for simpler reads |

# %%
# Continuous materialized view creation (reference pattern)
#
# This is a Preview feature — not executed here.
# The patterns below show how to create and query materialized views.

print('=== Continuous Materialized View (Reference) ===')
print()
print('Example 1: Aggregation view — entity count per group')
print()

cmv_sql_agg = f"""CREATE CONTINUOUS MATERIALIZED VIEW `entity_group_stats`
AS SELECT
  SUBSTR(_key, 1, 1) AS entity_group,
  COUNT(*) AS entity_count
FROM `{BT_TABLE}`
GROUP BY entity_group"""

print(cmv_sql_agg)
print()
print('Example 2: Secondary index — lookup by a feature value')
print()

cmv_sql_index = f"""CREATE CONTINUOUS MATERIALIZED VIEW `features_by_category`
AS SELECT
  metadata['category'] AS category,
  _key AS entity_key,
  features['_values'] AS feature_values
FROM `{BT_TABLE}`
ORDER BY category, entity_key"""

print(cmv_sql_index)
print()
print('gcloud CLI equivalent:')
print(f'  gcloud bigtable materialized-views create entity-group-stats \\\\')
print(f'    --instance={BT_INSTANCE} \\\\')
print(f'    --project={PROJECT_ID} \\\\')
print(f'    --definition-file=cmv-definition.sql')
print()
print('Query a materialized view (same as querying a table):')
print(f'  SELECT * FROM `entity_group_stats`')
print()
print('Note: This is a Preview feature as of May 2026.')
print('Not executed here — check current status before using in production.')
# Out:
# === Continuous Materialized View (Reference) ===
#
# Example 1: Aggregation view — entity count per group
#
# CREATE CONTINUOUS MATERIALIZED VIEW `entity_group_stats`
# AS SELECT
#   SUBSTR(_key, 1, 1) AS entity_group,
#   COUNT(*) AS entity_count
# FROM `features`
# GROUP BY entity_group
#
# Example 2: Secondary index — lookup by a feature value
#
# CREATE CONTINUOUS MATERIALIZED VIEW `features_by_category`
# AS SELECT
#   metadata['category'] AS category,
#   _key AS entity_key,
#   features['_values'] AS feature_values
# FROM `features`
# ORDER BY category, entity_key
#
# gcloud CLI equivalent:
#   gcloud bigtable materialized-views create entity-group-stats \\
#     --instance=feature-store \\
#     --project=statmike-mlops-349915 \\
#     --definition-file=cmv-definition.sql
#
# Query a materialized view (same as querying a table):
#   SELECT * FROM `entity_group_stats`
#
# Note: This is a Preview feature as of May 2026.
# ...

# %% [markdown]
# ### Materialized Views vs Other Sync Strategies
#
# | Aspect | EXPORT DATA (S1) | Continuous Query (S3) | Streaming Pipeline (S4) | Materialized View (S8) |
# |--------|-----------------|----------------------|------------------------|------------------------|
# | **Direction** | BQ → BT | BQ → BT | Pub/Sub → BT | Within BT |
# | **Aggregation** | In BQ SQL | In BQ SQL | In pipeline code | In GoogleSQL |
# | **Maintenance** | Manual or scheduled | Always running (BQ slots) | Pipeline monitoring | Fully managed |
# | **Freshness** | Snapshot at export time | Seconds | Sub-second | Eventually consistent |
# | **Infrastructure** | BQ reservation | BQ reservation | Pub/Sub + Dataflow | None (built into BT) |
# | **Status** | GA | GA | GA | **Preview** |
#
# **When to use materialized views:** You need pre-computed aggregates or secondary indexes that stay fresh automatically, and you want to avoid managing external pipelines. The trade-off is eventual consistency and Preview-status limitations.

# %% [markdown]
# ---
# ## Section 9: Cleanup
#
# Delete the reservation and assignment to stop slot billing. The features remain in Bigtable — only the BigQuery reservation resources are removed.
#
# > **Important:** Delete in reverse order — assignment first, then reservation. The API rejects deletion of a reservation that still has assignments.

# %%
# Delete reservation resources (reverse order)
print('Cleaning up reservation resources...')

# Step 1: Delete all assignments for the reservation
try:
    assignments = list(reservation_client.list_assignments(parent=reservation.name))
    for a in assignments:
        reservation_client.delete_assignment(name=a.name)
        print(f'  Deleted assignment: {a.name}')
except NotFound:
    print(f'  No assignments found')
except Exception as e:
    print(f'  Assignment cleanup: {e}')

# Step 2: Delete the reservation
try:
    reservation_client.delete_reservation(name=reservation.name)
    print(f'  Deleted reservation: {reservation.name}')
except NotFound:
    print(f'  Reservation already deleted')
except Exception as e:
    print(f'  Reservation cleanup: {e}')

print('\nWaiting 30s for deletion to propagate...')
time.sleep(30)
print('Reservation cleanup complete. Features remain in Bigtable.')
# Out:
# Cleaning up reservation resources...
#   Deleted assignment: projects/statmike-mlops-349915/locations/US/reservations/feature-store-export/assignments/6618466362019364446
#   Deleted reservation: projects/statmike-mlops-349915/locations/US/reservations/feature-store-export
#
# Waiting 30s for deletion to propagate...
# Reservation cleanup complete. Features remain in Bigtable.

# %%
# Verify cleanup
remaining = list(reservation_client.list_reservations(parent=parent))
our_reservations = [r for r in remaining if RESERVATION_ID in r.name]
if our_reservations:
    print(f'WARNING: Reservation still exists: {our_reservations[0].name}')
    print('  This will continue to incur slot charges.')
else:
    print(f'Reservation {RESERVATION_ID} successfully deleted.')
    print('No ongoing slot charges.')
# Out:
# Reservation feature-store-export successfully deleted.
# No ongoing slot charges.

# %% [markdown]
# ---
# ## Summary
#
# This notebook explored four synchronization strategies plus Data Boost for batch reads for keeping Bigtable features fresh, from simplest to most complex:
#
# | Strategy | Freshness | Complexity | Cost | Best For |
# |----------|-----------|------------|------|----------|
# | **One-time EXPORT DATA** | Snapshot only | Lowest | Lowest | Backfill, schema migration |
# | **Scheduled query** | Minutes to hours | Low | Low-moderate | Slowly-changing features |
# | **Continuous query** | Seconds | Moderate | Moderate-high | SQL-expressible features needing near-real-time updates |
# | **Streaming pipeline** | Sub-second | Highest | Variable | Lowest latency, custom logic |
# | **Data Boost** | Up to 35 min lag | Low | Per-byte | Training extraction, analytics (zero serving impact) |
# | **Materialized views** | Eventually consistent | Lowest | Included | Pre-computed aggregates, secondary indexes (Preview) |
#
# ### Key Takeaways
#
# 1. **Start simple.** One-time EXPORT DATA is the right first step. Add complexity only when freshness requirements demand it.
#
# 2. **Reservations control cost.** Create reservations on demand and delete them immediately after use. For continuous queries, plan for 24/7 slot costs.
#
# 3. **APPENDS() is the bridge.** The continuous query pattern reuses the same EXPORT DATA SQL — the only structural change is wrapping the source with `APPENDS()` and switching to a CONTINUOUS reservation.
#
# 4. **Streaming is a different paradigm.** When sub-second freshness is required, bypass BigQuery for the hot path entirely and write directly to Bigtable via Dataflow.
#
# ### Related Notebooks
#
# - [**NB5: Streaming and Direct Writes**](./Bigtable%20Feature%20Store%20-%20Streaming%20and%20Direct%20Writes.ipynb) — when sub-second freshness demands bypassing BigQuery entirely, NB5 shows the direct-write path with batch mutations, atomic increments, and change streams
# - [**NB9: Dynamic Features**](./Bigtable%20Feature%20Store%20-%20Dynamic%20Features.ipynb) — combines streaming writes with serve-time computation for features that are computed on-the-fly

# %% [markdown]
# ### Cleanup Reminder
#
# When you are done with the Bigtable Feature Store series, return to [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) and follow the **Cleanup** section to delete the Bigtable instance, BigQuery dataset, and any other billable resources.
