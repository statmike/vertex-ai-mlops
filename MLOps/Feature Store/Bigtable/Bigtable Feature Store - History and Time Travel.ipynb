# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2FFeature+Store%2FBigtable&file=Bigtable+Feature+Store+-+History+and+Time+Travel.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2FFeature%2520Store%2FBigtable%2FBigtable%2520Feature%2520Store%2520-%2520History%2520and%2520Time%2520Travel.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520History%2520and%2520Time%2520Travel.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520History%2520and%2520Time%2520Travel.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520History%2520and%2520Time%2520Travel.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520History%2520and%2520Time%2520Travel.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Bigtable Feature Store — History & Time-Travel
#
# ML models need point-in-time correct features: "what did this entity's features look like at 2pm last Tuesday?" Getting this wrong causes training-serving skew. This notebook compares two approaches to storing feature history in Bigtable and shows how to extract point-in-time features for training.
#
# **Prerequisites:** Run [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) first.

# %% [markdown]
# ---
# ## Configuration

# %%
PROJECT_ID = 'statmike-mlops-349915'
REGION = 'us-central1'
ZONE = 'us-central1-a'

BQ_PROJECT = PROJECT_ID
BQ_DATASET = 'bigtable_feature_store'

BT_INSTANCE = 'feature-store'
BT_COLUMN_FAMILY = 'features'

# Tables created in this notebook
BT_TABLE_HISTORY_KEY = 'features-history-key'
BT_TABLE_HISTORY_CELL = 'features-history-cell'

DATASET_REF = f'{BQ_PROJECT}.{BQ_DATASET}'

print(f'Project:    {PROJECT_ID}')
print(f'BQ Dataset: {DATASET_REF}')
print(f'BT Instance: {BT_INSTANCE}')
print(f'History tables: {BT_TABLE_HISTORY_KEY}, {BT_TABLE_HISTORY_CELL}')
# Out:
# Project:    statmike-mlops-349915
# BQ Dataset: statmike-mlops-349915.bigtable_feature_store
# BT Instance: feature-store
# History tables: features-history-key, features-history-cell

# %% [markdown]
# ### Packages

# %%
import subprocess, sys, shutil

def install(*packages):
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call(
            [uv, 'pip', 'install', '-q', '--prerelease=allow',
             '--python', sys.executable, *packages])
    else:
        subprocess.check_call(
            [sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install(
    'google-cloud-bigquery', 'db-dtypes',
    'google-cloud-bigtable',
    'pandas', 'numpy',
)

# %% [markdown]
# ### Authentication

# %%
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC used automatically

# %% [markdown]
# ### Client Setup

# %%
import datetime
import json
import struct
import time

import numpy as np
import pandas as pd

from google.cloud import bigquery
from google.cloud import bigtable
from google.cloud.bigtable import column_family as cf
from google.cloud.bigtable import row_filters
from google.cloud.bigtable.row_set import RowSet, RowRange
from google.api_core.exceptions import AlreadyExists, NotFound

bq = bigquery.Client(project=BQ_PROJECT)
bt_client = bigtable.Client(project=PROJECT_ID, admin=True)
instance = bt_client.instance(BT_INSTANCE)

print('Clients initialized:')
print(f'  BigQuery:  {bq.project}')
print(f'  Bigtable:  {BT_INSTANCE}')
# Out:
# Clients initialized:
#   BigQuery:  statmike-mlops-349915
#   Bigtable:  feature-store

# %% [markdown]
# ---
# ## Prerequisites Check
#
# Verify the BQ dataset exists and we can connect to the Bigtable instance.

# %%
# Verify BQ dataset
try:
    dataset = bq.get_dataset(DATASET_REF)
    print(f'BQ dataset exists: {DATASET_REF}')
    print(f'  Location: {dataset.location}')
except NotFound:
    raise RuntimeError(
        f'Dataset {DATASET_REF} not found. '
        'Run Notebook 0 (Environment) first to create the dataset and source tables.'
    )

# Verify Bigtable instance
if instance.exists():
    instance.reload()
    print(f'Bigtable instance exists: {BT_INSTANCE}')
else:
    raise RuntimeError(
        f'Bigtable instance {BT_INSTANCE} not found. '
        'Run Notebook 0 (Environment) first.'
    )

# Verify sparse_events table exists in BQ
try:
    sparse_table = bq.get_table(f'{DATASET_REF}.sparse_events')
    print(f'Source table: sparse_events ({sparse_table.num_rows:,} rows)')
except NotFound:
    raise RuntimeError(
        f'Table {DATASET_REF}.sparse_events not found. '
        'Run Notebook 0 (Environment) first.'
    )
# Out:
# BQ dataset exists: statmike-mlops-349915.bigtable_feature_store
#   Location: US
# Bigtable instance exists: feature-store
# Source table: sparse_events (2,600,000 rows)

# %% [markdown]
# ---
# ## Section 1: Why History Matters
#
# A feature store that only keeps the latest value works for serving. But training requires **point-in-time correctness** — the ability to reconstruct what features looked like at any historical moment. This is related to BigQuery's [time travel](https://cloud.google.com/bigquery/docs/time-travel) concept, but applied at the feature level.
#
# ### Training-Serving Skew
#
# Consider a fraud model. At training time, you join features to labeled transactions using the transaction timestamp. If you accidentally use *current* feature values instead of *historical* values, the model learns patterns that won't exist at serving time. This is **training-serving skew** — the most common silent failure in production ML.
#
# ```
# Transaction at 2024-06-15 14:00:00 UTC:
#
#   WRONG: Use today's feature values (spending_30d_avg = $142.50)
#          The model sees the future — values influenced by events after the transaction.
#
#   RIGHT: Use feature values as-of 2024-06-15 14:00:00 UTC (spending_30d_avg = $87.20)
#          The model sees exactly what was known at decision time.
# ```
#
# ### Point-in-Time Correctness
#
# For a transaction at time T, you need the feature values that were **known at time T**, not values computed later. This matters for:
#
# | Use Case | Why PIT Matters |
# |----------|----------------|
# | **Training** | Features must reflect what was known when the label was generated |
# | **Backtesting** | Simulating model performance on historical data requires historical features |
# | **Auditing** | Regulators may ask "what did the model see when it made this decision?" |
# | **Debugging** | Reproducing a bad prediction requires the exact feature state at that time |
#
# ### Two Storage Strategies
#
# Bigtable offers two natural ways to store feature history, each with different trade-offs:
#
# - **Design A: History in the Row Key** — encode the timestamp in the row key so each snapshot is a separate row
# - **Design B: Cell Versioning** — use Bigtable's native cell versioning to store multiple values per column
#
# We'll implement both, compare them, and show when to use which.

# %% [markdown]
# ---
# ## Section 2: Design Choice A — History in the Row Key
#
# In this design, each feature snapshot gets its own row. The row key encodes both the entity identity and the timestamp:
#
# ```
# Row key format: {entity_group}#{entity_id}#{reverse_timestamp}
#
# Example rows:
#   A#000001#9999999999999 → oldest snapshot
#   A#000001#9999999999500 → newer snapshot
#   A#000001#9999999999000 → newest snapshot
# ```
#
# **Reverse timestamp:** We use `MAX_TIMESTAMP - event_timestamp` so that the newest entries sort first in Bigtable's lexicographic ordering. This makes "get the latest N snapshots" a simple prefix scan with a row limit.
#
# ### Create the Table

# %%
# Create a dedicated table for Design A: history in the key
table_history_key = instance.table(BT_TABLE_HISTORY_KEY)

if not table_history_key.exists():
    # No automatic GC — history retention is managed manually
    max_age_rule = cf.MaxAgeGCRule(datetime.timedelta(days=365))
    table_history_key.create(column_families={BT_COLUMN_FAMILY: max_age_rule})
    print(f'Created table: {BT_TABLE_HISTORY_KEY}')
    print(f'  Column family: {BT_COLUMN_FAMILY}')
    print(f'  GC policy: MaxAge(365 days)')
else:
    print(f'Table exists: {BT_TABLE_HISTORY_KEY}')
    existing = list(table_history_key.list_column_families().keys())
    print(f'  Column families: {existing}')
# Out:
# Table exists: features-history-key
#   Column families: ['features']

# %% [markdown]
# ### Sample Data from BigQuery
#
# We'll pull events for 10 entities from `sparse_events`. Each entity has multiple events over time — these become the historical snapshots we write to Bigtable.

# %%
# Select 10 entities with multiple events
sample_df = bq.query(f'''
    WITH entity_counts AS (
        SELECT entity_group, entity_id, COUNT(*) AS event_count
        FROM `{DATASET_REF}.sparse_events`
        GROUP BY entity_group, entity_id
        HAVING COUNT(*) >= 5
        ORDER BY FARM_FINGERPRINT(CONCAT(entity_group, entity_id))
        LIMIT 10
    )
    SELECT
        e.entity_group,
        e.entity_id,
        e.event_timestamp,
        e.metric_1 AS feature_1,
        e.metric_2 AS feature_2,
        e.metric_3 AS feature_3
    FROM `{DATASET_REF}.sparse_events` e
    JOIN entity_counts c
        ON e.entity_group = c.entity_group AND e.entity_id = c.entity_id
    ORDER BY e.entity_group, e.entity_id, e.event_timestamp
''').to_dataframe()

print(f'Sample data: {len(sample_df)} events across {sample_df[["entity_group", "entity_id"]].drop_duplicates().shape[0]} entities')
print(f'\nEntities:')
entity_summary = sample_df.groupby(['entity_group', 'entity_id']).agg(
    events=('event_timestamp', 'count'),
    earliest=('event_timestamp', 'min'),
    latest=('event_timestamp', 'max'),
).reset_index()
print(entity_summary.to_string(index=False))
# Out:
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Sample data: 200 events across 10 entities
#
# Entities:
# entity_group entity_id  events                         earliest                           latest
#            D    002525      20 2026-02-10 17:38:13.084697+00:00 2026-05-01 11:51:13.084697+00:00
#            I    003844      20 2026-02-07 03:37:13.084697+00:00 2026-04-30 12:35:13.084697+00:00
#            J    001645      20 2026-02-11 15:36:13.084697+00:00 2026-05-02 19:03:13.084697+00:00
#            J    004866      20 2026-02-18 09:57:13.084697+00:00 2026-05-06 09:45:13.084697+00:00
#            K    002787      20 2026-02-08 11:33:13.084697+00:00 2026-05-01 18:27:13.084697+00:00
#            L    002489      20 2026-02-11 03:11:13.084697+00:00 2026-05-05 09:22:13.084697+00:00
# ...

# %% [markdown]
# ### Write Historical Snapshots with Compound Keys
#
# Each event becomes a separate row in Bigtable. The row key encodes entity identity and a reverse timestamp so newest entries sort first.

# %%
# Maximum timestamp for reverse key computation
MAX_TIMESTAMP = 9999999999999  # 13-digit max (milliseconds)

def make_history_key(entity_group, entity_id, event_timestamp):
    """Build a compound row key with reverse timestamp.
    
    Format: {entity_group}#{entity_id}#{reverse_timestamp}
    Reverse timestamp ensures newest entries sort first.
    """
    if isinstance(event_timestamp, pd.Timestamp):
        ts_millis = int(event_timestamp.timestamp() * 1000)
    else:
        ts_millis = int(event_timestamp * 1000)
    reverse_ts = MAX_TIMESTAMP - ts_millis
    return f'{entity_group}#{entity_id}#{reverse_ts:013d}'


def extract_timestamp_from_key(row_key):
    """Extract the original timestamp from a compound row key."""
    parts = row_key.split('#')
    reverse_ts = int(parts[2])
    ts_millis = MAX_TIMESTAMP - reverse_ts
    return datetime.datetime.fromtimestamp(ts_millis / 1000, tz=datetime.timezone.utc)


# Write sample data to Bigtable
rows_written = 0
rows = []

for _, event in sample_df.iterrows():
    row_key = make_history_key(
        event['entity_group'],
        event['entity_id'],
        event['event_timestamp'],
    )
    
    row = table_history_key.direct_row(row_key)
    
    # Write each feature as a separate column qualifier
    for col in ['feature_1', 'feature_2', 'feature_3']:
        value = event[col]
        if pd.notna(value):
            row.set_cell(
                BT_COLUMN_FAMILY,
                col,
                str(value).encode('utf-8'),
            )
    
    rows.append(row)
    rows_written += 1

# Batch mutate for efficiency
responses = table_history_key.mutate_rows(rows)
errors = [r for r in responses if r.code != 0]

print(f'Wrote {rows_written} rows to {BT_TABLE_HISTORY_KEY}')
if errors:
    print(f'  Errors: {len(errors)}')
else:
    print(f'  All writes successful')

# Show a few example keys
print(f'\nExample row keys:')
for _, event in sample_df.head(3).iterrows():
    key = make_history_key(event['entity_group'], event['entity_id'], event['event_timestamp'])
    print(f'  {key}  →  {event["event_timestamp"]}')
# Out:
# Wrote 200 rows to features-history-key
#   All writes successful
#
# Example row keys:
#   D#002525#8229254906915  →  2026-02-10 17:38:13.084697+00:00
#   D#002525#8229140486915  →  2026-02-12 01:25:13.084697+00:00
#   D#002525#8228920946915  →  2026-02-14 14:24:13.084697+00:00

# %% [markdown]
# ### Range Scan: Read All History for One Entity
#
# Since all rows for an entity share the same prefix (`{entity_group}#{entity_id}#`), a [prefix scan](https://cloud.google.com/bigtable/docs/reads) retrieves the full history. The reverse timestamp ordering means rows come back newest-first.

# %%
# Pick the first entity from our sample
test_entity_group = sample_df.iloc[0]['entity_group']
test_entity_id = sample_df.iloc[0]['entity_id']
prefix = f'{test_entity_group}#{test_entity_id}#'

print(f'Reading all history for entity: {test_entity_group}#{test_entity_id}')
print(f'Row key prefix: {prefix}')
print()

# Prefix scan
row_set = RowSet()
row_set.add_row_range(RowRange(start_key=prefix.encode('utf-8'),
                               end_key=(prefix[:-1] + chr(ord(prefix[-1]) + 1)).encode('utf-8')))

partial_rows = table_history_key.read_rows(
    row_set=row_set,
    filter_=row_filters.CellsColumnLimitFilter(1),
)
partial_rows.consume_all()

print(f'Found {len(partial_rows.rows)} historical snapshots:\n')

history_records = []
for row_key_bytes, row_data in sorted(partial_rows.rows.items()):
    row_key = row_key_bytes.decode('utf-8')
    original_ts = extract_timestamp_from_key(row_key)
    
    record = {'row_key': row_key, 'timestamp': original_ts}
    for col_bytes, cells in row_data.cells.get(BT_COLUMN_FAMILY, {}).items():
        col_name = col_bytes.decode('utf-8')
        record[col_name] = cells[0].value.decode('utf-8')
    history_records.append(record)

history_df = pd.DataFrame(history_records)
print(history_df.to_string(index=False))
# Out:
# Reading all history for entity: D#002525
# Row key prefix: D#002525#
#
# Found 20 historical snapshots:
#
#                row_key                        timestamp feature_1 feature_2 feature_3
# D#002525#8222363726915 2026-05-01 11:51:13.084000+00:00      7.79     44.79    180.92
# D#002525#8223284246915 2026-04-20 20:09:13.084000+00:00     60.77     30.52     80.01
# D#002525#8223462326915 2026-04-18 18:41:13.084000+00:00     30.35     21.65    165.98
# D#002525#8223675746915 2026-04-16 07:24:13.084000+00:00     97.57     38.35       6.0
# D#002525#8224048706915 2026-04-11 23:48:13.084000+00:00     16.61      4.07    178.17
# D#002525#8224059626915 2026-04-11 20:46:13.084000+00:00     77.84     29.63      11.4
# D#002525#8224061186915 2026-04-11 20:20:13.084000+00:00     51.62     27.33     59.23
# D#002525#8224366766915 2026-04-08 07:27:13.084000+00:00      48.1     21.94     21.73
# D#002525#8224536146915 2026-04-06 08:24:13.084000+00:00     48.71     33.77     82.19
# ...

# %% [markdown]
# ### Point-in-Time Read: Features As-Of a Specific Time
#
# To get features as-of time T, we need the **first row** that sorts after the reverse timestamp of T. Since newer timestamps have smaller reverse timestamps (sort earlier), we scan starting from the reverse timestamp of T and take the first result — that's the most recent snapshot at or before time T.

# %%
def read_features_at_time_key_design(table, entity_group, entity_id, as_of_timestamp):
    """Read features as-of a specific time using Design A (history in key).
    
    The reverse timestamp means we need the first row whose reverse_ts
    is >= the reverse of our target time (i.e., original timestamp <= target).
    """
    if isinstance(as_of_timestamp, str):
        as_of_timestamp = pd.Timestamp(as_of_timestamp)
    
    ts_millis = int(as_of_timestamp.timestamp() * 1000)
    reverse_ts = MAX_TIMESTAMP - ts_millis
    
    # Start key: entity prefix + reverse of target time
    start_key = f'{entity_group}#{entity_id}#{reverse_ts:013d}'
    # End key: everything up to next entity
    end_prefix = f'{entity_group}#{entity_id}$'  # '$' > '#' in ASCII
    
    row_set = RowSet()
    row_set.add_row_range(RowRange(
        start_key=start_key.encode('utf-8'),
        end_key=end_prefix.encode('utf-8'),
    ))
    
    partial_rows = table.read_rows(
        row_set=row_set,
        filter_=row_filters.CellsColumnLimitFilter(1),
        limit=1,  # We only need the first (most recent at-or-before T)
    )
    partial_rows.consume_all()
    
    if not partial_rows.rows:
        return None
    
    row_key_bytes = list(partial_rows.rows.keys())[0]
    row_data = partial_rows.rows[row_key_bytes]
    row_key = row_key_bytes.decode('utf-8')
    original_ts = extract_timestamp_from_key(row_key)
    
    features = {'_timestamp': original_ts, '_row_key': row_key}
    for col_bytes, cells in row_data.cells.get(BT_COLUMN_FAMILY, {}).items():
        features[col_bytes.decode('utf-8')] = cells[0].value.decode('utf-8')
    
    return features


# Demonstrate: pick a time between two known events
entity_events = sample_df[
    (sample_df['entity_group'] == test_entity_group) &
    (sample_df['entity_id'] == test_entity_id)
].sort_values('event_timestamp')

if len(entity_events) >= 2:
    # Choose a time between the 2nd and 3rd events
    idx = min(1, len(entity_events) - 2)
    t_before = entity_events.iloc[idx]['event_timestamp']
    t_after = entity_events.iloc[idx + 1]['event_timestamp']
    
    # Query at midpoint
    midpoint = t_before + (t_after - t_before) / 2
    
    print(f'Entity: {test_entity_group}#{test_entity_id}')
    print(f'\nKnown events:')
    print(f'  Event {idx}:   {t_before}')
    print(f'  Midpoint:  {midpoint}  <-- querying at this time')
    print(f'  Event {idx+1}:   {t_after}')
    
    result = read_features_at_time_key_design(
        table_history_key, test_entity_group, test_entity_id, midpoint
    )
    
    if result:
        print(f'\nFeatures as-of {midpoint}:')
        for k, v in result.items():
            print(f'  {k}: {v}')
        print(f'\nCorrectness: returned snapshot from {result["_timestamp"]} (should be <= {midpoint})')
    else:
        print('\nNo features found at that time.')
else:
    print(f'Entity has only {len(entity_events)} events — need at least 2 for demonstration.')
# Out:
# Entity: D#002525
#
# Known events:
#   Event 1:   2026-02-12 01:25:13.084697+00:00
#   Midpoint:  2026-02-13 07:54:43.084697+00:00  <-- querying at this time
#   Event 2:   2026-02-14 14:24:13.084697+00:00
#
# Features as-of 2026-02-13 07:54:43.084697+00:00:
#   _timestamp: 2026-02-12 01:25:13.084000+00:00
#   _row_key: D#002525#8229140486915
#   feature_1: 63.05
#   feature_2: 23.93
#   feature_3: 158.92
#
# Correctness: returned snapshot from 2026-02-12 01:25:13.084000+00:00 (should be <= 2026-02-13 07:54:43.084697+00:00)

# %% [markdown]
# ### Design A: Pros and Cons
#
# | Aspect | Assessment |
# |--------|------------|
# | **Range scans** | Natural — prefix scan retrieves all history for an entity in timestamp order |
# | **Training data extraction** | Efficient — scan all entities in a range and filter by time |
# | **Latest value** | Prefix scan + limit 1 (slightly more expensive than a direct read) |
# | **Garbage collection** | Manual — you must delete old rows yourself or rely on MaxAge GC on the column family |
# | **Hotspotting** | Risk if many entities write at similar times (sequential reverse timestamps) |
# | **Storage** | More rows = more row key overhead |
# | **Serving key compatibility** | Different key format than a simple `entity_id` serving table |

# %% [markdown]
# ---
# ## Section 3: Design Choice B — Cell Versioning
#
# Bigtable natively supports multiple versions of each cell, each tagged with a timestamp. Instead of encoding history in the row key, we store all versions in the same row:
#
# ```
# Row key: {entity_group}#{entity_id}
#
# Cell versions for column "feature_1":
#   2024-06-15 14:00:00  →  42.5
#   2024-06-14 10:30:00  →  38.2
#   2024-06-13 09:15:00  →  35.0
# ```
#
# This is Bigtable's native time-series capability. Each `set_cell()` call can include a `timestamp` parameter, and Bigtable stores the value as a separate version.
#
# ### Create the Table with MaxVersionsGCRule

# %%
# Create a dedicated table for Design B: cell versioning
table_history_cell = instance.table(BT_TABLE_HISTORY_CELL)

if not table_history_cell.exists():
    # Automatic GC: keep at most 10 versions per cell
    max_versions_rule = cf.MaxVersionsGCRule(10)
    table_history_cell.create(column_families={BT_COLUMN_FAMILY: max_versions_rule})
    print(f'Created table: {BT_TABLE_HISTORY_CELL}')
    print(f'  Column family: {BT_COLUMN_FAMILY}')
    print(f'  GC policy: MaxVersions(10)')
else:
    print(f'Table exists: {BT_TABLE_HISTORY_CELL}')
    families = table_history_cell.list_column_families()
    for name, family in families.items():
        print(f'  Family: {name}, GC rule: {family.gc_rule}')
# Out:
# Table exists: features-history-cell
#   Family: features, GC rule: <google.cloud.bigtable.column_family.MaxVersionsGCRule object at 0x7b6d184fcad0>
#   Family: features, GC rule: <google.cloud.bigtable.column_family.MaxVersionsGCRule object at 0x7b6d184fcad0>

# %% [markdown]
# ### Write Historical Snapshots as Cell Versions
#
# Same 10 entities, but now each event is written as a new cell version on the same row key. The `timestamp` parameter in `set_cell()` controls which version is created.

# %%
# Write sample data using cell versioning
rows_written = 0
rows = []

for _, event in sample_df.iterrows():
    # Simple key: entity_group#entity_id (no timestamp)
    row_key = f'{event["entity_group"]}#{event["entity_id"]}'
    
    row = table_history_cell.direct_row(row_key)
    
    # Convert event timestamp to Bigtable timestamp (datetime object)
    event_ts = event['event_timestamp']
    if isinstance(event_ts, pd.Timestamp):
        bt_timestamp = event_ts.to_pydatetime()
    else:
        bt_timestamp = datetime.datetime.fromtimestamp(
            event_ts, tz=datetime.timezone.utc
        )
    
    # Write each feature with the event timestamp as the cell version
    for col in ['feature_1', 'feature_2', 'feature_3']:
        value = event[col]
        if pd.notna(value):
            row.set_cell(
                BT_COLUMN_FAMILY,
                col,
                str(value).encode('utf-8'),
                timestamp=bt_timestamp,
            )
    
    rows.append(row)
    rows_written += 1

# Batch mutate
responses = table_history_cell.mutate_rows(rows)
errors = [r for r in responses if r.code != 0]

print(f'Wrote {rows_written} cell versions to {BT_TABLE_HISTORY_CELL}')
if errors:
    print(f'  Errors: {len(errors)}')
else:
    print(f'  All writes successful')

# Show unique row keys (should be fewer than total writes)
unique_keys = sample_df.apply(
    lambda r: f'{r["entity_group"]}#{r["entity_id"]}', axis=1
).nunique()
print(f'\n  Total writes: {rows_written}')
print(f'  Unique row keys: {unique_keys}')
print(f'  Average versions per row: {rows_written / unique_keys:.1f}')
# Out:
# Wrote 200 cell versions to features-history-cell
#   All writes successful
#
#   Total writes: 200
#   Unique row keys: 10
#   Average versions per row: 20.0

# %% [markdown]
# ### Read Latest: CellsColumnLimitFilter
#
# For serving, you typically want only the latest version of each feature. `CellsColumnLimitFilter(1)` returns just the newest cell version per column.

# %%
# Read only the latest version for our test entity
test_key = f'{test_entity_group}#{test_entity_id}'

row = table_history_cell.read_row(
    test_key.encode('utf-8'),
    filter_=row_filters.CellsColumnLimitFilter(1),
)

if row:
    print(f'Latest features for {test_key}:\n')
    for col_bytes, cells in sorted(row.cells.get(BT_COLUMN_FAMILY, {}).items()):
        col_name = col_bytes.decode('utf-8')
        cell = cells[0]
        print(f'  {col_name}: {cell.value.decode("utf-8")}  (version: {cell.timestamp})')
else:
    print(f'No row found for {test_key}')
# Out:
# Latest features for D#002525:
#
#   feature_1: 7.79  (version: 2026-05-01 11:51:13.084000+00:00)
#   feature_2: 44.79  (version: 2026-05-01 11:51:13.084000+00:00)
#   feature_3: 180.92  (version: 2026-05-01 11:51:13.084000+00:00)

# %% [markdown]
# ### Read at Time T: TimestampRangeFilter
#
# To get features as-of time T, use a [`TimestampRangeFilter`](https://cloud.google.com/bigtable/docs/using-filters) that restricts cell versions to those at or before T. Combined with `CellsColumnLimitFilter(1)`, this returns the most recent version at or before the target time.

# %%
def read_features_at_time_cell_design(table, entity_group, entity_id, as_of_timestamp):
    """Read features as-of a specific time using Design B (cell versioning).
    
    Uses TimestampRangeFilter to restrict to versions <= as_of_timestamp,
    then CellsColumnLimitFilter(1) to get only the most recent such version.
    """
    if isinstance(as_of_timestamp, str):
        as_of_timestamp = pd.Timestamp(as_of_timestamp)
    
    if isinstance(as_of_timestamp, pd.Timestamp):
        as_of_dt = as_of_timestamp.to_pydatetime()
    else:
        as_of_dt = as_of_timestamp
    
    # Chain: timestamp range (end is exclusive) + limit 1 per column
    ts_range = row_filters.TimestampRange(end=as_of_dt)
    time_filter = row_filters.TimestampRangeFilter(ts_range)
    limit_filter = row_filters.CellsColumnLimitFilter(1)
    chained = row_filters.RowFilterChain(filters=[time_filter, limit_filter])
    
    row_key = f'{entity_group}#{entity_id}'
    row = table.read_row(row_key.encode('utf-8'), filter_=chained)
    
    if not row:
        return None
    
    features = {}
    for col_bytes, cells in row.cells.get(BT_COLUMN_FAMILY, {}).items():
        col_name = col_bytes.decode('utf-8')
        cell = cells[0]
        features[col_name] = cell.value.decode('utf-8')
        features[f'{col_name}_timestamp'] = cell.timestamp
    
    return features


# Demonstrate: same midpoint query as Design A
if len(entity_events) >= 2:
    idx = min(1, len(entity_events) - 2)
    t_before = entity_events.iloc[idx]['event_timestamp']
    t_after = entity_events.iloc[idx + 1]['event_timestamp']
    midpoint = t_before + (t_after - t_before) / 2
    
    print(f'Entity: {test_entity_group}#{test_entity_id}')
    print(f'Querying as-of: {midpoint}')
    print()
    
    result = read_features_at_time_cell_design(
        table_history_cell, test_entity_group, test_entity_id, midpoint
    )
    
    if result:
        print(f'Features as-of {midpoint}:')
        for k, v in result.items():
            if not k.endswith('_timestamp'):
                ts_key = f'{k}_timestamp'
                ts_val = result.get(ts_key, 'N/A')
                print(f'  {k}: {v}  (version: {ts_val})')
    else:
        print('No features found at that time.')
# Out:
# Entity: D#002525
# Querying as-of: 2026-02-13 07:54:43.084697+00:00
#
# Features as-of 2026-02-13 07:54:43.084697+00:00:
#   feature_1: 63.05  (version: 2026-02-12 01:25:13.084000+00:00)
#   feature_2: 23.93  (version: 2026-02-12 01:25:13.084000+00:00)
#   feature_3: 158.92  (version: 2026-02-12 01:25:13.084000+00:00)

# %% [markdown]
# ### Read All Versions
#
# To see the full history stored in a row, read without the column limit filter (or use `CellsColumnLimitFilter(N)` for the N most recent).

# %%
# Read all versions for one entity
test_key = f'{test_entity_group}#{test_entity_id}'

# No CellsColumnLimitFilter — get all versions
row = table_history_cell.read_row(test_key.encode('utf-8'))

if row:
    print(f'All cell versions for {test_key}:\n')
    for col_bytes, cells in sorted(row.cells.get(BT_COLUMN_FAMILY, {}).items()):
        col_name = col_bytes.decode('utf-8')
        print(f'  {col_name} ({len(cells)} versions):')
        for cell in cells:
            print(f'    {cell.timestamp}  →  {cell.value.decode("utf-8")}')
        print()
else:
    print(f'No row found for {test_key}')
# Out:
# All cell versions for D#002525:
#
#   feature_1 (20 versions):
#     2026-05-01 11:51:13.084000+00:00  →  7.79
#     2026-04-20 20:09:13.084000+00:00  →  60.77
#     2026-04-18 18:41:13.084000+00:00  →  30.35
#     2026-04-16 07:24:13.084000+00:00  →  97.57
#     2026-04-11 23:48:13.084000+00:00  →  16.61
#     2026-04-11 20:46:13.084000+00:00  →  77.84
#     2026-04-11 20:20:13.084000+00:00  →  51.62
#     2026-04-08 07:27:13.084000+00:00  →  48.1
#     2026-04-06 08:24:13.084000+00:00  →  48.71
#     2026-03-31 03:37:13.084000+00:00  →  6.93
#     2026-03-28 15:11:13.084000+00:00  →  55.79
#     2026-03-22 10:47:13.084000+00:00  →  20.83
#     2026-03-21 14:38:13.084000+00:00  →  55.25
#     2026-03-17 12:20:13.084000+00:00  →  13.59
#     2026-02-21 18:37:13.084000+00:00  →  18.49
#     2026-02-16 15:53:13.084000+00:00  →  49.44
#     2026-02-15 20:57:13.084000+00:00  →  44.45
#     2026-02-14 14:24:13.084000+00:00  →  59.49
#     2026-02-12 01:25:13.084000+00:00  →  63.05
# ...

# %% [markdown]
# ### Design B: Pros and Cons
#
# | Aspect | Assessment |
# |--------|------------|
# | **Serving key** | Same key format as a serving-only table — no key translation needed |
# | **Latest read** | `CellsColumnLimitFilter(1)` — fast, simple |
# | **Automatic GC** | `MaxVersionsGCRule` handles cleanup automatically |
# | **Fewer rows** | All history for an entity lives in one row |
# | **Historical read** | Requires filters (`TimestampRangeFilter`) — slightly more complex |
# | **Row size** | Many versions = larger rows; can hit row size limits for very high-frequency entities |
# | **Range scans** | Cannot scan across entities by time range without reading all rows |

# %% [markdown]
# ---
# ## Section 4: Point-in-Time Joins with Bigtable Filters
#
# The training data use case: given a list of (entity, timestamp) pairs from your label table, retrieve the feature values that were known at each timestamp. This is the **point-in-time join** — the fundamental operation for building training datasets from a feature store.
#
# We'll implement this for both designs and compare with BigQuery's `ML.FEATURES_AT_TIME`.

# %%
# Build a list of (entity, timestamp) pairs to look up
# Use actual event timestamps shifted slightly forward to simulate
# "what were the features just before this event?"

pit_queries = []
for _, event in sample_df.iterrows():
    # Shift timestamp forward by 1 second to get features "just before" this event
    query_ts = event['event_timestamp'] + pd.Timedelta(seconds=1)
    pit_queries.append({
        'entity_group': event['entity_group'],
        'entity_id': event['entity_id'],
        'query_timestamp': query_ts,
    })

pit_df = pd.DataFrame(pit_queries)
print(f'Point-in-time queries: {len(pit_df)} lookups')
print(pit_df.head(10).to_string(index=False))
# Out:
# Point-in-time queries: 200 lookups
# entity_group entity_id                  query_timestamp
#            D    002525 2026-02-10 17:38:14.084697+00:00
#            D    002525 2026-02-12 01:25:14.084697+00:00
#            D    002525 2026-02-14 14:24:14.084697+00:00
#            D    002525 2026-02-15 20:57:14.084697+00:00
#            D    002525 2026-02-16 15:53:14.084697+00:00
#            D    002525 2026-02-21 18:37:14.084697+00:00
#            D    002525 2026-03-17 12:20:14.084697+00:00
#            D    002525 2026-03-21 14:38:14.084697+00:00
#            D    002525 2026-03-22 10:47:14.084697+00:00
#            D    002525 2026-03-28 15:11:14.084697+00:00

# %% [markdown]
# ### Design A: PIT Join Using RowRange

# %%
# Point-in-time join using Design A (history in key)
start_time = time.perf_counter()

design_a_results = []
for _, query in pit_df.iterrows():
    result = read_features_at_time_key_design(
        table_history_key,
        query['entity_group'],
        query['entity_id'],
        query['query_timestamp'],
    )
    if result:
        result['entity_group'] = query['entity_group']
        result['entity_id'] = query['entity_id']
        result['query_timestamp'] = query['query_timestamp']
        design_a_results.append(result)

design_a_time = time.perf_counter() - start_time

print(f'Design A (history in key): {len(design_a_results)} results in {design_a_time:.3f}s')
print(f'  Avg per lookup: {design_a_time / len(pit_df) * 1000:.1f}ms')

if design_a_results:
    result_df_a = pd.DataFrame(design_a_results)
    display_cols = [c for c in result_df_a.columns if c in 
                    ['entity_group', 'entity_id', 'query_timestamp', '_timestamp',
                     'feature_1', 'feature_2', 'feature_3']]
    print(f'\nSample results:')
    print(result_df_a[display_cols].head(5).to_string(index=False))
# Out:
# Design A (history in key): 200 results in 1.040s
#   Avg per lookup: 5.2ms
#
# Sample results:
#                       _timestamp feature_1 feature_2 feature_3 entity_group entity_id                  query_timestamp
# 2026-02-10 17:38:13.084000+00:00     64.12     31.64    145.38            D    002525 2026-02-10 17:38:14.084697+00:00
# 2026-02-12 01:25:13.084000+00:00     63.05     23.93    158.92            D    002525 2026-02-12 01:25:14.084697+00:00
# 2026-02-14 14:24:13.084000+00:00     59.49     29.33     55.43            D    002525 2026-02-14 14:24:14.084697+00:00
# 2026-02-15 20:57:13.084000+00:00     44.45     45.08    139.02            D    002525 2026-02-15 20:57:14.084697+00:00
# 2026-02-16 15:53:13.084000+00:00     49.44      24.6      15.1            D    002525 2026-02-16 15:53:14.084697+00:00

# %% [markdown]
# ### Design B: PIT Join Using TimestampRangeFilter

# %%
# Point-in-time join using Design B (cell versioning)
start_time = time.perf_counter()

design_b_results = []
for _, query in pit_df.iterrows():
    result = read_features_at_time_cell_design(
        table_history_cell,
        query['entity_group'],
        query['entity_id'],
        query['query_timestamp'],
    )
    if result:
        result['entity_group'] = query['entity_group']
        result['entity_id'] = query['entity_id']
        result['query_timestamp'] = query['query_timestamp']
        design_b_results.append(result)

design_b_time = time.perf_counter() - start_time

print(f'Design B (cell versioning): {len(design_b_results)} results in {design_b_time:.3f}s')
print(f'  Avg per lookup: {design_b_time / len(pit_df) * 1000:.1f}ms')

if design_b_results:
    result_df_b = pd.DataFrame(design_b_results)
    feature_cols = [c for c in result_df_b.columns if c in 
                    ['entity_group', 'entity_id', 'query_timestamp',
                     'feature_1', 'feature_2', 'feature_3']]
    print(f'\nSample results:')
    print(result_df_b[feature_cols].head(5).to_string(index=False))
# Out:
# Design B (cell versioning): 200 results in 1.079s
#   Avg per lookup: 5.4ms
#
# Sample results:
# feature_1 feature_2 feature_3 entity_group entity_id                  query_timestamp
#     64.12     31.64    145.38            D    002525 2026-02-10 17:38:14.084697+00:00
#     63.05     23.93    158.92            D    002525 2026-02-12 01:25:14.084697+00:00
#     59.49     29.33     55.43            D    002525 2026-02-14 14:24:14.084697+00:00
#     44.45     45.08    139.02            D    002525 2026-02-15 20:57:14.084697+00:00
#     49.44      24.6      15.1            D    002525 2026-02-16 15:53:14.084697+00:00

# %% [markdown]
# ### Compare with BigQuery: ML.FEATURES_AT_TIME
#
# BigQuery provides [`ML.FEATURES_AT_TIME`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-feature-time) for point-in-time feature retrieval directly in SQL. This is the batch analytics approach — no Bigtable needed, but with higher latency.

# %%
# Pick one entity and timestamp for demonstration
demo_entity = pit_df.iloc[0]
demo_ts = demo_entity['query_timestamp'].strftime('%Y-%m-%d %H:%M:%S UTC')
demo_group = demo_entity['entity_group']
demo_id = demo_entity['entity_id']

print(f'ML.FEATURES_AT_TIME query for entity {demo_group}/{demo_id} at {demo_ts}\n')

bq_pit_sql = f"""
SELECT * FROM ML.FEATURES_AT_TIME(
    TABLE `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`,
    time => '{demo_ts}',
    num_rows => 1,
    ignore_feature_nulls => TRUE
)
WHERE entity_group = '{demo_group}' AND entity_id = '{demo_id}'
"""

start_time = time.perf_counter()
try:
    bq_result = bq.query(bq_pit_sql).to_dataframe()
    bq_pit_time = time.perf_counter() - start_time
    
    print(f'BQ result ({bq_pit_time:.2f}s):')
    print(bq_result.to_string(index=False))
except Exception as e:
    bq_pit_time = time.perf_counter() - start_time
    print(f'BQ query failed ({bq_pit_time:.2f}s): {e}')
    print('\nNote: ML.FEATURES_AT_TIME requires the source table to have')
    print('appropriate columns (entity key + feature columns + timestamp).')
    print('If sparse_events uses a different schema, the query needs adjustment.')
# Out:
# ML.FEATURES_AT_TIME query for entity D/002525 at 2026-02-10 17:38:14 UTC
#
# BQ query failed (0.33s): 400 Invalid table-valued function ML.FEATURES_AT_TIME
# feature_table must include a 'feature_timestamp' column. at [2:15]; reason: invalidQuery, location: query, message: Invalid table-valued function ML.FEATURES_AT_TIME
# feature_table must include a 'feature_timestamp' column. at [2:15]
#
# Location: US
# Job ID: a90b60a8-14f1-4735-8485-9c2fb9a9a739
#
#
# Note: ML.FEATURES_AT_TIME requires the source table to have
# appropriate columns (entity key + feature columns + timestamp).
# If sparse_events uses a different schema, the query needs adjustment.

# %% [markdown]
# ### When to Use Which
#
# | Scenario | Best Approach | Why |
# |----------|--------------|-----|
# | **Large-batch training extraction** | BigQuery (`ML.FEATURES_AT_TIME`) | Scans entire tables efficiently; no per-entity round trips |
# | **Individual serving lookup** | Bigtable (Design B) | Sub-10ms point reads; same key as serving |
# | **Historical audit** | Bigtable (Design A) | Range scan retrieves full entity timeline |
# | **Backfill/reprocessing** | BigQuery | SQL handles complex joins and aggregations |
# | **Real-time PIT at serving** | Bigtable (either) | Millisecond latency, no query scheduling overhead |

# %% [markdown]
# ---
# ## Section 5: Training Data Extraction Patterns
#
# Building a training dataset requires point-in-time features for every labeled example. There are two patterns depending on the scale and latency requirements.
#
# ### Pattern 1: BigQuery Bulk Extraction
#
# Use BigQuery's [`ML.ENTITY_FEATURES_AT_TIME`](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-entity-feature-time) when you have a large entity-time table (your label table) and want features for all of them at once. BigQuery handles the PIT join internally.

# %%
# Pattern 1: BQ bulk extraction using ML.ENTITY_FEATURES_AT_TIME
# First, create a temporary entity-time table from our sample

# Build the entity-time pairs as a query
entity_time_sql = f"""
WITH entity_times AS (
    SELECT
        entity_group,
        entity_id,
        event_timestamp AS feature_timestamp
    FROM `{DATASET_REF}.sparse_events`
    WHERE entity_group = '{demo_group}'
    ORDER BY event_timestamp
    LIMIT 20
)
SELECT
    entity_group,
    entity_id,
    feature_timestamp
FROM entity_times
"""

print('Pattern 1: BigQuery ML.ENTITY_FEATURES_AT_TIME')
print('This joins a feature table with an entity-time table to get PIT features.\n')

# Show the SQL pattern (may need schema adjustment for the actual table)
bulk_sql = f"""
SELECT * FROM ML.ENTITY_FEATURES_AT_TIME(
    TABLE `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`,
    ({entity_time_sql}),
    num_rows => 1,
    ignore_feature_nulls => TRUE
)
"""

start_time = time.perf_counter()
try:
    bulk_result = bq.query(bulk_sql).to_dataframe()
    bulk_time = time.perf_counter() - start_time
    print(f'Bulk extraction: {len(bulk_result)} rows in {bulk_time:.2f}s')
    print(f'\nSample:')
    print(bulk_result.head(5).to_string(index=False))
except Exception as e:
    bulk_time = time.perf_counter() - start_time
    print(f'Bulk query result ({bulk_time:.2f}s): {e}')
    print('\nNote: ML.ENTITY_FEATURES_AT_TIME requires specific column naming.')
    print('The entity-time subquery must produce columns matching the feature table keys.')
    print('Adjust column names if the sparse_events schema differs.')
# Out:
# Pattern 1: BigQuery ML.ENTITY_FEATURES_AT_TIME
# This joins a feature table with an entity-time table to get PIT features.
#
# Bulk query result (0.30s): 400 Invalid table-valued function ML.ENTITY_FEATURES_AT_TIME
# feature_table must include a 'feature_timestamp' column. at [2:15]; reason: invalidQuery, location: query, message: Invalid table-valued function ML.ENTITY_FEATURES_AT_TIME
# feature_table must include a 'feature_timestamp' column. at [2:15]
#
# Location: US
# Job ID: 6fcebfb5-6149-4a58-abdf-12f5b0b72ed5
#
#
# Note: ML.ENTITY_FEATURES_AT_TIME requires specific column naming.
# The entity-time subquery must produce columns matching the feature table keys.
# Adjust column names if the sparse_events schema differs.

# %% [markdown]
# ### Pattern 2: Bigtable Selective Extraction
#
# When you need features for specific entities at specific times — especially during online inference or when BQ is too slow for interactive use — use Bigtable directly.

# %%
# Pattern 2: Bigtable selective extraction
# Useful when you need specific entities at specific times

# Build a list of lookups (simulating a label table)
lookup_requests = pit_df.head(10).to_dict('records')

print('Pattern 2: Bigtable selective extraction')
print(f'Looking up {len(lookup_requests)} entity-time pairs\n')

# Use Design B (cell versioning) for selective lookups
start_time = time.perf_counter()
selective_results = []

for req in lookup_requests:
    features = read_features_at_time_cell_design(
        table_history_cell,
        req['entity_group'],
        req['entity_id'],
        req['query_timestamp'],
    )
    if features:
        features['entity_key'] = f"{req['entity_group']}#{req['entity_id']}"
        features['query_ts'] = req['query_timestamp']
        selective_results.append(features)

selective_time = time.perf_counter() - start_time

print(f'Retrieved {len(selective_results)} results in {selective_time:.3f}s')
print(f'  Avg: {selective_time / len(lookup_requests) * 1000:.1f}ms per lookup')

if selective_results:
    sel_df = pd.DataFrame(selective_results)
    show_cols = [c for c in sel_df.columns if c in 
                 ['entity_key', 'query_ts', 'feature_1', 'feature_2', 'feature_3']]
    print(f'\nResults:')
    print(sel_df[show_cols].to_string(index=False))
# Out:
# Pattern 2: Bigtable selective extraction
# Looking up 10 entity-time pairs
#
# Retrieved 10 results in 0.053s
#   Avg: 5.3ms per lookup
#
# Results:
# feature_1 feature_2 feature_3 entity_key                         query_ts
#     64.12     31.64    145.38   D#002525 2026-02-10 17:38:14.084697+00:00
#     63.05     23.93    158.92   D#002525 2026-02-12 01:25:14.084697+00:00
#     59.49     29.33     55.43   D#002525 2026-02-14 14:24:14.084697+00:00
#     44.45     45.08    139.02   D#002525 2026-02-15 20:57:14.084697+00:00
#     49.44      24.6      15.1   D#002525 2026-02-16 15:53:14.084697+00:00
#     18.49     16.86     71.98   D#002525 2026-02-21 18:37:14.084697+00:00
#     13.59      0.35     12.79   D#002525 2026-03-17 12:20:14.084697+00:00
#     55.25     13.94     31.02   D#002525 2026-03-21 14:38:14.084697+00:00
#     20.83     47.35     77.08   D#002525 2026-03-22 10:47:14.084697+00:00
#     55.79     31.57    127.43   D#002525 2026-03-28 15:11:14.084697+00:00

# %% [markdown]
# ### Choosing Between Patterns
#
# | Factor | Pattern 1 (BigQuery) | Pattern 2 (Bigtable) |
# |--------|---------------------|---------------------|
# | **Scale** | Millions of entity-time pairs | Hundreds to thousands |
# | **Latency** | Seconds to minutes | Milliseconds per lookup |
# | **Cost** | BQ query cost (bytes scanned) | Bigtable read ops |
# | **Complexity** | Single SQL statement | Loop with client calls |
# | **When to use** | Batch training pipeline | Online inference, interactive debugging |

# %% [markdown]
# ---
# ## Section 6: Garbage Collection Policies
#
# Bigtable's [garbage collection rules](https://cloud.google.com/bigtable/docs/garbage-collection) automatically delete old cell versions. This is how you control the size of your feature history without manual cleanup.
#
# ### Available GC Rules
#
# | Rule | What It Does | Example |
# |------|-------------|--------|
# | `MaxVersionsGCRule(N)` | Keep the N most recent versions | `MaxVersionsGCRule(10)` — keep last 10 snapshots |
# | `MaxAgeGCRule(duration)` | Delete versions older than duration | `MaxAgeGCRule(days=90)` — 90-day retention |
# | `GCRuleUnion([rules])` | Delete if **any** rule matches (OR) | Delete if older than 90 days OR more than 10 versions |
# | `GCRuleIntersection([rules])` | Delete if **all** rules match (AND) | Delete if older than 90 days AND more than 10 versions |

# %%
# Demonstrate creating tables with different GC policies

gc_examples = {
    'gc-demo-max-versions': cf.MaxVersionsGCRule(5),
    'gc-demo-max-age': cf.MaxAgeGCRule(datetime.timedelta(days=90)),
    'gc-demo-union': cf.GCRuleUnion([
        cf.MaxVersionsGCRule(10),
        cf.MaxAgeGCRule(datetime.timedelta(days=90)),
    ]),
    'gc-demo-intersection': cf.GCRuleIntersection([
        cf.MaxVersionsGCRule(10),
        cf.MaxAgeGCRule(datetime.timedelta(days=90)),
    ]),
}

print('GC Policy Examples:\n')

for table_name, gc_rule in gc_examples.items():
    demo_table = instance.table(table_name)
    
    if not demo_table.exists():
        demo_table.create(column_families={BT_COLUMN_FAMILY: gc_rule})
        print(f'  Created: {table_name}')
    else:
        print(f'  Exists:  {table_name}')
    
    families = demo_table.list_column_families()
    for fam_name, fam in families.items():
        print(f'    Family "{fam_name}": {fam.gc_rule}')
    print()
# Out:
# GC Policy Examples:
#
#   Created: gc-demo-max-versions
#     Family "features": <google.cloud.bigtable.column_family.MaxVersionsGCRule object at 0x7b6d18555810>
#
#   Created: gc-demo-max-age
#     Family "features": <google.cloud.bigtable.column_family.MaxAgeGCRule object at 0x7b6d18556060>
#
#   Created: gc-demo-union
#     Family "features": <google.cloud.bigtable.column_family.GCRuleUnion object at 0x7b6d1b68b890>
#
#   Created: gc-demo-intersection
#     Family "features": <google.cloud.bigtable.column_family.GCRuleIntersection object at 0x7b6d1b68b610>

# %% [markdown]
# ### How GC Affects Historical Reads
#
# GC policies directly impact what historical data is available:
#
# - **MaxVersions(5):** Only the 5 most recent feature snapshots per entity are kept. Older snapshots are silently deleted during compaction. If you need features from 6 snapshots ago, they're gone.
#
# - **MaxAge(90 days):** Any version older than 90 days is eligible for deletion. Training data extraction that needs features from 6 months ago will find empty cells.
#
# - **Union (OR):** Aggressive cleanup — a version is deleted if it violates *either* rule. Keeps storage tight but limits historical depth.
#
# - **Intersection (AND):** Conservative cleanup — a version is only deleted if it violates *both* rules. Keeps more history but uses more storage.
#
# **Choosing a policy:**
#
# | Use Case | Recommended Policy |
# |----------|-------------------|
# | Serving only (latest features) | `MaxVersionsGCRule(1)` |
# | Short-term history (debugging, audit) | `MaxVersionsGCRule(10)` |
# | Time-bounded retention (compliance) | `MaxAgeGCRule(days=N)` |
# | Training data extraction | Intersection (keep history until both limits exceeded) |
# | Cost-sensitive | Union (aggressive cleanup) |

# %%
# Demonstrate how MaxVersions affects reads
# Write 8 versions to a table with MaxVersions(5)

demo_table = instance.table('gc-demo-max-versions')
demo_key = 'gc-test-entity'

# Write 8 versions with different timestamps
base_time = datetime.datetime(2024, 6, 1, 12, 0, 0, tzinfo=datetime.timezone.utc)

for i in range(8):
    ts = base_time + datetime.timedelta(hours=i)
    row = demo_table.direct_row(demo_key)
    row.set_cell(
        BT_COLUMN_FAMILY,
        'value',
        f'version_{i}'.encode('utf-8'),
        timestamp=ts,
    )
    row.commit()

print(f'Wrote 8 versions to gc-demo-max-versions (MaxVersions=5)')
print(f'  Versions written: version_0 through version_7')

# Read back — should only get 5 most recent (version_3 through version_7)
# Note: GC is asynchronous, so all 8 may still be visible immediately
row = demo_table.read_row(demo_key.encode('utf-8'))

if row:
    cells = row.cells.get(BT_COLUMN_FAMILY, {}).get(b'value', [])
    print(f'\nVersions readable: {len(cells)}')
    print(f'  (GC is asynchronous — old versions are deleted during compaction)')
    for cell in cells:
        print(f'    {cell.timestamp}  →  {cell.value.decode("utf-8")}')
else:
    print('Row not found.')
# Out:
# Wrote 8 versions to gc-demo-max-versions (MaxVersions=5)
#   Versions written: version_0 through version_7
#
# Versions readable: 8
#   (GC is asynchronous — old versions are deleted during compaction)
#     2024-06-01 19:00:00+00:00  →  version_7
#     2024-06-01 18:00:00+00:00  →  version_6
#     2024-06-01 17:00:00+00:00  →  version_5
#     2024-06-01 16:00:00+00:00  →  version_4
#     2024-06-01 15:00:00+00:00  →  version_3
#     2024-06-01 14:00:00+00:00  →  version_2
#     2024-06-01 13:00:00+00:00  →  version_1
#     2024-06-01 12:00:00+00:00  →  version_0

# %% [markdown]
# **Note on GC timing:** Bigtable garbage collection is asynchronous. When you write a 6th version to a MaxVersions(5) table, all 6 versions may be visible for a short time until compaction runs. Don't rely on GC for security-critical data deletion — it's a storage optimization, not a real-time constraint.

# %% [markdown]
# ### TTL and Feature Freshness
#
# GC policies control **storage** — they delete old cell versions automatically. But there's a complementary concern at the **application level**: is a feature value still *fresh enough* to use for serving?
#
# Two approaches:
#
# | Approach | Level | Mechanism |
# |----------|-------|-----------|
# | **`MaxAgeGCRule`** | Bigtable | Automatically deletes cells older than a duration. Coarse — applies to the entire column family. |
# | **`_last_updated` field** | Application | Store a timestamp in each row's payload. The serving endpoint checks `now - _last_updated > threshold` and returns a stale-data response or default values. Per-row granularity. |
#
# `MaxAgeGCRule` handles the storage side: old data is eventually cleaned up. But it doesn't tell the serving layer whether features are fresh *enough* — a row might be 23 hours old (within GC retention) but too stale for a real-time fraud model that needs features updated within the last hour.
#
# The application-level approach fills this gap. See [Notebook 8: Serving Integration](./Bigtable%20Feature%20Store%20-%20Serving%20Integration.ipynb) (Section 5: Production Patterns) for a freshness-aware serving endpoint pattern.

# %%
# Application-level feature freshness check
# Write two demo rows: one fresh, one stale

FRESHNESS_THRESHOLD = datetime.timedelta(hours=24)

# Fresh row: updated just now
fresh_ts = datetime.datetime.now(datetime.timezone.utc)
fresh_row = table_history_cell.direct_row('ttl_demo_fresh')
fresh_row.set_cell(
    BT_COLUMN_FAMILY, 'feature_1', b'42.5',
    timestamp=fresh_ts,
)
fresh_row.set_cell(
    BT_COLUMN_FAMILY, '_last_updated',
    str(time.time()).encode('utf-8'),
    timestamp=fresh_ts,
)
fresh_row.commit()

# Stale row: updated 7 days ago
stale_time = time.time() - (7 * 86400)
stale_ts = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=7)
stale_row = table_history_cell.direct_row('ttl_demo_stale')
stale_row.set_cell(
    BT_COLUMN_FAMILY, 'feature_1', b'38.2',
    timestamp=stale_ts,
)
stale_row.set_cell(
    BT_COLUMN_FAMILY, '_last_updated',
    str(stale_time).encode('utf-8'),
    timestamp=stale_ts,
)
stale_row.commit()

# Check freshness for both
print(f'Freshness threshold: {FRESHNESS_THRESHOLD}\n')

for demo_key in ['ttl_demo_fresh', 'ttl_demo_stale']:
    row = table_history_cell.read_row(
        demo_key.encode('utf-8'),
        filter_=row_filters.CellsColumnLimitFilter(1),
    )
    if row:
        cells = row.cells.get(BT_COLUMN_FAMILY, {})
        last_updated = float(cells[b'_last_updated'][0].value.decode('utf-8'))
        age = datetime.timedelta(seconds=time.time() - last_updated)
        is_fresh = age < FRESHNESS_THRESHOLD

        feature_val = cells[b'feature_1'][0].value.decode('utf-8')
        status = 'FRESH' if is_fresh else 'STALE'
        print(f'{demo_key}:')
        print(f'  feature_1:    {feature_val}')
        print(f'  age:          {age}')
        print(f'  threshold:    {FRESHNESS_THRESHOLD}')
        print(f'  status:       {status}')
        print()

print('A serving endpoint would return predictions for FRESH rows')
print('and return an error or default values for STALE rows.')
# Out:
# Freshness threshold: 1 day, 0:00:00
#
# ttl_demo_fresh:
#   feature_1:    42.5
#   age:          0:00:00.018151
#   threshold:    1 day, 0:00:00
#   status:       FRESH
#
# ttl_demo_stale:
#   feature_1:    38.2
#   age:          7 days, 0:00:00.017739
#   threshold:    1 day, 0:00:00
#   status:       STALE
#
# A serving endpoint would return predictions for FRESH rows
# and return an error or default values for STALE rows.

# %% [markdown]
# ### Feature Freshness Patterns
#
# | Pattern | Mechanism | Granularity | Use case |
# |---------|-----------|-------------|----------|
# | `MaxAgeGCRule` | Bigtable GC | Column family | Automatic historical data expiry — old versions deleted during compaction |
# | `_last_updated` field | Application | Per row | Serve-time freshness gating — reject or flag stale features before prediction |
# | `_expires_at` field | Application | Per row | Hard expiry with a specific deadline — useful for features with known validity windows |
#
# The first pattern is a storage optimization; the second two are serving-time decisions. In production, you typically use both: `MaxAgeGCRule` to bound storage costs and `_last_updated` to gate serving quality.

# %% [markdown]
# ---
# ## Section 7: Trade-off Summary
#
# | Aspect | Design A: History in Key | Design B: Cell Versioning |
# |--------|------------------------|---------------------------|
# | **Row key** | `entity_group#entity_id#reverse_timestamp` | `entity_group#entity_id` |
# | **Latest read** | Prefix scan + limit 1 | `CellsColumnLimitFilter(1)` |
# | **Historical read** | `RowRange` scan | `TimestampRangeFilter` |
# | **GC** | Manual delete or MaxAge on column family | Automatic (`MaxVersionsGCRule` / `MaxAgeGCRule`) |
# | **Storage** | More rows (each snapshot = separate row) | More versions per row (compact) |
# | **Serving key compatibility** | Different key format than serving table | Same key — no translation needed |
# | **Training data extraction** | Natural range scans across entities | Filter-based per-entity lookups |
# | **Hotspotting risk** | Higher (sequential reverse timestamps) | Lower (writes spread by entity key) |
# | **Row size limits** | N/A (one snapshot per row) | Risk with high-frequency entities |
# | **TTL/Freshness** | MaxAge GC on column family + app-level `_last_updated` | MaxAge GC on column family + app-level `_last_updated` |
#
# ### Recommendations
#
# - **Use Design B (cell versioning)** as the default. It's simpler, uses the same key as serving, and automatic GC reduces operational burden. Most feature stores benefit from this approach.
#
# - **Use Design A (history in key)** when you need efficient range scans across time — for example, if you frequently extract "all feature snapshots for entity X between date A and date B" for training pipelines, or if individual snapshots are large (avoiding wide rows).
#
# - **Use BigQuery** for large-scale training data extraction. Bigtable excels at individual lookups; BigQuery excels at analytical joins across millions of rows. The right architecture uses both: BQ for batch training, Bigtable for online serving.
#
# ### Related Notebooks
#
# - [**NB7: Schema Evolution and Operations**](./Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb) — schema versioning, deprecation patterns, and backfilling strategies that interact with historical data retention

# %% [markdown]
# ---
# ## Cleanup
#
# Delete the demo tables created in this notebook. The main feature store tables are preserved for other notebooks in the series.

# %%
# Clean up GC demo tables
gc_demo_tables = [
    'gc-demo-max-versions',
    'gc-demo-max-age',
    'gc-demo-union',
    'gc-demo-intersection',
]

print('Cleaning up demo tables...')
for table_name in gc_demo_tables:
    demo_table = instance.table(table_name)
    if demo_table.exists():
        demo_table.delete()
        print(f'  Deleted: {table_name}')
    else:
        print(f'  Not found: {table_name}')

# Clean up TTL demo rows from the cell-versioning table
ttl_demo_keys = ['ttl_demo_fresh', 'ttl_demo_stale']
print('\nCleaning up TTL demo rows...')
for key in ttl_demo_keys:
    row = table_history_cell.direct_row(key)
    row.delete()
    row.commit()
    print(f'  Deleted: {key}')

# Keep history tables for potential use by later notebooks
print(f'\nPreserved:')
print(f'  {BT_TABLE_HISTORY_KEY} (Design A)')
print(f'  {BT_TABLE_HISTORY_CELL} (Design B)')
print('\nCleanup complete.')
# Out:
# Cleaning up demo tables...
#   Deleted: gc-demo-max-versions
#   Deleted: gc-demo-max-age
#   Deleted: gc-demo-union
#   Deleted: gc-demo-intersection
#
# Cleaning up TTL demo rows...
#   Deleted: ttl_demo_fresh
#   Deleted: ttl_demo_stale
#
# Preserved:
#   features-history-key (Design A)
#   features-history-cell (Design B)
#
# Cleanup complete.

# %% [markdown]
# ### Cleanup Reminder
#
# When you are done with the Bigtable Feature Store series, return to [Notebook 0: Environment](./Bigtable%20Feature%20Store%20-%20Environment.ipynb) and follow the **Cleanup** section to delete the Bigtable instance, BigQuery dataset, and any other billable resources.
