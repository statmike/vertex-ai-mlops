# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2FFeature+Store%2FBigtable&file=Bigtable+Feature+Store+-+Environment.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2FFeature%2520Store%2FBigtable%2FBigtable%2520Feature%2520Store%2520-%2520Environment.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Environment.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Environment.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Environment.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Feature%2520Store/Bigtable/Bigtable%2520Feature%2520Store%2520-%2520Environment.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Feature%20Store/Bigtable/Bigtable%20Feature%20Store%20-%20Environment.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Bigtable Feature Store — Environment
#
# This notebook creates the shared environment for the Bigtable Feature Store series. It generates synthetic data in [BigQuery](https://cloud.google.com/bigquery/docs/reference/standard-sql/data-types) with full data type coverage and creates a [Cloud Bigtable](https://cloud.google.com/bigtable/docs/overview) instance for online serving.
#
# **What this notebook creates:**
# - BigQuery dataset with two tables:
#   - **Dense table** (~130,000 rows) — 1 row per entity, 200+ features covering every BQ data type
#   - **Sparse table** (~2.6M rows) — multiple rows per entity with timestamps for time-series features
# - Cloud Bigtable development instance with a feature table
#
# **Compound entity key:** All data uses a two-part key (`entity_group` + `entity_id`) designed for the Bigtable [row key](https://cloud.google.com/bigtable/docs/schema-design) `{entity_group}#{entity_id}`.

# %% [markdown]
# ---
# ## Configuration
#
# Set project parameters. All notebooks in this series share these values.

# %%
PROJECT_ID = 'statmike-mlops-349915'
REGION = 'us-central1'
ZONE = 'us-central1-a'

SERIES = 'bigtable-feature-store'

# BigQuery
BQ_PROJECT = PROJECT_ID
BQ_DATASET = 'bigtable_feature_store'

# Bigtable
BT_INSTANCE = 'feature-store'
BT_TABLE = 'features'
BT_COLUMN_FAMILY = 'features'

print(f'Project:    {PROJECT_ID}')
print(f'Region:     {REGION}')
print(f'Zone:       {ZONE}')
print(f'BQ Dataset: {BQ_PROJECT}.{BQ_DATASET}')
print(f'Bigtable:   {BT_INSTANCE} / {BT_TABLE}')
# Out:
# Project:    statmike-mlops-349915
# Region:     us-central1
# Zone:       us-central1-a
# BQ Dataset: statmike-mlops-349915.bigtable_feature_store
# Bigtable:   feature-store / features

# %% [markdown]
# ---
# ## Environment
#
# > **Already set up the project environment?** The cell below is a no-op. See the [README](../readme.md) for uv setup details.
# >
# > **Running standalone?** The cell below installs required packages into your current kernel.

# %%
import subprocess, sys, shutil

def install(*packages):
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call(
            [uv, 'pip', 'install', '-q', '--prerelease=allow',
             '--python', sys.executable, *packages])
    else:
        subprocess.check_call(
            [sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install(
    'google-cloud-bigquery', 'db-dtypes',
    'google-cloud-bigtable',
    'pandas', 'numpy', 'matplotlib',
)

# %% [markdown]
# ---
# ## Authentication

# %%
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC used automatically

# %% [markdown]
# ---
# ## API Enablement
#
# Enable the Google Cloud APIs required by this series. This is idempotent — re-running is safe. The [BigQuery Reservation API](https://cloud.google.com/bigquery/docs/reservations-intro) is needed for `EXPORT DATA` to [Bigtable](https://cloud.google.com/bigquery/docs/export-to-bigtable), which requires [Enterprise or Enterprise Plus editions](https://cloud.google.com/bigquery/docs/editions-intro).

# %%
import subprocess

APIS = [
    'bigtable.googleapis.com',
    'bigtableadmin.googleapis.com',
    'bigquery.googleapis.com',
    'bigqueryreservation.googleapis.com',
    'bigquerydatatransfer.googleapis.com',
    'pubsub.googleapis.com',
    'monitoring.googleapis.com',
]

for api in APIS:
    result = subprocess.run(
        ['gcloud', 'services', 'enable', api, '--project', PROJECT_ID],
        capture_output=True, text=True,
    )
    status = 'enabled' if result.returncode == 0 else f'FAILED: {result.stderr.strip()}'
    print(f'  {api}: {status}')
# Out:
#   bigtable.googleapis.com: enabled
#   bigtableadmin.googleapis.com: enabled
#   bigquery.googleapis.com: enabled
#   bigqueryreservation.googleapis.com: enabled
#   bigquerydatatransfer.googleapis.com: enabled
#   pubsub.googleapis.com: enabled
#   monitoring.googleapis.com: enabled

# %% [markdown]
# ---
# ## Client Setup
#
# Initialize the BigQuery and [Bigtable Python](https://cloud.google.com/python/docs/reference/bigtable/latest) clients.

# %%
from google.cloud import bigquery
from google.cloud import bigtable
from google.cloud.bigtable import column_family as cf
import pandas as pd
import numpy as np
import json

bq = bigquery.Client(project=PROJECT_ID)
bt_admin = bigtable.Client(project=PROJECT_ID, admin=True)

print('Clients initialized:')
print(f'  BigQuery:  {bq.project}')
print(f'  Bigtable:  {bt_admin.project}')
# Out:
# Clients initialized:
#   BigQuery:  statmike-mlops-349915
#   Bigtable:  statmike-mlops-349915

# %% [markdown]
# ---
# ## BigQuery Dataset
#
# Create the dataset if it doesn't exist. All tables in this series live here.

# %%
dataset = bigquery.Dataset(f'{BQ_PROJECT}.{BQ_DATASET}')
dataset.location = 'US'
dataset = bq.create_dataset(dataset, exists_ok=True)
print(f'Dataset ready: {BQ_PROJECT}.{BQ_DATASET}')
# Out:
# Dataset ready: statmike-mlops-349915.bigtable_feature_store

# %% [markdown]
# ---
# ## Dense Table Generation
#
# The dense table provides **one row per entity** with 200+ feature columns covering every [BigQuery data type](https://cloud.google.com/bigquery/docs/reference/standard-sql/data-types). This is the primary table the other notebooks use for feature store sync operations.
#
# ### Design
#
# | Aspect | Value |
# |--------|-------|
# | **Entity groups** | 26 groups ("A" through "Z") |
# | **Entities per group** | 5,000 (IDs: "000001" through "005000") |
# | **Total rows** | 130,000 |
# | **Compound key** | `entity_group` + `entity_id` (Bigtable row key: `{entity_group}#{entity_id}`) |
# | **Label** | Binary `label` column derived from feature values — has learnable signal for model training (NB8) |
#
# ### Data Type Coverage
#
# | BQ Data Type | Column Prefix | Count |
# |-------------|---------------|-------|
# | INT64 | `feature_int_` | 5 |
# | FLOAT64 | `feature_float_` | 180 |
# | NUMERIC | `feature_numeric_` | 3 |
# | BIGNUMERIC | `feature_bignumeric_` | 2 |
# | STRING | `feature_string_` | 5 |
# | BYTES | `feature_bytes_` | 2 |
# | BOOL | `feature_bool_` | 3 |
# | DATE | `feature_date_` | 3 |
# | DATETIME | `feature_datetime_` | 2 |
# | TIME | `feature_time_` | 2 |
# | TIMESTAMP | `feature_timestamp_` | 3 |
# | GEOGRAPHY | `feature_geo_` | 2 |
# | JSON | `feature_json_` | 2 |
# | ARRAY<INT64> | `feature_array_int_` | 2 |
# | ARRAY<STRING> | `feature_array_string_` | 1 |
# | STRUCT | `feature_struct_` | 2 |
# | ARRAY<STRUCT> | `feature_array_struct_` | 1 |
# | RANGE<DATE> | `feature_range_date_` | 1 |
#
# The 180 `feature_float_` columns use varied distributions (uniform, scaled, offset) to provide realistic bulk feature data. Combined with the typed columns above, the table exceeds 200 total columns.
#
# ### NULLs
#
# Five columns have ~5% NULL values to test how serialization methods (NB2) and serving code (NB8) handle missing data: `feature_float_3`, `feature_float_4`, `feature_string_2`, `feature_date_2`, `feature_numeric_2`.

# %%
# Build and execute the dense table SQL
# The ~175 extra FLOAT64 columns are generated programmatically

# Float columns (feature_float_6 through feature_float_180)
float_columns = []
for i in range(6, 181):
    if i % 5 == 0:
        float_columns.append(f'    ROUND(RAND() * 1000, 4) AS feature_float_{i}')
    elif i % 5 == 1:
        float_columns.append(f'    ROUND(RAND() * 100 - 50, 4) AS feature_float_{i}')
    elif i % 5 == 2:
        float_columns.append(f'    ROUND(RAND() * 10, 4) AS feature_float_{i}')
    elif i % 5 == 3:
        float_columns.append(f'    ROUND(RAND() * 500 + 100, 4) AS feature_float_{i}')
    else:
        float_columns.append(f'    ROUND(RAND(), 6) AS feature_float_{i}')

float_cols_sql = ',\n'.join(float_columns)

dense_query = f"""
CREATE OR REPLACE TABLE `{BQ_PROJECT}.{BQ_DATASET}.dense_features` AS
WITH
entity_groups AS (
    SELECT CHR(code) AS entity_group
    FROM UNNEST(GENERATE_ARRAY(65, 90)) AS code
),
entity_ids AS (
    SELECT FORMAT('%06d', id) AS entity_id
    FROM UNNEST(GENERATE_ARRAY(1, 5000)) AS id
),
entities AS (
    SELECT entity_group, entity_id
    FROM entity_groups CROSS JOIN entity_ids
),
raw_features AS (
    SELECT
        entity_group,
        entity_id,

        -- INT64 features (5)
        CAST(FLOOR(RAND() * 1000) AS INT64) AS feature_int_1,
        CAST(FLOOR(RAND() * 10000) AS INT64) AS feature_int_2,
        CAST(FLOOR(RAND() * 100) AS INT64) AS feature_int_3,
        CAST(FLOOR(RAND() * 1000000) AS INT64) AS feature_int_4,
        CAST(MOD(ABS(FARM_FINGERPRINT(CONCAT(entity_group, entity_id))), 500) AS INT64) AS feature_int_5,

        -- FLOAT64 features (first 5 — the rest are generated below)
        ROUND(RAND() * 100, 4) AS feature_float_1,
        ROUND(RAND() * 1000, 4) AS feature_float_2,
        IF(RAND() > 0.05, ROUND(RAND() * 50 - 25, 4), NULL) AS feature_float_3,
        IF(RAND() > 0.05, ROUND(RAND() * 10, 4), NULL) AS feature_float_4,
        ROUND(RAND(), 6) AS feature_float_5,

        -- NUMERIC features (3)
        CAST(ROUND(RAND() * 99999, 2) AS NUMERIC) AS feature_numeric_1,
        IF(RAND() > 0.05, CAST(ROUND(RAND() * 9999999, 4) AS NUMERIC), NULL) AS feature_numeric_2,
        CAST(ROUND(RAND() * 100, 6) AS NUMERIC) AS feature_numeric_3,

        -- BIGNUMERIC features (2)
        CAST(ROUND(RAND() * 999999999999, 2) AS BIGNUMERIC) AS feature_bignumeric_1,
        CAST(ROUND(RAND() * 99999999, 8) AS BIGNUMERIC) AS feature_bignumeric_2,

        -- STRING features (5)
        CONCAT('cat_', CAST(CAST(FLOOR(RAND() * 20) AS INT64) AS STRING)) AS feature_string_1,
        IF(RAND() > 0.05, CONCAT('type_', CAST(CAST(FLOOR(RAND() * 50) AS INT64) AS STRING)), NULL) AS feature_string_2,
        ['alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta', 'eta', 'theta'][ORDINAL(CAST(CEIL(RAND() * 8) AS INT64))] AS feature_string_3,
        CONCAT(entity_group, '_', ['north', 'south', 'east', 'west'][ORDINAL(CAST(CEIL(RAND() * 4) AS INT64))]) AS feature_string_4,
        FORMAT('%s-%06d', entity_group, CAST(FLOOR(RAND() * 999999) AS INT64)) AS feature_string_5,

        -- BYTES features (2)
        CAST(CONCAT('bytes_', entity_group, entity_id) AS BYTES) AS feature_bytes_1,
        CAST(FORMAT('%06d', CAST(FLOOR(RAND() * 999999) AS INT64)) AS BYTES) AS feature_bytes_2,

        -- BOOL features (3)
        RAND() > 0.5 AS feature_bool_1,
        RAND() > 0.7 AS feature_bool_2,
        MOD(CAST(FLOOR(RAND() * 10) AS INT64), 2) = 0 AS feature_bool_3,

        -- DATE features (3)
        DATE_ADD(DATE '2020-01-01', INTERVAL CAST(FLOOR(RAND() * 1825) AS INT64) DAY) AS feature_date_1,
        IF(RAND() > 0.05, DATE_ADD(DATE '2022-06-01', INTERVAL CAST(FLOOR(RAND() * 730) AS INT64) DAY), NULL) AS feature_date_2,
        DATE_ADD(DATE '2023-01-01', INTERVAL CAST(FLOOR(RAND() * 365) AS INT64) DAY) AS feature_date_3,

        -- DATETIME features (2)
        DATETIME_ADD(DATETIME '2023-01-01 00:00:00', INTERVAL CAST(FLOOR(RAND() * 525600) AS INT64) MINUTE) AS feature_datetime_1,
        DATETIME_ADD(DATETIME '2024-01-01 00:00:00', INTERVAL CAST(FLOOR(RAND() * 525600) AS INT64) MINUTE) AS feature_datetime_2,

        -- TIME features (2)
        TIME_ADD(TIME '00:00:00', INTERVAL CAST(FLOOR(RAND() * 86400) AS INT64) SECOND) AS feature_time_1,
        TIME_ADD(TIME '00:00:00', INTERVAL CAST(FLOOR(RAND() * 86400) AS INT64) SECOND) AS feature_time_2,

        -- TIMESTAMP features (3)
        TIMESTAMP_ADD(TIMESTAMP '2023-01-01 00:00:00 UTC', INTERVAL CAST(FLOOR(RAND() * 525600) AS INT64) MINUTE) AS feature_timestamp_1,
        TIMESTAMP_ADD(TIMESTAMP '2024-01-01 00:00:00 UTC', INTERVAL CAST(FLOOR(RAND() * 525600) AS INT64) MINUTE) AS feature_timestamp_2,
        TIMESTAMP_ADD(TIMESTAMP '2024-06-01 00:00:00 UTC', INTERVAL CAST(FLOOR(RAND() * 262800) AS INT64) MINUTE) AS feature_timestamp_3,

        -- GEOGRAPHY features (2)
        ST_GEOGPOINT(
            ROUND(-180 + RAND() * 360, 6),
            ROUND(-90 + RAND() * 180, 6)
        ) AS feature_geo_1,
        ST_GEOGPOINT(
            ROUND(-122.5 + RAND() * 5, 6),
            ROUND(37.0 + RAND() * 3, 6)
        ) AS feature_geo_2,

        -- JSON features (2)
        JSON_OBJECT(
            'score', ROUND(RAND() * 100, 2),
            'label', CONCAT('class_', CAST(CAST(FLOOR(RAND() * 10) AS INT64) AS STRING)),
            'active', RAND() > 0.5
        ) AS feature_json_1,
        JSON_OBJECT(
            'x', ROUND(RAND() * 10, 4),
            'y', ROUND(RAND() * 10, 4),
            'tag', entity_group
        ) AS feature_json_2,

        -- ARRAY<INT64> features (2)
        [CAST(FLOOR(RAND() * 100) AS INT64), CAST(FLOOR(RAND() * 100) AS INT64), CAST(FLOOR(RAND() * 100) AS INT64)] AS feature_array_int_1,
        [CAST(FLOOR(RAND() * 1000) AS INT64), CAST(FLOOR(RAND() * 1000) AS INT64)] AS feature_array_int_2,

        -- ARRAY<STRING> features (1)
        [
            ['red', 'blue', 'green', 'yellow'][ORDINAL(CAST(CEIL(RAND() * 4) AS INT64))],
            ['circle', 'square', 'triangle'][ORDINAL(CAST(CEIL(RAND() * 3) AS INT64))]
        ] AS feature_array_string_1,

        -- STRUCT features (2)
        STRUCT(
            ROUND(RAND() * 100, 2) AS value,
            CONCAT('unit_', CAST(CAST(FLOOR(RAND() * 5) AS INT64) AS STRING)) AS unit,
            RAND() > 0.5 AS is_valid
        ) AS feature_struct_1,
        STRUCT(
            CAST(FLOOR(RAND() * 1000) AS INT64) AS count,
            ROUND(RAND(), 4) AS ratio
        ) AS feature_struct_2,

        -- ARRAY<STRUCT> features (1)
        [
            STRUCT(ROUND(RAND() * 10, 2) AS weight, CONCAT('item_', CAST(CAST(FLOOR(RAND() * 100) AS INT64) AS STRING)) AS name),
            STRUCT(ROUND(RAND() * 10, 2) AS weight, CONCAT('item_', CAST(CAST(FLOOR(RAND() * 100) AS INT64) AS STRING)) AS name),
            STRUCT(ROUND(RAND() * 10, 2) AS weight, CONCAT('item_', CAST(CAST(FLOOR(RAND() * 100) AS INT64) AS STRING)) AS name)
        ] AS feature_array_struct_1,

        -- RANGE<DATE> features (1)
        RANGE(
            DATE_ADD(DATE '2020-01-01', INTERVAL CAST(FLOOR(RAND() * 1000) AS INT64) DAY),
            DATE_ADD(DATE '2023-01-01', INTERVAL CAST(FLOOR(RAND() * 730) AS INT64) DAY)
        ) AS feature_range_date_1,

        -- Bulk FLOAT64 features (feature_float_6 through feature_float_180)
    {float_cols_sql}

    FROM entities
)
SELECT *,
    CASE WHEN (
        0.4 * feature_int_1 / 999.0 +
        0.3 * feature_float_1 / 100.0 +
        0.15 * (COALESCE(feature_float_3, 0.0) + 25.0) / 50.0 +
        0.15 * CAST(feature_bool_1 AS INT64)
        + (RAND() - 0.5) * 0.3
    ) > 0.6 THEN 'positive' ELSE 'negative' END AS label
FROM raw_features
"""

print(f'Dense table SQL: {len(dense_query):,} characters')
print('Executing CREATE OR REPLACE TABLE ...')

bq.query(dense_query).result()

print('Dense table created successfully.')
# Out:
# Dense table SQL: 15,560 characters
# Executing CREATE OR REPLACE TABLE ...
# Dense table created successfully.

# %% [markdown]
# ### Verify Dense Table

# %%
# Verify the dense table
print('=== Dense Table Verification ===\n')

# Row count
row_count = bq.query(f'''
    SELECT COUNT(*) AS n FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
''').to_dataframe().iloc[0]['n']
print(f'Row count: {row_count:,}')

# Column count from INFORMATION_SCHEMA
col_count = bq.query(f'''
    SELECT COUNT(*) AS n
    FROM `{BQ_PROJECT}.{BQ_DATASET}.INFORMATION_SCHEMA.COLUMNS`
    WHERE table_name = 'dense_features'
''').to_dataframe().iloc[0]['n']
print(f'Column count: {col_count}')

# Entity group distribution
eg_dist = bq.query(f'''
    SELECT entity_group, COUNT(*) AS n
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    GROUP BY entity_group
    ORDER BY entity_group
    LIMIT 5
''').to_dataframe()
print(f'\nEntity groups (first 5):')
print(eg_dist.to_string(index=False))

# Sample row
sample = bq.query(f'''
    SELECT entity_group, entity_id,
           feature_int_1, feature_float_1, feature_string_1,
           feature_bool_1, feature_date_1, feature_timestamp_1,
           feature_numeric_1, feature_geo_1, label
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    WHERE entity_group = 'A' AND entity_id = '000001'
''').to_dataframe()
print(f'\nSample row (A/000001):')
print(sample.T.to_string(header=False))

# Label distribution
label_dist = bq.query(f'''
    SELECT label, COUNT(*) AS n,
           ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(), 1) AS pct
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    GROUP BY label
    ORDER BY label
''').to_dataframe()
print(f'\nLabel distribution:')
print(label_dist.to_string(index=False))

# NULL rates
null_rates = bq.query(f'''
    SELECT
        ROUND(COUNTIF(feature_float_3 IS NULL) * 100.0 / COUNT(*), 1) AS float_3_null_pct,
        ROUND(COUNTIF(feature_float_4 IS NULL) * 100.0 / COUNT(*), 1) AS float_4_null_pct,
        ROUND(COUNTIF(feature_string_2 IS NULL) * 100.0 / COUNT(*), 1) AS string_2_null_pct,
        ROUND(COUNTIF(feature_date_2 IS NULL) * 100.0 / COUNT(*), 1) AS date_2_null_pct,
        ROUND(COUNTIF(feature_numeric_2 IS NULL) * 100.0 / COUNT(*), 1) AS numeric_2_null_pct
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
''').to_dataframe()
print(f'\nNULL rates (~5% expected):')
print(null_rates.T.to_string(header=False))
# Out:
# === Dense Table Verification ===
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Row count: 130,000
# Column count: 224
#
# Entity groups (first 5):
# entity_group    n
#            A 5000
#            B 5000
#            C 5000
#            D 5000
#            E 5000
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Sample row (A/000001):
# entity_group                                   A
# entity_id                                 000001
# feature_int_1                                 29
# feature_float_1                          21.3848
# feature_string_1                          cat_15
# ...

# %% [markdown]
# ### Data Type Inventory
#
# Verify we have the expected coverage across all BigQuery data types.

# %%
# Data type inventory
type_inventory = bq.query(f'''
    SELECT
        data_type,
        COUNT(*) AS column_count,
        STRING_AGG(column_name ORDER BY ordinal_position LIMIT 3) AS example_columns
    FROM `{BQ_PROJECT}.{BQ_DATASET}.INFORMATION_SCHEMA.COLUMNS`
    WHERE table_name = 'dense_features'
    GROUP BY data_type
    ORDER BY column_count DESC
''').to_dataframe()

print('Data type inventory for dense_features:')
print(type_inventory.to_string(index=False))
print(f'\nTotal columns: {type_inventory["column_count"].sum()}')
print(f'Distinct data types: {len(type_inventory)}')
# Out:
# Data type inventory for dense_features:
#                                         data_type  column_count                                             example_columns
#                                           FLOAT64           180             feature_float_1,feature_float_2,feature_float_3
#                                            STRING             8                     entity_group,entity_id,feature_string_1
#                                             INT64             5                   feature_int_1,feature_int_2,feature_int_3
#                                           NUMERIC             3       feature_numeric_1,feature_numeric_2,feature_numeric_3
#                                              BOOL             3                feature_bool_1,feature_bool_2,feature_bool_3
#                                              DATE             3                feature_date_1,feature_date_2,feature_date_3
# ...

# %% [markdown]
# ---
# ## Sparse Table Generation
#
# The sparse table provides **multiple rows per entity** with timestamps, simulating time-series event data. Each entity has ~20 events spread over the past 90 days.
#
# ### Design
#
# | Aspect | Value |
# |--------|-------|
# | **Entities** | Same 130,000 from dense table |
# | **Events per entity** | 20 |
# | **Total rows** | 2,600,000 |
# | **Time range** | 90 days of history |
# | **Event types** | purchase, view, click, search, return |
# | **Metrics** | 5 continuous FLOAT64 columns |
#
# This table is used by later notebooks to compute time-windowed aggregations (e.g., "count of purchases in last 7 days") and to test streaming feature updates.

# %%
# Generate the sparse events table
print('Creating sparse_events table (~2.6M rows)...')
print('This may take 30-60 seconds.\n')

sparse_query = f"""
CREATE OR REPLACE TABLE `{BQ_PROJECT}.{BQ_DATASET}.sparse_events` AS
WITH
entities AS (
    SELECT entity_group, entity_id
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
),
events_per_entity AS (
    SELECT
        entity_group,
        entity_id,
        event_num
    FROM entities
    CROSS JOIN UNNEST(GENERATE_ARRAY(1, 20)) AS event_num
)
SELECT
    entity_group,
    entity_id,
    TIMESTAMP_SUB(
        CURRENT_TIMESTAMP(),
        INTERVAL CAST(FLOOR(RAND() * 90 * 24 * 60) AS INT64) MINUTE
    ) AS event_timestamp,
    ['purchase', 'view', 'click', 'search', 'return'][ORDINAL(CAST(CEIL(RAND() * 5) AS INT64))] AS event_type,
    ROUND(RAND() * 100, 2) AS metric_1,
    ROUND(RAND() * 50, 2) AS metric_2,
    ROUND(RAND() * 200, 2) AS metric_3,
    ROUND(RAND() * 10, 2) AS metric_4,
    ROUND(RAND() * 1000, 2) AS metric_5,
    IF(RAND() > 0.9, 'positive', 'negative') AS label
FROM events_per_entity
"""

bq.query(sparse_query).result()
print('Sparse events table created.')
# Out:
# Creating sparse_events table (~2.6M rows)...
# This may take 30-60 seconds.
#
# Sparse events table created.

# %% [markdown]
# ### Verify Sparse Table

# %%
# Verify the sparse table
print('=== Sparse Table Verification ===\n')

# Row count
sparse_count = bq.query(f'''
    SELECT COUNT(*) AS n FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
''').to_dataframe().iloc[0]['n']
print(f'Row count: {sparse_count:,}')

# Events per entity distribution
events_dist = bq.query(f'''
    SELECT
        MIN(event_count) AS min_events,
        MAX(event_count) AS max_events,
        ROUND(AVG(event_count), 1) AS avg_events,
        COUNT(*) AS num_entities
    FROM (
        SELECT entity_group, entity_id, COUNT(*) AS event_count
        FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
        GROUP BY entity_group, entity_id
    )
''').to_dataframe()
print(f'\nEvents per entity:')
print(events_dist.to_string(index=False))

# Event type distribution
event_types = bq.query(f'''
    SELECT
        event_type,
        COUNT(*) AS n,
        ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(), 1) AS pct
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
    GROUP BY event_type
    ORDER BY n DESC
''').to_dataframe()
print(f'\nEvent type distribution:')
print(event_types.to_string(index=False))

# Timestamp range
ts_range = bq.query(f'''
    SELECT
        MIN(event_timestamp) AS earliest,
        MAX(event_timestamp) AS latest,
        TIMESTAMP_DIFF(MAX(event_timestamp), MIN(event_timestamp), DAY) AS span_days
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
''').to_dataframe()
print(f'\nTimestamp range:')
print(ts_range.to_string(index=False))

# Label distribution
label_dist = bq.query(f'''
    SELECT
        label,
        COUNT(*) AS n,
        ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(), 1) AS pct
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
    GROUP BY label
    ORDER BY label
''').to_dataframe()
print(f'\nLabel distribution:')
print(label_dist.to_string(index=False))
# Out:
# === Sparse Table Verification ===
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Row count: 2,600,000
#
# Events per entity:
#  min_events  max_events  avg_events  num_entities
#          20          20        20.0        130000
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Event type distribution:
# event_type      n  pct
#      click 520555 20.0
#       view 520525 20.0
#     return 520170 20.0
#   purchase 519984 20.0
#     search 518766 20.0
# ...

# %% [markdown]
# ---
# ## Data Investigation
#
# Explore the generated data to understand its structure, distributions, and relationships. These investigations confirm the data is ready for the feature store notebooks.

# %% [markdown]
# ### Schema Inspection

# %%
# Full schema of the dense table
schema_df = bq.query(f'''
    SELECT
        ordinal_position,
        column_name,
        data_type,
        is_nullable
    FROM `{BQ_PROJECT}.{BQ_DATASET}.INFORMATION_SCHEMA.COLUMNS`
    WHERE table_name = 'dense_features'
    ORDER BY ordinal_position
''').to_dataframe()

print(f'Dense table schema ({len(schema_df)} columns):')
print()

# Show first 30 and last 10
print('First 30 columns:')
print(schema_df.head(30).to_string(index=False))
print(f'\n... ({len(schema_df) - 40} more columns) ...\n')
print('Last 10 columns:')
print(schema_df.tail(10).to_string(index=False))
# Out:
# Dense table schema (224 columns):
#
# First 30 columns:
#  ordinal_position          column_name  data_type is_nullable
#                 1         entity_group     STRING         YES
#                 2            entity_id     STRING         YES
#                 3        feature_int_1      INT64         YES
#                 4        feature_int_2      INT64         YES
#                 5        feature_int_3      INT64         YES
#                 6        feature_int_4      INT64         YES
#                 7        feature_int_5      INT64         YES
#                 8      feature_float_1    FLOAT64         YES
#                 9      feature_float_2    FLOAT64         YES
#                10      feature_float_3    FLOAT64         YES
#                11      feature_float_4    FLOAT64         YES
#                12      feature_float_5    FLOAT64         YES
#                13    feature_numeric_1    NUMERIC         YES
# ...

# %% [markdown]
# ### Entity Group Distribution

# %%
# Entity group distribution — should be perfectly uniform (5,000 per group)
import matplotlib.pyplot as plt

eg_full = bq.query(f'''
    SELECT entity_group, COUNT(*) AS n
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
    GROUP BY entity_group
    ORDER BY entity_group
''').to_dataframe()

fig, ax = plt.subplots(figsize=(14, 4))
ax.bar(eg_full['entity_group'], eg_full['n'], color='#1976D2', alpha=0.8)
ax.set_xlabel('Entity Group', fontweight='bold')
ax.set_ylabel('Count', fontweight='bold')
ax.set_title('Entity Group Distribution (Dense Table)', fontsize=13, fontweight='bold')
ax.set_ylim(bottom=0)
plt.tight_layout()
plt.show()

print(f'\nAll groups have exactly {eg_full["n"].iloc[0]:,} entities: {eg_full["n"].nunique() == 1}')
# Out:
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# All groups have exactly 5,000 entities: True

# %% [markdown]
# ### Feature Value Distributions

# %%
# Feature value distributions for selected typed columns
dist_stats = bq.query(f'''
    SELECT
        -- INT64 stats
        ROUND(AVG(feature_int_1), 2) AS avg_int_1,
        ROUND(STDDEV(feature_int_1), 2) AS std_int_1,
        MIN(feature_int_1) AS min_int_1,
        MAX(feature_int_1) AS max_int_1,
        -- FLOAT64 stats
        ROUND(AVG(feature_float_1), 4) AS avg_float_1,
        ROUND(STDDEV(feature_float_1), 4) AS std_float_1,
        -- NUMERIC stats
        ROUND(AVG(CAST(feature_numeric_1 AS FLOAT64)), 2) AS avg_numeric_1,
        -- STRING cardinality
        COUNT(DISTINCT feature_string_1) AS distinct_string_1,
        COUNT(DISTINCT feature_string_3) AS distinct_string_3,
        -- BOOL proportions
        ROUND(COUNTIF(feature_bool_1) * 100.0 / COUNT(*), 1) AS pct_true_bool_1,
        ROUND(COUNTIF(feature_bool_2) * 100.0 / COUNT(*), 1) AS pct_true_bool_2,
        -- DATE range
        MIN(feature_date_1) AS min_date_1,
        MAX(feature_date_1) AS max_date_1
    FROM `{BQ_PROJECT}.{BQ_DATASET}.dense_features`
''').to_dataframe()

print('Feature distribution summary:')
print(dist_stats.T.to_string(header=False))
# Out:
# Feature distribution summary:
# avg_int_1              499.75
# std_int_1              287.93
# min_int_1                   0
# max_int_1                 999
# avg_float_1           50.1095
# std_float_1           28.8706
# avg_numeric_1        50052.28
# distinct_string_1          20
# distinct_string_3           8
# pct_true_bool_1          50.1
# pct_true_bool_2          29.9
# min_date_1         2020-01-01
# max_date_1         2024-12-29
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %% [markdown]
# ### Sparse Table: Daily Event Volume

# %%
# Sparse table: daily event volume and event type breakdown
daily_events = bq.query(f'''
    SELECT
        DATE(event_timestamp) AS event_date,
        event_type,
        COUNT(*) AS n
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
    GROUP BY event_date, event_type
    ORDER BY event_date, event_type
''').to_dataframe()

# Pivot for visualization
daily_pivot = daily_events.pivot_table(
    index='event_date', columns='event_type', values='n', fill_value=0
)

fig, ax = plt.subplots(figsize=(14, 5))
daily_pivot.plot(kind='bar', stacked=True, ax=ax, width=0.9, alpha=0.8)
ax.set_xlabel('Date', fontweight='bold')
ax.set_ylabel('Event Count', fontweight='bold')
ax.set_title('Daily Event Volume by Type (Sparse Table)', fontsize=13, fontweight='bold')
ax.legend(title='Event Type', bbox_to_anchor=(1.02, 1), loc='upper left')

# Only show every 7th tick label to avoid overcrowding
tick_labels = [d.strftime('%m-%d') if i % 7 == 0 else '' for i, d in enumerate(daily_pivot.index)]
ax.set_xticklabels(tick_labels, rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %% [markdown]
# ### Sparse Table: Metric Distributions

# %%
# Metric distributions in sparse table
metric_stats = bq.query(f'''
    SELECT
        ROUND(AVG(metric_1), 2) AS avg_metric_1,
        ROUND(STDDEV(metric_1), 2) AS std_metric_1,
        ROUND(AVG(metric_2), 2) AS avg_metric_2,
        ROUND(STDDEV(metric_2), 2) AS std_metric_2,
        ROUND(AVG(metric_3), 2) AS avg_metric_3,
        ROUND(STDDEV(metric_3), 2) AS std_metric_3,
        ROUND(AVG(metric_4), 2) AS avg_metric_4,
        ROUND(STDDEV(metric_4), 2) AS std_metric_4,
        ROUND(AVG(metric_5), 2) AS avg_metric_5,
        ROUND(STDDEV(metric_5), 2) AS std_metric_5
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
''').to_dataframe()

print('Sparse table metric summary:')
print(metric_stats.T.to_string(header=False))

# Events per entity histogram
events_per_entity = bq.query(f'''
    SELECT COUNT(*) AS event_count
    FROM `{BQ_PROJECT}.{BQ_DATASET}.sparse_events`
    GROUP BY entity_group, entity_id
''').to_dataframe()

fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(events_per_entity['event_count'], bins=range(0, 45), color='#E53935', alpha=0.8, edgecolor='white')
ax.set_xlabel('Events per Entity', fontweight='bold')
ax.set_ylabel('Number of Entities', fontweight='bold')
ax.set_title('Events per Entity Distribution (Sparse Table)', fontsize=13, fontweight='bold')
ax.axvline(x=events_per_entity['event_count'].mean(), color='black', linestyle='--',
           label=f'Mean: {events_per_entity["event_count"].mean():.1f}')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Sparse table metric summary:
# avg_metric_1   50.03
# std_metric_1   28.86
# avg_metric_2   25.00
# std_metric_2   14.44
# avg_metric_3  100.08
# std_metric_3   57.72
# avg_metric_4    5.00
# std_metric_4    2.89
# avg_metric_5  500.05
# std_metric_5  288.80
# /home/user/git/vertex-ai-mlops/MLOps/Feature Store/Bigtable/.venv/lib/python3.13/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %% [markdown]
# ---
# ## Bigtable Instance & Table
#
# ### Cloud Bigtable Architecture
#
# [Cloud Bigtable](https://cloud.google.com/bigtable/docs/overview) organizes resources in a hierarchy that maps directly to how data is stored, served, and protected:
#
# ```
# Project
# └── Instance          ← logical container (billing, access control)
#     ├── Cluster 1     ← physical compute + storage in a specific zone
#     │   └── Nodes     ← serve read/write requests
#     ├── Cluster 2     ← optional: another zone for replication
#     │   └── Nodes
#     └── ...
#         └── Tables    ← live inside the instance, replicated across clusters
# ```
#
# | Concept | What It Is | Documentation |
# |---------|-----------|---------------|
# | **[Instance](https://cloud.google.com/bigtable/docs/instances-clusters-nodes)** | Logical container for clusters and tables. All access control, monitoring, and billing happen at this level. | [Instances, clusters, nodes](https://cloud.google.com/bigtable/docs/instances-clusters-nodes) |
# | **Cluster** | A group of nodes in a single Google Cloud zone. Each cluster stores a full copy of the instance's data. | [Creating clusters](https://cloud.google.com/bigtable/docs/instances-clusters-nodes#clusters) |
# | **Nodes** | Compute resources that handle read/write traffic. More nodes = higher throughput. Bigtable distributes tablets (row ranges) across nodes automatically. | [Node scaling](https://cloud.google.com/bigtable/docs/instances-clusters-nodes#nodes) |
# | **[Replication](https://cloud.google.com/bigtable/docs/replication-overview)** | Multi-cluster instances replicate data automatically. Provides higher availability and read throughput. Eventually consistent between clusters (typically seconds). | [Replication overview](https://cloud.google.com/bigtable/docs/replication-overview) |
# | **[App Profile](https://cloud.google.com/bigtable/docs/app-profiles)** | Routing policy that controls which cluster handles a request. Required for multi-cluster instances. Also sets priority levels (HIGH/MEDIUM/LOW) to isolate workloads. | [App profiles](https://cloud.google.com/bigtable/docs/app-profiles) |
#
# **Instance types:**
# - **Production** — 3+ nodes, SLA-backed, auto-scales. For real workloads.
# - **[Development](https://cloud.google.com/bigtable/docs/instances-clusters-nodes#development)** — 1 node, no SLA, no replication. For learning and prototyping. Can be upgraded to production later.
#
# We use a **development instance** for this series to keep costs minimal while demonstrating all the same APIs and patterns. Everything you learn here — table design, column families, reads, writes, exports — works identically on production instances.
#
# ### App Profiles — Why They Matter
#
# Every Bigtable API request is routed through an [app profile](https://cloud.google.com/bigtable/docs/app-profiles). The default profile works for single-cluster instances, but app profiles become essential for:
#
# 1. **Traffic isolation** — Assign LOW priority to batch exports (`EXPORT DATA`) so they don't starve online serving reads that need HIGH priority.
# 2. **Cluster routing** — In multi-cluster setups, route reads to the nearest cluster and writes to a specific cluster for consistency.
# 3. **Workload identification** — Monitor which app profiles generate which traffic patterns in Cloud Monitoring dashboards.
#
# We create dedicated app profiles in **Notebook 1 (Fundamentals)** for export operations and explore production app profile patterns in **Notebook 7 (Schema Evolution & Operations)**.
#
# ### Table Design
#
# | Aspect | Value |
# |--------|-------|
# | **Instance** | `feature-store` (DEVELOPMENT) |
# | **[Table](https://cloud.google.com/bigtable/docs/managing-tables)** | `features` |
# | **[Column family](https://cloud.google.com/bigtable/docs/schema-design#column-families): `features`** | Stores all feature values. [GC policy](https://cloud.google.com/bigtable/docs/garbage-collection): `MaxVersionsGCRule(1)` — keep only the latest value per cell. |
# | **[Column family](https://cloud.google.com/bigtable/docs/schema-design#column-families): `metadata`** | Stores schema descriptors and metadata. GC policy: `MaxVersionsGCRule(1)`. |
# | **[Row key](https://cloud.google.com/bigtable/docs/schema-design)** | `{entity_group}#{entity_id}` (e.g., `A#000001`) — compound key enables prefix scans by group. |

# %%
from google.cloud.bigtable import enums

# Create or get the Bigtable instance
instance = bt_admin.instance(
    BT_INSTANCE,
    display_name='Bigtable Feature Store',
    instance_type=enums.Instance.Type.DEVELOPMENT,
)

if not instance.exists():
    cluster = instance.cluster(
        f'{BT_INSTANCE}-c1',
        location_id=ZONE,
        serve_nodes=0,  # Development instances don't specify nodes
    )
    operation = instance.create(clusters=[cluster])
    operation.result()  # Wait for creation
    print(f'Created Bigtable instance: {BT_INSTANCE} (DEVELOPMENT)')
else:
    instance.reload()
    print(f'Bigtable instance exists: {BT_INSTANCE}')

# Create the feature table with two column families
table = instance.table(BT_TABLE)

if not table.exists():
    max_versions = cf.MaxVersionsGCRule(1)  # Keep only latest version

    table.create(column_families={
        BT_COLUMN_FAMILY: max_versions,
        'metadata': max_versions,
    })
    print(f'Created table: {BT_TABLE}')
    print(f'  Column family: {BT_COLUMN_FAMILY} (features, keep latest version)')
    print(f'  Column family: metadata (schema metadata, keep latest version)')
else:
    existing = list(table.list_column_families().keys())
    print(f'Table exists: {BT_TABLE}')
    print(f'  Column families: {", ".join(existing)}')

    # Ensure metadata column family exists
    if 'metadata' not in existing:
        table.column_family('metadata', gc_rule=cf.MaxVersionsGCRule(1)).create()
        print(f'  Added column family: metadata')
# Out:
# Created Bigtable instance: feature-store (DEVELOPMENT)
# Created table: features
#   Column family: features (features, keep latest version)
#   Column family: metadata (schema metadata, keep latest version)

# %% [markdown]
# ### Verify Bigtable

# %%
# Verify Bigtable instance details
instance.reload()
clusters, failed_locations = instance.list_clusters()

print(f'Instance:     {instance.instance_id}')
print(f'Display name: {instance.display_name}')
print(f'Type:         DEVELOPMENT')
print(f'Clusters:     {len(clusters)}')
for cluster_info in clusters:
    print(f'  - {cluster_info.cluster_id} ({cluster_info.location_id})')

# Verify table and column families
table_ref = instance.table(BT_TABLE)
families = table_ref.list_column_families()
print(f'\nTable: {BT_TABLE}')
for name, family in families.items():
    print(f'  Column family: {name}')
    print(f'    GC rule: {family.gc_rule}')
# Out:
# Instance:     feature-store
# Display name: Bigtable Feature Store
# Type:         DEVELOPMENT
# Clusters:     1
#   - feature-store-c1 (us-central1-a)
#
# Table: features
#   Column family: features
#     GC rule: <google.cloud.bigtable.column_family.MaxVersionsGCRule object at 0x7b8539d2e990>
#   Column family: metadata
#     GC rule: <google.cloud.bigtable.column_family.MaxVersionsGCRule object at 0x7b8539d2e710>

# %% [markdown]
# ---
# ## Ways to Access Bigtable
#
# Bigtable offers many interfaces beyond the Python client used in this series. Understanding these helps you pick the right tool for each use case — from interactive exploration to high-throughput production serving.
#
# ### Client Libraries
#
# Official Google Cloud client libraries provide idiomatic APIs for each language. They all use [gRPC](https://cloud.google.com/bigtable/docs/reference/data/rpc) under the hood for high-performance streaming reads and writes.
#
# | Language | Client Library | Best For |
# |----------|---------------|----------|
# | **Python** | [`google-cloud-bigtable`](https://cloud.google.com/python/docs/reference/bigtable/latest) | Notebooks, data science, scripting — **used throughout this series** |
# | **Java** | [`google-cloud-bigtable`](https://cloud.google.com/java/docs/reference/google-cloud-bigtable/latest/overview) | Production serving (highest throughput), Android |
# | **Go** | [`cloud.google.com/go/bigtable`](https://cloud.google.com/go/docs/reference/cloud.google.com/go/bigtable/latest) | Microservices, CLI tools |
# | **Node.js** | [`@google-cloud/bigtable`](https://cloud.google.com/nodejs/docs/reference/bigtable/latest) | Web backends, serverless functions |
# | **C++** | `google-cloud-cpp` | Latency-sensitive applications |
# | **C#** | `Google.Cloud.Bigtable.V2` | .NET applications |
#
# > See the full list: [Client libraries for Cloud Bigtable](https://cloud.google.com/bigtable/docs/reference/libraries)
#
# ### SQL Interfaces
#
# | Interface | Description | Documentation |
# |-----------|------------|---------------|
# | **[GoogleSQL for Bigtable](https://cloud.google.com/bigtable/docs/googlesql-overview)** | Query Bigtable tables directly with SQL using the `_key` column and `MAP<>` data type for column families. Great for interactive exploration and debugging in the Cloud Console. | [Overview](https://cloud.google.com/bigtable/docs/googlesql-overview) · [Examples](https://cloud.google.com/bigtable/docs/googlesql-examples) · [Reference](https://cloud.google.com/bigtable/docs/reference/sql/googlesql-reference-overview) |
# | **[BigQuery external tables](https://cloud.google.com/bigtable/docs/bigquery-analysis)** | Query Bigtable from BigQuery using federated queries. Useful for ad-hoc analytics across BigQuery and Bigtable data. | [Query and analyze](https://cloud.google.com/bigtable/docs/bigquery-analysis) |
# | **[Protobuf queries](https://cloud.google.com/bigtable/docs/query-protobuf-data)** | Query individual fields within protobuf messages stored as bytes — no client-side deserialization needed. Works with GoogleSQL, materialized views, and BigQuery external tables. | [Query protobuf data](https://cloud.google.com/bigtable/docs/query-protobuf-data) |
#
# ### CLI & Admin Tools
#
# | Tool | Purpose | Documentation |
# |------|---------|---------------|
# | **`cbt`** | Command-line tool for reading, writing, and managing Bigtable data. Fast way to inspect rows without writing code. | [`cbt` overview](https://cloud.google.com/bigtable/docs/cbt-overview) |
# | **`gcloud bigtable`** | Admin operations: create/delete instances, manage clusters, configure app profiles and backups. | [gcloud reference](https://cloud.google.com/bigtable/docs/instances-clusters-nodes) |
# | **Bigtable Studio** | Visual SQL editor in the Cloud Console — write GoogleSQL queries interactively. | [Introduction to SQL](https://cloud.google.com/bigtable/docs/introduction-sql) |
#
# ### Choosing the Right Interface
#
# | Use Case | Recommended Interface |
# |----------|----------------------|
# | Online feature serving (< 10ms) | Python/Java/Go client library — direct `read_row()` |
# | Explore data interactively | GoogleSQL in Cloud Console or `cbt` CLI |
# | Ad-hoc analytics across BQ + Bigtable | BigQuery external tables |
# | Batch sync from BigQuery | `EXPORT DATA` (BigQuery SQL) |
# | High-throughput batch writes | Java or Python client with `mutate_rows()` |
# | Protobuf-encoded features | GoogleSQL with protobuf schema bundles |
# | CI/CD and scripting | `cbt` CLI or any client library |

# %% [markdown]
# ---
# ## Summary
#
# This notebook created all shared resources for the Bigtable Feature Store series.
#
# | Resource | Type | Details |
# |----------|------|---------|
# | `bigtable_feature_store` | BigQuery dataset | Container for all tables |
# | `dense_features` | BigQuery table | ~130,000 rows, 200+ columns, all BQ data types |
# | `sparse_events` | BigQuery table | ~2.6M rows, time-series events, 5 event types |
# | `feature-store` | Bigtable instance | DEVELOPMENT, single cluster in us-central1-a |
# | `features` | Bigtable table | Column families: `features`, `metadata` |
#
# ### Series Notebooks
#
# | # | Notebook | Focus |
# |---|----------|-------|
# | **0** | **Environment** (this notebook) | Shared resources: BQ data, Bigtable instance |
# | 1 | [Fundamentals](./Bigtable%20Feature%20Store%20-%20Fundamentals.ipynb) | End-to-end EXPORT DATA, schema metadata, latency baseline |
# | 2 | [Serialization](./Bigtable%20Feature%20Store%20-%20Serialization.ipynb) | Five encoding methods compared: native, JSON, concat, protobuf, hybrid |
# | 3 | [Synchronization](./Bigtable%20Feature%20Store%20-%20Synchronization.ipynb) | One-time, scheduled, continuous, and streaming sync patterns |
# | 4 | [History and Time Travel](./Bigtable%20Feature%20Store%20-%20History%20and%20Time%20Travel.ipynb) | Key-based vs cell versioning, point-in-time joins, GC policies |
# | 5 | [Streaming and Direct Writes](./Bigtable%20Feature%20Store%20-%20Streaming%20and%20Direct%20Writes.ipynb) | Direct writes, atomic operations, change streams, Pub/Sub |
# | 6 | [Key Design and Organization](./Bigtable%20Feature%20Store%20-%20Key%20Design%20and%20Organization.ipynb) | Row key patterns, hotspots, column families, Key Visualizer |
# | 7 | [Schema Evolution and Operations](./Bigtable%20Feature%20Store%20-%20Schema%20Evolution%20and%20Operations.ipynb) | Versioned schemas, backfilling, monitoring, security, cost |
# | 8 | [Serving Integration](./Bigtable%20Feature%20Store%20-%20Serving%20Integration.ipynb) | Model training, feature serving, FastAPI endpoint, live schema migration |
# | 9 | [Dynamic Features](./Bigtable%20Feature%20Store%20-%20Dynamic%20Features.ipynb) | Real-time feature computation: atomic counters, read+compute, streaming |

# %%
# Final resource summary with sizes
dense_info = bq.get_table(f'{BQ_PROJECT}.{BQ_DATASET}.dense_features')
sparse_info = bq.get_table(f'{BQ_PROJECT}.{BQ_DATASET}.sparse_events')

print('=== Resource Summary ===\n')
print(f'BigQuery:')
print(f'  dense_features:  {dense_info.num_rows:>10,} rows  {dense_info.num_bytes / 1e6:>8.1f} MB  {len(dense_info.schema):>4} columns')
print(f'  sparse_events:   {sparse_info.num_rows:>10,} rows  {sparse_info.num_bytes / 1e6:>8.1f} MB  {len(sparse_info.schema):>4} columns')
print(f'\nBigtable:')
print(f'  Instance: {BT_INSTANCE} (DEVELOPMENT, {ZONE})')
print(f'  Table:    {BT_TABLE} (column families: {BT_COLUMN_FAMILY}, metadata)')
print(f'\nAll resources ready. Proceed to Notebook 1: Fundamentals.')

# %% [markdown]
# ---
# ## Save Cleanup Parameters
#
# The cell below writes `cleanup.json` with the resource names created above. The teardown script `cleanup.py` reads this file, so you never have to edit it by hand. `cleanup.json` is gitignored (it holds project-specific values) — see the [Teardown / Cleanup](./readme.md#teardown--cleanup) section of the readme.

# %%
import json

cleanup_config = {
    'project_id': PROJECT_ID,
    'region': REGION,
    'bt_instance': BT_INSTANCE,
    'bt_writes_table': 'features-writes',  # change-stream table from NB5 (cleared before instance delete)
    'bq_dataset': BQ_DATASET,
}
with open('cleanup.json', 'w') as f:
    json.dump(cleanup_config, f, indent=2)

print('Wrote cleanup.json:')
print(json.dumps(cleanup_config, indent=2))

# %% [markdown]
# ---
# ## Cleanup
#
# When you are done with the **entire** Bigtable Feature Store series, tear down the billable resources with the `cleanup.py` script. It reads `cleanup.json` (written just above) so there's nothing to edit. **Do not run this until you have completed all notebooks you intend to run.**
#
# From this directory (`MLOps/Feature Store/Bigtable/`):
#
# ```bash
# # Dry run — show what would be deleted (default, safe)
# uv run python cleanup.py
#
# # Delete the Bigtable instance (first clears the NB5 change stream, then deletes clusters + tables)
# uv run python cleanup.py --yes
#
# # Also delete the BigQuery dataset (kept by default — it's cheap and reusable)
# uv run python cleanup.py --yes --include-dataset
# ```
#
# The Bigtable instance is the main cost; the BigQuery dataset is kept by default. The script is idempotent — already-deleted resources are reported, not errored. Pub/Sub topics/subscriptions from notebooks 3, 5, and 9 clean up after themselves.
