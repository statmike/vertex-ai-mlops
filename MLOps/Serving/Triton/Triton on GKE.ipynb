# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2FServing%2FTriton&file=Triton+on+GKE.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2FServing%2FTriton%2FTriton%2520on%2520GKE.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%2520on%2520GKE.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%2520on%2520GKE.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%2520on%2520GKE.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/Serving/Triton/Triton%2520on%2520GKE.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/Serving/Triton/Triton%20on%20GKE.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Triton on GKE
#
# Deploy Triton Inference Server to [GKE Autopilot](https://cloud.google.com/kubernetes-engine/docs/concepts/autopilot-overview) with L4 GPU and full Kubernetes control over the serving infrastructure. This notebook demonstrates:
#
# - GKE Autopilot cluster with GPU support
# - Two model repository strategies: **baked-in** (in container) and **GCS FUSE** (mounted volume)
# - Kubernetes Deployment, Service, and Horizontal Pod Autoscaler (HPA)
# - Health probes using Triton's built-in `/v2/health/ready` and `/v2/health/live` endpoints
# - HPA with Triton's Prometheus metrics for inference-aware autoscaling
# - Production patterns: graceful shutdown, rolling updates, startup probes
#
# **GKE vs Cloud Run vs Vertex AI for Triton:**
# - GKE: Full Kubernetes control, custom metrics HPA, GCS FUSE model loading, any GPU type
# - Cloud Run: Simplest deployment, scale-to-zero, limited GPU options
# - Vertex AI: Managed ML platform, Model Registry, rawPredict
#
# **Story arc:**
# 1. Create GKE Autopilot cluster
# 2. Build and deploy Triton with baked-in model repository
# 3. Test inference via LoadBalancer Service
# 4. Deploy alternative with GCS FUSE model repository
# 5. Configure HPA with Triton metrics
# 6. Production patterns (probes, rolling updates)
#
# **Models:**
# - v1: [`distilbert-base-uncased-finetuned-sst-2-english`](https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english) (67M params)
# - v2: [`textattack/bert-base-uncased-SST-2`](https://huggingface.co/textattack/bert-base-uncased-SST-2) (110M params)

# %% [markdown]
# ---
# ## Colab Setup
#
# To run this notebook in Colab, run the cells in this section. Otherwise, skip this section.

# %%
PROJECT_ID = 'statmike-mlops-349915' # replace with your project ID

# %%
try:
    import google.colab
    from google.colab import auth
    auth.authenticate_user()
    # !gcloud config set project {PROJECT_ID}
except Exception:
    pass

# %% [markdown]
# ---
# ## Environment
#
# > **Already set up the project environment?** The cell below is a no-op. See the [README](../readme.md) for uv setup details.
# >
# > **Running standalone?** The cell below installs required packages into your current kernel.

# %%
import subprocess, sys, shutil

def install(*packages):
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install(
    'google-cloud-aiplatform', 'google-cloud-storage',
    'google-cloud-artifact-registry', 'google-cloud-build',
    'google-cloud-container', 'kubernetes',
    'transformers', 'torch', 'sentencepiece',
    'tritonclient[http]', 'numpy', 'httpx',
)

# %% [markdown]
# ### API Enablement

# %%
# !gcloud services enable container.googleapis.com
# !gcloud services enable artifactregistry.googleapis.com
# !gcloud services enable cloudbuild.googleapis.com

# %% [markdown]
# ---
# ## Setup

# %% [markdown]
# inputs:

# %%
project = !gcloud config get-value project
PROJECT_ID = project[-1]
PROJECT_ID

# %%
REGION = 'us-central1'
SERIES = 'mlops'
EXPERIMENT = 'triton-gke'

GCS_BUCKET = PROJECT_ID
AR_REPO = 'mlops-serving'
GKE_CLUSTER = f'{SERIES}-triton-gke'
NAMESPACE = 'default'

# %%
project_number = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)'
PROJECT_NUMBER = project_number[0]
PROJECT_NUMBER

# %% [markdown]
# packages:

# %%
import json, os, time, subprocess
from pathlib import Path

import numpy as np
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
import httpx

from google.cloud import storage
from google.cloud import artifactregistry_v1
from google.cloud.devtools import cloudbuild_v1
from google.cloud import container_v1
from kubernetes import client as k8s_client
from kubernetes import config as k8s_config

# %% [markdown]
# clients:

# %%
gcs = storage.Client(project=PROJECT_ID)
bucket = gcs.bucket(GCS_BUCKET)
cb = cloudbuild_v1.CloudBuildClient()
ar = artifactregistry_v1.ArtifactRegistryClient()
gke = container_v1.ClusterManagerClient()

# %% [markdown]
# parameters:

# %%
DIR = f'files/{EXPERIMENT}'
SOURCE_DIR = f'{DIR}/source'
MODEL_REPO = f'{SOURCE_DIR}/model_repository'
MODELS_LOCAL = f'{DIR}/hf_models'

for d in [MODEL_REPO, MODELS_LOCAL]:
    os.makedirs(d, exist_ok=True)

# %% [markdown]
# ---
# ## Build Triton Container
#
# Download models, export to ONNX, create the ensemble pipeline, and build via Cloud Build. Same pattern as the [Vertex AI](./Triton%20on%20Vertex%20AI%20Endpoints.ipynb) and [Cloud Run](./Triton%20on%20Cloud%20Run.ipynb) notebooks.

# %%
MODELS = {
    'v1': {'hub_name': 'distilbert-base-uncased-finetuned-sst-2-english', 'triton_name': 'distilbert_onnx'},
    'v2': {'hub_name': 'textattack/bert-base-uncased-SST-2', 'triton_name': 'bert_onnx'},
}

for version, info in MODELS.items():
    local_dir = f'{MODELS_LOCAL}/{version}'
    if not os.path.exists(local_dir) or not any(os.scandir(local_dir)):
        print(f'Downloading {version}: {info["hub_name"]} ...')
        model = AutoModelForSequenceClassification.from_pretrained(info['hub_name'])
        tokenizer = AutoTokenizer.from_pretrained(info['hub_name'])
        model.save_pretrained(local_dir)
        tokenizer.save_pretrained(local_dir)
    else:
        print(f'{version}: already downloaded')

    onnx_dir = f'{MODEL_REPO}/{info["triton_name"]}/1'
    onnx_path = f'{onnx_dir}/model.onnx'
    os.makedirs(onnx_dir, exist_ok=True)
    if not os.path.exists(onnx_path):
        print(f'  Exporting to ONNX ...')
        m = AutoModelForSequenceClassification.from_pretrained(local_dir)
        t = AutoTokenizer.from_pretrained(local_dir)
        m.eval()
        dummy = t('Test.', return_tensors='pt', padding='max_length', max_length=128, truncation=True)
        torch.onnx.export(m, (dummy['input_ids'], dummy['attention_mask']), onnx_path,
            input_names=['input_ids', 'attention_mask'], output_names=['logits'],
            dynamic_axes={'input_ids': {0: 'b', 1: 's'}, 'attention_mask': {0: 'b', 1: 's'}, 'logits': {0: 'b'}},
            opset_version=17, do_constant_folding=True)
        print(f'  Exported ({os.path.getsize(onnx_path)/1024/1024:.1f} MB)')

# %%
import shutil

# ONNX configs (GPU)
for name in ['distilbert_onnx', 'bert_onnx']:
    config = f'''name: "{name}"
backend: "onnxruntime"
max_batch_size: 8
input [
  {{ name: "input_ids", data_type: TYPE_INT64, dims: [-1] }},
  {{ name: "attention_mask", data_type: TYPE_INT64, dims: [-1] }}
]
output [ {{ name: "logits", data_type: TYPE_FP32, dims: [2] }} ]
instance_group [ {{ count: 1, kind: KIND_GPU, gpus: [0] }} ]
dynamic_batching {{ preferred_batch_size: [2, 4, 8], max_queue_delay_microseconds: 100000 }}'''
    with open(f'{MODEL_REPO}/{name}/config.pbtxt', 'w') as f:
        f.write(config)

# Tokenizer
os.makedirs(f'{MODEL_REPO}/tokenizer/1/hf_tokenizer', exist_ok=True)
with open(f'{MODEL_REPO}/tokenizer/config.pbtxt', 'w') as f:
    f.write('name: "tokenizer"\nbackend: "python"\nmax_batch_size: 8\ninput [ { name: "TEXT", data_type: TYPE_STRING, dims: [1] } ]\noutput [\n  { name: "input_ids", data_type: TYPE_INT64, dims: [-1] },\n  { name: "attention_mask", data_type: TYPE_INT64, dims: [-1] }\n]\ninstance_group [ { count: 1, kind: KIND_CPU } ]')
with open(f'{MODEL_REPO}/tokenizer/1/model.py', 'w') as f:
    f.write('import numpy as np\nimport triton_python_backend_utils as pb_utils\nfrom transformers import AutoTokenizer\n\nclass TritonPythonModel:\n    def initialize(self, args):\n        self.tokenizer = AutoTokenizer.from_pretrained(f"{args[\'model_repository\']}/{args[\'model_version\']}/hf_tokenizer")\n    def execute(self, requests):\n        responses = []\n        for request in requests:\n            texts = [t.decode(\'utf-8\') for t in pb_utils.get_input_tensor_by_name(request, \'TEXT\').as_numpy().flatten()]\n            encoded = self.tokenizer(texts, padding=\'max_length\', truncation=True, max_length=128, return_tensors=\'np\')\n            responses.append(pb_utils.InferenceResponse([\n                pb_utils.Tensor(\'input_ids\', encoded[\'input_ids\'].astype(np.int64)),\n                pb_utils.Tensor(\'attention_mask\', encoded[\'attention_mask\'].astype(np.int64)),\n            ]))\n        return responses\n    def finalize(self): pass\n')
for f in Path(f'{MODELS_LOCAL}/v1').glob('*'):
    if f.name in ('tokenizer.json', 'tokenizer_config.json', 'vocab.txt', 'special_tokens_map.json'):
        shutil.copy2(f, f'{MODEL_REPO}/tokenizer/1/hf_tokenizer/')

# Postprocessor
os.makedirs(f'{MODEL_REPO}/postprocessor/1', exist_ok=True)
with open(f'{MODEL_REPO}/postprocessor/config.pbtxt', 'w') as f:
    f.write('name: "postprocessor"\nbackend: "python"\nmax_batch_size: 8\ninput [ { name: "logits", data_type: TYPE_FP32, dims: [2] } ]\noutput [\n  { name: "LABEL", data_type: TYPE_STRING, dims: [1] },\n  { name: "SCORE", data_type: TYPE_FP32, dims: [1] }\n]\ninstance_group [ { count: 1, kind: KIND_CPU } ]')
with open(f'{MODEL_REPO}/postprocessor/1/model.py', 'w') as f:
    f.write('import numpy as np\nimport triton_python_backend_utils as pb_utils\n\nclass TritonPythonModel:\n    def initialize(self, args): self.id2label = {0: \'NEGATIVE\', 1: \'POSITIVE\'}\n    def execute(self, requests):\n        responses = []\n        for request in requests:\n            logits = pb_utils.get_input_tensor_by_name(request, \'logits\').as_numpy()\n            exp_l = np.exp(logits - np.max(logits, axis=1, keepdims=True))\n            probs = exp_l / exp_l.sum(axis=1, keepdims=True)\n            pred = probs.argmax(axis=1)\n            labels = np.array([[self.id2label[i]] for i in pred], dtype=object)\n            scores = np.array([[probs[j, pred[j]]] for j in range(len(pred))], dtype=np.float32)\n            responses.append(pb_utils.InferenceResponse([pb_utils.Tensor(\'LABEL\', labels), pb_utils.Tensor(\'SCORE\', scores)]))\n        return responses\n    def finalize(self): pass\n')

# Ensemble
os.makedirs(f'{MODEL_REPO}/sentiment_ensemble/1', exist_ok=True)
with open(f'{MODEL_REPO}/sentiment_ensemble/config.pbtxt', 'w') as f:
    f.write('name: "sentiment_ensemble"\nplatform: "ensemble"\nmax_batch_size: 8\ninput [ { name: "TEXT", data_type: TYPE_STRING, dims: [1] } ]\noutput [ { name: "LABEL", data_type: TYPE_STRING, dims: [1] }, { name: "SCORE", data_type: TYPE_FP32, dims: [1] } ]\nensemble_scheduling {\n  step [\n    { model_name: "tokenizer", model_version: -1, input_map { key: "TEXT", value: "TEXT" }, output_map { key: "input_ids", value: "input_ids" }, output_map { key: "attention_mask", value: "attention_mask" } },\n    { model_name: "distilbert_onnx", model_version: -1, input_map { key: "input_ids", value: "input_ids" }, input_map { key: "attention_mask", value: "attention_mask" }, output_map { key: "logits", value: "logits" } },\n    { model_name: "postprocessor", model_version: -1, input_map { key: "logits", value: "logits" }, output_map { key: "LABEL", value: "LABEL" }, output_map { key: "SCORE", value: "SCORE" } }\n  ]\n}')

# Dockerfile (port 8000 for direct access on GKE — not proxied through Vertex AI)
with open(f'{SOURCE_DIR}/Dockerfile', 'w') as f:
    f.write('FROM nvcr.io/nvidia/tritonserver:24.12-py3\nRUN pip install --no-cache-dir transformers sentencepiece\nCOPY model_repository /models\nENTRYPOINT ["tritonserver", "--model-repository=/models", "--log-verbose=0"]\n')

print('Model repository and Dockerfile created.')

# %%
# Artifact Registry
docker_repo = None
for repo in ar.list_repositories(parent=f'projects/{PROJECT_ID}/locations/{REGION}'):
    if AR_REPO == repo.name.split('/')[-1]:
        docker_repo = repo
if not docker_repo:
    op = ar.create_repository(request=artifactregistry_v1.CreateRepositoryRequest(
        parent=f'projects/{PROJECT_ID}/locations/{REGION}', repository_id=AR_REPO,
        repository=artifactregistry_v1.Repository(name=AR_REPO, format_=artifactregistry_v1.Repository.Format.DOCKER)))
    docker_repo = op.result()
REPOSITORY = f"{REGION}-docker.pkg.dev/{PROJECT_ID}/{docker_repo.name.split('/')[-1]}"
IMAGE_URI = f'{REPOSITORY}/{EXPERIMENT}'

# Upload source
for root, dirs, files in os.walk(SOURCE_DIR):
    for fname in files:
        local_path = os.path.join(root, fname)
        blob_name = f'{SERIES}/{EXPERIMENT}/source/{os.path.relpath(local_path, SOURCE_DIR)}'
        bucket.blob(blob_name).upload_from_filename(local_path)

# Build
build = cloudbuild_v1.Build(steps=[
    {'name': 'gcr.io/cloud-builders/gsutil', 'args': ['cp', '-r', f'gs://{GCS_BUCKET}/{SERIES}/{EXPERIMENT}/source/*', '/workspace']},
    {'name': 'gcr.io/cloud-builders/docker', 'args': ['build', '-t', IMAGE_URI, '/workspace']},
])
build.images = [IMAGE_URI]
build.options = cloudbuild_v1.BuildOptions(machine_type=cloudbuild_v1.BuildOptions.MachineType.E2_HIGHCPU_32)

print('Starting Cloud Build ...')
op = cb.create_build(project_id=PROJECT_ID, build=build)
result = op.result()
print(f'Build status: {result.status.name}')
print(f'Image: {IMAGE_URI}')

# %% [markdown]
# ---
# ## Create GKE Autopilot Cluster
#
# Create a GKE Autopilot cluster. Autopilot manages nodes automatically — you just declare the resources your pods need (including GPUs) and GKE provisions the right nodes.
#
# > **Note:** Cluster creation takes ~10 minutes. GPU node provisioning (after deploying) can take an additional 5-15 minutes.

# %%
cluster_path = f'projects/{PROJECT_ID}/locations/{REGION}'

# Check if cluster already exists
existing = None
try:
    existing = gke.get_cluster(name=f'{cluster_path}/clusters/{GKE_CLUSTER}')
    print(f'Cluster already exists: {existing.name}')
except Exception:
    pass

if not existing:
    print(f'Creating Autopilot cluster: {GKE_CLUSTER} ...')
    cluster = container_v1.Cluster(
        name=GKE_CLUSTER,
        autopilot=container_v1.Autopilot(enabled=True),
    )
    operation = gke.create_cluster(
        request=container_v1.CreateClusterRequest(parent=cluster_path, cluster=cluster)
    )

    # Wait for cluster creation
    while True:
        op_status = gke.get_operation(name=f'{cluster_path}/operations/{operation.name}')
        if op_status.status == container_v1.Operation.Status.DONE:
            if op_status.error and op_status.error.code:
                raise RuntimeError(f'Cluster creation failed: {op_status.error.message}')
            print('Cluster created!')
            break
        if op_status.status == container_v1.Operation.Status.ABORTING:
            raise RuntimeError(f'Cluster creation aborted: {op_status.status_message}')
        print(f'  Status: {op_status.status.name} ...')
        time.sleep(30)

# %%
# Get cluster credentials for kubectl
cluster_info = gke.get_cluster(name=f'{cluster_path}/clusters/{GKE_CLUSTER}')
print(f'Cluster endpoint: {cluster_info.endpoint}')

# Configure kubernetes client
import google.auth
import google.auth.transport.requests
import base64, tempfile

credentials, _ = google.auth.default()
credentials.refresh(google.auth.transport.requests.Request())

# Write cluster CA cert to temp file
ca_cert = base64.b64decode(cluster_info.master_auth.cluster_ca_certificate)
ca_file = tempfile.NamedTemporaryFile(delete=False, suffix='.crt')
ca_file.write(ca_cert)
ca_file.close()

configuration = k8s_client.Configuration()
configuration.host = f'https://{cluster_info.endpoint}'
configuration.ssl_ca_cert = ca_file.name
configuration.api_key = {'authorization': f'Bearer {credentials.token}'}

api_client = k8s_client.ApiClient(configuration)
apps_v1 = k8s_client.AppsV1Api(api_client)
core_v1 = k8s_client.CoreV1Api(api_client)
autoscaling_v1 = k8s_client.AutoscalingV1Api(api_client)
print('Kubernetes client configured.')

def refresh_k8s_auth():
    """Refresh the OAuth2 token if it has expired (tokens last ~60 min)."""
    credentials.refresh(google.auth.transport.requests.Request())
    configuration.api_key = {'authorization': f'Bearer {credentials.token}'}
    print('K8s auth token refreshed.')

# %% [markdown]
# ---
# ## Deploy: Baked-In Model Repository
#
# Deploy Triton with the model repository baked into the container image. This is the simplest approach — no external storage needed. The trade-off is that updating models requires rebuilding the container.
#
# ### Deployment with GPU

# %%
DEPLOYMENT_NAME = 'triton-sentiment'

deployment = k8s_client.V1Deployment(
    metadata=k8s_client.V1ObjectMeta(name=DEPLOYMENT_NAME, labels={'app': DEPLOYMENT_NAME}),
    spec=k8s_client.V1DeploymentSpec(
        replicas=1,
        selector=k8s_client.V1LabelSelector(match_labels={'app': DEPLOYMENT_NAME}),
        template=k8s_client.V1PodTemplateSpec(
            metadata=k8s_client.V1ObjectMeta(labels={'app': DEPLOYMENT_NAME}),
            spec=k8s_client.V1PodSpec(
                containers=[
                    k8s_client.V1Container(
                        name='triton',
                        image=IMAGE_URI,
                        ports=[
                            k8s_client.V1ContainerPort(container_port=8000, name='http'),
                            k8s_client.V1ContainerPort(container_port=8001, name='grpc'),
                            k8s_client.V1ContainerPort(container_port=8002, name='metrics'),
                        ],
                        resources=k8s_client.V1ResourceRequirements(
                            limits={'nvidia.com/gpu': '1', 'cpu': '4', 'memory': '16Gi'},
                            requests={'nvidia.com/gpu': '1', 'cpu': '4', 'memory': '16Gi'},
                        ),
                        startup_probe=k8s_client.V1Probe(
                            http_get=k8s_client.V1HTTPGetAction(path='/v2/health/ready', port=8000),
                            initial_delay_seconds=30,
                            period_seconds=10,
                            failure_threshold=30,
                        ),
                        readiness_probe=k8s_client.V1Probe(
                            http_get=k8s_client.V1HTTPGetAction(path='/v2/health/ready', port=8000),
                            period_seconds=10,
                        ),
                        liveness_probe=k8s_client.V1Probe(
                            http_get=k8s_client.V1HTTPGetAction(path='/v2/health/live', port=8000),
                            period_seconds=30,
                        ),
                    ),
                ],
                node_selector={'cloud.google.com/gke-accelerator': 'nvidia-l4'},
            ),
        ),
    ),
)

try:
    apps_v1.delete_namespaced_deployment(DEPLOYMENT_NAME, NAMESPACE)
    time.sleep(5)
except Exception:
    pass

apps_v1.create_namespaced_deployment(namespace=NAMESPACE, body=deployment)
print(f'Deployment {DEPLOYMENT_NAME} created.')

# %% [markdown]
# ### Service (LoadBalancer)

# %%
SERVICE_NAME = 'triton-service'

service = k8s_client.V1Service(
    metadata=k8s_client.V1ObjectMeta(name=SERVICE_NAME),
    spec=k8s_client.V1ServiceSpec(
        type='LoadBalancer',
        selector={'app': DEPLOYMENT_NAME},
        ports=[
            k8s_client.V1ServicePort(name='http', port=8000, target_port=8000),
            k8s_client.V1ServicePort(name='grpc', port=8001, target_port=8001),
            k8s_client.V1ServicePort(name='metrics', port=8002, target_port=8002),
        ],
    ),
)

try:
    core_v1.delete_namespaced_service(SERVICE_NAME, NAMESPACE)
    time.sleep(5)
except Exception:
    pass

core_v1.create_namespaced_service(namespace=NAMESPACE, body=service)
print(f'Service {SERVICE_NAME} created.')

# %%
# Wait for deployment to be ready
# GPU node provisioning + image pull + model loading can take 15-25 minutes on first deploy
print('Waiting for Triton pods to be ready ...')
print('(GPU node provisioning + 15 GB image pull + model loading — this can take 15-25 min)')
for i in range(120):
    try:
        dep = apps_v1.read_namespaced_deployment(DEPLOYMENT_NAME, NAMESPACE)
        ready = dep.status.ready_replicas or 0
        desired = dep.status.replicas or 1
        if ready >= desired:
            print(f'Deployment ready: {ready}/{desired} replicas')
            break
        print(f'  {ready}/{desired} ready ... ({i*10}s)')
    except Exception as e:
        if '401' in str(e):
            refresh_k8s_auth()
        else:
            print(f'  Waiting ... ({i*10}s)')
    time.sleep(10)
else:
    print('Timeout waiting for deployment. Check pod status with:')
    print(f'  kubectl get pods -l app={DEPLOYMENT_NAME}')

# Wait for external IP
print('\nWaiting for external IP ...')
for i in range(30):
    try:
        svc = core_v1.read_namespaced_service(SERVICE_NAME, NAMESPACE)
        ingress = svc.status.load_balancer.ingress
        if ingress and ingress[0].ip:
            EXTERNAL_IP = ingress[0].ip
            print(f'External IP: {EXTERNAL_IP}')
            break
    except Exception as e:
        if '401' in str(e):
            refresh_k8s_auth()
    time.sleep(10)
else:
    print('Timeout waiting for external IP.')

# %% [markdown]
# ---
# ## Test Inference
#
# Send requests directly to Triton's HTTP API via the LoadBalancer IP — no authentication wrapper needed (unlike Vertex AI or Cloud Run).

# %%
TEST_INSTANCES = [
    "This movie is absolutely wonderful and I loved every minute of it!",
    "The food was terrible and the service was even worse.",
    "An average experience, nothing special but not bad either.",
]

triton_request = {
    "inputs": [{"name": "TEXT", "shape": [len(TEST_INSTANCES), 1], "datatype": "BYTES",
                "data": [[t] for t in TEST_INSTANCES]}],
    "outputs": [{"name": "LABEL"}, {"name": "SCORE"}],
}

response = httpx.post(f'http://{EXTERNAL_IP}:8000/v2/models/sentiment_ensemble/infer',
                      json=triton_request, timeout=60)
result = response.json()
outputs = {o['name']: o['data'] for o in result['outputs']}

print(f'GKE + L4 GPU (status: {response.status_code}):\n')
for text, label, score in zip(TEST_INSTANCES, outputs['LABEL'], outputs['SCORE']):
    if isinstance(label, list): label = label[0]
    if isinstance(score, list): score = score[0]
    print(f'  "{text[:60]}..."')
    print(f'    => {label} (score: {score:.6f})')
    print()

# %% [markdown]
# ---
# ## Model Repository Strategies
#
# | Strategy | Pros | Cons | Best for |
# |----------|------|------|----------|
# | **Baked-in** (above) | Simplest, no runtime deps | Rebuild container to update models | Stable models, CI/CD pipelines |
# | **GCS FUSE** | No rebuild, hot-reload capable | Startup latency (download), GCS costs | Frequent model updates |
# | **PVC** | Fastest startup (pre-loaded) | Provisioning complexity | Large models, lowest latency |
#
# ### GCS FUSE Volume Mount
#
# Mount a GCS bucket as a local filesystem using [GCS FUSE](https://cloud.google.com/kubernetes-engine/docs/how-to/persistent-volumes/cloud-storage-fuse-csi-driver). Triton reads the model repository from the mounted path at startup. Model updates in GCS are visible without rebuilding the container.
#
# > **Note:** GCS FUSE deployment is shown as a reference pattern. To use it, upload your model repository to GCS and modify the Deployment to use the FUSE sidecar annotation.
#
# ```yaml
# # Key annotations and volume config for GCS FUSE:
# metadata:
#   annotations:
#     gke-gcsfuse/volumes: "true"        # Enable FUSE sidecar
# spec:
#   volumes:
#     - name: model-repo
#       csi:
#         driver: gcsfuse.csi.storage.gke.io
#         volumeAttributes:
#           bucketName: "your-bucket"
#           mountOptions: "implicit-dirs"
#   containers:
#     - name: triton
#       command: ["tritonserver", "--model-repository=/models"]
#       volumeMounts:
#         - name: model-repo
#           mountPath: /models
#           subPath: "path/to/model_repository"
# ```

# %% [markdown]
# ---
# ## HPA with Triton Metrics
#
# Triton exposes [Prometheus metrics](https://docs.nvidia.com/deeplearning/triton-inference-server/user-guide/docs/user_guide/metrics.html) on port 8002. Key metrics for autoscaling:
#
# - `nv_inference_queue_duration_us` — Time requests wait in the queue (indicates load)
# - `nv_inference_request_success` — Successful inference count (throughput)
# - `nv_inference_compute_infer_duration_us` — Inference compute time
#
# For this notebook, we use a simple CPU-based HPA. Production deployments would use [custom metrics](https://cloud.google.com/kubernetes-engine/docs/how-to/custom-metrics) from Triton's Prometheus endpoint.
#
# ### Basic HPA

# %%
hpa = k8s_client.V1HorizontalPodAutoscaler(
    metadata=k8s_client.V1ObjectMeta(name='triton-hpa'),
    spec=k8s_client.V1HorizontalPodAutoscalerSpec(
        scale_target_ref=k8s_client.V1CrossVersionObjectReference(
            api_version='apps/v1', kind='Deployment', name=DEPLOYMENT_NAME,
        ),
        min_replicas=1,
        max_replicas=3,
        target_cpu_utilization_percentage=70,
    ),
)

try:
    autoscaling_v1.delete_namespaced_horizontal_pod_autoscaler('triton-hpa', NAMESPACE)
except Exception:
    pass

autoscaling_v1.create_namespaced_horizontal_pod_autoscaler(namespace=NAMESPACE, body=hpa)
print('HPA created: min=1, max=3, target CPU=70%')

# Brief wait for the controller to initialize
time.sleep(5)
hpa_status = autoscaling_v1.read_namespaced_horizontal_pod_autoscaler('triton-hpa', NAMESPACE)
print(f'Current replicas: {hpa_status.status.current_replicas}')
print(f'Desired replicas: {hpa_status.status.desired_replicas}')

# %% [markdown]
# ### Custom Metrics HPA (Reference)
#
# For production, configure HPA with Triton's inference metrics via the [Custom Metrics Stackdriver Adapter](https://cloud.google.com/kubernetes-engine/docs/how-to/custom-metrics):
#
# ```yaml
# apiVersion: autoscaling/v2
# kind: HorizontalPodAutoscaler
# metadata:
#   name: triton-hpa-custom
# spec:
#   scaleTargetRef:
#     apiVersion: apps/v1
#     kind: Deployment
#     name: triton-sentiment
#   minReplicas: 1
#   maxReplicas: 5
#   metrics:
#     - type: Pods
#       pods:
#         metric:
#           name: nv_inference_queue_duration_us
#         target:
#           type: AverageValue
#           averageValue: "50000"     # Scale up when avg queue > 50ms
# ```
#
# This requires:
# 1. [Prometheus → Cloud Monitoring export](https://cloud.google.com/stackdriver/docs/managed-prometheus) for Triton metrics
# 2. [Custom Metrics Adapter](https://cloud.google.com/kubernetes-engine/docs/how-to/custom-metrics) deployed to the cluster

# %% [markdown]
# ---
# ## Triton Prometheus Metrics
#
# Query Triton's metrics endpoint directly to see inference statistics.

# %%
metrics_response = httpx.get(f'http://{EXTERNAL_IP}:8002/metrics', timeout=30)
lines = metrics_response.text.split('\n')

# Show key metrics
key_metrics = ['nv_inference_request_success', 'nv_inference_request_failure',
               'nv_inference_count', 'nv_inference_exec_count']

print('Triton Metrics (selected):')
for line in lines:
    for metric in key_metrics:
        if line.startswith(metric) and not line.startswith('#'):
            print(f'  {line}')

# %% [markdown]
# ---
# ## Production Patterns
#
# ### Health Probes
#
# Triton provides built-in health endpoints:
# - **`/v2/health/live`** — Is the server process running? (liveness probe)
# - **`/v2/health/ready`** — Are all models loaded and ready? (readiness probe)
#
# Our deployment already uses these probes. The key settings:
# - **startupProbe:** Higher `failureThreshold` (30) to allow time for model loading
# - **readinessProbe:** Moderate frequency (10s) — removes pod from service if models fail
# - **livenessProbe:** Lower frequency (30s) — restarts pod only if server process dies
#
# ### Graceful Shutdown
#
# Triton handles SIGTERM gracefully — it stops accepting new requests, finishes in-flight requests, and exits. Kubernetes sends SIGTERM during pod termination. Set `terminationGracePeriodSeconds` to allow time for in-flight requests to complete.
#
# ### Rolling Updates
#
# The default Deployment strategy (`RollingUpdate`) works well with Triton:
# - New pods start and pass startup probe before receiving traffic
# - Old pods are drained and terminated
# - Zero-downtime model updates by changing the container image

# %% [markdown]
# ---
# ## Platform Comparison: Triton Deployment Options
#
# | Aspect | Vertex AI | Cloud Run | GKE |
# |--------|:---:|:---:|:---:|
# | **Setup complexity** | Low | Low | Medium |
# | **GPU options** | Vertex AI types | L4 | Any (L4, A100, H100) |
# | **Scale-to-zero** | No (min 1 replica) | Yes | Yes (with config) |
# | **Autoscaling** | Vertex AI native | Concurrency-based | HPA (CPU/custom) |
# | **Triton metrics** | Not exposed | Not exposed | Full Prometheus |
# | **Model repo updates** | Rebuild container | Rebuild container | GCS FUSE / rebuild |
# | **Auth model** | Access tokens | OIDC ID tokens | K8s RBAC / none |
# | **Prediction API** | rawPredict (HTTPS) | HTTPS | HTTP (LoadBalancer) |
# | **gRPC support** | No (rawPredict HTTP only) | No | Yes (port 8001) |
# | **Networking** | Managed | Managed | Full K8s control |
# | **Cost model** | Per-node-hour | Per-request | Per-pod |
# | **Best for** | ML teams, Model Registry | Serverless, bursty traffic | Full control, sustained load |

# %% [markdown]
# ---
# ## Cleanup
#
# Remove all Kubernetes resources and the GKE cluster.

# %%
# Refresh token in case it expired during the notebook run
refresh_k8s_auth()

# Delete K8s resources
print('Deleting Kubernetes resources ...')
try:
    autoscaling_v1.delete_namespaced_horizontal_pod_autoscaler('triton-hpa', NAMESPACE)
    print('  HPA deleted')
except Exception:
    pass

try:
    core_v1.delete_namespaced_service(SERVICE_NAME, NAMESPACE)
    print('  Service deleted')
except Exception:
    pass

try:
    apps_v1.delete_namespaced_deployment(DEPLOYMENT_NAME, NAMESPACE)
    print('  Deployment deleted')
except Exception:
    pass

# Brief wait for LoadBalancer cleanup before deleting cluster
print('Waiting for resource cleanup ...')
time.sleep(15)

# %%
# Delete the GKE cluster
print(f'Deleting cluster {GKE_CLUSTER} ...')
operation = gke.delete_cluster(name=f'{cluster_path}/clusters/{GKE_CLUSTER}')

while True:
    try:
        op_status = gke.get_operation(name=f'{cluster_path}/operations/{operation.name}')
        if op_status.status == container_v1.Operation.Status.DONE:
            print('Cluster deleted!')
            break
        print(f'  Status: {op_status.status.name} ...')
        time.sleep(15)
    except Exception:
        print('Cluster deleted!')
        break

# %% [markdown]
# ### Remove GCS Artifacts (Optional)

# %%
# for blob in bucket.list_blobs(prefix=f'{SERIES}/{EXPERIMENT}/'):
#     blob.delete()
# print(f'Removed gs://{GCS_BUCKET}/{SERIES}/{EXPERIMENT}/')
