# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FMLOps%2Fresources&file=graphics.ipynb)
# <!--- header table --->
# <table align="left">
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/MLOps/resources/graphics.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FMLOps%2Fresources%2Fgraphics.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/MLOps/resources/graphics.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/github-logo-32px.png" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/MLOps/resources/graphics.ipynb">
#       <img src="https://lh3.googleusercontent.com/UiNooY4LUgW_oTvpsNhPpQzsstV5W8F7rYgxgGBD85cWJoLmrOzhVs_ksK_vgx40SHs7jCqkTkCk=e14-rj-sc0xffffff-h130-w32" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# # Graphics For `./MLOps`
#
# - Embed images with relative links and html within markdown like this:
# ```
# <p align="center"><center>
#     <img src="./resources/images/grounding/vs_app_preview.png" width="75%">
# </center><p>
# ```

# %% [markdown]
# ## Installation

# %%
#!npm install -g @mermaid-js/mermaid-cli

# %% [markdown]
# ## Setup

# %%
import os
import base64
import requests
import subprocess
from IPython.display import Image, display

from mermaid import Mermaid

# %%
mainpath = './images/created/'

# %% [markdown]
# ## Colors

# %%
gcolors = dict(
    blue = ['#E8F0FE','#D2E3FC','#AECBFA','#8AB4F8','#669DF6','#4285F4','#1A73E8','#1967D2','#185ABC','#174EA6'],
    red = ['#FCE8E6','#FAD2CF','#F6AEA9','#F28B82','#EE675C','#EA4335','#D93025','#C5221F','#B31412','#A50E0E'],
    yellow = ['#FEF7E0','#FEEFC3','#FDE293','#FDD663','#FCC934','#FBBC04','#F9AB00','#F29900','#EA8600','#E37400'],
    green = ['#E6F4EA','#CEEAD6','#A8DAB5','#81C995','#5BB974','#34A853','#1E8E3E','#188038','#137333','#0D652D'],
    grey = ['#F8F9FA','#F1F3F4','#E8EAED','#DADCE0','#BDC1C6','#9AA0A6','#80868B','#5F6368','#3C4043','#202124']
)

# %%
import IPython
def colorer(scheme, text):
    for colors in scheme.keys():
        IPython.display.display(
            IPython.display.Markdown(
                ' '.join(
                    f'<span style="font-family: monospace"><span style="color: {color}">{text}</span></span>'
                    for color in scheme[colors]
                )
            )
        )
colorer(gcolors, 'Vertex AI')
# Out:
# <span style="font-family: monospace"><span style="color: #E8F0FE">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #D2E3FC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #AECBFA">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #8AB4F8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #669DF6">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #4285F4">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1A73E8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1967D2">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #185ABC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #174EA6">Vertex AI</span></span>
# ...

# %% [markdown]
# ---
# ## Helper Funtions: For Mermaid Plots
#
# Designed to render plots from encoded strings sent to `https://mermaid.ink` after [this tutorial](https://mermaid.js.org/ecosystem/tutorials.html#jupyter-integration-with-mermaid-js)

# %%
def mermaid_render(graph, mainpath = mainpath, filepath = None, remote = True):
    if filepath:
        # verify director exists:
        fullpath = mainpath+filepath
        directory = os.path.dirname(fullpath)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)
    
    if remote: # use mermaid.ink/img to do the render
        encode = base64.b64encode(graph.encode('utf-8')).decode('ascii')
        response = requests.get('https://mermaid.ink/img/' + encode)
        if filepath:
            # save file
            with open(fullpath, 'wb') as f:
                f.write(response.content)
        return Image(response.content)
    else: # use local mermaid-cli (mmdc)
    #    if filepath:
    #        with open(fullpath+'.mdd', 'w') as f:
    #            f.write(graph)
    #        subprocess.run(["mmdc", "-i", fullpath+'.mdd', "-o", fullpath]) # -o is output to file, -t for theme, -b for background, -i is the input graph
    #        os.remove(fullpath+'.mdd')
    #    else: print('The `filepath` parameter is required for local processing (remote = False).')
        print('Still working on headless chrome in notebook')
        return #Image(fullpath)

# %% [markdown]
# ---
# ## Example: /example/example.png

# %%
filepath = 'example/example.png'

# %%
mermaid_render("""
graph LR;
    A--> B & C & D;
    B--> A & E;
    C--> A & E;
    D--> A & E;
    E--> B & C & D;
""")

# %%
mermaid_render("""
graph LR;
    A--> B & C & D;
    B--> A & E;
    C--> A & E;
    D--> A & E;
    E--> B & C & D;
""", filepath = filepath)#, remote = False)

# %% [markdown]
# ---
# ## MLOps: /mlops/overview.png

# %%
filepath = 'mlops/overview.png'

# %%
inits = "%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20, 'subGraphTitleMargin': {'top': 15, 'bottom': 15}}}}%%"
mermaid_render(f"""
{inits}
flowchart LR
    subgraph vertexai [Vertex AI]
        direction TB
        subgraph ide ["Development (IDE)"]
            direction LR
            sdk([SDK])
            colab([Colab])
            ecolab(["Enterprise\nColab"])
            workbench(["Workbench\nInstances"])
            workstation(["Cloud\nWorkstations"])
            sdk ~~~ colab ~~~ ecolab ~~~ workbench ~~~ workstation
        end
        subgraph orchestrate [MLOps Orchestration Pipelines]
            direction TB
            subgraph lifecycle [ML Lifecycle]
                direction LR
                subgraph fm [Feature Management]
                    # %%fs{{Feature Store}}
                end
                subgraph train [Training]
                    # %%customjobs([Custom Jobs])
                    # %%persistant(["Persitant Resources"])
                    # %%htjob([Hyperparameter Tuning Jobs])
                    # %%nas(["Neural Architecture Search (NAS) Jobs"])
                    # %%trainpipe([Training Pipelines])
                    # %%customjobs ~~~ persistant ~~~ htjob ~~~ nas ~~~ trainpipe
                end
                subgraph serve [Serving]
                    # %%h1[ ]
                    # %%online([Online Endpoints])
                    # %%batch([Batch Predictions])
                    # %%vector([Vector Search])
                    # %%h2[ ]
                    # %%h1 ~~~ online ~~~ batch ~~~ vector ~~~ h2
                end
                subgraph monitoring [Model Monitoring]

                end
                fm ~~~ train ~~~ serve ~~~ monitoring
            end
            subgraph govern [Govern & Manage]
                direction LR
                registry([Model Registry])
                experiments([Experiment\nTracking])
                mlmeta([ML Metadata])
                observe([Observability])
                explain([Explainability])
                registry ~~~ experiments ~~~ mlmeta ~~~ observe ~~~ explain
            end
            lifecycle ~~~ govern
        end
        ide ~~~ orchestrate
    end
    dm[(Data Management)]
    cicd>CI/CD]
    dm ~~~ vertexai ~~~ cicd
    
    
    
    
    style vertexai fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    style dm fill:{gcolors['grey'][4]}, stroke:#333, stroke-width:1px, rx:10, ry:10
    style cicd fill:{gcolors['grey'][4]}, stroke:#333, stroke-width:1px, rx:10, ry:10
    
    style ide fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
        style sdk fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style colab fill:{gcolors['grey'][4]}, stroke-width:0px, rx:10, ry:10
        style ecolab fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style workbench fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style workstation fill:{gcolors['grey'][4]}, stroke-width:0px, rx:10, ry:10
    
    style orchestrate fill:{gcolors['green'][4]}, stroke:{gcolors['yellow'][4]}, stroke-width:14px, rx:10, ry:10
    
    style lifecycle fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
        style fm fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style train fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style serve fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style monitoring fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    style govern fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
        style registry fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style experiments fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style mlmeta fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style observe fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
        style explain fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    
    # %%style h1 fill-opacity:0, stroke-opacity:0
    # %%style h2 fill-opacity:0, stroke-opacity:0
""", filepath = filepath)

# %% [markdown]
# ---
# ## Feature Store: /featurestore/overview.png

# %%
filepath = 'featurestore/overview.png'

# %%
#"%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20, 'subGraphTitleMargin': {'top': 15, 'bottom': 15}}}}%%"
inits = "%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20}}}%%"
#inits =""
mermaid_render(f"""
{inits}
flowchart LR;
    subgraph bigquery [BigQuery]
        bq_table([Table/View])
    end
    subgraph feature_store [Vertex AI Feature Store]
        subgraph feature_registry [Feature Registry]
            feature_groups1([Feature Groups])
            feature_groups2([Feature Groups])
            features1([Feature])
            features2([Feature])
            features3([Feature])
            features4([Feature])
        end
        subgraph online_store [Online Store]
            feature_view1([Feature View])
            feature_view2([Feature View])
        end
    end
    
    bq_table -- (1 to 1) --> feature_groups1
    bq_table -- (1 to 1) --> feature_groups2
    feature_groups1 --> features1
    feature_groups1 --> features2
    feature_groups2 --> features3
    feature_groups2 --> features4
    features1 -- (1 or more) --> feature_view1
    features2 -- (1 or more) --> feature_view1
    features3 -- (1 or more) --> feature_view1
    features4 -- (1 or more) --> feature_view1
    bq_table -- 1 row per entity --> feature_view2
    
    style bigquery fill:{gcolors['blue'][4]}, stroke-width:0px, rx:10, ry:10
    style feature_store fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    style feature_registry fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
    style online_store fill:{gcolors['red'][4]}, stroke-width:0px, rx:10, ry:10
""", filepath = filepath)
