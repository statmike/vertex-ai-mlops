# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2Fdata%2Bai%2Fbq-ai-functions%2Ffunctions%2Fai_agg&file=ai_agg.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2Fdata%252Bai%2Fbq-ai-functions%2Ffunctions%2Fai_agg%2Fai_agg.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_agg/ai_agg.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # AI.AGG — BigQuery AI Functions
#
# `AI.AGG` is an aggregate function that uses a Gemini model to aggregate data based on natural language instructions. It automatically handles multi-level batching, so it can analyze data that exceeds the Gemini context window.
#
# **When to use it:**
# - You need to summarize, analyze, or find patterns across groups of rows
# - Your data may exceed the Gemini context window (AI.AGG auto-batches)
# - You want one result per GROUP BY group, not one per row
#
# **Alternatives:**
# - [`AI.GENERATE`](../ai_generate/) — Per-row generation. For aggregation, you'd need to manually batch data into a single prompt (e.g., with `STRING_AGG` or `ARRAY_AGG` + `TO_JSON_STRING`)
# - [`AI.GENERATE_TEXT`](../ai_generate_text/) — Same manual batching issue, but supports non-Gemini models
#
# **Key differences from AI.GENERATE:**
# - `AI.AGG` is an **aggregate** function (like `SUM`, `COUNT`) — use with `GROUP BY`
# - `AI.GENERATE` is a **scalar** function — returns one result per input row
# - `AI.AGG` automatically batches large datasets; `AI.GENERATE` requires manual batching
#
# **Featured in:** [Content Analysis Pipeline](../../workflows/content_analysis/) | [Content Moderation](../../workflows/content_moderation/) | [Document Intelligence](../../workflows/document_intelligence/) | [Log Analysis](../../workflows/log_analysis/)
#
# **Multimodal:** Supports image input via [ObjectRef](../../reference/unstructured-data-infrastructure.md#objectref-and-objectrefruntime-schema-reference). Pass a STRUCT input with `ObjectRef` fields to aggregate over images.
#
# **References:** [Full syntax reference](../../RESOURCES.md) | [Official documentation](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-ai-agg) | [Setup guide](../../setup/)

# %% [markdown]
# ---
# ## Setup
#
# Set your project and location, authenticate, and create a temporary dataset for this notebook.
#
# > This function doesn't require a connection or model for basic SQL usage — it uses end-user credentials automatically. A connection is needed for the `connection_id` parameter and multimodal examples. See the [Setup Reference](../../setup/) for details.

# %%
PROJECT_ID = 'statmike-mlops-349915'  # <-- Replace with your project ID
LOCATION = 'US'  # BigQuery dataset location
DATASET_ID = 'bq_ai_functions'  # Shared dataset across all notebooks
CONNECTION_ID = 'bq_ai_functions'  # Shared connection (for connection_id and multimodal examples)
BUCKET = PROJECT_ID  # GCS bucket for multimodal examples

# %% [markdown]
# ### Environment
#
# > **Already set up the project environment?** Skip to [Examples](#examples--sql).
# > **Running standalone** (Colab, Colab Enterprise, Vertex AI Workbench)? Run the cells below to install packages, authenticate, and create the shared dataset. See the [Setup Reference](../../setup/) for details.

# %%
import subprocess, sys, shutil

def install(*packages):
    """Install packages using uv (fast) with pip fallback."""
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install('google-cloud-bigquery', 'db-dtypes', 'bigquery-magics', 'tqdm', 'bigframes', 'google-cloud-storage')

# %%
# Authenticate (Colab only — other environments use Application Default Credentials)
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC is used automatically

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project=PROJECT_ID)
pd.set_option('display.max_colwidth', None)

# Create the shared dataset (idempotent)
dataset_ref = bigquery.DatasetReference(PROJECT_ID, DATASET_ID)
dataset = bigquery.Dataset(dataset_ref)
dataset.location = LOCATION
client.create_dataset(dataset, exists_ok=True)
print(f'Dataset {PROJECT_ID}.{DATASET_ID} ready')

# Register %%bigquery cell magic (auto-loaded in Colab, needed elsewhere)
# %load_ext bigquery_magics
# Out:
# Dataset statmike-mlops-349915.bq_ai_functions ready

# %%
import subprocess as _sp, json as _json

# Create connection (idempotent)
_sp.run(['bq', 'mk', '--connection', '--location', LOCATION,
         '--connection_type', 'CLOUD_RESOURCE',
         '--project_id', PROJECT_ID, CONNECTION_ID],
        capture_output=True, text=True)

# Get service account and grant required roles
r = _sp.run(['bq', 'show', '--connection', '--format=json',
             '--project_id', PROJECT_ID, '--location', LOCATION, CONNECTION_ID],
            capture_output=True, text=True, check=True)
sa = _json.loads(r.stdout)['cloudResource']['serviceAccountId']
for role in ['roles/aiplatform.user', 'roles/storage.objectViewer']:
    _sp.run(['gcloud', 'projects', 'add-iam-policy-binding', PROJECT_ID,
             f'--member=serviceAccount:{sa}', f'--role={role}', '--quiet'],
            capture_output=True, text=True)
print(f'Connection {CONNECTION_ID} ready (SA: {sa})')
# Out:
# Connection bq_ai_functions ready (SA: bqcx-1026793852137-hx0g@gcp-sa-bigquery-condel.iam.gserviceaccount.com)

# %% [markdown]
# ---
# ## Examples — SQL
#
# Progressive examples from simplest to most advanced. Each cell adds one new concept.
#
# `AI.AGG` is an **aggregate function** — it works like `SUM()` or `COUNT()`. Without `GROUP BY`, it aggregates all rows into one result. With `GROUP BY`, it returns one result per group.

# %% [markdown]
# ### 1. Simplest call — aggregate without GROUP BY
#
# Without `GROUP BY`, `AI.AGG` aggregates all input rows into a single summary.

# %%
query = """
SELECT
  AI.AGG(
    review,
    'What is the overall sentiment of these reviews?'
  ) AS sentiment_summary
FROM UNNEST([
  'Absolutely love this product! Best purchase ever.',
  'Terrible quality, broke after one week.',
  'Pretty decent for the price. Nothing fancy.',
  'Would not recommend. Waste of money.',
  'Exceeded my expectations in every way!'
]) AS review
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['sentiment_summary'])
# Out:
# The overall sentiment of these reviews is mixed, leaning slightly toward negative.
#
# While there are two highly positive reviews expressing strong satisfaction, they are offset by two strongly negative reviews citing poor quality and lack of value. One neutral review provides a balanced perspective, noting the product is acceptable for its price point. Overall, the feedback is polarized, indicating inconsistent customer experiences.

# %% [markdown]
# ### 2. GROUP BY — one summary per group
#
# `AI.AGG` returns one STRING per group, making it ideal for summarizing data by category.

# %%
query = """
SELECT
  category,
  AI.AGG(
    feedback,
    'Summarize the main themes in this feedback.'
  ) AS themes
FROM UNNEST([
  STRUCT('product' AS category, 'The battery life is incredible' AS feedback),
  STRUCT('product', 'Screen quality is outstanding'),
  STRUCT('product', 'Too heavy to carry around comfortably'),
  STRUCT('shipping', 'Arrived two days early, great packaging'),
  STRUCT('shipping', 'Package was damaged during transit'),
  STRUCT('shipping', 'Delivery took three weeks instead of five days'),
  STRUCT('support', 'Agent resolved my issue in minutes'),
  STRUCT('support', 'Was on hold for over an hour before getting help'),
  STRUCT('support', 'Very knowledgeable and patient support team')
]) AS t
GROUP BY category
"""
client.query(query).to_dataframe()
# Out:
#    category  \
# 0   product
# 1  shipping
# 2   support
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             themes
# 0                                                                                                                        The feedback highlights a contrast between the device's high-performance hardware and its physical portability. The main themes are:\n\n*   **Positive Performance:** Users are highly impressed with the battery longevity and the quality of the display.\n*   **Ergonomic Concerns:** The device is perceived as too heavy, which negatively impacts its portability and ease of use for mobile users.
# 1                                                       The feedback highlights significant inconsistency in the delivery experience. The main themes are:\n\n*   **Delivery Speed:** Experiences are polarized, ranging from early arrivals to significant delays.\n*   **Package Condition:** There are concerns regarding the physical handling of shipments, with reports of damage occurring during transit.\n*   **Logistics Reliability:** The overall sentiment suggests a lack of predictability in the shipping process.
# 2  The feedback highlights a significant contrast in the customer experience, centered on two main themes:\n\n*   **Support Quality:** Customers generally perceive the support team as highly effective, noting that agents are knowledgeable, patient, and capable of resolving issues quickly.\n*   **Wait Times:** There is a clear pain point regarding accessibility, specifically long hold times, which negatively impacts the overall service experience despite the high quality of the support provided once connected.

# %% [markdown]
# ### 3. DISTINCT — deduplicate before aggregating
#
# Use `DISTINCT` to remove duplicate inputs before sending them to the model.

# %%
query = """
SELECT
  AI.AGG(
    DISTINCT comment,
    'What topics do these comments discuss?'
  ) AS topics
FROM UNNEST([
  'Great performance on the new update',
  'Great performance on the new update',
  'Battery drain is still an issue',
  'Battery drain is still an issue',
  'Love the new camera features',
  'UI feels sluggish after the patch'
]) AS comment
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['topics'])
# Out:
# These comments discuss the following topics regarding the recent software update:
#
# *   **Performance:** Users have mixed feedback, noting both improved speed and sluggishness in the user interface.
# *   **Battery Life:** There are ongoing concerns regarding battery drain.
# *   **Features:** Users have expressed appreciation for the new camera capabilities.

# %% [markdown]
# ### 4. TO_JSON_STRING — aggregate structured rows
#
# Use `TO_JSON_STRING` to pass multiple columns as context. The model sees each row's full structure.

# %%
query = """
WITH tickets AS (
  SELECT *
  FROM UNNEST([
    STRUCT('Alice' AS agent, 'password reset' AS issue, 2 AS resolution_minutes),
    STRUCT('Alice', 'account locked', 5),
    STRUCT('Bob', 'billing error', 15),
    STRUCT('Bob', 'refund request', 30),
    STRUCT('Bob', 'subscription cancel', 8),
    STRUCT('Carol', 'login failure', 3),
    STRUCT('Carol', 'two-factor setup', 7)
  ])
)
SELECT
  agent,
  AI.AGG(
    TO_JSON_STRING(STRUCT(agent, issue, resolution_minutes)),
    'Analyze this support agent performance. What types of issues do they handle and how quickly?'
  ) AS performance_summary
FROM tickets
GROUP BY agent
"""
client.query(query).to_dataframe()
# Out:
#    agent  \
# 0  Alice
# 1    Bob
# 2  Carol
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   performance_summary
# 0                                                                                                                                                                                                                                                                                                                                                                                                                     Based on the data provided, here is the performance analysis for the support agent:\n\n**Issue Types Handled:**\nAlice handles account-related access issues, specifically **password resets** and **account lockouts**.\n\n**Resolution Speed:**\n*   **Average Resolution Time:** 3.5 minutes.\n*   **Performance Breakdown:**\n    *   **Password Resets:** Handled very efficiently in 2 minutes.\n    *   **Account Lockouts:** Handled in 5 minutes.\n\nOverall, Alice demonstrates a high level of efficiency, resolving both types of access issues in under 6 minutes.
# 1  Based on the data provided for Bob, here is an analysis of his performance:\n\n### **Issue Types Handled**\nBob handles a variety of administrative and financial support tasks, specifically:\n*   **Billing Errors:** Issues related to payment discrepancies.\n*   **Refund Requests:** Processing customer money-back inquiries.\n*   **Subscription Cancellations:** Managing account terminations.\n\n### **Resolution Speed**\nBob demonstrates high efficiency, with an average resolution time of **17.67 minutes** across all ticket types. \n\n*   **Fastest:** Subscription cancellations (8 minutes), suggesting he has a streamlined process for account closures.\n*   **Most Time-Consuming:** Refund requests (30 minutes), which likely require more verification or approval steps compared to other tasks.\n*   **Mid-Range:** Billing errors (15 minutes).\n\nOverall, Bob shows a strong ability to handle financial and account-based queries with a quick turnaround time.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Based on the data provided, Carol handles technical access and security-related issues. Her performance breakdown is as follows:\n\n*   **Issue Types:** She manages account access concerns, specifically "login failure" and "two-factor setup."\n*   **Resolution Speed:** She is highly efficient, with an average resolution time of **5 minutes** per issue. She resolves login failures very quickly (3 minutes) and requires slightly more time for two-factor setup (7 minutes).

# %% [markdown]
# ### 5. Finding patterns across data
#
# `AI.AGG` excels at root cause analysis and pattern identification across structured log data.

# %%
query = """
WITH error_logs AS (
  SELECT *
  FROM UNNEST([
    STRUCT('2025-01-15 08:23:01' AS timestamp, 'auth-service' AS service, 'Connection timeout to user DB' AS message),
    STRUCT('2025-01-15 08:23:05', 'auth-service', 'Failed to validate token: DB unavailable'),
    STRUCT('2025-01-15 08:23:12', 'api-gateway', 'Upstream auth-service returned 503'),
    STRUCT('2025-01-15 08:23:15', 'api-gateway', 'Circuit breaker opened for auth-service'),
    STRUCT('2025-01-15 08:24:00', 'payment-service', 'Transaction failed: auth token invalid'),
    STRUCT('2025-01-15 08:24:02', 'notification-service', 'Unable to send email: rate limit exceeded'),
    STRUCT('2025-01-15 08:25:00', 'auth-service', 'Connection to user DB restored'),
    STRUCT('2025-01-15 08:25:01', 'api-gateway', 'Circuit breaker closed for auth-service')
  ])
)
SELECT
  AI.AGG(
    TO_JSON_STRING(STRUCT(timestamp, service, message)),
    'Analyze these error logs. What was the root cause, which services were affected, and what was the sequence of events?'
  ) AS incident_analysis
FROM error_logs
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['incident_analysis'])
# Out:
# ### Incident Analysis Report
#
# #### Root Cause
# The root cause of the incident was a **connectivity failure between the `auth-service` and the user database**. This database outage prevented the authentication service from validating tokens, triggering a cascading failure across dependent services.
#
# #### Affected Services
# *   **`auth-service`**: Primary point of failure; unable to connect to the database.
# *   **`api-gateway`**: Experienced upstream errors and triggered circuit breaker protection.
# *   **`payment-service`**: Failed to process transactions due to the inability to validate authentication tokens.
# *   **`notification-service`**: Experienced secondary issues (rate limiting), likely due to retry logic or system instability during the outage.
#
# #### Sequence of Events
# 1.  **08:23:01 – 08:23:05**: The `auth-service` loses connection to the user database, resulting in connection timeouts and subsequent failures to validate user tokens.
# 2.  **08:23:12 – 08:23:15**: The `api-gateway` detects the `auth-service` failures (503 errors) and trips its circuit breaker to prevent further strain on the failing service.
# 3.  **08:24:00 – 08:24:02**: Downstream services begin reporting failures; the `payment-service` fails transactions due to invalid tokens, and the `notification-service` reports rate-limiting errors.
# 4.  **08:25:00 – 08:25:01**: The connection to the user database is restored. The `auth-service` recovers, and the `api-gateway` closes the circuit breaker, returning the system to normal operation.

# %% [markdown]
# ### 6. Specifying an endpoint
#
# Override the default model with any Gemini model that doesn't require thinking budget.

# %%
query = """
SELECT
  AI.AGG(
    review,
    'What do customers like and dislike? Be concise.',
    endpoint => 'gemini-2.5-flash'
  ) AS summary
FROM UNNEST([
  'Fast delivery but the box was crushed.',
  'Product works great, very happy with it.',
  'Instructions were confusing but the item itself is solid.'
]) AS review
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['summary'])
# Out:
# Customers like fast delivery and product quality/functionality. They dislike damaged packaging and confusing instructions.

# %% [markdown]
# ### 7. Using a public dataset
#
# Analyze real IMDB reviews grouped by movie — demonstrates AI.AGG's ability to handle large groups with automatic batching.

# %%
query = """
SELECT
  title,
  movie_id,
  AI.AGG(
    review,
    'Summarize the overall sentiment towards this movie.'
  ) AS sentiment
FROM `bigquery-public-data.imdb.reviews`
WHERE movie_id IN ('tt0339384', 'tt0084787', 'tt0029850')
GROUP BY movie_id, title
"""
client.query(query).to_dataframe()
# Out:
#                    title   movie_id  \
# 0       Alexander Nevsky  tt0029850
# 1              The Thing  tt0084787
# 2  Mickey's PhilharMagic  tt0339384
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        sentiment
# 0  The overall sentiment towards *Alexander Nevsky* is overwhelmingly positive, with many reviewers regarding it as a cinematic masterpiece and a landmark in film history. While viewers acknowledge its nature as a piece of 1938 Soviet propaganda, the consensus is that its artistic merits transcend its political origins.\n\nKey themes in the feedback include:\n\n*   **Visual Mastery:** Eisenstein’s direction, particularly his use of composition, editing, and the iconic "Battle on the Ice" sequence, is frequently cited as a benchmark for epic filmmaking. Many reviewers note its profound influence on subsequent directors and films, including *Lord of the Rings* and *Conan the Barbarian*.\n*   **Musical Brilliance:** Sergei Prokofiev’s score is almost universally praised. Many viewers consider the integration of music and imagery to be one of the film's greatest strengths, with some noting that the experience is even more powerful when performed with a live orchestra.\n*   **Stylistic Choices:** While some modern viewers find the acting "stilted," "mannered," or "melodramatic," others defend these choices as intentional artistic decisions consistent with Eisenstein’s theories of montage and his desire to create stylized, heroic archetypes rather than naturalistic characters.\n*   **Historical and Political Context:** Most reviewers recognize the film as a deliberate rallying cry against Nazi Germany. While some find the propaganda elements heavy-handed or the comic subplots jarring, most argue that the film should be appreciated as a significant work of art that reflects the values and tensions of its time.\n*   **Technical Considerations:** A recurring minor criticism involves the quality of the original sound and the effectiveness of the subtitles in some versions, though these are often viewed as secondary to the film's visual and auditory power.\n\nUltimately, the film is highly recommended by enthusiasts of cinema history, who view it as a "must-see" epic that remains visually and emotionally resonant decades after its release.
# 1                                                                                                                                                                               The overall sentiment towards John Carpenter’s *The Thing* (1982) is overwhelmingly positive, with many reviewers hailing it as a masterpiece of the horror and science fiction genres. While the film was a commercial and critical failure upon its initial release—largely due to being overshadowed by the optimistic tone of *E.T. the Extra-Terrestrial*—it has since achieved status as a legendary cult classic.\n\nKey themes in the audience's praise include:\n\n*   **Atmosphere and Tension:** Viewers consistently highlight the film’s masterful use of isolation, claustrophobia, and paranoia. The setting of Antarctica is frequently cited as the perfect backdrop for a story where the characters cannot trust one another.\n*   **Practical Effects:** There is widespread acclaim for Rob Bottin’s practical special effects. Many reviewers argue that these physical, "visceral" effects are superior to modern CGI, noting that they remain terrifying and impressive decades later.\n*   **Direction and Craft:** John Carpenter is highly praised for his direction, with many fans considering this his finest work. His ability to build suspense, his choice of a grounded, realistic cast, and his refusal to rely on typical Hollywood tropes are frequently lauded.\n*   **The Score:** Ennio Morricone’s minimalist, pulsing soundtrack is widely recognized as a crucial element that effectively heightens the film's sense of dread and doom.\n*   **Enduring Quality:** A recurring sentiment is that the film has aged remarkably well. Fans appreciate its uncompromising, bleak, and ambiguous ending, which stands in stark contrast to more conventional, "feel-good" cinema.\n\nIn summary, the audience views *The Thing* as an intelligent, terrifying, and technically brilliant film that was unfairly maligned in its time but has rightfully earned its place as one of the greatest horror movies ever made.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       The overall sentiment towards *Mickey's Philharmagic* is overwhelmingly positive and enthusiastic. Reviewers consistently describe it as a "breathtaking" and "magical" experience that transcends age, appealing equally to adults and children. \n\nKey highlights from the feedback include:\n*   **Technical Excellence:** The 3D effects are highly praised for their quality and immersion, with many noting they are among the best in the Disney parks.\n*   **Emotional Impact:** The combination of classic Disney music, humor, and nostalgia creates a joyful experience that leaves viewers smiling.\n*   **High Replay Value:** The show is so engaging that visitors frequently report wanting to watch it multiple times in a single day.\n*   **Broad Appeal:** Even those who do not identify as "Disney fans" or who are typically skeptical of 3D attractions found the show to be a standout highlight of their trip. \n\nIn summary, the consensus is that the attraction is a must-see, high-quality production that successfully captures the "magic" of Disney.

# %% [markdown]
# ### 8. Using connection_id — service account credentials
#
# By default, `AI.AGG` uses end-user credentials. The `connection_id` parameter lets you use a Cloud resource connection's service account instead — useful for shared environments, production pipelines, or when end-user credentials don't have Vertex AI access.

# %%
query = f"""
SELECT
  AI.AGG(
    review,
    'What is the overall sentiment of these reviews?',
    connection_id => '{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}'
  ) AS sentiment_summary
FROM UNNEST([
  'Absolutely love this product! Best purchase ever.',
  'Terrible quality, broke after one week.',
  'Pretty decent for the price. Nothing fancy.',
  'Would not recommend. Waste of money.',
  'Exceeded my expectations in every way!'
]) AS review
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['sentiment_summary'])
# Out:
# The overall sentiment of these reviews is mixed, leaning slightly toward negative.
#
# While there are two highly positive reviews expressing strong satisfaction, they are offset by two strongly negative reviews citing poor quality and lack of value. One neutral review provides a balanced perspective, noting the product is acceptable for its price point. Overall, the feedback is polarized, indicating inconsistent customer experiences.

# %% [markdown]
# ### 9. Quantitative aggregation — counting and ranking
#
# `AI.AGG` isn't limited to text summaries. It can count, rank, compare quantities, and extract structured insights from data — treating the model as an analyst, not just a summarizer.

# %%
query = """
WITH tasks AS (
  SELECT *
  FROM UNNEST([
    STRUCT('backend' AS team, 'critical' AS priority, 'Fix auth token expiry' AS task),
    STRUCT('backend', 'critical', 'Patch SQL injection vulnerability'),
    STRUCT('backend', 'high', 'Optimize query performance'),
    STRUCT('backend', 'medium', 'Add request logging'),
    STRUCT('frontend', 'critical', 'Fix checkout form validation'),
    STRUCT('frontend', 'high', 'Implement dark mode'),
    STRUCT('frontend', 'high', 'Add accessibility labels'),
    STRUCT('frontend', 'low', 'Update footer copyright year'),
    STRUCT('data', 'critical', 'Fix broken ETL pipeline'),
    STRUCT('data', 'high', 'Add data quality checks'),
    STRUCT('data', 'medium', 'Document schema changes'),
    STRUCT('data', 'medium', 'Archive old partitions')
  ])
)
SELECT
  AI.AGG(
    TO_JSON_STRING(STRUCT(team, priority, task)),
    'Count the tasks by priority level for each team. Which team has the most critical items? Present as a concise breakdown.'
  ) AS task_analysis
FROM tasks
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['task_analysis'])
# Out:
# ### Task Priority Breakdown by Team
#
# | Team | Critical | High | Medium | Low |
# | :--- | :---: | :---: | :---: | :---: |
# | **Backend** | 2 | 1 | 1 | 0 |
# | **Frontend** | 1 | 2 | 0 | 1 |
# | **Data** | 1 | 1 | 2 | 0 |
#
# **Team with the most critical items:** **Backend** (2 tasks).

# %% [markdown]
# ### 10. AI.AGG vs manual STRING_AGG + AI.GENERATE
#
# Before `AI.AGG`, aggregating data required manually concatenating rows into a single prompt with `STRING_AGG` + `AI.GENERATE`. This works for small datasets but breaks when data exceeds the context window. `AI.AGG` handles batching automatically.
#
# Compare both approaches on the same data:

# %%
query = """
WITH feedback AS (
  SELECT *
  FROM UNNEST([
    STRUCT('product' AS category, 'The battery life is incredible' AS comment),
    STRUCT('product', 'Screen quality is outstanding'),
    STRUCT('product', 'Too heavy to carry around comfortably'),
    STRUCT('shipping', 'Arrived two days early, great packaging'),
    STRUCT('shipping', 'Package was damaged during transit'),
    STRUCT('shipping', 'Delivery took three weeks instead of five days')
  ])
),

-- Approach 1: Manual STRING_AGG + AI.GENERATE (the old way)
manual_approach AS (
  SELECT
    category,
    (AI.GENERATE(
      CONCAT(
        'Summarize the main themes in this feedback: ',
        STRING_AGG(comment, ' | ')
      )
    )).result AS themes
  FROM feedback
  GROUP BY category
),

-- Approach 2: AI.AGG (the better way)
agg_approach AS (
  SELECT
    category,
    AI.AGG(comment, 'Summarize the main themes in this feedback.') AS themes
  FROM feedback
  GROUP BY category
)

SELECT
  'STRING_AGG + AI.GENERATE' AS approach,
  category, themes
FROM manual_approach
UNION ALL
SELECT
  'AI.AGG' AS approach,
  category, themes
FROM agg_approach
ORDER BY category, approach
"""
client.query(query).to_dataframe()
# Out:
#                    approach  category  \
# 0                    AI.AGG   product
# 1  STRING_AGG + AI.GENERATE   product
# 2                    AI.AGG  shipping
# 3  STRING_AGG + AI.GENERATE  shipping
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             themes
# 0                                                                                                                                                                                                        The feedback highlights a contrast between the device's high-performance hardware and its physical portability. The main themes are:\n\n*   **Positive Performance:** Users are highly impressed with the battery longevity and the quality of the display.\n*   **Ergonomic Concerns:** The device is perceived as too heavy, which negatively impacts its portability and ease of use for mobile users.
# 1                                                                                                                                                                                                                                                                                                                        The main themes in this feedback are:\n\n*   **Exceptional Battery Life:** The device offers a long-lasting battery.\n*   **High-Quality Display:** The screen provides an excellent visual experience.\n*   **Significant Weight:** The device is too heavy for comfortable portability.
# 2                                                                                                                                       The feedback highlights significant inconsistency in the delivery experience. The main themes are:\n\n*   **Delivery Speed:** Experiences are polarized, ranging from early arrivals to significant delays.\n*   **Package Condition:** There are concerns regarding the physical handling of shipments, with reports of damage occurring during transit.\n*   **Logistics Reliability:** The overall sentiment suggests a lack of predictability in the shipping process.
# 3  The main themes in this feedback are:\n\n*   **Positive:** The product itself was well-packaged internally ("great packaging") and arrived earlier than expected (though this is contradicted by other points).\n*   **Negative:**\n    *   **Shipping Damage:** The external packaging was compromised during transit.\n    *   **Extremely Slow Delivery:** The delivery timeframe was significantly longer than advertised (three weeks instead of five days).\n\nEssentially, while the internal packaging was good, the shipping process was severely flawed, leading to damage and a very long wait time.

# %% [markdown]
# ### 11. Multimodal — aggregate documents with ObjectRef
#
# `AI.AGG` takes multimodal input as a `STRUCT` wrapping an `ObjectRef`. An object table's `ref` column goes in directly.
#
# > **`AI.AGG` is the one multimodal function whose reference page still specifies `ObjectRefRuntime`** — every other `AI.*` page documents the input type as `ObjectRef` or `ARRAY<ObjectRef>`. The bare column works here anyway, and the page's own Known Issues argue for it: rows carrying arrays of `ObjectRefRuntime` objects "might be skipped," and some image objects created by `OBJ.GET_ACCESS_URL` "might fail to process." Passing `ref` sidesteps both.

# %%
from google.cloud import storage
from pathlib import Path

gcs = storage.Client(project=PROJECT_ID)
bucket = gcs.bucket(BUCKET)
prefix = 'bq_ai_functions/ai_agg_docs'

data_dir = Path('../../data/documents')
if not data_dir.exists():
    data_dir = Path('data/documents')

files_to_upload = [
    ('invoices/invoice_001.pdf', 'invoice_001.pdf'),
    ('invoices/invoice_002.pdf', 'invoice_002.pdf'),
    ('invoices/invoice_003.pdf', 'invoice_003.pdf'),
    ('receipts/receipt_001.pdf', 'receipt_001.pdf'),
    ('receipts/receipt_002.pdf', 'receipt_002.pdf'),
    ('receipts/receipt_003.pdf', 'receipt_003.pdf'),
]

for src, dst in files_to_upload:
    blob = bucket.blob(f'{prefix}/{dst}')
    if not blob.exists():
        blob.upload_from_filename(str(data_dir / src))
print(f'{len(files_to_upload)} documents uploaded to gs://{BUCKET}/{prefix}/')

client.query(f"""
CREATE OR REPLACE EXTERNAL TABLE `{PROJECT_ID}.{DATASET_ID}.ai_agg_docs`
WITH CONNECTION `{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}`
OPTIONS (
  object_metadata = 'SIMPLE',
  uris = ['gs://{BUCKET}/{prefix}/*.pdf']
)
""").result()
print('Object table ai_agg_docs ready')
# Out:
# 6 documents uploaded to gs://statmike-mlops-349915/bq_ai_functions/ai_agg_docs/
# Object table ai_agg_docs ready

# %%
query = f"""
SELECT
  AI.AGG(
    STRUCT(ref),
    'These are financial documents (invoices and receipts). Summarize the types of documents, the vendors/stores involved, and the typical transaction amounts.',
    connection_id => '{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}'
  ) AS document_summary
FROM
  `{PROJECT_ID}.{DATASET_ID}.ai_agg_docs`
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['document_summary'])
# Out:
# The provided financial documents consist of three professional service invoices and three retail sales receipts.
#
# The invoices come from Harmony Event Solutions LLC and Nexus Innovations Group for services such as event planning, software development, and strategic consulting. These represent significant business expenses, with individual totals ranging from $7,605.63 to $21,217.00.
#
# The retail receipts are from Gadget Galaxy, Tech Haven Electronics, and Electronics World. These cover minor purchases like electronic accessories, cables, and batteries, with much smaller transaction amounts between $68.68 and $96.75.
#
# In total, these six documents represent $39,147.82 in spending. While the average transaction is approximately $6,524.64, this figure is heavily influenced by the high-value professional service invoices, which make up the vast majority of the total expenditure.

# %%
# Cleanup multimodal resources
client.query(f'DROP EXTERNAL TABLE IF EXISTS `{PROJECT_ID}.{DATASET_ID}.ai_agg_docs`').result()
blobs = list(bucket.list_blobs(prefix=prefix))
for blob in blobs:
    blob.delete()
print(f'Cleaned up object table and {len(blobs)} GCS files')
# Out:
# Cleaned up object table and 6 GCS files

# %% [markdown]
# ---
# ## Examples — `%%bigquery` Magics
#
# The same examples using IPython magic commands. Magics let you write SQL directly in notebook cells without Python string wrapping.
#
# Key patterns:
# - `%%bigquery` — run SQL, display results inline
# - `%%bigquery df` — run SQL, capture results into a pandas DataFrame

# %% [markdown]
# ### Simple aggregation

# %%
# %%bigquery --project {PROJECT_ID}
#
# SELECT
#   AI.AGG(
#     review,
#     'What is the overall sentiment?'
#   ) AS sentiment
# FROM UNNEST([
#   'Love it!', 'Terrible.', 'It was okay.', 'Best purchase ever!'
# ]) AS review
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                                                                                                                                                                                                         sentiment
# 0  The overall sentiment is mixed, leaning slightly positive. While there are two highly enthusiastic positive reviews, there is also one strongly negative review and one neutral review, resulting in a balanced but polarized set of feedback.

# %% [markdown]
# ### Aggregation with GROUP BY — capture to DataFrame

# %%
# %%bigquery df_agg --project {PROJECT_ID}
#
# SELECT
#   category,
#   AI.AGG(
#     feedback,
#     'Summarize the main themes.'
#   ) AS themes
# FROM UNNEST([
#   STRUCT('product' AS category, 'Battery life is great' AS feedback),
#   STRUCT('product', 'Too heavy'),
#   STRUCT('shipping', 'Fast delivery'),
#   STRUCT('shipping', 'Box was damaged')
# ]) AS t
# GROUP BY category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_agg
# Out:
#    category  \
# 0   product
# 1  shipping
#
#                                                                                                                                                                                                                                                   themes
# 0                                                                                    The feedback highlights a trade-off between performance and portability: while the battery life is highly regarded, the device's weight is perceived as a drawback.
# 1  The main themes identified are:\n\n*   **Logistics Efficiency:** Positive feedback regarding the speed of delivery.\n*   **Packaging Quality:** Concerns regarding the condition of the product upon arrival due to damage to the shipping container.

# %% [markdown]
# ---
# ## Examples — BigFrames
#
# There is no native BigFrames API for `AI.AGG` yet. Use `session.read_gbq_query()` to execute AI.AGG queries and get results as a BigFrames DataFrame.

# %%
import bigframes.pandas as bpd

bpd.close_session()  # Reset session to apply connection settings
bpd.options.bigquery.project = PROJECT_ID
bpd.options.bigquery.location = LOCATION

# %% [markdown]
# ### AI.AGG via `read_gbq_query()`

# %%
query = """
SELECT
  category,
  AI.AGG(
    feedback,
    'Summarize the key themes in this feedback. Keep it concise.'
  ) AS themes
FROM UNNEST([
  STRUCT('product' AS category, 'Battery life is incredible' AS feedback),
  STRUCT('product', 'Screen quality is outstanding'),
  STRUCT('product', 'Too heavy to carry'),
  STRUCT('shipping', 'Arrived early, great packaging'),
  STRUCT('shipping', 'Package was damaged'),
  STRUCT('support', 'Quick and helpful response'),
  STRUCT('support', 'Long hold time before getting help')
]) AS t
GROUP BY category
"""
bf_df = bpd.read_gbq_query(query)
bf_df.to_pandas()
# Out:
#     Query processed 0 Bytes in a moment of slot time.
#    category  \
# 0   product
# 1  shipping
# 2   support
#
#                                                                                                                                                                                                     themes
# 0                                      The feedback highlights high satisfaction with the device's battery life and screen quality, contrasted by concerns regarding its excessive weight and portability.
# 1  The feedback highlights inconsistent delivery experiences, specifically noting positive impressions regarding early arrival and packaging quality, contrasted by reports of damaged items upon receipt.
# 2                          The feedback highlights a contrast in service quality: while the support team is praised for being quick and helpful, the experience is negatively impacted by long wait times.

# %% [markdown]
# ---
# ## Cleanup
#
# Most examples use inline data (UNNEST and public datasets). The multimodal example (Example 11) creates and cleans up its own GCS files and object table.

# %% [markdown]
# ### Remove all shared resources
#
# When finished with **all** notebooks, uncomment and run the cell below to delete the shared dataset and all tables, models, and other resources within it.

# %%
# client.delete_dataset(
#     f'{PROJECT_ID}.{DATASET_ID}',
#     delete_contents=True,
#     not_found_ok=True
# )
# print(f'Dataset {PROJECT_ID}.{DATASET_ID} deleted')
