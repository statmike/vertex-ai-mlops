# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2Fdata%2Bai%2Fbq-ai-functions%2Ffunctions%2Fai_generate_text&file=ai_generate_text.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2Fdata%252Bai%2Fbq-ai-functions%2Ffunctions%2Fai_generate_text%2Fai_generate_text.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # AI.GENERATE_TEXT — BigQuery AI Functions
#
# `AI.GENERATE_TEXT` is a table-valued function that generates text using a remote model. It supports Gemini, Claude, Llama, Mistral, and open models — making it the most flexible generation function.
#
# **When to use it:**
# - You need to use non-Gemini models (Claude, Llama, Mistral)
# - You want table-valued output with all input columns preserved
# - You need Google Search grounding with `ground_with_google_search`
# - You have an existing `CREATE MODEL` workflow
#
# **Alternatives:**
# - [`AI.GENERATE`](../ai_generate/) — Scalar function, no model required, Gemini only
# - [`AI.GENERATE_TABLE`](../ai_generate_table/) — TVF with structured output via output_schema
# - [`ML.GENERATE_TEXT`](../ml_generate_text/) — Legacy predecessor with ml_generate_text_ column prefixes
#
# **Multimodal:** Supports document, image, and video input via [ObjectRef](../../RESOURCES.md#objectref-and-objectrefruntime-schema-reference). Pass a STRUCT prompt with ObjectRefRuntime fields to analyze unstructured data from Cloud Storage.
#
# **References:** [Full syntax reference](../../RESOURCES.md) | [Official documentation](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-ai-generate-text) | [Setup guide](../../setup/)

# %% [markdown]
# ---
# ## Setup
#
# Set your project and location, authenticate, and create a temporary dataset for this notebook.
#
# > This function requires a connection and a remote model. The cells below create them if they don't exist. See the [Setup Reference](../../setup/) for details.

# %%
PROJECT_ID = 'statmike-mlops-349915'  # <-- Replace with your project ID
LOCATION = 'US'  # BigQuery dataset location
DATASET_ID = 'bq_ai_functions'  # Shared dataset across all notebooks
CONNECTION_ID = 'bq_ai_functions'  # Shared connection
BUCKET = PROJECT_ID  # GCS bucket (same name as project)

# %% [markdown]
# ### Environment
#
# > **Already set up the project environment?** The cell below is a no-op — packages are already in your kernel. See the [Setup Reference](../../setup/) for details.
# >
# > **Running standalone** (Colab, Colab Enterprise, Vertex AI Workbench)? The cell below installs required packages into your current kernel.

# %%
import subprocess, sys, shutil

def install(*packages):
    """Install packages using uv (fast) with pip fallback."""
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install('google-cloud-bigquery', 'db-dtypes', 'bigquery-magics', 'tqdm', 'bigframes', 'google-cloud-storage')

# %%
# Authenticate (Colab only — other environments use Application Default Credentials)
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC is used automatically

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project=PROJECT_ID)
pd.set_option('display.max_colwidth', None)

# Create the shared dataset (idempotent)
dataset_ref = bigquery.DatasetReference(PROJECT_ID, DATASET_ID)
dataset = bigquery.Dataset(dataset_ref)
dataset.location = LOCATION
client.create_dataset(dataset, exists_ok=True)
print(f'Dataset {PROJECT_ID}.{DATASET_ID} ready')

# Register %%bigquery cell magic (auto-loaded in Colab, needed elsewhere)
# %load_ext bigquery_magics
# Out:
# Dataset statmike-mlops-349915.bq_ai_functions ready

# %%
import subprocess as _sp, json as _json

# Create connection (idempotent)
_sp.run(['bq', 'mk', '--connection', '--location', LOCATION,
         '--connection_type', 'CLOUD_RESOURCE',
         '--project_id', PROJECT_ID, CONNECTION_ID],
        capture_output=True, text=True)

# Get service account and grant Vertex AI User role
r = _sp.run(['bq', 'show', '--connection', '--format=json',
             '--project_id', PROJECT_ID, '--location', LOCATION, CONNECTION_ID],
            capture_output=True, text=True, check=True)
sa = _json.loads(r.stdout)['cloudResource']['serviceAccountId']
for role in ['roles/aiplatform.user', 'roles/storage.objectViewer']:
    _sp.run(['gcloud', 'projects', 'add-iam-policy-binding', PROJECT_ID,
             f'--member=serviceAccount:{sa}', f'--role={role}', '--quiet'],
            capture_output=True, text=True)
print(f'Connection {CONNECTION_ID} ready (SA: {sa})')
# Out:
# Connection bq_ai_functions ready (SA: bqcx-1026793852137-hx0g@gcp-sa-bigquery-condel.iam.gserviceaccount.com)

# %%
# Create remote Gemini model (idempotent)
client.query(f'''
CREATE OR REPLACE MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`
  REMOTE WITH CONNECTION `{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}`
  OPTIONS (endpoint = \'gemini-2.5-flash\')
''').result()
print('Model gemini_flash ready')
# Out:
# Model gemini_flash ready

# %% [markdown]
# ---
# ## Examples — SQL
#
# Progressive examples from simplest to most advanced. Each cell adds one new concept.

# %% [markdown]
# ### 1. Simplest call — single prompt
#
# The input query must have a `prompt` column. AI.GENERATE_TEXT returns all input columns plus `result`, `status`, and metadata columns.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is BigQuery?' AS prompt)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# **BigQuery is a fully-managed, serverless, highly scalable, and cost-effective enterprise data warehouse designed by Google Cloud.**
#
# In simpler terms, it's like a super-powered database that lets you analyze massive amounts of data very quickly, without having to worry about managing any of the underlying infrastructure.
#
# Here's a breakdown of what that means and why it's so powerful:
#
# **Key Characteristics and Features:**
#
# *   **Fully-Managed & Serverless:** This is a huge advantage. You don't need to provision, maintain, or scale servers. Google handles all the infrastructure, patching, and upgrades. You just upload your data and start querying. This frees up your engineers to focus on analysis rather than operations.
# *   **Highly Scalable:** BigQuery can handle petabytes and even exabytes of data. It automatically scales compute and storage resources as your data grows and your queries become more complex, without any manual intervention.
# *   **Cost-Effective:** You only pay for the storage you use and the data you query. There are no upfront costs for infrastructure, and Google's unique architecture (separation of compute and storage) makes it very efficient.
# *   **Columnar Storage:** Unlike traditional row-oriented databases, BigQuery stores data in a columnar format. This is highly optimized for analytical queries (like summing a column or finding averages) because it only needs to read the relevant columns, not entire rows.
# *   **Massively Parallel Processing (MPP):** BigQuery uses a distributed architecture to process queries across thousands of machines simultaneously. This is what enables its incredible speed, even on massive datasets.
# *   **Standard SQL:** BigQuery uses standard SQL, making it familiar to anyone with database experience. This reduces the learning curve and allows for easy integration with existing tools.
# *   **Real-time Analytics:** It can ingest and query streaming data in real-time, allowing for up-to-the-minute insights.
# *   **Built-in Machine Learning (BigQuery ML):** You can build and execute machine learning models directly within BigQuery using SQL. This simplifies the ML workflow for analysts and data scientists.
# *   **GeoSpatial Analysis (BigQuery GIS):** Supports geospatial data types and functions, allowing for powerful location-based analysis.
# *   **Data Sharing and Collaboration:** Easily share datasets and query results with other users or even publicly.
# *   **Integration with Google Cloud Ecosystem:** Seamlessly integrates with other Google Cloud services like Dataflow, Dataproc, Looker Studio (formerly Google Data Studio), Cloud Storage, and more.
# *   **Data Governance and Security:** Robust security features including encryption at rest and in transit, identity and access management (IAM), and compliance certifications.
#
# **How it Works (Simplified):**
#
# 1.  **Ingest Data:** You load your data into BigQuery. This can be from various sources like files in Cloud Storage (CSV, JSON, Parquet, Avro), streaming data from Pub/Sub, or other databases.
# 2.  **Store Data:** BigQuery stores this data in its highly optimized columnar format across distributed storage.
# 3.  **Query Data:** You write SQL queries to analyze your data.
# 4.  **Process Query:** BigQuery's query engine automatically distributes the query processing across thousands of servers, leveraging its MPP architecture to return results very quickly.
# 5.  **Return Results:** The results are returned to you, ready for further analysis, visualization, or integration with other applications.
#
# **Who uses BigQuery and Why?**
#
# *   **Data Analysts:** For ad-hoc querying, reporting, and dashboarding on large datasets.
# *   **Data Scientists:** For preparing data for machine learning, feature engineering, and building ML models directly in BigQuery ML.
# *   **Business Intelligence (BI) Professionals:** To power interactive dashboards and reports using tools like Looker, Tableau, Power BI, etc.
# *   **Developers:** To build data-driven applications that require fast access to large amounts of data.
# *   **Enterprises:** For data warehousing, operational analytics, customer behavior analysis, supply chain optimization, and much more across various industries.
#
# **In essence, BigQuery empowers organizations to extract valuable insights from their vast amounts of data quickly and efficiently, without the operational burden of traditional data warehouses.** It's a cornerstone of modern data analytics and business intelligence in the cloud.

# %% [markdown]
# ### 2. Processing multiple rows
#
# Each row in the input gets its own model call. The prompt column is built with CONCAT.

# %%
query = f'''
SELECT prompt, result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT CONCAT('What country is ', city, ' in? Answer in one word.') AS prompt, city
   FROM UNNEST(['Tokyo', 'Paris', 'Nairobi']) AS city)
)
'''
client.query(query).to_dataframe()
# Out:
#                                             prompt  result
# 0    What country is Paris in? Answer in one word.  France
# 1  What country is Nairobi in? Answer in one word.   Kenya
# 2    What country is Tokyo in? Answer in one word.   Japan

# %% [markdown]
# ### 3. Controlling generation parameters
#
# Pass generation parameters as a STRUCT. Parameters are named arguments, not JSON.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'Write a haiku about cloud computing.' AS prompt),
  STRUCT(0.8 AS temperature, 100 AS max_output_tokens)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# Servers in the sky,
# Data flows, a digital stream,
# Flexible, on demand.

# %% [markdown]
# ### 4. Google Search grounding
#
# Enable Google Search grounding with `ground_with_google_search`. The model will search the web for current information.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is the current population of Tokyo?' AS prompt),
  STRUCT(TRUE AS ground_with_google_search)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# The estimated population of the Tokyo urban agglomeration in 2026 is 36,953,600. This figure represents the population of Tokyo along with its adjacent suburban areas. Other sources estimate the current metro area population of Tokyo in 2026 to be 36,954,000, which is a 0.22% decline from 2025.
#
# It's worth noting that defining the "population of Tokyo" can be complex due to how its figures are laid out. The 23 wards that historically made up the city of Tokyo had an approximate population of 9,262,046 in 2016. However, the Tokyo metropolis itself has a population exceeding 13 million. The greater Tokyo metropolitan area, which spans over three prefectures, is considerably larger, with an estimated population of over 36 million, making it the most populous metropolitan area in the world.

# %% [markdown]
# ### 5. Safety settings
#
# Control content safety filtering with `safety_settings`.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'Explain the science of fireworks.' AS prompt),
  STRUCT(
    [STRUCT('HARM_CATEGORY_DANGEROUS_CONTENT' AS category, 'BLOCK_ONLY_HIGH' AS threshold)] AS safety_settings
  )
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# Fireworks are a beautiful blend of chemistry, physics, and art, all carefully orchestrated to create dazzling displays of light, sound, and smoke. Here's a breakdown of the science behind them:
#
# ## The Fundamental Components of a Firework:
#
# Every firework, from a simple firecracker to a massive aerial shell, contains five key components:
#
# 1.  **Oxidizer:** Provides the oxygen needed for combustion. Without an oxidizer, the fuel wouldn't burn effectively or at all. Common oxidizers include potassium nitrate ($\text{KNO}_3$), potassium perchlorate ($\text{KClO}_4$), and potassium chlorate ($\text{KClO}_3$).
# 2.  **Fuel:** The substance that burns, releasing energy in the form of heat and light. Charcoal (carbon) and sulfur are common fuels. Metals like aluminum and magnesium are also used as fuels, contributing to bright white light and heat.
# 3.  **Binder:** A substance that holds the fuel and oxidizer together in a solid, compact form, creating a "pyrotechnic star" or "composition." Dextrin (a starch) is a common binder, mixed with water to form a paste.
# 4.  **Colorant:** Specific metal salts that, when heated to high temperatures, emit light at characteristic wavelengths, producing the vibrant colors we see. This is the heart of a firework's visual appeal.
# 5.  **Stabilizer/Chlorine Donor (optional but common):** Some metal salts require chlorine to produce their characteristic color. Chlorine donors (like PVC or hexachloroethane) help achieve this. Stabilizers like sodium bicarbonate ($\text{NaHCO}_3$) can prevent unwanted reactions or decomposition.
#
# ## How a Firework Works (A General Aerial Shell):
#
# Let's trace the journey of a typical aerial firework, the kind shot into the sky:
#
# 1.  **Lift Charge (Launch):** At the bottom of the firework shell is a "lift charge" – usually black powder (a mixture of potassium nitrate, charcoal, and sulfur). This charge is ignited by a fuse. The rapid burning of the black powder produces a large volume of hot gas, propelling the shell high into the air through a launch tube (mortar).
#
# 2.  **Time Delay Fuse:** As the lift charge ignites, it also lights a time delay fuse within the shell. This fuse is designed to burn for a specific duration, allowing the shell to reach its maximum altitude before the main burst.
#
# 3.  **Burst Charge:** At the core of the firework shell, surrounded by the pyrotechnic stars, is the "burst charge" – again, usually black powder. When the time delay fuse burns down, it ignites the burst charge.
#
# 4.  **Star Dispersion and Ignition:** The rapid explosion of the burst charge does two things:
#     *   **Disperses the Stars:** It forcefully ejects the pre-made pyrotechnic "stars" (small pellets containing fuel, oxidizer, binder, and colorant) outward in all directions.
#     *   **Ignites the Stars:** The extreme heat from the burst charge ignites the outer layer of each star.
#
# 5.  **Combustion and Light Emission (The "Magic"):** This is where the science of color comes into play:
#
#     *   **Incandescence:** As the fuel and oxidizer in the star burn, they generate immense heat (thousands of degrees Celsius). Small solid particles of burning fuel, hot metal, and reaction products are heated to incandescence. Like a glowing piece of coal, they emit light across a broad spectrum, contributing to the bright white and yellow aspects of the firework. Metals like aluminum and magnesium are particularly good at incandescence, creating bright white sparks.
#     *   **Atomic Emission (The Colors!):** This is the primary mechanism for the distinct, vibrant colors. The high temperatures energize the electrons in the metal atoms within the colorants. These energized electrons jump to higher energy levels. However, they are unstable in these higher states and quickly fall back to their original, lower energy levels. As they fall, they release the excess energy as photons of light. The *wavelength* of the photon (and thus the color we perceive) is specific to the energy difference between the levels, which in turn is specific to the type of metal atom. This is the same principle used in neon signs and atomic spectroscopy.
#
# ## The Chemistry of Color:
#
# Here's a table of common colorants and their corresponding colors:
#
# | Color       | Metal Compound (Example)              | Mechanism                                                 |
# | :---------- | :------------------------------------ | :-------------------------------------------------------- |
# | **Red**     | Strontium salts (e.g., Strontium Carbonate ($\text{SrCO}_3$)) | Atomic emission from Strontium (Sr) atoms.            |
# | **Orange**  | Calcium salts (e.g., Calcium Chloride ($\text{CaCl}_2$))     | Atomic emission from Calcium (Ca) atoms.              |
# | **Yellow**  | Sodium salts (e.g., Sodium Nitrate ($\text{NaNO}_3$))       | Atomic emission from Sodium (Na) atoms.               |
# | **Green**   | Barium salts (e.g., Barium Chloride ($\text{BaCl}_2$))       | Atomic emission from Barium (Ba) atoms.               |
# | **Blue**    | Copper salts (e.g., Copper(I) Chloride ($\text{CuCl}$))     | Atomic emission from Copper (Cu) atoms. Requires a chlorine donor to form $\text{CuCl}$ in situ.  Blue is notoriously difficult to achieve purely and brightly. |
# | **Violet/Purple** | Mixture of Strontium (red) and Copper (blue) salts | Combination of atomic emissions from both metals.     |
# | **White**   | Magnesium (Mg) or Aluminum (Al) metals | Intense incandescence of burning metal particles.         |
# | **Silver**  | Aluminum or Magnesium flakes, Titanium filings | Incandescence and sparking from burning metal flakes. |
#
# ## Other Effects:
#
# *   **Sound (Crackles, Whistles, Bangs):**
#     *   **Bangs:** Caused by a rapid, confined explosion, often using black powder or flash powder (a more energetic mixture of oxidizer and metal powder like aluminum or magnesium).
#     *   **Whistles:** Produced by a rapidly burning pyrotechnic composition pressed into a tube. As the gases escape, they resonate within the tube, creating a whistling sound.
#     *   **Crackles/Popping:** Achieved by incorporating bismuth oxide into the star composition. When ignited, it produces tiny, rapid explosions.
#
# *   **Smoke:** The particulate matter (soot, unburnt fuel, metal oxides, and other reaction products) generated by the combustion of the pyrotechnic composition. Different compositions can produce different colored smoke, though less common in traditional aerial fireworks.
#
# *   **Sparkles/Trails:**
#     *   **Long-lasting trails:** Often achieved by adding iron filings or charcoal to the stars. The burning particles create a bright, shimmering effect as they fall.
#     *   **Glitter:** Large, slow-burning metallic flakes (often aluminum-magnesium alloys) that produce a sparkling effect.
#
# ## Safety and Environmental Concerns:
#
# While beautiful, fireworks involve dangerous chemistry:
#
# *   **Explosives:** They are inherently explosive and require careful handling.
# *   **Toxic Byproducts:** The combustion of various chemicals releases gases and particulate matter into the atmosphere, including sulfur dioxide, carbon monoxide, nitrogen oxides, and metallic residues.
# *   **Perchlorates:** Often used as oxidizers, perchlorates can be persistent in the environment and affect water quality.
# *   **Noise Pollution:** The loud explosions can be distressing to people, pets, and wildlife.
#
# ## The Art and Engineering:
#
# Beyond the chemistry, fireworks involve significant engineering and artistry:
#
# *   **Star Arrangement:** The way stars are packed into the shell (e.g., in concentric rings, specific patterns) determines the final shape of the burst (e.g., peony, chrysanthemum, willow, ring).
# *   **Timing:** Precise timing of the lift charge, delay fuse, and burst charge is crucial for the shell to reach its intended altitude and explode at the right moment.
# *   **Multi-Break Shells:** Complex fireworks can contain multiple compartments, each with its own burst charge and stars, leading to a sequence of explosions and effects.
#
# In essence, a firework is a carefully engineered chemical reaction, designed to create a momentary, controlled explosion that transforms chemical energy into stunning visual and auditory spectacle.

# %% [markdown]
# ### 6. Inspecting response metadata
#
# `AI.GENERATE_TEXT` returns additional columns beyond `result`: `full_response` (full JSON), `status`, `safety_attributes`, and token usage. These are useful for debugging, cost tracking, and safety auditing.

# %%
query = f'''
SELECT *
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is 2 + 2? Answer in one word.' AS prompt)
)
'''
df = client.query(query).to_dataframe()
print('Columns returned:', list(df.columns))
print(f'Result: {df.iloc[0]["result"]}')
print(f'Status: {df.iloc[0]["status"]}')
# Out:
# Columns returned: ['result', 'rai_result', 'grounding_result', 'statistics', 'full_response', 'status', 'prompt']
# Result: Four
# Status:

# %% [markdown]
# ### 7. Processing table data at scale
#
# Use a CTE or subquery to select specific rows, then pass to AI.GENERATE_TEXT. Materialize first when using LIMIT to avoid extra charges.

# %%
query = f'''
WITH reviews AS (
  SELECT *
  FROM UNNEST([
    STRUCT('r1' AS id, 'Amazing product, fast delivery!' AS review),
    STRUCT('r2', 'Terrible quality. Broke after one day.'),
    STRUCT('r3', 'Average product, nothing special.'),
    STRUCT('r4', 'Great value for the price!')
  ])
)
SELECT id, review, result AS sentiment
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT id, review,
   CONCAT('Classify this review as positive, negative, or neutral. Return only the label: ', review) AS prompt
   FROM reviews)
)
'''
client.query(query).to_dataframe()
# Out:
#    id                                  review sentiment
# 0  r1         Amazing product, fast delivery!  Positive
# 1  r4              Great value for the price!  Positive
# 2  r3       Average product, nothing special.   Neutral
# 3  r2  Terrible quality. Broke after one day.  Negative

# %% [markdown]
# ---
# ## Examples — Multimodal with ObjectRef
#
# `AI.GENERATE_TEXT` can analyze documents, images, and video stored in Cloud Storage. Use the **ObjectRef pipeline** to create a STRUCT prompt with signed references:
#
# ```
# OBJ.MAKE_REF(uri, connection)        → ObjectRef
#   → OBJ.FETCH_METADATA(objectref)    → adds content type and size
#     → OBJ.GET_ACCESS_URL(ref, 'r')   → ObjectRefRuntime (signed URL)
# ```
#
# The STRUCT replaces the STRING prompt. See the [ObjectRef reference](../../RESOURCES.md#objectref-and-objectrefruntime-schema-reference) for details.

# %%
from google.cloud import storage as _storage
from pathlib import Path

# Upload invoice for the multimodal example
_gcs = _storage.Client(project=PROJECT_ID)
_bucket = _gcs.bucket(BUCKET)
_prefix = 'bq_ai_functions/ai_generate_text'

_data = Path('../../data/documents')
if not _data.exists():
    _data = Path('data/documents')

blob = _bucket.blob(f'{_prefix}/invoice_001.pdf')
if not blob.exists():
    blob.upload_from_filename(str(_data / 'invoices' / 'invoice_001.pdf'))
    print(f'Uploaded invoice_001.pdf → gs://{BUCKET}/{_prefix}/invoice_001.pdf')
else:
    print(f'Already exists: gs://{BUCKET}/{_prefix}/invoice_001.pdf')
# Out:
# Uploaded invoice_001.pdf → gs://statmike-mlops-349915/bq_ai_functions/ai_generate_text/invoice_001.pdf

# %% [markdown]
# ### 8. Summarize a document
#
# Pass a document via ObjectRef using a STRUCT prompt to analyze content from Cloud Storage.

# %%
query = f"""
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT STRUCT(
    'Summarize this document in 2-3 sentences.' AS prompt,
    [OBJ.GET_ACCESS_URL(
      OBJ.FETCH_METADATA(
        OBJ.MAKE_REF(
          'gs://{BUCKET}/bq_ai_functions/ai_generate_text/invoice_001.pdf',
          '{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}'
        )
      ), 'r'
    )] AS object_ref_runtime
  ) AS prompt)
)
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# This invoice from Nexus Innovations Group to Global Reach Marketing LLC (Attn: Samantha Chen) details charges for marketing services. The services include Website Redesign & Development (Phase 1), Strategic Consulting - Q3 2024, and Social Media Management - July 2024. The total amount due for invoice INV-2024-0013 is $10,067.25, with payment due by August 14, 2024.

# %% [markdown]
# ---
# ## Examples — `%%bigquery` Magics
#
# The same examples using IPython magic commands. Magics let you write SQL directly in notebook cells without Python string wrapping.
#
# Key patterns:
# - `%%bigquery` — run SQL, display results inline
# - `%%bigquery df` — run SQL, capture results into a pandas DataFrame

# %% [markdown]
# ### Basic call with `%%bigquery`
#
# **Note:** `%%bigquery` magics cannot interpolate Python variables in the SQL body. Use `--project` on the magic line for project, but model/table references must be hardcoded or use `client.query()` instead.
#
# Since AI.GENERATE_TEXT requires a `MODEL` reference with project/dataset, most examples are better run via `client.query()` with f-strings. Here we show one example with hardcoded references.

# %%
# %%bigquery --project {PROJECT_ID}
#
# SELECT result
# FROM AI.GENERATE_TEXT(
#   MODEL `statmike-mlops-349915.bq_ai_functions.gemini_flash`,
#   (SELECT 'Write a haiku about SQL.' AS prompt),
#   STRUCT(0.8 AS temperature)
# )
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                                               result
# 0  Data's structured home,\nQueries unlock hidden truths,\nKnowledge starts to flow.

# %% [markdown]
# ### Capture results to a DataFrame

# %%
# %%bigquery df_text --project {PROJECT_ID}
#
# SELECT city, result AS country
# FROM AI.GENERATE_TEXT(
#   MODEL `statmike-mlops-349915.bq_ai_functions.gemini_flash`,
#   (SELECT CONCAT('What country is ', city, ' in? One word.') AS prompt, city
#    FROM UNNEST(['Tokyo', 'Paris', 'Nairobi']) AS city)
# )
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_text
# Out:
#       city country
# 0    Paris  France
# 1    Tokyo   Japan
# 2  Nairobi   Kenya

# %% [markdown]
# ---
# ## Examples — BigFrames
#
# BigFrames wraps `AI.GENERATE_TEXT` via `bbq.ai.generate_text()`. It takes a model name string and a DataFrame.
#
# **Key difference from SQL:** The function takes a model name and a DataFrame/Series with a `prompt` column.

# %%
import bigframes.pandas as bpd
import bigframes.bigquery as bbq

bpd.options.bigquery.project = PROJECT_ID
bpd.options.bigquery.location = LOCATION

# %% [markdown]
# ### Basic generation

# %%
# Create input DataFrame with a 'prompt' column
df = bpd.DataFrame({
    'city': ['Tokyo', 'Paris', 'Nairobi'],
    'prompt': [
        'What country is Tokyo in? Answer in one word.',
        'What country is Paris in? Answer in one word.',
        'What country is Nairobi in? Answer in one word.',
    ]
})

# Use the model reference as a string
model_name = f'{PROJECT_ID}.{DATASET_ID}.gemini_flash'
result = bbq.ai.generate_text(model_name, df)

result[['city', 'result']].to_pandas()
# Out:
#     Query processed 0 Bytes in 11 seconds of slot time. [<a target="_blank" href="https://console.cloud.google.com/bigquery?project=statmike-mlops-349915&j=bq:US:9f70b66a-6f2d-4d76-8925-97e08c099575&page=queryresults">Job statmike-mlops-349915:US.9f70b66a-6f2d-4d76-8925-97e08c099575 details</a>]
#     Query processed 166 Bytes in a second of slot time.
#       city  result
# 0    Paris  France
# 1    Tokyo   Japan
# 2  Nairobi   Kenya

# %% [markdown]
# ---
# ## Cleanup
#
# Remove GCS files uploaded for the multimodal examples. Shared resources (dataset, models, connection) are left for other notebooks.

# %%
# Delete GCS files uploaded for multimodal examples
from google.cloud import storage

gcs_client = storage.Client(project=PROJECT_ID)
bucket = gcs_client.bucket(BUCKET)
prefix = 'bq_ai_functions/ai_generate_text/'

blobs = list(bucket.list_blobs(prefix=prefix))
for blob in blobs:
    blob.delete()
    print(f'Deleted gs://{BUCKET}/{blob.name}')
if not blobs:
    print('No GCS files to clean up')
# Out:
# Deleted gs://statmike-mlops-349915/bq_ai_functions/ai_generate_text/invoice_001.pdf

# %% [markdown]
# ### Remove all shared resources
#
# When finished with **all** notebooks, uncomment and run the cell below to delete the shared dataset and all tables, models, and other resources within it.

# %%
# client.delete_dataset(
#     f'{PROJECT_ID}.{DATASET_ID}',
#     delete_contents=True,
#     not_found_ok=True
# )
# print(f'Dataset {PROJECT_ID}.{DATASET_ID} deleted')
