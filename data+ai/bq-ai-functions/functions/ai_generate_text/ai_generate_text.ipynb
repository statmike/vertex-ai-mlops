# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2Fdata%2Bai%2Fbq-ai-functions%2Ffunctions%2Fai_generate_text&file=ai_generate_text.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2Fdata%252Bai%2Fbq-ai-functions%2Ffunctions%2Fai_generate_text%2Fai_generate_text.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/functions/ai_generate_text/ai_generate_text.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # AI.GENERATE_TEXT — BigQuery AI Functions
#
# `AI.GENERATE_TEXT` is a table-valued function that generates text using a remote model. It supports Gemini, Claude, Llama, Mistral, and open models — making it the most flexible generation function.
#
# **When to use it:**
# - You need to use non-Gemini models (Claude, Llama, Mistral)
# - You want table-valued output with all input columns preserved
# - You need Google Search grounding with `ground_with_google_search`
# - You have an existing `CREATE MODEL` workflow
#
# **Alternatives:**
# - [`AI.GENERATE`](../ai_generate/) — Scalar function, no model required, Gemini only
# - [`AI.GENERATE_TABLE`](../ai_generate_table/) — TVF with structured output via output_schema
# - [`ML.GENERATE_TEXT`](../ml_generate_text/) — Legacy predecessor with ml_generate_text_ column prefixes
#
# **Multimodal:** Supports document, image, and video input via [ObjectRef](../../RESOURCES.md#objectref-and-objectrefruntime-schema-reference). Pass a STRUCT prompt with ObjectRefRuntime fields to analyze unstructured data from Cloud Storage.
#
# **References:** [Full syntax reference](../../RESOURCES.md) | [Official documentation](https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-ai-generate-text) | [Setup guide](../../setup/)

# %% [markdown]
# ---
# ## Setup
#
# Set your project and location, authenticate, and create a temporary dataset for this notebook.
#
# > This function requires a connection and a remote model. The cells below create them if they don't exist. See the [Setup Reference](../../setup/) for details.

# %%
PROJECT_ID = 'statmike-mlops-349915'  # <-- Replace with your project ID
LOCATION = 'US'  # BigQuery dataset location
DATASET_ID = 'bq_ai_functions'  # Shared dataset across all notebooks
CONNECTION_ID = 'bq_ai_functions'  # Shared connection
BUCKET = PROJECT_ID  # GCS bucket (same name as project)

# %% [markdown]
# ### Environment
#
# > **Already set up the project environment?** The cell below is a no-op — packages are already in your kernel. See the [Setup Reference](../../setup/) for details.
# >
# > **Running standalone** (Colab, Colab Enterprise, Vertex AI Workbench)? The cell below installs required packages into your current kernel.

# %%
import subprocess, sys, shutil

def install(*packages):
    """Install packages using uv (fast) with pip fallback."""
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install('google-cloud-bigquery', 'db-dtypes', 'bigquery-magics', 'tqdm', 'bigframes', 'google-cloud-storage')

# %%
# Authenticate (Colab only — other environments use Application Default Credentials)
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC is used automatically

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project=PROJECT_ID)
pd.set_option('display.max_colwidth', None)

# Create the shared dataset (idempotent)
dataset_ref = bigquery.DatasetReference(PROJECT_ID, DATASET_ID)
dataset = bigquery.Dataset(dataset_ref)
dataset.location = LOCATION
client.create_dataset(dataset, exists_ok=True)
print(f'Dataset {PROJECT_ID}.{DATASET_ID} ready')

# Register %%bigquery cell magic (auto-loaded in Colab, needed elsewhere)
# %load_ext bigquery_magics
# Out:
# Dataset statmike-mlops-349915.bq_ai_functions ready

# %%
import subprocess as _sp, json as _json

# Create connection (idempotent)
_sp.run(['bq', 'mk', '--connection', '--location', LOCATION,
         '--connection_type', 'CLOUD_RESOURCE',
         '--project_id', PROJECT_ID, CONNECTION_ID],
        capture_output=True, text=True)

# Get service account and grant Vertex AI User role
r = _sp.run(['bq', 'show', '--connection', '--format=json',
             '--project_id', PROJECT_ID, '--location', LOCATION, CONNECTION_ID],
            capture_output=True, text=True, check=True)
sa = _json.loads(r.stdout)['cloudResource']['serviceAccountId']
for role in ['roles/aiplatform.user', 'roles/storage.objectViewer']:
    _sp.run(['gcloud', 'projects', 'add-iam-policy-binding', PROJECT_ID,
             f'--member=serviceAccount:{sa}', f'--role={role}', '--quiet'],
            capture_output=True, text=True)
print(f'Connection {CONNECTION_ID} ready (SA: {sa})')
# Out:
# Connection bq_ai_functions ready (SA: bqcx-1026793852137-hx0g@gcp-sa-bigquery-condel.iam.gserviceaccount.com)

# %%
# Create remote Gemini model (idempotent)
client.query(f'''
CREATE OR REPLACE MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`
  REMOTE WITH CONNECTION `{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}`
  OPTIONS (endpoint = \'gemini-2.5-flash\')
''').result()
print('Model gemini_flash ready')
# Out:
# Model gemini_flash ready

# %% [markdown]
# ---
# ## Examples — SQL
#
# Progressive examples from simplest to most advanced. Each cell adds one new concept.

# %% [markdown]
# ### 1. Simplest call — single prompt
#
# The input query must have a `prompt` column. AI.GENERATE_TEXT returns all input columns plus `result`, `status`, and metadata columns.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is BigQuery?' AS prompt)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# BigQuery is a **fully-managed, serverless, highly scalable, and cost-effective enterprise data warehouse** offered by Google Cloud Platform (GCP). It's designed to store and analyze massive datasets, ranging from terabytes to petabytes, using standard SQL.
#
# Here's a breakdown of its key characteristics and what makes it so powerful:
#
# **Key Characteristics:**
#
# 1.  **Fully Managed and Serverless:**
#     *   **No infrastructure to manage:** You don't need to provision, maintain, or scale servers. Google handles all the underlying infrastructure, operating systems, and database software.
#     *   **Automatic scaling:** BigQuery automatically scales its compute and storage resources up and down based on your query workload. You only pay for what you use.
#
# 2.  **Highly Scalable:**
#     *   **Petabyte-scale storage:** It can store massive amounts of data without performance degradation.
#     *   **Massively parallel processing (MPP):** BigQuery uses a distributed architecture to process queries across thousands of machines simultaneously, enabling incredibly fast query execution even on huge datasets.
#
# 3.  **Cost-Effective:**
#     *   **Pay-as-you-go pricing:** You primarily pay for data stored and data scanned by queries. There are no upfront costs or minimum fees.
#     *   **Columnar storage:** BigQuery stores data in a columnar format, which is highly optimized for analytical queries. This means it only reads the columns required for a query, reducing the amount of data scanned and thus the cost.
#
# 4.  **Standard SQL:**
#     *   You can query your data using familiar ANSI SQL, making it accessible to a wide range of data professionals.
#     *   It supports complex SQL functions, joins, subqueries, and window functions.
#
# 5.  **Real-time Analytics:**
#     *   While not a transactional database, BigQuery is designed for fast analytical queries. It can handle streaming data ingestion and provide near real-time insights.
#
# 6.  **Built-in Machine Learning (BigQuery ML):**
#     *   Allows you to create and execute machine learning models directly within BigQuery using SQL. This eliminates the need to export data to separate ML platforms.
#     *   Supports common ML models like linear regression, logistic regression, k-means, and more.
#
# 7.  **Data Integration:**
#     *   Seamlessly integrates with other GCP services (e.g., Cloud Storage, Dataflow, Dataproc, Looker Studio).
#     *   Supports various data sources and formats, including CSV, JSON, Avro, Parquet, ORC, and Cloud Spanner.
#
# 8.  **Security:**
#     *   Offers robust security features, including IAM (Identity and Access Management) for fine-grained access control, encryption at rest and in transit, and auditing.
#
# **How it Works (Simplified):**
#
# 1.  **Data Ingestion:** Data can be loaded into BigQuery from various sources (batch or streaming).
# 2.  **Storage (Colossus):** Data is stored in Google's distributed file system, Colossus, in a highly optimized columnar format.
# 3.  **Query Execution (Dremel):** When you run a SQL query, BigQuery's query engine (Dremel) parallelizes the query across thousands of servers. It only scans the necessary columns and partitions of data, performing computations in parallel and then aggregating the results.
#
# **Common Use Cases:**
#
# *   **Business Intelligence (BI):** Powering dashboards and reports for business insights.
# *   **Data Warehousing:** Centralizing large datasets from various sources for analytical purposes.
# *   **Ad-hoc Analysis:** Quickly exploring and understanding large datasets.
# *   **Machine Learning:** Training and deploying ML models directly on your data.
# *   **Log Analysis:** Analyzing massive streams of log data for operational insights and security.
# *   **Marketing Analytics:** Understanding customer behavior and campaign performance.
#
# **In essence, BigQuery empowers organizations to extract valuable insights from vast amounts of data quickly and cost-effectively, without the burden of managing complex infrastructure.** It's a go-to solution for anyone needing to perform serious analytics on big data.

# %% [markdown]
# ### 2. Processing multiple rows
#
# Each row in the input gets its own model call. The prompt column is built with CONCAT.

# %%
query = f'''
SELECT prompt, result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT CONCAT('What country is ', city, ' in? Answer in one word.') AS prompt, city
   FROM UNNEST(['Tokyo', 'Paris', 'Nairobi']) AS city)
)
'''
client.query(query).to_dataframe()
# Out:
#                                             prompt  result
# 0    What country is Paris in? Answer in one word.  France
# 1    What country is Tokyo in? Answer in one word.   Japan
# 2  What country is Nairobi in? Answer in one word.   Kenya

# %% [markdown]
# ### 3. Controlling generation parameters
#
# Pass generation parameters as a STRUCT. Parameters are named arguments, not JSON.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'Write a haiku about cloud computing.' AS prompt),
  STRUCT(0.8 AS temperature, 100 AS max_output_tokens)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# Servers in the sky,
# Data flows, a digital stream,
# Flexible and vast.

# %% [markdown]
# ### 4. Google Search grounding
#
# Enable Google Search grounding with `ground_with_google_search`. The model will search the web for current information.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is the current population of Tokyo?' AS prompt),
  STRUCT(TRUE AS ground_with_google_search)
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# The population of Tokyo varies depending on whether one is referring to the city proper, the Tokyo Metropolis (prefecture), or the greater metropolitan area.
#
# Here's a breakdown of the current population figures for Tokyo:
#
# *   **Tokyo city (23 wards):** Estimates for Tokyo's 23 wards in 2026 are around 10,316,210.
# *   **Tokyo Metropolis (prefecture):** As of 2025, the total population of Tokyo (referring to the prefecture) is 14,195,730. Projections for 2026 indicate a slight increase to 14,270,748.
# *   **Greater Tokyo Metropolitan Area:** This larger area, which includes Tokyo and parts of neighboring prefectures, is the most populous metropolitan area in the world. Its estimated population in 2026 is 36,954,000. Other sources estimate the metropolitan area population at 33.4 million for 2025, ranking it third worldwide. Some estimates for 2026 place the greater metropolitan area population at 36.2 million.

# %% [markdown]
# ### 5. Safety settings
#
# Control content safety filtering with `safety_settings`.

# %%
query = f'''
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'Explain the science of fireworks.' AS prompt),
  STRUCT(
    [STRUCT('HARM_CATEGORY_DANGEROUS_CONTENT' AS category, 'BLOCK_ONLY_HIGH' AS threshold)] AS safety_settings
  )
)
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# Fireworks, those dazzling explosions of light and sound that captivate audiences worldwide, are a remarkable blend of chemistry, physics, and artistry. The science behind them is surprisingly intricate, involving carefully crafted chemical reactions and precise engineering.
#
# Here's a breakdown of the key scientific principles at play:
#
# **1. The "Motor" (Lift Charge):**
#
# *   **Composition:** The primary component for launching a firework is **black powder**, a finely ground mixture of:
#     *   **Potassium nitrate (KNO₃):** The oxidizer, providing oxygen for combustion.
#     *   **Charcoal (carbon, C):** The fuel, which burns readily.
#     *   **Sulfur (S):** Lowers the ignition temperature and increases the burn rate.
# *   **Mechanism:** When ignited, black powder burns rapidly, producing a large volume of hot gases (carbon dioxide, nitrogen, sulfur dioxide). These gases are trapped within the firework shell, creating immense pressure. This pressure is then directed downwards through a narrow opening (the "choke" or "nozzle" in rockets, or simply pushing the shell out of a mortar tube), generating the thrust needed to propel the firework into the sky.
#
# **2. The "Payload" (Stars and Bursting Charge):**
#
# Once the firework reaches its desired altitude, another explosive charge, known as the **bursting charge** (also typically black powder or a faster-burning composition), ignites. This charge is designed to:
#
# *   **Disperse the "stars":** The stars are small, pre-made pellets that contain the chemicals responsible for the colors, glitter, and other visual effects. The bursting charge scatters these stars outwards.
# *   **Create the "boom":** The rapid ignition and expansion of gases from the bursting charge also create the characteristic loud report associated with many fireworks.
#
# **3. The "Stars" (The Magic of Color and Effect):**
#
# This is where the real artistry and chemistry shine. Stars are carefully formulated pellets, typically consisting of:
#
# *   **Oxidizer:** Provides oxygen for the fuel to burn, ensuring a brilliant and sustained light. Common oxidizers include potassium perchlorate (KClO₄), potassium nitrate (KNO₃), and barium nitrate (Ba(NO₃)₂). Perchlorates are particularly powerful.
# *   **Fuel:** Provides the energy for the reaction. Charcoal, sulfur, and various organic compounds (like dextrin or shellac, which also act as binders) are common fuels.
# *   **Colorant:** This is the heart of the firework's visual appeal. Specific metal salts are used, and when heated to extremely high temperatures by the burning fuel and oxidizer, their electrons become excited. As these electrons fall back to their original energy levels, they emit light at specific wavelengths, resulting in different colors. This phenomenon is called **atomic emission**.
#
#     *   **Red:** Strontium salts (e.g., strontium carbonate, SrCO₃)
#     *   **Orange:** Calcium salts (e.g., calcium chloride, CaCl₂)
#     *   **Yellow:** Sodium salts (e.g., sodium nitrate, NaNO₃)
#     *   **Green:** Barium salts (e.g., barium chloride, BaCl₂, or barium nitrate, Ba(NO₃)₂)
#     *   **Blue:** Copper salts (e.g., copper chloride, CuCl₂) - *Blue is notoriously difficult to achieve a pure, vibrant color due to the high temperatures required and the tendency for copper to react with other components.*
#     *   **Violet/Purple:** A mixture of strontium salts (red) and copper salts (blue).
#     *   **White/Silver:** Magnesium (Mg) or Aluminum (Al) metals burn fiercely and brightly. Titanium (Ti) also produces white sparks.
# *   **Binder:** Holds the star's ingredients together, allowing it to be formed into a compact pellet. Dextrin (a carbohydrate) is a common binder.
# *   **Chlorine Donor (for some colors):** For vibrant blue and green, a chlorine donor (like PVC, polyvinyl chloride, or hexachlorobenzene) is often added. The chlorine reacts with the metal ions to form metal chloride molecules, which emit more intense light at the desired wavelengths.
# *   **Effect Components:** Beyond color, other chemicals are added for various visual effects:
#     *   **Glitter/Strobe:** Metal flakes (like aluminum or magnesium) combined with a slow-burning composition.
#     *   **Sparkle:** Iron filings or charcoal chunks produce visible sparks as they burn.
#     *   **Whistle:** A precisely packed, fast-burning chemical mixture (like potassium perchlorate and potassium benzoate or salicylate) that vibrates rapidly as it burns, creating a whistling sound.
#     *   **Crackling:** Bismuth oxide or lead oxide mixed with other chemicals to create small, localized explosions.
#
# **4. The Fuse:**
#
# *   A slow-burning cord that initiates the entire sequence. It's designed to burn at a consistent rate, allowing for safe ignition and a predictable delay before the main action begins. Fuses typically contain black powder wrapped in a protective casing.
#
# **Physics in Play:**
#
# *   **Newton's Laws of Motion:** The lift charge demonstrates Newton's Third Law (for every action, there is an equal and opposite reaction) as the expanding gases propel the firework upwards.
# *   **Light and Color:** The emission of light from excited electrons is a quantum mechanical phenomenon. The specific wavelength of light emitted determines the perceived color.
# *   **Sound:** The rapid expansion of gases during the bursting charge creates a shockwave that we perceive as sound. The intensity of the sound is related to the amount of gas produced and the speed of its expansion.
# *   **Aerodynamics:** The design of rocket fireworks, with fins and a pointed nose cone, helps to stabilize their flight path.
#
# **Safety Considerations:**
#
# Due to the powerful chemical reactions and high temperatures involved, fireworks are inherently dangerous and require careful handling and strict regulations. Uncontrolled explosions, accidental ignition, and improper storage can lead to severe injuries or fatalities.
#
# **In summary, a firework is a miniature chemical factory and rocket, meticulously designed to perform a series of controlled explosions. It's a testament to human ingenuity in harnessing the power of chemistry and physics to create breathtaking displays of light, sound, and wonder.**

# %% [markdown]
# ### 6. Inspecting response metadata
#
# `AI.GENERATE_TEXT` returns additional columns beyond `result`: `full_response` (full JSON), `status`, `safety_attributes`, and token usage. These are useful for debugging, cost tracking, and safety auditing.

# %%
query = f'''
SELECT *
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT 'What is 2 + 2? Answer in one word.' AS prompt)
)
'''
df = client.query(query).to_dataframe()
print('Columns returned:', list(df.columns))
print(f'Result: {df.iloc[0]["result"]}')
print(f'Status: {df.iloc[0]["status"]}')
# Out:
# Columns returned: ['result', 'rai_result', 'grounding_result', 'statistics', 'full_response', 'status', 'prompt']
# Result: Four
# Status:

# %% [markdown]
# ### 7. Processing table data at scale
#
# Use a CTE or subquery to select specific rows, then pass to AI.GENERATE_TEXT. Materialize first when using LIMIT to avoid extra charges.

# %%
query = f'''
WITH reviews AS (
  SELECT *
  FROM UNNEST([
    STRUCT('r1' AS id, 'Amazing product, fast delivery!' AS review),
    STRUCT('r2', 'Terrible quality. Broke after one day.'),
    STRUCT('r3', 'Average product, nothing special.'),
    STRUCT('r4', 'Great value for the price!')
  ])
)
SELECT id, review, result AS sentiment
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT id, review,
   CONCAT('Classify this review as positive, negative, or neutral. Return only the label: ', review) AS prompt
   FROM reviews)
)
'''
client.query(query).to_dataframe()
# Out:
#    id                                  review sentiment
# 0  r3       Average product, nothing special.   Neutral
# 1  r1         Amazing product, fast delivery!  Positive
# 2  r4              Great value for the price!  Positive
# 3  r2  Terrible quality. Broke after one day.  Negative

# %% [markdown]
# ---
# ## Examples — Multimodal with ObjectRef
#
# `AI.GENERATE_TEXT` can analyze documents, images, and video stored in Cloud Storage. Use the **ObjectRef pipeline** to create a STRUCT prompt with signed references:
#
# ```
# OBJ.MAKE_REF(uri, connection)        → ObjectRef
#   → OBJ.FETCH_METADATA(objectref)    → adds content type and size
#     → OBJ.GET_ACCESS_URL(ref, 'r')   → ObjectRefRuntime (signed URL)
# ```
#
# The STRUCT replaces the STRING prompt. See the [ObjectRef reference](../../RESOURCES.md#objectref-and-objectrefruntime-schema-reference) for details.

# %%
from google.cloud import storage as _storage
from pathlib import Path

# Upload invoice for the multimodal example
_gcs = _storage.Client(project=PROJECT_ID)
_bucket = _gcs.bucket(BUCKET)
_prefix = 'bq_ai_functions/ai_generate_text'

_data = Path('../../data/documents')
if not _data.exists():
    _data = Path('data/documents')

blob = _bucket.blob(f'{_prefix}/invoice_001.pdf')
if not blob.exists():
    blob.upload_from_filename(str(_data / 'invoices' / 'invoice_001.pdf'))
    print(f'Uploaded invoice_001.pdf → gs://{BUCKET}/{_prefix}/invoice_001.pdf')
else:
    print(f'Already exists: gs://{BUCKET}/{_prefix}/invoice_001.pdf')
# Out:
# Uploaded invoice_001.pdf → gs://statmike-mlops-349915/bq_ai_functions/ai_generate_text/invoice_001.pdf

# %% [markdown]
# ### 8. Summarize a document
#
# Pass a document via ObjectRef using a STRUCT prompt to analyze content from Cloud Storage.

# %%
query = f"""
SELECT result
FROM AI.GENERATE_TEXT(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT STRUCT(
    'Summarize this document in 2-3 sentences.' AS prompt,
    [OBJ.GET_ACCESS_URL(
      OBJ.FETCH_METADATA(
        OBJ.MAKE_REF(
          'gs://{BUCKET}/bq_ai_functions/ai_generate_text/invoice_001.pdf',
          '{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}'
        )
      ), 'r'
    )] AS object_ref_runtime
  ) AS prompt)
)
"""
df = client.query(query).to_dataframe()
print(df.iloc[0]['result'])
# Out:
# This invoice from Nexus Innovations Group charges Global Reach Marketing LLC for services including website redesign, strategic consulting, and social media management. The total amount due for these services, including tax, is $10,067.25. Payment for invoice INV-2024-0013 is due by August 14, 2024, under Net 30 terms.

# %% [markdown]
# ---
# ## Examples — `%%bigquery` Magics
#
# The same examples using IPython magic commands. Magics let you write SQL directly in notebook cells without Python string wrapping.
#
# Key patterns:
# - `%%bigquery` — run SQL, display results inline
# - `%%bigquery df` — run SQL, capture results into a pandas DataFrame

# %% [markdown]
# ### Basic call with `%%bigquery`
#
# **Note:** `%%bigquery` magics cannot interpolate Python variables in the SQL body. Use `--project` on the magic line for project, but model/table references must be hardcoded or use `client.query()` instead.
#
# Since AI.GENERATE_TEXT requires a `MODEL` reference with project/dataset, most examples are better run via `client.query()` with f-strings. Here we show one example with hardcoded references.

# %%
# %%bigquery --project {PROJECT_ID}
#
# SELECT result
# FROM AI.GENERATE_TEXT(
#   MODEL `statmike-mlops-349915.bq_ai_functions.gemini_flash`,
#   (SELECT 'Write a haiku about SQL.' AS prompt),
#   STRUCT(0.8 AS temperature)
# )
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                                         result
# 0  Data in a base,\nQueries fetch what you desire,\nKnowledge comes with ease.

# %% [markdown]
# ### Capture results to a DataFrame

# %%
# %%bigquery df_text --project {PROJECT_ID}
#
# SELECT city, result AS country
# FROM AI.GENERATE_TEXT(
#   MODEL `statmike-mlops-349915.bq_ai_functions.gemini_flash`,
#   (SELECT CONCAT('What country is ', city, ' in? One word.') AS prompt, city
#    FROM UNNEST(['Tokyo', 'Paris', 'Nairobi']) AS city)
# )
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_text
# Out:
#       city country
# 0    Paris  France
# 1  Nairobi   Kenya
# 2    Tokyo   Japan

# %% [markdown]
# ---
# ## Examples — BigFrames
#
# BigFrames wraps `AI.GENERATE_TEXT` via `bbq.ai.generate_text()`. It takes a model name string and a DataFrame.
#
# **Key difference from SQL:** The function takes a model name and a DataFrame/Series with a `prompt` column.

# %%
import bigframes.pandas as bpd
import bigframes.bigquery as bbq

bpd.options.bigquery.project = PROJECT_ID
bpd.options.bigquery.location = LOCATION

# %% [markdown]
# ### Basic generation

# %%
# Create input DataFrame with a 'prompt' column
df = bpd.DataFrame({
    'city': ['Tokyo', 'Paris', 'Nairobi'],
    'prompt': [
        'What country is Tokyo in? Answer in one word.',
        'What country is Paris in? Answer in one word.',
        'What country is Nairobi in? Answer in one word.',
    ]
})

# Use the model reference as a string
model_name = f'{PROJECT_ID}.{DATASET_ID}.gemini_flash'
result = bbq.ai.generate_text(model_name, df)

result[['city', 'result']].to_pandas()
# Out:
#     Query processed 0 Bytes in 5 seconds of slot time. [<a target="_blank" href="https://console.cloud.google.com/bigquery?project=statmike-mlops-349915&j=bq:US:50c797b8-0c45-4582-93f6-14518c724d98&page=queryresults">Job statmike-mlops-349915:US.50c797b8-0c45-4582-93f6-14518c724d98 details</a>]
#     Query processed 166 Bytes in 2 seconds of slot time.
#       city  result
# 0    Tokyo   Japan
# 1    Paris  France
# 2  Nairobi   Kenya

# %% [markdown]
# ---
# ## Cleanup
#
# Remove GCS files uploaded for the multimodal examples. Shared resources (dataset, models, connection) are left for other notebooks.

# %%
# Delete GCS files uploaded for multimodal examples
from google.cloud import storage

gcs_client = storage.Client(project=PROJECT_ID)
bucket = gcs_client.bucket(BUCKET)
prefix = 'bq_ai_functions/ai_generate_text/'

blobs = list(bucket.list_blobs(prefix=prefix))
for blob in blobs:
    blob.delete()
    print(f'Deleted gs://{BUCKET}/{blob.name}')
if not blobs:
    print('No GCS files to clean up')
# Out:
# Deleted gs://statmike-mlops-349915/bq_ai_functions/ai_generate_text/invoice_001.pdf

# %% [markdown]
# ### Remove all shared resources
#
# When finished with **all** notebooks, uncomment and run the cell below to delete the shared dataset and all tables, models, and other resources within it.

# %%
# client.delete_dataset(
#     f'{PROJECT_ID}.{DATASET_ID}',
#     delete_contents=True,
#     not_found_ok=True
# )
# print(f'Dataset {PROJECT_ID}.{DATASET_ID} deleted')
