# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2Fdata%2Bai%2Fbq-ai-functions%2Fworkflows%2Flog_analysis&file=log_analysis.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2Fdata%252Bai%2Fbq-ai-functions%2Fworkflows%2Flog_analysis%2Flog_analysis.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/bq-ai-functions/workflows/log_analysis/log_analysis.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Log Analysis — BigQuery AI Functions
#
# An end-to-end log analysis pipeline that composes four AI functions to analyze application support tickets:
#
# 1. **Generate** sample support tickets with `AI.GENERATE_TABLE`
# 2. **Classify** each ticket by category with `AI.CLASSIFY`
# 3. **Score** each ticket for priority with `AI.SCORE`
# 4. **Summarize** patterns by category with `AI.AGG` (the star of this workflow)
#
# **What this demonstrates:**
# - `AI.AGG` as the natural aggregation function — summarize groups of tickets without manual batching
# - Composing classify → score → aggregate in a single analytical pipeline
# - Using `TO_JSON_STRING` to pass structured data to `AI.AGG`
# - Comparing `AI.AGG` with the manual `STRING_AGG` + `AI.GENERATE` approach
#
# **Functions used:** [`AI.GENERATE_TABLE`](../../functions/ai_generate_table/) | [`AI.CLASSIFY`](../../functions/ai_classify/) | [`AI.SCORE`](../../functions/ai_score/) | [`AI.AGG`](../../functions/ai_agg/)
#
# **Prerequisites:** [Setup guide](../../setup/) | [Function reference](../../RESOURCES.md)

# %% [markdown]
# ---
# ## Setup
#
# Set your project and location, authenticate, and create shared resources.
#
# > This workflow uses `AI.GENERATE_TABLE` (requires a connection and remote model) and `AI.CLASSIFY`, `AI.SCORE`, `AI.AGG` (no model needed). See the [Setup Reference](../../setup/) for details.

# %%
PROJECT_ID = 'statmike-mlops-349915'  # <-- Replace with your project ID
LOCATION = 'US'  # BigQuery dataset location
DATASET_ID = 'bq_ai_functions'  # Shared dataset across all notebooks
CONNECTION_ID = 'bq_ai_functions'  # Shared connection

# %% [markdown]
# ### Environment
#
# > **Already set up the project environment?** The cell below is a no-op — packages are already in your kernel. See the [Setup Reference](../../setup/) for details.
# >
# > **Running standalone** (Colab, Colab Enterprise, Vertex AI Workbench)? The cell below installs required packages into your current kernel.

# %%
import subprocess, sys, shutil

def install(*packages):
    """Install packages using uv (fast) with pip fallback."""
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install('google-cloud-bigquery', 'db-dtypes', 'bigquery-magics', 'tqdm')

# %%
# Authenticate (Colab only — other environments use Application Default Credentials)
try:
    from google.colab import auth
    auth.authenticate_user()
except ImportError:
    pass  # Not in Colab — ADC is used automatically

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project=PROJECT_ID)
pd.set_option('display.max_colwidth', None)

# Create the shared dataset (idempotent)
dataset_ref = bigquery.DatasetReference(PROJECT_ID, DATASET_ID)
dataset = bigquery.Dataset(dataset_ref)
dataset.location = LOCATION
client.create_dataset(dataset, exists_ok=True)
print(f'Dataset {PROJECT_ID}.{DATASET_ID} ready')

# Register %%bigquery cell magic (auto-loaded in Colab, needed elsewhere)
# %load_ext bigquery_magics
# Out:
# Dataset statmike-mlops-349915.bq_ai_functions ready

# %%
import subprocess as _sp, json as _json

# Create connection (idempotent)
_sp.run(['bq', 'mk', '--connection', '--location', LOCATION,
         '--connection_type', 'CLOUD_RESOURCE',
         '--project_id', PROJECT_ID, CONNECTION_ID],
        capture_output=True, text=True)

# Get service account and grant Vertex AI User role
r = _sp.run(['bq', 'show', '--connection', '--format=json',
             '--project_id', PROJECT_ID, '--location', LOCATION, CONNECTION_ID],
            capture_output=True, text=True, check=True)
sa = _json.loads(r.stdout)['cloudResource']['serviceAccountId']
_sp.run(['gcloud', 'projects', 'add-iam-policy-binding', PROJECT_ID,
         f'--member=serviceAccount:{sa}', '--role=roles/aiplatform.user', '--quiet'],
        capture_output=True, text=True)
print(f'Connection {CONNECTION_ID} ready (SA: {sa})')
# Out:
# Connection bq_ai_functions ready (SA: bqcx-1026793852137-hx0g@gcp-sa-bigquery-condel.iam.gserviceaccount.com)

# %%
# Create remote Gemini model for AI.GENERATE_TABLE (idempotent)
client.query(f'''
CREATE OR REPLACE MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`
  REMOTE WITH CONNECTION `{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}`
  OPTIONS (endpoint = 'gemini-2.5-flash')
''').result()
print('Model gemini_flash ready')
# Out:
# Model gemini_flash ready

# %% [markdown]
# ---
# ## Step 1 — Generate sample support tickets with AI.GENERATE_TABLE
#
# Generate 30 realistic IT support tickets from seed categories. Each ticket has a user, description, resolution, and timestamps — mimicking real helpdesk data.

# %%
output_schema = """user_name STRING OPTIONS(description = "The employee who submitted the ticket"),
       ticket_description STRING OPTIONS(description = "Detailed description of the issue"),
       resolution STRING OPTIONS(description = "How the issue was resolved, or current status if unresolved"),
       resolution_hours FLOAT64 OPTIONS(description = "Hours from ticket creation to resolution, or NULL if unresolved")"""

query = f'''
CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_ID}.workflow_log_tickets` AS
SELECT ticket_id, user_name, ticket_description, resolution, resolution_hours
FROM AI.GENERATE_TABLE(
  MODEL `{PROJECT_ID}.{DATASET_ID}.gemini_flash`,
  (SELECT
    ticket_id,
    CONCAT(
      'Generate one realistic IT support ticket. Category: ', category,
      '. Scenario: ', scenario,
      '. Write a detailed description (2-3 sentences) and a resolution. ',
      'Create a believable employee name. ',
      'Set resolution_hours between 0.5 and 48, or null if unresolved.'
    ) AS prompt
   FROM UNNEST([
     STRUCT(1 AS ticket_id, 'access' AS category, 'new employee needs VPN access' AS scenario),
     STRUCT(2, 'access', 'password reset for locked account'),
     STRUCT(3, 'access', 'MFA token not working after phone upgrade'),
     STRUCT(4, 'access', 'shared drive permissions denied'),
     STRUCT(5, 'access', 'SSO login loop on new laptop'),
     STRUCT(6, 'hardware', 'laptop screen flickering intermittently'),
     STRUCT(7, 'hardware', 'keyboard keys sticking after coffee spill'),
     STRUCT(8, 'hardware', 'docking station not detecting external monitors'),
     STRUCT(9, 'hardware', 'battery draining in under 2 hours'),
     STRUCT(10, 'hardware', 'trackpad unresponsive after OS update'),
     STRUCT(11, 'software', 'Slack keeps crashing on startup'),
     STRUCT(12, 'software', 'Excel macro broken after Office update'),
     STRUCT(13, 'software', 'VPN disconnects every 30 minutes'),
     STRUCT(14, 'software', 'Docker containers failing to build'),
     STRUCT(15, 'software', 'IDE license expired and blocking work'),
     STRUCT(16, 'network', 'Wi-Fi drops in conference room B'),
     STRUCT(17, 'network', 'cannot reach internal wiki from remote'),
     STRUCT(18, 'network', 'latency spikes during video calls'),
     STRUCT(19, 'network', 'DNS resolution failing for staging servers'),
     STRUCT(20, 'network', 'printer not found on office network'),
     STRUCT(21, 'security', 'suspicious login from unknown location'),
     STRUCT(22, 'security', 'phishing email reported by multiple users'),
     STRUCT(23, 'security', 'unauthorized app installed on work laptop'),
     STRUCT(24, 'security', 'sensitive file shared externally by accident'),
     STRUCT(25, 'security', 'antivirus flagging a development tool'),
     STRUCT(26, 'data', 'accidental deletion of production database rows'),
     STRUCT(27, 'data', 'ETL pipeline failing with schema mismatch'),
     STRUCT(28, 'data', 'dashboard showing stale data after migration'),
     STRUCT(29, 'data', 'backup restoration needed for corrupted file'),
     STRUCT(30, 'data', 'BigQuery query hitting quota limits')
   ])),
  STRUCT(
    \"\"\"{output_schema}\"\"\" AS output_schema
  )
)
'''
client.query(query).result()

tickets = client.query(
    f'SELECT ticket_id, user_name, LEFT(ticket_description, 80) AS description_preview, resolution_hours FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_tickets` ORDER BY ticket_id'
).to_dataframe()
print(f'{len(tickets)} tickets generated')
tickets.head(10)
# Out:
# 30 tickets generated
#    ticket_id      user_name  \
# 0          1  Sarah Jenkins
# 1          2  Sarah Jenkins
# 2          3    Emily White
# 3          4  Emily Johnson
# 4          5     Sarah Chen
# 5          6    Marcus Chen
# 6          7     Sarah Chen
# 7          8    Elara Vance
# 8          9  Sarah Jenkins
# 9         10  Sarah Jenkins
#
#                                                                 description_preview  \
# 0  I am a new employee in the Marketing department and require VPN access to perfor
# 1  My account, sarah.jenkins@company.com, is currently locked. I've tried multiple
# 2  After upgrading my phone to a new model, my MFA authenticator app (Duo Mobile) i
# 3  I am unable to access the 'Finance Shared Drive' (F: drive). When I try to open
# 4  I am unable to log into any company applications on my new laptop. When attempti
# 5  My laptop screen has started flickering intermittently, especially when I move t
# 6  My keyboard keys are sticking and some are unresponsive after I accidentally spi
# 7  My external monitors are not being detected when connected to my docking station
# 8  My company laptop's battery has been draining extremely quickly over the past we
# 9  My laptop's trackpad stopped responding entirely after I installed the latest op
#
#    resolution_hours
# 0              3.50
# 1              1.50
# 2              1.75
# 3              3.50
# 4              2.50
# 5              7.25
# 6              2.50
# 7              2.50
# 8             28.75
# 9              3.25

# %% [markdown]
# ---
# ## Step 2 — Classify tickets by category with AI.CLASSIFY
#
# Use `AI.CLASSIFY` to categorize each ticket. The generated data has known categories, but in a real scenario you'd classify unstructured ticket text into operational categories.

# %%
query = f'''
CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_ID}.workflow_log_classified` AS
SELECT
  ticket_id,
  user_name,
  ticket_description,
  resolution,
  resolution_hours,
  AI.CLASSIFY(
    ticket_description,
    [('access', 'Account access, permissions, authentication, SSO, VPN credentials'),
     ('hardware', 'Physical device issues: laptops, monitors, keyboards, docking stations'),
     ('software', 'Application bugs, crashes, license issues, build failures'),
     ('network', 'Connectivity, Wi-Fi, DNS, latency, printer discovery'),
     ('security', 'Suspicious activity, phishing, unauthorized access, data leaks'),
     ('data', 'Database issues, ETL failures, backups, query performance')]
  ) AS category
FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_tickets`
'''
client.query(query).result()

classified = client.query(f'''
  SELECT category, COUNT(*) AS count,
    ROUND(AVG(IFNULL(resolution_hours, 0)), 1) AS avg_hours
  FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_classified`
  GROUP BY category
  ORDER BY count DESC
''').to_dataframe()
print('Ticket distribution by category:')
classified
# Out:
# Ticket distribution by category:
#    category  count  avg_hours
# 0   network      6        3.4
# 1    access      5        2.5
# 2      data      5        8.2
# 3  hardware      5        8.8
# 4  security      5        4.8
# 5  software      4        2.8

# %% [markdown]
# ---
# ## Step 3 — Score tickets for priority with AI.SCORE
#
# Use `AI.SCORE` to rate each ticket's business impact on a 1–10 scale. This helps triage which issues affect the most people or business operations.

# %%
query = f'''
CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_ID}.workflow_log_scored` AS
SELECT
  ticket_id,
  user_name,
  ticket_description,
  resolution,
  resolution_hours,
  category,
  AI.SCORE(CONCAT(
    'Rate the business impact of this IT support ticket on a scale of 1 to 10, ',
    'where 1 is minor inconvenience and 10 is critical business disruption ',
    '(e.g. data loss, security breach, entire team blocked): ',
    ticket_description,
    ' Resolution: ', IFNULL(resolution, 'UNRESOLVED')
  )) AS priority
FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_classified`
'''
client.query(query).result()

scored = client.query(f'''
  SELECT category,
    ROUND(AVG(priority), 1) AS avg_priority,
    ROUND(MAX(priority), 1) AS max_priority,
    COUNT(*) AS count
  FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_scored`
  GROUP BY category
  ORDER BY avg_priority DESC
''').to_dataframe()
print('Priority scores by category:')
scored
# Out:
# Priority scores by category:
#    category  avg_priority  max_priority  count
# 0      data           6.4           9.0      5
# 1  security           6.0           9.0      5
# 2    access           5.0           6.0      5
# 3  software           4.5           6.0      4
# 4   network           3.8           5.0      6
# 5  hardware           3.2           4.0      5

# %% [markdown]
# ### High-priority tickets
#
# Tickets scoring 7+ that need immediate attention.

# %%
high_priority = client.query(f'''
  SELECT ticket_id, user_name, category, priority,
    LEFT(ticket_description, 120) AS description
  FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_scored`
  WHERE priority >= 7
  ORDER BY priority DESC
''').to_dataframe()

if len(high_priority) == 0:
    print('No high-priority tickets — operations are running smoothly!')
else:
    print(f'{len(high_priority)} high-priority tickets:')
    high_priority
# Out:
# 3 high-priority tickets:

# %% [markdown]
# ---
# ## Step 4 — Summarize patterns with AI.AGG
#
# This is where `AI.AGG` shines. Instead of manually concatenating tickets into a prompt with `STRING_AGG`, we let `AI.AGG` handle the batching and aggregation automatically. It returns one summary per category — identifying common patterns, root causes, and recommended actions.

# %%
query = f'''
SELECT
  category,
  AI.AGG(
    TO_JSON_STRING(STRUCT(
      ticket_id, user_name, ticket_description,
      resolution, resolution_hours, priority
    )),
    'You are an IT operations analyst. Analyze these support tickets for this category. '
    'Identify: (1) common patterns or root causes, (2) average resolution effectiveness, '
    '(3) any systemic issues that need proactive fixes, (4) one actionable recommendation. '
    'Be concise.'
  ) AS category_analysis
FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_scored`
GROUP BY category
'''
df_analysis = client.query(query).to_dataframe()
for _, row in df_analysis.iterrows():
    print(f'=== {row["category"].upper()} ===')
    print(row['category_analysis'])
    print()
# Out:
# === NETWORK ===
# **Common Patterns/Root Causes:** All tickets stem from network connectivity issues, specifically DNS resolution problems (stale/expired records), VPN instability, Wi-Fi interference, and printer network configuration errors. These are largely due to configuration errors or misconfigurations.
#
# **Average Resolution Effectiveness:** The average resolution time for these tickets is 3.42 hours.
#
# **Systemic Issues:**
# *   **DNS Management:** Persistent issues with stale or expired DNS records indicate a need for improved proactive monitoring and management of internal DNS.
# *   **VPN Configuration:** Recurring VPN disconnections suggest a lack of standardized VPN server or client configurations.
# *   **Network Infrastructure Monitoring:** Intermittent Wi-Fi and latency point to gaps in monitoring for interference, congestion, and optimal access point placement.
# *   **Device Configuration Persistence:** The printer losing its static IP highlights potential issues with device configuration persistence or network device management.
#
# **Actionable Recommendation:** Implement a proactive network health monitoring system to automate checks for DNS record validity, audit VPN server configurations, monitor Wi-Fi channel utilization, and ensure static IP address integrity for critical network devices.
#
# === SOFTWARE ===
# Here's an analysis of the support tickets:
#
# **Common Patterns/Root Causes:** We're seeing a mix of software configuration issues, particularly with corrupted application caches (like Slack) and security setting changes after updates (Excel macros). Licensing problems, specifically unexpected expirations (IntelliJ IDEA), also popped up. Finally, outdated software versions causing compatibility issues (Docker daemon) indicate an infrastructure-related pattern.
#
# **Average Resolution Effectiveness:** On average, these tickets took about 2.81 hours to resolve.
#
# **Systemic Issues:** There's a clear lack of proactive cache management for common applications. Application updates seem to be silently altering critical security settings, which is disruptive. We also lack automated alerts or processes for license renewals. Lastly, inconsistent software versioning and patching across critical infrastructure components are leading to compatibility problems.
#
# **Actionable Recommendation:** Let's implement a scheduled review process for critical software versions on both build servers and user workstations to proactively prevent compatibility issues.
#
# === HARDWARE ===
# **Common Patterns/Root Causes:** We're seeing a mix of hardware degradation (batteries, display cables) and accidental damage (liquid spills). Software/driver conflicts, particularly after OS updates, and faulty peripherals also contribute.
#
# **Average Resolution Effectiveness:** The average resolution time for these tickets is 8.85 hours.
#
# **Systemic Issues:** Hardware component wear and tear, especially for batteries and display cables, is a recurring theme. OS updates occasionally introduce driver conflicts, impacting functionality like trackpads.
#
# **Actionable Recommendation:** Implement a proactive hardware refresh cycle for laptops, focusing on batteries and display assemblies every 3-4 years, to reduce failures from degradation.
#
# === ACCESS ===
# Here's an analysis of the support tickets:
#
# (1) Common Patterns/Root Causes: We're frequently seeing issues related to new employee onboarding (VPN access, account lockouts), access permission problems (especially shared drives), MFA device changes, and browser/SSO cache conflicts.
#
# (2) Average Resolution Effectiveness: The average resolution time for these tickets is 12.75 hours across 5 tickets.
#
# (3) Systemic Issues: There appear to be gaps in our new employee onboarding process, leading to delays in access provisioning. We also have a potential risk of accidental AD group removals during system maintenance. Additionally, there's a lack of clear self-service options for common issues like MFA re-enrollment or SSO troubleshooting.
#
# (4) Actionable Recommendation: Implement a pre-onboarding checklist for new hires to ensure all necessary access (VPN, accounts) is provisioned and tested before their start date.
#
# === SECURITY ===
# Here's an analysis of the security incident tickets:
#
# **1. Common Patterns/Root Causes:**
# *   User error and lack of awareness are significant, leading to accidental data exposure, unauthorized software, and phishing susceptibility.
# *   External threats like phishing and unauthorized login attempts are ongoing.
# *   Antivirus false positives occasionally disrupt operations.
#
# **2. Average Resolution Effectiveness:**
# *   The average resolution time is 4.75 hours. While immediate issues are resolved, the recurrence of user-related problems suggests that underlying behavioral causes aren't being fully addressed.
#
# **3. Systemic Issues:**
# *   There's insufficient user security training, as many incidents originate from user actions.
# *   Gaps exist in proactive threat detection, allowing phishing and unauthorized logins to reach users.
# *   Antivirus policy management needs improvement to prevent false positives with critical internal tools.
#
# **4. Actionable Recommendation:**
# Implement mandatory, quarterly interactive security awareness training modules focusing on phishing recognition, safe sharing practices, and authorized software installation, coupled with regular simulated phishing campaigns.
#
# === DATA ===
# As an IT operations analyst, I've reviewed these support tickets and identified a few key areas.
#
# **Common Patterns/Root Causes:** A significant pattern is data integrity and availability issues, accounting for three out of five tickets. These often stem from user error, accidental deletions, or post-migration problems. We also saw an ETL pipeline failure due to a schema mismatch and a BigQuery quota limitation.
#
# **Average Resolution Effectiveness:** The average resolution time was 8.19 hours, and all tickets were successfully resolved, indicating good effectiveness in addressing immediate problems.
#
# **Systemic Issues Needing Proactive Fixes:** We have a clear need for better data governance and access control, especially given the accidental deletion incident. Inadequate change management for data pipelines is also apparent, as schema changes are not being properly integrated. Finally, the quota issue suggests we could benefit from query optimization and improved resource planning for analytical workloads. On a positive note, our backup and recovery procedures seem effective, as we were able to restore corrupted or deleted data.
#
# **Actionable Recommendation:** Implement stricter access controls and mandatory peer review processes for all production database DML operations to prevent accidental data loss.

# %% [markdown]
# ### Overall incident summary with AI.AGG
#
# Without `GROUP BY`, `AI.AGG` aggregates all tickets into a single cross-category summary — an operational overview for leadership.

# %%
query = f'''
SELECT
  AI.AGG(
    TO_JSON_STRING(STRUCT(ticket_id, category, ticket_description, priority, resolution_hours)),
    'You are a VP of IT writing a weekly operations report. Summarize all support tickets into a '
    'brief executive report (3-4 paragraphs). Cover: overall volume and category breakdown, '
    'most critical issues, resolution performance, and top 2 recommendations for the coming week.'
  ) AS weekly_report
FROM `{PROJECT_ID}.{DATASET_ID}.workflow_log_scored`
'''
df = client.query(query).to_dataframe()
print(df.iloc[0]['weekly_report'])
# Out:
# This week, our support teams handled a total of 29 tickets, maintaining a consistent volume. The distribution across categories was fairly even, with access and network issues each accounting for 6 tickets, followed closely by data, hardware, and security with 5 tickets each. Software-related issues were the least frequent, with 4 tickets. A significant portion of our efforts, 16 tickets, were dedicated to critical issues (Priority 5 or higher), highlighting the need for proactive measures in these areas.
#
# Among the most critical incidents, we addressed a Priority 9 data issue where an accidental DELETE statement removed 50,000 entries from our production 'products' table. Simultaneously, a Priority 9 security incident involved multiple employees receiving a sophisticated phishing email containing a fraudulent login link. These high-priority events underscore the potential for significant operational disruption and data compromise, demanding immediate and robust responses from our teams.
#
# Our resolution performance for the week saw a total of 139.7 hours spent on resolving tickets, resulting in an average resolution time of approximately 4.8 hours per ticket. This metric reflects our team's dedication to addressing issues promptly, even with the presence of several high-severity incidents. We continue to monitor these metrics closely to identify opportunities for further efficiency gains and ensure our support operations remain responsive and effective.
#
# Looking ahead, I recommend two key areas of focus for the coming week. First, we need to proactively address the recurring data integrity and access issues, especially those that have the potential to impact our production systems and critical reporting. Second, given the recent phishing incident, it is imperative that we enhance our security awareness training, with a specific emphasis on improving phishing detection skills and reinforcing safe data handling practices across the organization.

# %% [markdown]
# ---
# ## Cleanup
#
# Drop tables created by this workflow. Shared resources (dataset, models, connection) are left for other notebooks.

# %%
for table in ['workflow_log_tickets', 'workflow_log_classified', 'workflow_log_scored']:
    client.delete_table(f'{PROJECT_ID}.{DATASET_ID}.{table}', not_found_ok=True)
    print(f'Dropped {table}')
# Out:
# Dropped workflow_log_tickets
# Dropped workflow_log_classified
# Dropped workflow_log_scored

# %% [markdown]
# ### Remove all shared resources
#
# When finished with **all** notebooks, uncomment and run the cell below to delete the shared dataset and all tables, models, and other resources within it.

# %%
# client.delete_dataset(
#     f'{PROJECT_ID}.{DATASET_ID}',
#     delete_contents=True,
#     not_found_ok=True
# )
# print(f'Dataset {PROJECT_ID}.{DATASET_ID} deleted')
