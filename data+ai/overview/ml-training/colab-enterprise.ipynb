# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2Fdata%2Bai%2Foverview%2Fml-training&file=colab-enterprise.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2Fdata%252Bai%2Foverview%2Fml-training%2Fcolab-enterprise.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/overview/ml-training/colab-enterprise.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/overview/ml-training/colab-enterprise.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/overview/ml-training/colab-enterprise.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/data%252Bai/overview/ml-training/colab-enterprise.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/data%2Bai/overview/ml-training/colab-enterprise.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Colab Enterprise — Remote Notebook Execution
#
# This notebook demonstrates how to **execute a notebook programmatically** on [Colab Enterprise](https://cloud.google.com/colab/docs/introduction) using the [Vertex AI NotebookExecutionJob API](https://cloud.google.com/vertex-ai/docs/reference/rest/v1beta1/projects.locations.notebookExecutionJobs).
#
# The payload is [`bigframes-local.ipynb`](./bigframes-local.ipynb) from this same folder — the BigFrames + XGBoost training notebook. Instead of running it locally, we send it to a Colab Enterprise runtime where it executes on managed infrastructure, closer to the data.
#
# **What it demonstrates:**
# 1. **Discover** available runtime templates
# 2. **Submit** a notebook for remote execution via the API
# 3. **Poll** for completion
# 4. **Download** the executed notebook (with all outputs) from GCS
# 5. **Review** execution results, timing, and generated plots
#
# **The story:** Data scientists can trigger heavy notebook executions remotely, bypassing local hardware limitations while maintaining a notebook interface. The same notebook runs identically — no code changes needed.
#
# **References:**
# - [Colab Enterprise documentation](https://cloud.google.com/colab/docs/introduction)
# - [NotebookExecutionJob API](https://cloud.google.com/vertex-ai/docs/reference/rest/v1beta1/projects.locations.notebookExecutionJobs)
# - [Runtime template documentation](https://cloud.google.com/colab/docs/create-runtime-template)

# %% [markdown]
# ---
# ## Colab Setup
#
# To run this notebook in Colab, run the cells in this section. Otherwise, skip this section.

# %%
PROJECT_ID = 'statmike-mlops-349915'

# %%
try:
    from google.colab import auth
    auth.authenticate_user()
    # !gcloud config set project {PROJECT_ID}
    print('Colab authorized to GCP')
except ImportError:
    pass

# %% [markdown]
# ---
# ## Installs
#
# > **Already set up the project environment?** Skip to [Setup](#setup).
# > **Running standalone** (Colab, Colab Enterprise, Vertex AI Workbench)? Run the cell below to install packages.

# %%
import subprocess, sys, shutil

def install(*packages):
    """Install packages using uv (fast) with pip fallback."""
    uv = shutil.which('uv')
    if uv:
        subprocess.check_call([uv, 'pip', 'install', '-q', '--python', sys.executable, *packages])
    else:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', '--upgrade', *packages])

install('google-cloud-bigquery', 'google-cloud-storage', 'requests')

# %% [markdown]
# ---
# ## Setup

# %%
REGION = 'us-central1'
BQ_DATASET = 'data_ai_overview'
NOTEBOOK_PATH = 'bigframes-local.ipynb'

# %%
import json
import base64
import os
import time

import requests
from google.auth import default
from google.auth.transport.requests import Request as AuthRequest
from google.cloud import bigquery, storage

# %%
credentials, _ = default()
bq = bigquery.Client(project=PROJECT_ID)
gcs_client = storage.Client(project=PROJECT_ID)

# %%
dataset = bigquery.Dataset(f'{PROJECT_ID}.{BQ_DATASET}')
dataset.location = 'US'
bq.create_dataset(dataset, exists_ok=True)
print(f'Dataset ready: {PROJECT_ID}.{BQ_DATASET}')
# Out:
# Dataset ready: statmike-mlops-349915.data_ai_overview

# %%
DIR = 'temp/colab-enterprise'
if not os.path.exists(DIR):
    os.makedirs(DIR)

# %%
def get_token():
    """Get a fresh access token from Application Default Credentials."""
    credentials.refresh(AuthRequest())
    return credentials.token

def api_get(url):
    """Make an authenticated GET request and return the JSON response."""
    resp = requests.get(url, headers={'Authorization': f'Bearer {get_token()}'})
    resp.raise_for_status()
    return resp.json()

def api_post(url, data):
    """Make an authenticated POST request and return the JSON response."""
    resp = requests.post(
        url,
        headers={'Authorization': f'Bearer {get_token()}', 'Content-Type': 'application/json'},
        json=data
    )
    resp.raise_for_status()
    return resp.json()

# %% [markdown]
# ---
# ## The Payload Notebook
#
# We'll execute [`bigframes-local.ipynb`](./bigframes-local.ipynb) — the BigFrames + XGBoost training notebook from this same folder. It explores the fraud detection dataset via BigFrames, trains an XGBoost classifier locally, and produces evaluation metrics and plots.
#
# It's a good test case because it installs packages, connects to BigQuery, trains a model, and generates matplotlib plots — all things that should work seamlessly on a Colab Enterprise runtime.

# %%
with open(NOTEBOOK_PATH) as f:
    payload_nb = json.load(f)

code_cells = [c for c in payload_nb['cells'] if c['cell_type'] == 'code']
md_cells = [c for c in payload_nb['cells'] if c['cell_type'] == 'markdown']

print(f'Notebook: {NOTEBOOK_PATH}')
print(f'  Total cells:    {len(payload_nb["cells"])}')
print(f'  Code cells:     {len(code_cells)}')
print(f'  Markdown cells: {len(md_cells)}')
print(f'\nCode cell previews:')
for i, cell in enumerate(code_cells):
    first_line = ''.join(cell['source']).split('\n')[0][:80]
    print(f'  [{i}] {first_line}')
# Out:
# Notebook: bigframes-local.ipynb
#   Total cells:    24
#   Code cells:     14
#   Markdown cells: 10
#
# Code cell previews:
#   [0] PROJECT_ID = 'statmike-mlops-349915'
#   [1] try:
#   [2] import subprocess, sys, shutil
#   [3] REGION = 'us-central1'
#   [4] from google.cloud import bigquery
#   [5] dataset = bigquery.Dataset(f'{PROJECT_ID}.{BQ_DATASET}')
#   [6] bf = bfpd.read_gbq(BQ_SOURCE)
#   [7] bf.describe()
#   [8] class_counts = bf['Class'].value_counts()
#   [9] import time
#   [10] from sklearn.model_selection import train_test_split
#   [11] import xgboost as xgb
#   [12] from sklearn.metrics import classification_report, confusion_matrix, roc_auc_sco
#   [13] fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# %% [markdown]
# ---
# ## Discover Runtime Templates
#
# To execute a notebook on Colab Enterprise, you need a **runtime template**. Runtime templates define the compute configuration (machine type, disk, accelerators, idle timeout) and are created by administrators in the Google Cloud Console.
#
# There are two types:
# - `ONE_CLICK` — the default runtime template provided by Google Cloud
# - `USER_DEFINED` — custom templates created by project administrators
#
# - [Runtime template documentation](https://cloud.google.com/colab/docs/create-runtime-template)
# - [NotebookRuntimeTemplate API](https://cloud.google.com/vertex-ai/docs/reference/rest/v1beta1/projects.locations.notebookRuntimeTemplates)

# %%
templates_url = (
    f'https://{REGION}-aiplatform.googleapis.com/v1beta1/'
    f'projects/{PROJECT_ID}/locations/{REGION}/notebookRuntimeTemplates'
)
data = api_get(templates_url)
templates = data.get('notebookRuntimeTemplates', [])

print(f'Found {len(templates)} runtime template(s):\n')
for t in templates:
    name = t.get('displayName', 'unnamed')
    rt_type = t.get('notebookRuntimeType', 'UNKNOWN')
    machine = t.get('machineSpec', {}).get('machineType', 'default')
    print(f'  {name}')
    print(f'    Type:    {rt_type}')
    print(f'    Machine: {machine}')
    print(f'    Resource: {t["name"]}')
    print()
# Out:
# Found 5 runtime template(s):
#
#   pymc-runtime-1779574047
#     Type:    USER_DEFINED
#     Machine: e2-standard-4
#     Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/1872536471823450112
#
#   Default with GPU
#     Type:    ONE_CLICK
#     Machine: g2-standard-4
#     Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/4917088567181705216
#
#   Memory Boost
#     Type:    USER_DEFINED
#     Machine: e2-highmem-16
#     Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/6693430965714288640
#
#   Default
#     Type:    ONE_CLICK
#     Machine: e2-standard-4
#     Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/3924781522137120768
#
#   Standard E2 Runtime (4 vCPUs, 16 GB RAM)
#     Type:    USER_DEFINED
#     Machine: e2-standard-4
#     Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/e2-standard-4

# %%
runtime_template = None
for t in templates:
    if t.get('notebookRuntimeType') == 'USER_DEFINED':
        runtime_template = t
        break
if runtime_template is None and templates:
    runtime_template = templates[0]

if runtime_template:
    RUNTIME_TEMPLATE_NAME = runtime_template['name']
    print(f'Selected: {runtime_template.get("displayName", "unnamed")}')
    print(f'Resource: {RUNTIME_TEMPLATE_NAME}')
else:
    print('No runtime templates found.')
    print('Create one in the Console: Colab Enterprise > Runtime Templates')
# Out:
# Selected: pymc-runtime-1779574047
# Resource: projects/1026793852137/locations/us-central1/notebookRuntimeTemplates/1872536471823450112

# %% [markdown]
# ---
# ## Execute the Notebook
#
# The [Vertex AI NotebookExecutionJob API](https://cloud.google.com/vertex-ai/docs/reference/rest/v1beta1/projects.locations.notebookExecutionJobs) executes a notebook on a Colab Enterprise runtime and writes the executed notebook (with all outputs) to GCS.
#
# **Key concepts:**
# - `directNotebookSource` — the notebook content is sent inline as base64 (no need to upload to GCS first)
# - `notebookRuntimeTemplateResourceName` — which runtime template to use
# - `executionUser` — runs the notebook under a specific user's credentials
# - `gcsOutputUri` — where the executed notebook is written
#
# **Important API notes:**
# - Use the `v1beta1` endpoint. The `v1` endpoint causes `executionUser` jobs to hang in `PENDING`.
# - Do NOT pass a custom `notebookExecutionJobId` with `executionUser` mode — this also causes `PENDING` hangs. Let the API generate the job ID.
# - Each execution gets a fresh kernel — no state persists between executions.
# - The execution user must have visited the Colab Enterprise OAuth consent URL at least once.

# %%
EXECUTION_USER = !gcloud config get-value account
EXECUTION_USER = EXECUTION_USER[-1]
print(f'Execution user: {EXECUTION_USER}')
# Out:
# Execution user: statmike@statmike.altostrat.com

# %%
with open(NOTEBOOK_PATH) as f:
    nb_json = json.load(f)

for cell in nb_json['cells']:
    if cell['cell_type'] == 'code':
        cell['outputs'] = []
        cell['execution_count'] = None

nb_json['metadata']['kernelspec'] = {
    'display_name': 'Python 3',
    'language': 'python',
    'name': 'python3',
}

nb_clean = json.dumps(nb_json).encode()
nb_b64 = base64.b64encode(nb_clean).decode()

GCS_OUTPUT = f'gs://{PROJECT_ID}/colab-enterprise/executions/bigframes-local'
job_display_name = f'bigframes-local-{int(time.time())}'

print(f'Notebook:       {NOTEBOOK_PATH}')
print(f'Original size:  {os.path.getsize(NOTEBOOK_PATH):,} bytes')
print(f'Cleaned size:   {len(nb_clean):,} bytes (outputs stripped, kernel reset to python3)')
print(f'GCS output:     {GCS_OUTPUT}')
print(f'Display name:   {job_display_name}')
# Out:
# Notebook:       bigframes-local.ipynb
# Original size:  97,095 bytes
# Cleaned size:   10,686 bytes (outputs stripped, kernel reset to python3)
# GCS output:     gs://statmike-mlops-349915/colab-enterprise/executions/bigframes-local
# Display name:   bigframes-local-1779829309

# %%
create_url = (
    f'https://{REGION}-aiplatform.googleapis.com/v1beta1/'
    f'projects/{PROJECT_ID}/locations/{REGION}/notebookExecutionJobs'
)

exec_body = {
    'displayName': job_display_name,
    'directNotebookSource': {'content': nb_b64},
    'notebookRuntimeTemplateResourceName': RUNTIME_TEMPLATE_NAME,
    'gcsOutputUri': GCS_OUTPUT,
    'executionUser': EXECUTION_USER,
    'executionTimeout': '3600s',
}

result = api_post(create_url, exec_body)

op_name = result.get('name', '')
parts = op_name.split('/')
JOB_ID = parts[parts.index('notebookExecutionJobs') + 1]

print(f'Job submitted!')
print(f'Job ID:    {JOB_ID}')
print(f'Operation: {op_name}')
# Out:
# Job submitted!
# Job ID:    5341754317567164416
# Operation: projects/1026793852137/locations/us-central1/notebookExecutionJobs/5341754317567164416/operations/5462762332482437120

# %% [markdown]
# ---
# ## Poll for Completion
#
# Notebook execution jobs are asynchronous. Poll the job status until it reaches a terminal state (`SUCCEEDED`, `FAILED`, or `CANCELLED`).

# %%
job_url = (
    f'https://{REGION}-aiplatform.googleapis.com/v1beta1/'
    f'projects/{PROJECT_ID}/locations/{REGION}/'
    f'notebookExecutionJobs/{JOB_ID}'
)

start_time = time.time()
while True:
    time.sleep(30)
    job = api_get(job_url)
    state = job.get('jobState', '')
    elapsed = int(time.time() - start_time)

    if state == 'JOB_STATE_RUNNING':
        print(f'  Running... ({elapsed}s elapsed)')
    elif state == 'JOB_STATE_SUCCEEDED':
        print(f'  Succeeded! ({elapsed}s elapsed)')
        break
    elif state in ('JOB_STATE_FAILED', 'JOB_STATE_CANCELLED'):
        error_msg = (
            job.get('error', {}).get('message')
            or job.get('status', {}).get('message')
            or state
        )
        print(f'  {state} ({elapsed}s elapsed)')
        print(f'  Error: {error_msg}')
        break
    else:
        print(f'  {state}... ({elapsed}s elapsed)')
# Out:
#   JOB_STATE_PENDING... (30s elapsed)
#   JOB_STATE_PENDING... (60s elapsed)
#   Running... (90s elapsed)
#   Succeeded! (120s elapsed)

# %% [markdown]
# ---
# ## Download Results from GCS
#
# After successful execution, the notebook with all outputs is written to GCS at:
#
# ```
# {gcsOutputUri}/{jobId}/content.ipynb
# ```
#
# The executed notebook contains printed text, tables, rendered plots, and any errors that occurred during execution.

# %%
gcs_path = f'{GCS_OUTPUT}/{JOB_ID}/content.ipynb'

gcs_parts = gcs_path.replace('gs://', '').split('/', 1)
bucket_name = gcs_parts[0]
blob_path = gcs_parts[1]

bucket = gcs_client.bucket(bucket_name)
blob = bucket.blob(blob_path)

completed_path = os.path.join(DIR, 'completed_bigframes_local.ipynb')
blob.download_to_filename(completed_path)

print(f'Downloaded executed notebook to: {completed_path}')
print(f'GCS source: {gcs_path}')
# Out:
# Downloaded executed notebook to: temp/colab-enterprise/completed_bigframes_local.ipynb
# GCS source: gs://statmike-mlops-349915/colab-enterprise/executions/bigframes-local/5341754317567164416/content.ipynb

# %% [markdown]
# ---
# ## Review Execution Results
#
# The executed notebook contains cell-level timing metadata and all outputs. Parse it to extract timing information and identify any errors.

# %%
from datetime import datetime

with open(completed_path) as f:
    executed_nb = json.load(f)

code_cells = [c for c in executed_nb['cells'] if c['cell_type'] == 'code']
print(f'Executed notebook: {len(executed_nb["cells"])} cells ({len(code_cells)} code)\n')

timings = []
errors = []
for i, cell in enumerate(executed_nb['cells']):
    if cell['cell_type'] != 'code':
        continue

    for out in cell.get('outputs', []):
        if out.get('output_type') == 'error':
            errors.append({
                'cell': i,
                'ename': out.get('ename', ''),
                'evalue': out.get('evalue', ''),
            })

    ex = cell.get('metadata', {}).get('execution', {})
    start = ex.get('iopub.execute_input') or ex.get('iopub.status.busy')
    end = ex.get('shell.execute_reply') or ex.get('iopub.status.idle')
    if start and end:
        try:
            t0 = datetime.fromisoformat(start.replace('Z', '+00:00'))
            t1 = datetime.fromisoformat(end.replace('Z', '+00:00'))
            duration = (t1 - t0).total_seconds()
            preview = ''.join(cell.get('source', []))[:60].strip()
            timings.append({'cell': i, 'seconds': duration, 'preview': preview})
        except (ValueError, TypeError):
            pass

if timings:
    total = sum(t['seconds'] for t in timings)
    print(f'Total execution time: {total:.1f}s ({len(timings)} timed cells)\n')

    slow = sorted(timings, key=lambda t: -t['seconds'])[:5]
    print('Slowest cells:')
    for t in slow:
        m, s = divmod(int(t['seconds']), 60)
        fmt = f'{m}m {s:02d}s' if m > 0 else f'{s}s'
        print(f"  Cell {t['cell']:>3}: {fmt:>8}  — {t['preview']}")

if errors:
    print(f'\nErrors ({len(errors)}):')
    for e in errors:
        print(f"  Cell {e['cell']}: {e['ename']}: {e['evalue'][:200]}")
elif timings:
    print('\nNo errors detected.')
# Out:
# Executed notebook: 24 cells (14 code)
#
# Total execution time: 39.7s (14 timed cells)
#
# Slowest cells:
#   Cell  16:      13s  — import time
#
# start = time.time()
# df = bf.to_pandas()
# elapsed
#   Cell   9:       8s  — from google.cloud import bigquery
# import bigframes.pandas as
#   Cell  13:       6s  — bf.describe()
#   Cell  17:       3s  — from sklearn.model_selection import train_test_split
#
# X = df
#   Cell  19:       2s  — import xgboost as xgb
#
# scale = (y_train == 0).sum() / (y_tra
#
# No errors detected.

# %%
from IPython.display import display, Image as IPImage

plot_count = 0
for i, cell in enumerate(executed_nb['cells']):
    if cell['cell_type'] != 'code':
        continue
    for out in cell.get('outputs', []):
        img_data = out.get('data', {}).get('image/png')
        if img_data:
            plot_count += 1
            preview = ''.join(cell.get('source', []))[:60].strip()
            print(f'Plot {plot_count} (cell {i}): {preview}')
            display(IPImage(data=base64.b64decode(img_data)))
            print()

if plot_count == 0:
    print('No plot outputs found in the executed notebook.')
else:
    print(f'\nTotal: {plot_count} plot(s) extracted from the executed notebook.')
# Out:
# Plot 1 (cell 22): fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#
# cm = confus
# Total: 1 plot(s) extracted from the executed notebook.

# %% [markdown]
# ---
# ## Summary & Next Steps
#
# This notebook demonstrated remote notebook execution on Colab Enterprise:
#
# 1. **Discovered** available runtime templates in the project
# 2. **Submitted** `bigframes-local.ipynb` for execution via the NotebookExecutionJob API
# 3. **Polled** until the job completed on managed infrastructure
# 4. **Downloaded** the executed notebook with all outputs from GCS
# 5. **Reviewed** execution timing, errors, and rendered plots
#
# The same notebook ran identically on a Colab Enterprise runtime — no code changes, no local compute. This pattern enables automated testing, CI/CD for notebooks, batch parameterized runs, and scheduled execution.
#
# ### Related notebooks in this series
#
# | Notebook | What It Demonstrates |
# |---|---|
# | `bigframes-local.ipynb` | The payload notebook — local BigFrames + XGBoost training |
# | `bqml.ipynb` | In-database training with BigQuery ML |
# | `dataproc-serverless.ipynb` | Distributed processing with PySpark |
# | `vertex-training.ipynb` | Custom container training (Python, R, C++) |
# | `model-registry.ipynb` | Centralizing models from all approaches |
# | `kfp-orchestration.ipynb` | Orchestrating everything in one pipeline |
