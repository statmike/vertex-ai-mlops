# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FApplied+ML%2FAI+Agents%2Fbigquery-context&file=bigquery_context.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FApplied%2520ML%2FAI%2520Agents%2Fbigquery-context%2Fbigquery_context.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%2520ML/AI%2520Agents/bigquery-context/bigquery_context.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%2520ML/AI%2520Agents/bigquery-context/bigquery_context.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%2520ML/AI%2520Agents/bigquery-context/bigquery_context.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%2520ML/AI%2520Agents/bigquery-context/bigquery_context.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb"><img src="https://www.svgrepo.com/download/5445/download-button.svg" alt="Download icon" width="20px"></a> <a href="https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20ML/AI%20Agents/bigquery-context/bigquery_context.ipynb">Download Notebook</a> <i>(right-click and "Save As")</i>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # BigQuery Context — Six Approaches to Table Discovery
#
# This notebook is a hands-on guide to understanding six different approaches for finding the best BigQuery tables to answer a user's question. Rather than running the ADK agents directly, we **reproduce each approach step-by-step** so you can see exactly:
#
# 1. **What metadata each API returns** — for the same table, side by side
# 2. **What gets nominated** — which tables each approach sends to the reranker, and in what format
# 3. **What the reranker receives** — the actual metadata string, so you can see the richness difference
# 4. **What the reranker outputs** — structured results with confidence scores, column hints, and SQL suggestions
#
# Five of the six approaches use the same shared reranker ([Gemini structured output](https://ai.google.dev/gemini-api/docs/structured-output) → `RerankerResponse`), so the only variable is *how tables are discovered* and *what metadata describes them*. The sixth — **Search Direct** — skips the reranker entirely and takes semantic search's own returned order as the final ranking; pairing it with Approach 2 (same retrieval, *with* the reranker) isolates exactly what the LLM rerank stage adds.
#
# **To run the agents interactively**, see the [readme](readme.md) — use `uv run adk web .` to launch the ADK web UI.

# %% [markdown]
# > **This notebook is the single-run *story*; `examples/` is the rigorous *benchmark*.**
# >
# > Catalog enrichment is the thing we want to measure — does richer metadata (profiling, glossary, guidelines) make table discovery better? To measure that cleanly, `scripts/setup.py` replicates the **identical corpus** into one dataset per enrichment tier (`{prefix}_tier0` schema-only .. `{prefix}_tier3` fully enriched). Same tables and data everywhere; the *only* variable across tiers is how much the catalog holds. Every topic appears at every tier, so tier is decoupled from topic — a clean factorial ablation.
# >
# > This notebook walks through all six approaches **once, at the fully-enriched tier** (`ACTIVE_TIER`, default 3), so you can *see* what each API returns and what the reranker does with it. The [`examples/`](examples/README.md) benchmark then sweeps **approach × tier × question × run (n=5)** and reports rank-aware metrics (Recall@k, MRR, nDCG), discovery-vs-rerank recall, precision against distractor tables, isolated latency, and reranker token cost — the evidence, with plots and confidence intervals.

# %% [markdown]
# ---
# ## Setup
#
# This notebook runs inside the `bigquery-context` project directory. Prerequisites:
# 1. `uv sync --extra dev` — install dependencies
# 2. `.env` with `GOOGLE_CLOUD_PROJECT=your-project-id`
# 3. `uv run python scripts/setup.py` — replicate the corpus into one dataset per enrichment tier (`{prefix}_tier0`..`_tier3`) and populate the Knowledge Catalog (profile scans, glossary terms, and guidelines) at the appropriate tiers
#
# See the [readme](readme.md) for details.

# %%
PROJECT_ID = "statmike-mlops-349915"

# %%
import json
import os

from dotenv import load_dotenv

load_dotenv()

os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID
os.environ.setdefault("GOOGLE_GENAI_USE_VERTEXAI", "TRUE")

# Imports below intentionally follow the env-var setup above: config reads these
# environment variables at import time, so load_dotenv() must run first.
from google.cloud import bigquery, dataplex_v1  # noqa: E402
from google.protobuf import json_format  # noqa: E402

from config import (  # noqa: E402
    AGENT_MODEL,
    BQ_LOCATION,
    GOOGLE_CLOUD_LOCATION,
    GOOGLE_CLOUD_PROJECT,
    SCOPE,
    TOOL_MODEL,
    TOP_K,
    get_dataplex_entry_name,
    get_datasets,
    get_scoped_tables,
    is_table_in_scope,
)
from context_cache import (  # noqa: E402
    get_all_briefs,
    get_all_detailed,
    get_detailed_for_tables,
    get_table_ids,
)
from context_cache.util_lookup_context import lookup_context  # noqa: E402
from reranker.util_rerank import call_reranker  # noqa: E402

bq_client = bigquery.Client(project=GOOGLE_CLOUD_PROJECT)
catalog_client = dataplex_v1.CatalogServiceClient()

print(f"Project:     {GOOGLE_CLOUD_PROJECT}")
print(f"Location:    {GOOGLE_CLOUD_LOCATION}")
print(f"Agent Model: {AGENT_MODEL}")
print(f"Tool Model:  {TOOL_MODEL}")
print(f"Top K:       {TOP_K}")
print(f"Datasets:    {get_datasets()}")
print(f"Scope:       {SCOPE}")
# Out:
# Project:     statmike-mlops-349915
# Location:    us-central1
# Agent Model: gemini-3.6-flash
# Tool Model:  gemini-3.5-flash-lite
# Top K:       5
# Datasets:    ['bigquery_context_tier3']
# Scope:       ['bigquery_context_tier3']

# %% [markdown]
# ### Verify Demo Resources

# %%
for dataset_id in get_datasets():
    try:
        tables = list(bq_client.list_tables(f"{GOOGLE_CLOUD_PROJECT}.{dataset_id}"))
        print(f"  {dataset_id}: {[t.table_id for t in tables]}")
    except Exception:
        print(f"  {dataset_id}: NOT FOUND — run: uv run python scripts/setup.py")
# Out:
#   bigquery_context_tier3: ['air_quality_annual_summary', 'austin_bikeshare_stations', 'austin_bikeshare_trips', 'austin_crime', 'citibike_stations', 'county_natality', 'hurricanes', 'nyc_taxi_trips_2022', 'population_by_zip_2010', 'taxi_zone_geom', 'unemployment_cps', 'us_counties', 'usa_names_1910_current', 'weather_stations', 'zip_codes']

# %% [markdown]
# ### Define the Question
#
# We use the same question for all approaches so results are directly comparable.

# %%
QUESTION = "Which US counties have the most weather stations per capita?"
print(f"Question: {QUESTION}")

# This notebook tells the single-run story at the fully-enriched tier (ACTIVE_TIER,
# default 3). setup.py replicates the identical corpus into one dataset per tier
# ({prefix}_tier0.._tier3); the only difference between tiers is catalog enrichment.
# SCOPE / get_datasets() resolve to the single active-tier dataset, so every cell
# below reads exactly one tier's copy of the corpus. See examples/ for the full
# factorial benchmark that sweeps every tier.
from config import ACTIVE_TIER, tier_dataset  # noqa: E402

EXAMPLE_TABLE = "weather_stations"
EXAMPLE_DATASET = tier_dataset(ACTIVE_TIER)
EXAMPLE_FULL_ID = f"{GOOGLE_CLOUD_PROJECT}.{EXAMPLE_DATASET}.{EXAMPLE_TABLE}"
print(f"Active tier:   {ACTIVE_TIER}")
print(f"Example table: {EXAMPLE_FULL_ID}")
# Out:
# Question: Which US counties have the most weather stations per capita?
# Active tier:   3
# Example table: statmike-mlops-349915.bigquery_context_tier3.weather_stations

# %% [markdown]
# ---
# ## The APIs — Same Table, Different Metadata
#
# Before walking through the six approaches, let's see what metadata each API returns for the **same table** (`weather_stations`). This makes the richness differences concrete.
#
# The catalog product was renamed from "Dataplex Universal Catalog" to **Knowledge Catalog** in April 2026. The rename is branding only — the API namespace, client library (`google-cloud-dataplex` / `dataplex_v1`), CLI, and IAM roles are unchanged, so the code below still imports and calls `dataplex_v1`.
#
# | API | SDK / Protocol | Used By | Key Difference |
# |---|---|---|---|
# | BQ `get_table_info` | BigQuery Python SDK | Approach 1 | Schema + row count, no column descriptions or profiling |
# | Knowledge Catalog `lookup_entry` | `google-cloud-dataplex` SDK | Approach 2 | Schema + catalog aspects, no data profiling stats |
# | Knowledge Catalog `lookup_context` | `google-cloud-dataplex` SDK (preview) | Approaches 3, 4, 5 (via cache) | Schema + `dataProfile` per column, plus glossary terms, `frequent_joins`, and `guidelines` when the catalog is enriched |
#
# Approach 6 (Search Direct) fetches no per-table metadata at all — it uses only the `search_entries` result order (the same search Approaches 2 and 5 run) and skips both `lookup_entry`/`lookup_context` and the reranker.

# %% [markdown]
# ### BigQuery API: `get_table_info`
#
# This is what Approach 1 works with — the standard BigQuery SDK. It returns column names, types, and modes, plus table description and row count. Column descriptions come through when they exist in the BQ schema, but there are no data profiling statistics.

# %%
table = bq_client.get_table(EXAMPLE_FULL_ID)

bq_metadata = f"## {EXAMPLE_FULL_ID}\n"
bq_metadata += f"Description: {table.description or '(none)'}\n"
bq_metadata += f"Rows: {table.num_rows:,}\n"
bq_metadata += "Columns:\n"
for field in table.schema:
    desc = f" - {field.description}" if field.description else ""
    bq_metadata += f"  - {field.name} ({field.field_type}){desc}\n"

print(bq_metadata)
print(f"\n--- {len(bq_metadata):,} chars ---")
# Out:
# ## statmike-mlops-349915.bigquery_context_tier3.weather_stations
# Description: Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.
# Rows: 0
# Columns:
#   - id (STRING)
#   - latitude (FLOAT)
#   - longitude (FLOAT)
#   - elevation (FLOAT)
#   - state (STRING)
#   - name (STRING)
#   - gsn_flag (STRING)
#   - hcn_crn_flag (STRING)
#   - wmoid (INTEGER)
#   - source_url (STRING)
#   - etl_timestamp (TIMESTAMP)
#
#
# --- 465 chars ---

# %% [markdown]
# ### Knowledge Catalog SDK: `lookup_entry`
#
# This is what Approach 2 works with — the Knowledge Catalog Python SDK's [`lookup_entry`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_entry) (still on the `dataplex_v1` client). It returns schema with column names/types/descriptions, entry source metadata, and catalog aspects. No data profiling statistics — the metadata is richer than BQ's but still schema-level only.

# %%
# Use the same entry name builder as the agents
entry_name = get_dataplex_entry_name(EXAMPLE_DATASET, EXAMPLE_TABLE)
print(f"Entry name: {entry_name}\n")

lookup_req = dataplex_v1.LookupEntryRequest(
    name=f"projects/{GOOGLE_CLOUD_PROJECT}/locations/{BQ_LOCATION.lower()}",
    entry=entry_name,
    view=dataplex_v1.EntryView.FULL,
)
entry = catalog_client.lookup_entry(request=lookup_req)
entry_dict = json_format.MessageToDict(entry._pb)

# Build the summary the same way approach 2's callback does
lookup_entry_metadata = {
    "display_name": entry_dict.get("entrySource", {}).get("displayName", ""),
    "description": entry_dict.get("entrySource", {}).get("description", ""),
}
for key, aspect in entry_dict.get("aspects", {}).items():
    if "schema" in key:
        lookup_entry_metadata["schema"] = aspect.get("data", {})

lookup_entry_json = json.dumps(lookup_entry_metadata, indent=2)
print(f"## {EXAMPLE_FULL_ID}")
print(lookup_entry_json)
print(f"\n--- {len(lookup_entry_json):,} chars ---")
# Out:
# Entry name: projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations
# ## statmike-mlops-349915.bigquery_context_tier3.weather_stations
# {
#   "display_name": "weather_stations",
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": {
#     "fields": [
#       {
#         "mode": "NULLABLE",
#         "dataType": "STRING",
#         "name": "id",
#         "metadataType": "STRING"
#       },
#       {
#         "mode": "NULLABLE",
#         "dataType": "FLOAT",
#         "name": "latitude",
#         "metadataType": "NUMBER"
#       },
#       {
#         "mode": "NULLABLE",
#         "dataType": "FLOAT",
#         "name": "longitude",
#         "metadataType": "NUMBER"
#       },
#       {
#         "mode": "NULLABLE",
# ...

# %% [markdown]
# ### Knowledge Catalog SDK: `lookup_context`
#
# This is what Approaches 3, 4, and 5 work with (via the shared cache). The [`lookup_context`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_context) API (`CatalogServiceClient.lookup_context`, **preview**) returns LLM-ready metadata capsules in JSON format. When data profiling has been run, each column includes a `dataProfile` section with `nullRatio`, `distinctValues`, and `sampleValues`.
#
# The capsule also surfaces the richer catalog enrichments when they exist: glossary term links (`related_terms` / `business_descriptions`), observed join relationships (`frequent_joins`), and authored NL→SQL `guidelines`. How much shows up depends on the table's **enrichment tier** (see the tiers below) — because this notebook runs at the fully-enriched tier (`ACTIVE_TIER`, default 3), `weather_stations` here carries `dataProfile` plus glossary-linked column meaning plus guidelines.

# %% [markdown]
# #### The Enrichment Tiers
#
# `lookup_context` only returns as much as the catalog holds. To measure how discovery quality tracks catalog richness *without confounding it with topic*, `scripts/setup.py` replicates the **identical corpus** into one dataset per enrichment tier — `{prefix}_tier0` .. `{prefix}_tier3`. Same tables, same data, same descriptions; the **only** difference between tier datasets is how much catalog enrichment each carries:
#
# | Tier dataset | Tier | Profiling | Glossary | Guidelines |
# |---|---|---|---|---|
# | `{prefix}_tier0` | **0 · schema only** | — | — | — |
# | `{prefix}_tier1` | **1 · + profiling** | ✓ | — | — |
# | `{prefix}_tier2` | **2 · + glossary** | ✓ | ✓ | — |
# | `{prefix}_tier3` | **3 · + guidelines** | ✓ | ✓ | ✓ |
#
# Each tier adds one enrichment on top of the previous. **Profiling** attaches per-column `dataProfile` stats (a `DataProfileScan` with catalog publishing). **Glossary** links columns to business terms authored via `BusinessGlossaryServiceClient` + entry links, surfacing as `related_terms` / `business_descriptions`. **Guidelines** attach NL→SQL guidance via the `guidelines` system aspect (Google's example-queries feature is AI-generated with no manual authoring API — `guidelines` is the user-authorable hook that surfaces the same way).
#
# Because every topic appears at every tier, tier is decoupled from topic — a clean factorial ablation of enrichment. This notebook runs entirely at the active tier (`ACTIVE_TIER`, default 3), so `weather_stations` here carries the full profiling + glossary + guidelines stack. The benchmark in `examples/` sweeps all four tiers and slices recall by tier to show the payoff — see [`examples/README.md`](examples/README.md).

# %%
dataplex_entry_name = get_dataplex_entry_name(EXAMPLE_DATASET, EXAMPLE_TABLE)
lookup_context_json = lookup_context([dataplex_entry_name])

# Parse and pretty-print
lookup_context_parsed = json.loads(lookup_context_json)
lookup_context_pretty = json.dumps(lookup_context_parsed, indent=2)
print(lookup_context_pretty)
print(f"\n--- {len(lookup_context_pretty):,} chars ---")
# Out:
# [
#   {
#     "catalogEntry": "projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#     "resource": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#     "simpleName": "statmike-mlops-349915.bigquery_context_tier3.weather_stations",
#     "type": "BigQuery View",
#     "createTime": "2026-07-28T12:30:53.539Z",
#     "updateTime": "2026-07-28T12:30:53.701Z",
#     "ancestors": [
#       {
#         "catalogEntry": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3",
#         "type": "dataplex-types.global.bigquery-dataset"
#       }
#     ],
#     "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#     "schema": [
#       {
#         "name": "elevation",
#         "type": "FLOAT",
# ...

# %%
# Proving the tiers: the same lookup_context call on the SAME table returns more
# as the tier rises. Because the corpus is replicated identically across tiers,
# we can contrast the tier-0 copy (schema only) against the tier-3 copy
# (profiling + glossary + guidelines) of one table — holding topic constant.
def enrichment_summary(dataset, table):
    entry = json.loads(lookup_context([get_dataplex_entry_name(dataset, table)]))[0]
    cols = entry.get("schema", [])
    return {
        "columns": len(cols),
        "dataProfile": any("dataProfile" in c for c in cols),
        "glossary terms": sum(1 for c in cols if "terms" in c),
        "guidelines": "overview" in entry or "guidelines" in entry,
    }


tier3 = enrichment_summary(tier_dataset(3), EXAMPLE_TABLE)
tier0 = enrichment_summary(tier_dataset(0), EXAMPLE_TABLE)

print(f"Table held constant: {EXAMPLE_TABLE}\n")
print(f"{'enrichment':<16}{'Tier 3 copy':<26}{'Tier 0 copy'}")
print("-" * 62)
for k in ("columns", "dataProfile", "glossary terms", "guidelines"):
    print(f"{k:<16}{str(tier3[k]):<26}{tier0[k]}")
print("\nSame table, same data — the Tier 3 copy carries profiling + glossary-linked")
print("columns + guidelines; the Tier 0 copy returns bare schema. The only variable")
print("is catalog enrichment, which is exactly what the examples/ benchmark ablates.")
# Out:
# Table held constant: weather_stations
#
# enrichment      Tier 3 copy               Tier 0 copy
# --------------------------------------------------------------
# columns         11                        11
# dataProfile     True                      False
# glossary terms  2                         0
# guidelines      False                     False
#
# Same table, same data — the Tier 3 copy carries profiling + glossary-linked
# columns + guidelines; the Tier 0 copy returns bare schema. The only variable
# is catalog enrichment, which is exactly what the examples/ benchmark ablates.

# %% [markdown]
# ### Shared Context Cache: Brief vs Detailed
#
# The shared cache (`context_cache/`) is populated once at startup from the `lookup_context` API. It stores two views per table — both derived from the same JSON response:
#
# - **Brief**: built *subtractively* — everything in the capsule **except** the heavy per-column `dataProfile` stats (and a tiny noise denylist). This keeps the cheap, high-signal enrichments (glossary terms, `frequent_joins`, `guidelines`) so they still reach the LLM during Approach 4's pre-filtering. New capsule keys flow through automatically without code changes.
# - **Detailed**: Full JSON including `dataProfile` per column. Used by the reranker in Approaches 3, 4, and 5.
#
# Let's see both views for our example table:

# %%
# Brief view — what the LLM sees in Approach 4 for pre-filtering
all_briefs_parsed = json.loads(get_all_briefs())
example_brief = next((b for b in all_briefs_parsed if b.get("table_id") == EXAMPLE_FULL_ID), None)
if example_brief:
    brief_str = json.dumps(example_brief, indent=2)
    print("=== BRIEF (no dataProfile) ===")
    print(brief_str)
    print(f"\n--- {len(brief_str):,} chars ---")
# Out:
# === BRIEF (no dataProfile) ===
# {
#   "catalogEntry": "projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "resource": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "simpleName": "statmike-mlops-349915.bigquery_context_tier3.weather_stations",
#   "createTime": "2026-07-28T12:30:53.539Z",
#   "updateTime": "2026-07-28T12:30:53.701Z",
#   "ancestors": [
#     {
#       "catalogEntry": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3",
#       "type": "dataplex-types.global.bigquery-dataset"
#     }
#   ],
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": [
#     {
#       "name": "elevation",
#       "type": "FLOAT",
#       "mode": "NULLABLE"
#     },
#     {
# ...

# %%
# Detailed view — what the reranker sees in Approaches 3, 4, 5
detailed_for_example = get_detailed_for_tables([EXAMPLE_FULL_ID])
detailed_parsed = json.loads(detailed_for_example)
if detailed_parsed:
    detailed_str = json.dumps(detailed_parsed[0], indent=2)
    print("=== DETAILED (with dataProfile) ===")
    print(detailed_str)
    print(f"\n--- {len(detailed_str):,} chars ---")
# Out:
# === DETAILED (with dataProfile) ===
# {
#   "catalogEntry": "projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "resource": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "simpleName": "statmike-mlops-349915.bigquery_context_tier3.weather_stations",
#   "type": "BigQuery View",
#   "createTime": "2026-07-28T12:30:53.539Z",
#   "updateTime": "2026-07-28T12:30:53.701Z",
#   "ancestors": [
#     {
#       "catalogEntry": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3",
#       "type": "dataplex-types.global.bigquery-dataset"
#     }
#   ],
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": [
#     {
#       "name": "elevation",
#       "type": "FLOAT",
# ...

# %%
# Side-by-side: metadata size for the same table across APIs
print(f"Metadata size for {EXAMPLE_TABLE} across APIs:")
print(f"  BQ get_table_info:      {len(bq_metadata):>6,} chars  (schema + row count)")
print(f"  KC lookup_entry:        {len(lookup_entry_json):>6,} chars  (schema + aspects)")
print(f"  Cache brief:            {len(brief_str):>6,} chars  (lookup_context minus dataProfile)")
print(
    f"  Cache detailed:         {len(detailed_str):>6,} chars  (full lookup_context with dataProfile)"
)
print()
print(f"The detailed view is {len(detailed_str) / len(bq_metadata):.1f}x richer than BQ metadata.")
print(f"The brief view is {len(brief_str) / len(bq_metadata):.1f}x the size of BQ metadata.")
print()
print("Key additions in lookup_context vs BQ/lookup_entry:")
print("  - dataProfile.nullRatio — what fraction of values are null")
print("  - dataProfile.distinctValues — cardinality as a percentage")
print("  - dataProfile.sampleValues — actual example values from the data")
# Out:
# Metadata size for weather_stations across APIs:
#   BQ get_table_info:         465 chars  (schema + row count)
#   KC lookup_entry:         1,723 chars  (schema + aspects)
#   Cache brief:             2,247 chars  (lookup_context minus dataProfile)
#   Cache detailed:          5,227 chars  (full lookup_context with dataProfile)
#
# The detailed view is 11.2x richer than BQ metadata.
# The brief view is 4.8x the size of BQ metadata.
#
# Key additions in lookup_context vs BQ/lookup_entry:
#   - dataProfile.nullRatio — what fraction of values are null
#   - dataProfile.distinctValues — cardinality as a percentage
#   - dataProfile.sampleValues — actual example values from the data

# %% [markdown]
# ---
# ## Approach 1: BQ Metadata Tools (`agent_bq_tools`)
#
# **Discovery:** LLM-driven tool calls via ADK [BigQueryToolset](https://google.github.io/adk-docs/integrations/bigquery/) — `list_dataset_ids` → `list_table_ids` → `get_table_info` per table.
# **Metadata API:** BigQuery SDK — schema (columns, types, modes), description, row count.
# **Reranker called as:** ADK tool (`rerank_tables`) — the LLM decides when to call it.
# **Reranker receives:** `get_table_info` text for all inspected tables (no `dataProfile`).
# **Cache usage:** None.
# **Per-query API calls:** 4–10+ BQ API calls.

# %% [markdown]
# ### Step 1: Discover and Gather Metadata
#
# The agent enumerates datasets → tables → schemas using BQ API calls. Here we reproduce that workflow:

# %%
bq_metadata_parts = []
bq_nominated_ids = []

for ds in get_datasets():
    scoped = get_scoped_tables(ds)
    if scoped is None:
        table_ids = [t.table_id for t in bq_client.list_tables(f"{GOOGLE_CLOUD_PROJECT}.{ds}")]
    else:
        table_ids = scoped

    for table_id in table_ids:
        full_id = f"{GOOGLE_CLOUD_PROJECT}.{ds}.{table_id}"
        tbl = bq_client.get_table(full_id)
        bq_nominated_ids.append(full_id)

        part = f"## {full_id}\n"
        part += f"Description: {tbl.description or '(none)'}\n"
        part += f"Rows: {tbl.num_rows:,}\n"
        part += "Columns:\n"
        for field in tbl.schema:
            desc = f" - {field.description}" if field.description else ""
            part += f"  - {field.name} ({field.field_type}){desc}\n"
        bq_metadata_parts.append(part)

        cols_with_desc = sum(1 for f in tbl.schema if f.description)
        print(
            f"  {full_id}: {len(tbl.schema)} cols ({cols_with_desc} with descriptions), {len(part):,} chars"
        )

bq_candidate_metadata = "\n".join(bq_metadata_parts)
print(f"\nNominated: {len(bq_nominated_ids)} tables")
print(f"Total metadata for reranker: {len(bq_candidate_metadata):,} chars")
# Out:
#   statmike-mlops-349915.bigquery_context_tier3.air_quality_annual_summary: 55 cols (55 with descriptions), 9,548 chars
#   statmike-mlops-349915.bigquery_context_tier3.austin_bikeshare_stations: 16 cols (0 with descriptions), 638 chars
#   statmike-mlops-349915.bigquery_context_tier3.austin_bikeshare_trips: 10 cols (10 with descriptions), 791 chars
#   statmike-mlops-349915.bigquery_context_tier3.austin_crime: 18 cols (12 with descriptions), 1,349 chars
#   statmike-mlops-349915.bigquery_context_tier3.citibike_stations: 18 cols (0 with descriptions), 766 chars
#   statmike-mlops-349915.bigquery_context_tier3.county_natality: 10 cols (10 with descriptions), 889 chars
#   statmike-mlops-349915.bigquery_context_tier3.hurricanes: 153 cols (115 with descriptions), 21,468 chars
#   statmike-mlops-349915.bigquery_context_tier3.nyc_taxi_trips_2022: 20 cols (0 with descriptions), 780 chars
# ...

# %% [markdown]
# ### Step 2: Preview What the Reranker Receives
#
# The metadata string below is what Approach 1 passes to the reranker. Notice: plain text, no JSON structure, no `dataProfile`. The reranker has to work with column names, types, and descriptions only.

# %%
# Show the reranker input for our example table
example_part = next(p for p in bq_metadata_parts if EXAMPLE_TABLE in p)
print("Reranker input for weather_stations (Approach 1):")
print(example_part)
# Out:
# Reranker input for weather_stations (Approach 1):
# ## statmike-mlops-349915.bigquery_context_tier3.weather_stations
# Description: Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.
# Rows: 0
# Columns:
#   - id (STRING)
#   - latitude (FLOAT)
#   - longitude (FLOAT)
#   - elevation (FLOAT)
#   - state (STRING)
#   - name (STRING)
#   - gsn_flag (STRING)
#   - hcn_crn_flag (STRING)
#   - wmoid (INTEGER)
#   - source_url (STRING)
#   - etl_timestamp (TIMESTAMP)

# %% [markdown]
# ### Step 3: Rerank

# %%
result_bq_tools = call_reranker(
    question=QUESTION,
    candidate_metadata=bq_candidate_metadata,
    discovery_method="bq_tools",
    top_k=TOP_K,
)

print(f"Ranked {len(result_bq_tools.ranked_tables)} table(s):\n")
for t in result_bq_tools.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
    print(f"     {t.reasoning}")
    if t.sql_hints:
        print(f"     SQL: {t.sql_hints}")
    print()
# Out:
# Ranked 5 table(s):
#
#   #1 [0.95] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#      Contains the inventory of weather stations with geographic coordinates, which can be spatially joined to county boundaries to count stations per county.
#      SQL: Spatial join weather stations to US county boundaries using ST_Contains or ST_DWithin on station coordinates and county_geom.
#
#   #2 [0.95] statmike-mlops-349915.bigquery_context_tier3.us_counties
#      Provides US county boundaries and FIPS codes necessary for aggregating weather stations by county and calculating per-capita metrics.
#      SQL: GROUP BY county_name and state FIPS to aggregate counts per county. Join with county-level population estimates to calculate per capita ratios.
#
#   #3 [0.80] statmike-mlops-349915.bigquery_context_tier3.county_natality
# ...

# %% [markdown]
# ---
# ## Approach 2: Knowledge Catalog Search (`agent_kc_search`)
#
# **Discovery:** Knowledge Catalog [`search_entries`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_search_entries) with `semantic_search=True`, scoped to configured datasets.
# **Metadata API:** Knowledge Catalog [`lookup_entry`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_entry) per matched table — schema + catalog aspects, no `dataProfile`.
# **Reranker called as:** Direct function call in `before_agent_callback` (LLM skipped).
# **Reranker receives:** `lookup_entry` JSON (schema + aspects, no `dataProfile`).
# **Cache usage:** None.
# **Per-query API calls:** 1 search + N lookup calls.
#
# This is the **baseline** that Approach 5 improves upon — same semantic search, but weaker metadata.

# %% [markdown]
# ### Step 1: Semantic Search + Entry Lookup

# %%
# Step 1a: Semantic search — scoped to the active-tier dataset.
# Bare-form query: the free-text question, then space-separated predicates with
# NO parentheses around the question and no explicit AND (predicates are
# implicitly ANDed). Wrapping the question in parentheses makes the query parser
# silently drop the parent: predicate, leaking out-of-scope tables — verified
# live (see examples/probe_scope_filter.py). Scope is a single tier dataset, so
# parent: takes exactly one value. The is_table_in_scope() filter below stays as
# harmless defense-in-depth; with the bare query it drops nothing.
ds = get_datasets()[0]
search_query = f"{QUESTION} system=BIGQUERY parent:datasets/{ds}"
print(f"Search query:\n  {search_query}\n")

request = dataplex_v1.SearchEntriesRequest(
    name=f"projects/{GOOGLE_CLOUD_PROJECT}/locations/global",
    query=search_query,
    page_size=20,
    semantic_search=True,
)

search_results = []
for result in catalog_client.search_entries(request=request):
    entry = result.dataplex_entry
    source = entry.entry_source
    fqn = entry.fully_qualified_name or ""
    parts = fqn.rsplit(".", 2)
    if len(parts) >= 2 and not is_table_in_scope(parts[-2], parts[-1]):
        continue
    search_results.append(
        {
            "entry_name": entry.name,
            "fqn": fqn,
            "display_name": source.display_name if source else "",
            "description": source.description if source else "",
        }
    )
    print(f"  Found: {source.display_name if source else entry.name}")

print(f"\nIn-scope results: {len(search_results)}")
# Out:
# Search query:
#   Which US counties have the most weather stations per capita? system=BIGQUERY parent:datasets/bigquery_context_tier3
#   Found: county_natality
#   Found: air_quality_annual_summary
#   Found: weather_stations
#   Found: us_counties
#   Found: austin_bikeshare_stations
#   Found: citibike_stations
#
# In-scope results: 6

# %%
# Step 1b: lookup_entry for each match — build metadata for the reranker
search_metadata_parts = []
search_nominated_ids = []

for sr in search_results:
    fqn = sr["fqn"]
    fqn_parts = fqn.rsplit(".", 2)
    table_header = (
        f"{GOOGLE_CLOUD_PROJECT}.{fqn_parts[-2]}.{fqn_parts[-1]}" if len(fqn_parts) >= 3 else fqn
    )

    lookup_req = dataplex_v1.LookupEntryRequest(
        name=f"projects/{GOOGLE_CLOUD_PROJECT}/locations/{BQ_LOCATION.lower()}",
        entry=sr["entry_name"],
        view=dataplex_v1.EntryView.FULL,
    )
    entry = catalog_client.lookup_entry(request=lookup_req)
    entry_dict = json_format.MessageToDict(entry._pb)

    summary = {
        "display_name": sr["display_name"],
        "description": sr["description"],
    }
    for key, aspect in entry_dict.get("aspects", {}).items():
        if "schema" in key:
            summary["schema"] = aspect.get("data", {})

    search_nominated_ids.append(table_header)
    search_metadata_parts.append(f"## {table_header}\n{json.dumps(summary, indent=2)}")
    print(f"  {table_header}: {len(search_metadata_parts[-1]):,} chars")

search_candidate_metadata = "\n\n".join(search_metadata_parts)
print(f"\nNominated: {len(search_nominated_ids)} tables")
print(f"Total metadata for reranker: {len(search_candidate_metadata):,} chars")
# Out:
#   statmike-mlops-349915.bigquery_context_tier3.county_natality: 2,340 chars
#   statmike-mlops-349915.bigquery_context_tier3.air_quality_annual_summary: 17,224 chars
#   statmike-mlops-349915.bigquery_context_tier3.weather_stations: 1,788 chars
#   statmike-mlops-349915.bigquery_context_tier3.us_counties: 2,967 chars
#   statmike-mlops-349915.bigquery_context_tier3.austin_bikeshare_stations: 2,540 chars
#   statmike-mlops-349915.bigquery_context_tier3.citibike_stations: 2,903 chars
#
# Nominated: 6 tables
# Total metadata for reranker: 29,772 chars

# %% [markdown]
# ### Step 2: Preview What the Reranker Receives
#
# Approach 2 passes `lookup_entry` JSON to the reranker. Compare this to Approach 1's plain text — it's structured JSON with nested schema, but still no `dataProfile`.

# %%
# Show reranker input for our example table
example_search_part = next(p for p in search_metadata_parts if EXAMPLE_TABLE in p)
print("Reranker input for weather_stations (Approach 2):")
print(example_search_part)
# Out:
# Reranker input for weather_stations (Approach 2):
# ## statmike-mlops-349915.bigquery_context_tier3.weather_stations
# {
#   "display_name": "weather_stations",
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": {
#     "fields": [
#       {
#         "mode": "NULLABLE",
#         "dataType": "STRING",
#         "name": "id",
#         "metadataType": "STRING"
#       },
#       {
#         "mode": "NULLABLE",
#         "dataType": "FLOAT",
#         "name": "latitude",
#         "metadataType": "NUMBER"
#       },
#       {
#         "mode": "NULLABLE",
#         "dataType": "FLOAT",
#         "name": "longitude",
#         "metadataType": "NUMBER"
#       },
#       {
#         "mode": "NULLABLE",
#         "dataType": "FLOAT",
#         "name": "elevation",
#         "metadataType": "NUMBER"
#       },
#       {
#         "mode": "NULLABLE",
# ...

# %% [markdown]
# ### Step 3: Rerank

# %%
result_kc_search = call_reranker(
    question=QUESTION,
    candidate_metadata=search_candidate_metadata,
    discovery_method="kc_search",
    top_k=TOP_K,
)

print(f"Ranked {len(result_kc_search.ranked_tables)} table(s):\n")
for t in result_kc_search.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
    print(f"     {t.reasoning}")
    if t.sql_hints:
        print(f"     SQL: {t.sql_hints}")
    print()
# Out:
# Ranked 3 table(s):
#
#   #1 [0.95] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#      Contains the weather station inventory with geographic coordinates which can be spatially joined to county boundaries.
#      SQL: Use ST_GeogPoint(longitude, latitude) to spatially join weather stations to us_counties.county_geom for county-level aggregation.
#
#   #2 [0.95] statmike-mlops-349915.bigquery_context_tier3.us_counties
#      Provides US county boundaries and geometries required to aggregate weather stations per county.
#      SQL: GROUP BY county_name and state_fips_code after performing ST_Within spatial join with weather stations.
#
#   #3 [0.65] statmike-mlops-349915.bigquery_context_tier3.county_natality
#      Contains annual births by county which can serve as a proxy for population statistics if explicit census population data is missing, though it primarily tracks natality statistics.
# ...

# %% [markdown]
# ---
# ## Approach 3: Knowledge Catalog Context (`agent_kc_context`)
#
# **Discovery:** None — all tables come from the shared cache (pre-populated at startup).
# **Metadata API:** Knowledge Catalog [`lookup_context`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_context) (preview, via cache) — full JSON with `dataProfile` plus any glossary/`frequent_joins`/`guidelines` enrichments.
# **Reranker called as:** Direct function call in `before_agent_callback` (LLM skipped).
# **Reranker receives:** `lookup_context` JSON for ALL cached tables — full `dataProfile` included.
# **Cache usage:** `get_all_detailed()` — every table, full metadata.
# **Per-query API calls:** 0 (everything from cache).
#
# Sends the **richest metadata** but evaluates **all tables** — relies entirely on the reranker to filter.

# %% [markdown]
# ### Step 1: Get All Detailed Context from Cache

# %%
context_all_detailed = get_all_detailed()
context_nominated_ids = get_table_ids()

print(f"Nominated: {len(context_nominated_ids)} tables (all cached)")
print(f"Total metadata for reranker: {len(context_all_detailed):,} chars")
print(
    f"\nThis is {len(context_all_detailed) / len(bq_candidate_metadata):.1f}x the size of Approach 1's metadata"
)
print(
    f"and {len(context_all_detailed) / len(search_candidate_metadata):.1f}x the size of Approach 2's metadata"
)
# Out:
# Nominated: 15 tables (all cached)
# Total metadata for reranker: 122,521 chars
#
# This is 3.1x the size of Approach 1's metadata
# and 4.1x the size of Approach 2's metadata

# %% [markdown]
# ### Step 2: Preview What the Reranker Receives
#
# The reranker gets the full `lookup_context` capsule for every table — including `dataProfile` with `sampleValues`, and any glossary/`frequent_joins`/`guidelines` enrichments the table carries. Here's our example table in this format:

# %%
# Show the detailed cached entry for our example table
example_detailed = get_detailed_for_tables([EXAMPLE_FULL_ID])
example_detailed_parsed = json.loads(example_detailed)
if example_detailed_parsed:
    print("Reranker input for weather_stations (Approach 3):")
    print(json.dumps(example_detailed_parsed[0], indent=2))
# Out:
# Reranker input for weather_stations (Approach 3):
# {
#   "catalogEntry": "projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "resource": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "simpleName": "statmike-mlops-349915.bigquery_context_tier3.weather_stations",
#   "type": "BigQuery View",
#   "createTime": "2026-07-28T12:30:53.539Z",
#   "updateTime": "2026-07-28T12:30:53.701Z",
#   "ancestors": [
#     {
#       "catalogEntry": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3",
#       "type": "dataplex-types.global.bigquery-dataset"
#     }
#   ],
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": [
#     {
#       "name": "elevation",
#       "type": "FLOAT",
# ...

# %% [markdown]
# ### Step 3: Rerank

# %%
result_kc_context = call_reranker(
    question=QUESTION,
    candidate_metadata=context_all_detailed,
    discovery_method="kc_context",
    top_k=TOP_K,
)

print(f"Ranked {len(result_kc_context.ranked_tables)} table(s):\n")
for t in result_kc_context.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
    print(f"     {t.reasoning}")
    if t.sql_hints:
        print(f"     SQL: {t.sql_hints}")
    print()
# Out:
# Ranked 5 table(s):
#
#   #1 [0.95] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#      Contains weather stations with their geographic coordinates, which can be mapped to US counties to count stations per county.
#      SQL: Use ST_CONTAINS or spatial joins with us_counties on station latitude/longitude to assign weather stations to counties, then GROUP BY county.
#
#   #2 [0.95] statmike-mlops-349915.bigquery_context_tier3.us_counties
#      Provides US county boundaries and FIPS codes necessary for spatial aggregation of weather stations and joining with population data.
#      SQL: Use county_geom for spatial joins with weather stations using ST_CONTAINS.
#
#   #3 [0.80] statmike-mlops-349915.bigquery_context_tier3.county_natality
#      Contains county-level population-related statistics (births and mother counts) or can serve as a proxy for county populations, or alternatively population data can be retrieved via county demographic mappings.
# ...

# %% [markdown]
# ---
# ## Approach 4: Context Pre-Filter (`agent_context_prefilter`)
#
# **Discovery:** LLM reviews **brief** summaries (from cache) of all tables and nominates candidates.
# **Metadata API:** Knowledge Catalog [`lookup_context`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_context) (preview, via cache) — briefs for LLM, detailed for reranker.
# **Reranker called as:** Direct function call in `after_agent_callback` (after LLM nominates).
# **Reranker receives:** `lookup_context` JSON for **nominated tables only** — full `dataProfile`.
# **Cache usage:** `get_all_briefs()` for LLM → `get_detailed_for_tables()` for reranker.
# **Per-query API calls:** 0 (everything from cache).
#
# Two-stage approach: compact briefs for LLM filtering, full metadata for reranking. The briefs keep the cheap enrichments (glossary terms, `frequent_joins`, `guidelines`) but drop the heavy `dataProfile` — so the LLM nominates on rich-but-compact signal, and only the nominated tables' full `dataProfile` reaches the reranker.

# %% [markdown]
# ### Step 1: LLM Reviews Brief Summaries
#
# The agent's system prompt embeds `get_all_briefs()` — every table's brief summary without `dataProfile`. The LLM reads these and decides which tables to nominate.

# %%
all_briefs = get_all_briefs()
print(f"Brief summaries: {len(get_table_ids())} tables, {len(all_briefs):,} chars total")
print(f"Average: ~{len(all_briefs) // len(get_table_ids()):,} chars/table\n")

# Show the brief for our example table
example_brief_entry = next(
    (b for b in json.loads(all_briefs) if b.get("table_id") == EXAMPLE_FULL_ID), None
)
if example_brief_entry:
    print(f"Brief for {EXAMPLE_TABLE} (what the LLM sees):")
    print(json.dumps(example_brief_entry, indent=2))
# Out:
# Brief summaries: 15 tables, 52,809 chars total
# Average: ~3,520 chars/table
#
# Brief for weather_stations (what the LLM sees):
# {
#   "catalogEntry": "projects/statmike-mlops-349915/locations/us/entryGroups/@bigquery/entries/bigquery.googleapis.com/projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "resource": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3/tables/weather_stations",
#   "simpleName": "statmike-mlops-349915.bigquery_context_tier3.weather_stations",
#   "createTime": "2026-07-28T12:30:53.539Z",
#   "updateTime": "2026-07-28T12:30:53.701Z",
#   "ancestors": [
#     {
#       "catalogEntry": "projects/statmike-mlops-349915/datasets/bigquery_context_tier3",
#       "type": "dataplex-types.global.bigquery-dataset"
#     }
#   ],
#   "description": "Global Historical Climatology Network weather station inventory. Station locations with latitude, longitude, elevation, and name.",
#   "schema": [
#     {
# ...

# %% [markdown]
# ### Step 2: LLM Nominates Candidates
#
# We simulate the LLM's nomination step — reviewing briefs and selecting relevant tables:

# %%
from google import genai
from google.genai import types as genai_types

from config import TOOL_MODEL_LOCATION

genai_client = genai.Client(
    vertexai=True,
    project=GOOGLE_CLOUD_PROJECT,
    location=TOOL_MODEL_LOCATION or "us-central1",
)

nomination_prompt = f"""\
Review the brief metadata summaries below and identify which tables are
relevant to answering the user's question. Return a JSON array of fully
qualified table IDs (project.dataset.table). Be generous — include
borderline tables since a downstream reranker will sort by relevance.

## Question
{QUESTION}

## Table Summaries
{all_briefs}"""

response = genai_client.models.generate_content(
    model=TOOL_MODEL,
    contents=nomination_prompt,
    config=genai_types.GenerateContentConfig(
        response_mime_type="application/json",
        temperature=0.0,
    ),
)


# The nominating LLM sometimes returns the catalog entry-path form
# (projects/.../datasets/.../tables/<t>) instead of the dotted
# project.dataset.table key. get_detailed_for_tables() normalizes this
# internally before the reranker (so reranking works either way), but we
# normalize here too so the downstream cross-approach comparison keys on the
# same dotted IDs every other approach uses.
def _to_dotted(tid):
    if "/" in tid:
        p = tid.split("/")
        try:
            return f"{p[p.index('projects') + 1]}.{p[p.index('datasets') + 1]}.{p[p.index('tables') + 1]}"
        except (ValueError, IndexError):
            return tid
    return tid


prefilter_nominated_ids = [_to_dotted(tid) for tid in json.loads(response.text)]
print(f"LLM nominated {len(prefilter_nominated_ids)} table(s):\n")
for tid in prefilter_nominated_ids:
    print(f"  {tid}")
# Out:
# LLM nominated 5 table(s):
#
#   statmike-mlops-349915.bigquery_context_tier3.weather_stations
#   statmike-mlops-349915.bigquery_context_tier3.us_counties
#   statmike-mlops-349915.bigquery_context_tier3.population_by_zip_2010
#   statmike-mlops-349915.bigquery_context_tier3.county_natality
#   statmike-mlops-349915.bigquery_context_tier3.zip_codes

# %% [markdown]
# ### Step 3: Fetch Detailed Context for Nominees + Rerank
#
# The `after_agent_callback` fetches full detailed context from the cache for **only** the nominated tables, then passes it to the reranker. This is the key efficiency — the reranker sees rich `dataProfile` metadata but only for the subset the LLM selected.

# %%
prefilter_detailed = get_detailed_for_tables(prefilter_nominated_ids)
print(
    f"Detailed context for {len(prefilter_nominated_ids)} nominees: {len(prefilter_detailed):,} chars"
)
print(f"  vs {len(context_all_detailed):,} chars for ALL tables in Approach 3")
print(
    f"  → {100 * len(prefilter_detailed) / len(context_all_detailed):.0f}% of Approach 3's input\n"
)

result_context_prefilter = call_reranker(
    question=QUESTION,
    candidate_metadata=prefilter_detailed,
    discovery_method="context_prefilter",
    top_k=TOP_K,
)

print(f"Ranked {len(result_context_prefilter.ranked_tables)} table(s):\n")
for t in result_context_prefilter.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
    print(f"     {t.reasoning}")
    if t.sql_hints:
        print(f"     SQL: {t.sql_hints}")
    print()
# Out:
# Detailed context for 5 nominees: 32,955 chars
#   vs 122,521 chars for ALL tables in Approach 3
#   → 27% of Approach 3's input
# Ranked 4 table(s):
#
#   #1 [0.99] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#      Contains weather station locations, coordinates, and unique station identifiers needed to count weather stations per geographic area.
#      SQL: Use ST_Covers or spatial joins with us_counties on station latitude/longitude, or spatial geometry to map stations to US counties. COUNT(id) to get the total number of stations.
#
#   #2 [0.98] statmike-mlops-349915.bigquery_context_tier3.us_counties
#      Provides US county boundaries, names, and FIPS codes necessary for grouping weather stations by county.
#      SQL: Perform a spatial join with weather_stations using ST_WITHIN(ST_GEOGPOINT(longitude, latitude), county_geom) or ST_INTERSECTS.
#
#   #3 [0.85] statmike-mlops-349915.bigquery_context_tier3.population_by_zip_2010
# ...

# %% [markdown]
# ---
# ## Approach 5: Semantic Context (`agent_semantic_context`)
#
# **Discovery:** Knowledge Catalog [`search_entries`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_search_entries) with `semantic_search=True` (same as Approach 2).
# **Metadata API:** Knowledge Catalog [`lookup_context`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_lookup_context) (preview, via cache) — full JSON with `dataProfile`.
# **Reranker called as:** Direct function call in `before_agent_callback` (LLM skipped).
# **Reranker receives:** `lookup_context` JSON for **matched tables only** — full `dataProfile`.
# **Cache usage:** `get_detailed_for_tables()` — only search-matched tables.
# **Per-query API calls:** 1 search + 0 lookups (cache replaces N `lookup_entry` calls).
#
# The **improved version of Approach 2**: same semantic search discovery, but richer metadata from the cache instead of per-table `lookup_entry` calls.

# %% [markdown]
# ### Step 1: Semantic Search + Cache Lookup
#
# Same search as Approach 2, but instead of calling `lookup_entry` per table, we look up detailed context from the shared cache — zero additional API calls.

# %%
# Same semantic search as Approach 2
request = dataplex_v1.SearchEntriesRequest(
    name=f"projects/{GOOGLE_CLOUD_PROJECT}/locations/global",
    query=search_query,  # reuse from Approach 2
    page_size=20,
    semantic_search=True,
)

semantic_matched_ids = []
for result in catalog_client.search_entries(request=request):
    entry = result.dataplex_entry
    fqn = entry.fully_qualified_name or ""
    parts = fqn.rsplit(".", 2)
    if len(parts) >= 2:
        if not is_table_in_scope(parts[-2], parts[-1]):
            continue
        full_id = f"{GOOGLE_CLOUD_PROJECT}.{parts[-2]}.{parts[-1]}"
        semantic_matched_ids.append(full_id)

# Cache lookup replaces N lookup_entry API calls
semantic_detailed = get_detailed_for_tables(semantic_matched_ids)

print(f"Search returned: {len(semantic_matched_ids)} in-scope tables")
print(f"Detailed context from cache: {len(semantic_detailed):,} chars")
print(f"\nApproach 2 would make {len(semantic_matched_ids)} lookup_entry API calls for this")
print("Approach 5 makes 0 — all from cache")
print(
    f"\nApproach 2 reranker input: {len(search_candidate_metadata):,} chars (lookup_entry, no dataProfile)"
)
print(
    f"Approach 5 reranker input: {len(semantic_detailed):,} chars (lookup_context, with dataProfile)"
)
# Out:
# Search returned: 6 in-scope tables
# Detailed context from cache: 56,372 chars
#
# Approach 2 would make 6 lookup_entry API calls for this
# Approach 5 makes 0 — all from cache
#
# Approach 2 reranker input: 29,772 chars (lookup_entry, no dataProfile)
# Approach 5 reranker input: 56,372 chars (lookup_context, with dataProfile)

# %% [markdown]
# ### Step 2: Rerank

# %%
result_semantic_context = call_reranker(
    question=QUESTION,
    candidate_metadata=semantic_detailed,
    discovery_method="semantic_context",
    top_k=TOP_K,
)

print(f"Ranked {len(result_semantic_context.ranked_tables)} table(s):\n")
for t in result_semantic_context.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
    print(f"     {t.reasoning}")
    if t.sql_hints:
        print(f"     SQL: {t.sql_hints}")
    print()
# Out:
# Ranked 3 table(s):
#
#   #1 [0.95] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#      Contains weather station locations and identifiers needed to count weather stations per geographic area/county.
#      SQL: Use latitude and longitude with ST_CONTAINS or spatial joins against county boundaries to map stations to counties, then COUNT station IDs.
#
#   #2 [0.90] statmike-mlops-349915.bigquery_context_tier3.us_counties
#      Provides US county boundaries and geometries necessary to aggregate weather stations and population totals per county.
#      SQL: Perform a spatial join using ST_CONTAINS(county_geom, ST_GEOGPOINT(longitude, latitude)) to assign stations to counties.
#
#   #3 [0.75] statmike-mlops-349915.bigquery_context_tier3.county_natality
#      Provides population-related metrics (birth counts and demographics by county) which can serve as a proxy or denominator for per capita calculations if alternative population tables are unavailable.
# ...

# %% [markdown]
# ---
# ## Approach 6: Search Direct (`agent_search_direct`)
#
# **Discovery:** Knowledge Catalog [`search_entries`](https://cloud.google.com/python/docs/reference/dataplex/latest/google.cloud.dataplex_v1.services.catalog_service.CatalogServiceClient#google_cloud_dataplex_v1_services_catalog_service_CatalogServiceClient_search_entries) with `semantic_search=True` — the **identical** bare-form query as Approaches 2 and 5.
# **Metadata API:** None — no `lookup_entry` / `lookup_context`; the search result is the whole answer.
# **Reranker called as:** **Not called.** Semantic search's own returned order *is* the final ranking.
# **Reranker receives:** Nothing — there is no rerank stage.
# **Cache usage:** None.
# **Per-query API calls:** 1 search + 0 lookups.
#
# This is the **control for the reranker**. Approaches 2 and 6 run the exact same retrieval; the only difference is that #2 pipes the candidates through the LLM reranker and #6 does not. Any gap between them — in recall, extra tables, or rank quality — is precisely what the reranker buys. The `RerankerResponse` below is built directly from search order: `rank` = search position, `confidence` a smooth descending proxy (search returns no score of its own), and the full returned set is kept as-is (search already pruned it — no `top_k` truncation).

# %%
# Same bare-form semantic search as Approaches 2 and 5 — reuse the request.
# The returned ORDER is this approach's ranking; no lookup, no rerank.
from schemas import RankedTable, RerankerResponse  # noqa: E402

request = dataplex_v1.SearchEntriesRequest(
    name=f"projects/{GOOGLE_CLOUD_PROJECT}/locations/global",
    query=search_query,  # identical bare query reused from Approach 2
    page_size=20,
    semantic_search=True,
)

search_direct_ids = []
for result in catalog_client.search_entries(request=request):
    fqn = result.dataplex_entry.fully_qualified_name or ""
    parts = fqn.rsplit(".", 2)
    if len(parts) >= 2:
        if not is_table_in_scope(parts[-2], parts[-1]):
            continue
        search_direct_ids.append(f"{GOOGLE_CLOUD_PROJECT}.{parts[-2]}.{parts[-1]}")

# Build a RerankerResponse straight from search order — no LLM involved.
# rank = search position; confidence is a smooth descending proxy in (0.5, 1.0].
n = len(search_direct_ids)
ranked = [
    RankedTable(
        table_id=tid,
        rank=i + 1,
        confidence=round(1.0 - (0.5 * i / n), 3) if n else 0.0,
        reasoning="Ranked by Knowledge Catalog semantic search relevance order (no LLM rerank).",
        discovery_method="search_direct",
    )
    for i, tid in enumerate(search_direct_ids)
]
result_search_direct = RerankerResponse(
    question=QUESTION,
    top_k=TOP_K,
    ranked_tables=ranked,
    notes="Search-direct: semantic search's own returned order is the final ranking; no reranker was applied.",
)

print(f"Search returned {n} in-scope table(s) — used as-is, no rerank:\n")
for t in result_search_direct.ranked_tables:
    print(f"  #{t.rank} [{t.confidence:.2f}] {t.table_id}")
print("\nReranker tokens used: 0 (the reranker is never called for this approach)")
# Out:
# Search returned 6 in-scope table(s) — used as-is, no rerank:
#
#   #1 [1.00] statmike-mlops-349915.bigquery_context_tier3.county_natality
#   #2 [0.92] statmike-mlops-349915.bigquery_context_tier3.air_quality_annual_summary
#   #3 [0.83] statmike-mlops-349915.bigquery_context_tier3.weather_stations
#   #4 [0.75] statmike-mlops-349915.bigquery_context_tier3.us_counties
#   #5 [0.67] statmike-mlops-349915.bigquery_context_tier3.austin_bikeshare_stations
#   #6 [0.58] statmike-mlops-349915.bigquery_context_tier3.citibike_stations
#
# Reranker tokens used: 0 (the reranker is never called for this approach)

# %% [markdown]
# ---
# ## Cross-Approach Comparison
#
# Now let's compare all six approaches side-by-side: what each nominated, what survived reranking, and how the metadata richness affected results. Watch the **KC Search (#2) vs Search Direct (#6)** columns — same retrieval, with and without the reranker — to read the rerank stage's effect directly.

# %%
results = {
    "bq_tools": result_bq_tools,
    "kc_search": result_kc_search,
    "kc_context": result_kc_context,
    "context_prefilter": result_context_prefilter,
    "semantic_context": result_semantic_context,
    "search_direct": result_search_direct,
}

nominations = {
    "bq_tools": set(bq_nominated_ids),
    "kc_search": set(search_nominated_ids),
    "kc_context": set(context_nominated_ids),
    "context_prefilter": set(prefilter_nominated_ids),
    "semantic_context": set(semantic_matched_ids),
    "search_direct": set(search_direct_ids),
}

# Search Direct sends nothing to a reranker — its "reranker input" is 0 chars.
metadata_sizes = {
    "bq_tools": len(bq_candidate_metadata),
    "kc_search": len(search_candidate_metadata),
    "kc_context": len(context_all_detailed),
    "context_prefilter": len(prefilter_detailed),
    "semantic_context": len(semantic_detailed),
    "search_direct": 0,
}

approach_labels = [
    "1: BQ Tools",
    "2: KC Search",
    "3: KC Context",
    "4: PreFilter",
    "5: Semantic",
    "6: Direct",
]
approach_keys = [
    "bq_tools",
    "kc_search",
    "kc_context",
    "context_prefilter",
    "semantic_context",
    "search_direct",
]

# Collect all tables from nominations and rankings
all_tables = set()
for ids in nominations.values():
    all_tables |= ids
for result in results.values():
    for t in result.ranked_tables:
        all_tables.add(t.table_id)


# Sort by consensus (most approaches ranking them first)
def sort_key(tid):
    ranked_count = sum(
        1 for key in approach_keys if any(t.table_id == tid for t in results[key].ranked_tables)
    )
    best_conf = max(
        (
            next((t.confidence for t in results[key].ranked_tables if t.table_id == tid), 0.0)
            for key in approach_keys
        ),
        default=0.0,
    )
    return (-ranked_count, -best_conf, tid)


sorted_tables = sorted(all_tables, key=sort_key)


# Short names for readability
def short_name(full_id):
    parts = full_id.split(".")
    return f"{parts[1]}.{parts[2]}" if len(parts) == 3 else full_id


# --- Cross-approach table ---
print(f"Question: {QUESTION}\n")
header = f"{'Table':<50} " + " ".join(f"{label:<14}" for label in approach_labels)
print(header)
print("-" * len(header))

for tid in sorted_tables:
    cols = []
    for key in approach_keys:
        ranked = next((t for t in results[key].ranked_tables if t.table_id == tid), None)
        nominated = tid in nominations[key]
        if ranked:
            cols.append(f"#{ranked.rank} ({ranked.confidence:.2f})")
        elif nominated:
            cols.append("nominated")
        else:
            cols.append("—")
    print(f"{short_name(tid):<50} " + " ".join(f"{c:<14}" for c in cols))

# --- Metadata richness ---
print(
    f"\n{'Reranker input size':<50} "
    + " ".join(f"{metadata_sizes[k]:>10,} ch  " for k in approach_keys)
)
print(
    f"{'Tables nominated':<50} " + " ".join(f"{len(nominations[k]):>10}    " for k in approach_keys)
)
print(
    f"{'Tables ranked':<50} "
    + " ".join(f"{len(results[k].ranked_tables):>10}    " for k in approach_keys)
)
print("\nApproach 6 (Search Direct) sends 0 chars to a reranker — its ranked set is")
print("semantic search's own output. Compare its column to Approach 2 (same search,")
print("plus the reranker) to see what the LLM rerank stage changes.")
# Out:
# Question: Which US counties have the most weather stations per capita?
#
# Table                                              1: BQ Tools    2: KC Search   3: KC Context  4: PreFilter   5: Semantic    6: Direct
# --------------------------------------------------------------------------------------------------------------------------------------------
# bigquery_context_tier3.weather_stations            #1 (0.95)      #1 (0.95)      #1 (0.95)      #1 (0.99)      #1 (0.95)      #3 (0.83)
# bigquery_context_tier3.us_counties                 #2 (0.95)      #2 (0.95)      #2 (0.95)      #2 (0.98)      #2 (0.90)      #4 (0.75)
# bigquery_context_tier3.county_natality             #3 (0.80)      #3 (0.65)      #3 (0.80)      nominated      #3 (0.75)      #1 (1.00)
# bigquery_context_tier3.population_by_zip_2010      #5 (0.60)      —              #5 (0.60)      #3 (0.85)      —              —
# ...

# %% [markdown]
# ---
# ## Run as ADK Agents
#
# The approaches above are packaged as [ADK](https://google.github.io/adk-docs/) agents. Run them interactively:
#
# ```bash
# uv run adk web --allow_origins="*" .
# ```
#
# Use the agent selector dropdown to choose `agent_orchestrator` (runs all six in parallel) or any individual approach. The orchestrator pipeline:
#
# 1. **ParallelAgent** — runs all six discovery agents concurrently
# 2. **compare_results** — `before_agent_callback` builds a cross-approach comparison table from session state, LLM synthesizes the analysis
#
# See the [readme](readme.md) for architecture details and example questions.
#
# ---
# ## Cleanup
#
# Delete all BQ datasets, views, and Knowledge Catalog artifacts (profile scans, glossary, entry links):
#
# ```bash
# uv run python scripts/cleanup.py
# ```
