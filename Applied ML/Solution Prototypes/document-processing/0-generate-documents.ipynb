# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FApplied+ML%2FSolution+Prototypes%2Fdocument-processing&file=0-generate-documents.ipynb)
# <!--- header table --->
# <table align="left">
# <tr>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FApplied%2520ML%2FSolution%2520Prototypes%2Fdocument-processing%2F0-generate-documents.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Share This On: </b>
#     <a href="https://www.linkedin.com/sharing/share-offsite/?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://reddit.com/submit?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb"><img src="https://redditinc.com/hubfs/Reddit%20Inc/Brand/Reddit_Logo.png" alt="Reddit Logo" width="20px"></a>
#     <a href="https://bsky.app/intent/compose?text=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://twitter.com/intent/tweet?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20ML/Solution%20Prototypes/document-processing/0-generate-documents.ipynb"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# <tr>
#   <td colspan="5" style="text-align: right">
#     <b>Connect With Author On: </b>
#     <a href="https://www.linkedin.com/in/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/8/81/LinkedIn_icon.svg" alt="Linkedin Logo" width="20px"></a>
#     <a href="https://www.github.com/statmike"><img src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub Logo" width="20px"></a>
#     <a href="https://www.youtube.com/@statmike-channel"><img src="https://upload.wikimedia.org/wikipedia/commons/f/fd/YouTube_full-color_icon_%282024%29.svg" alt="YouTube Logo" width="20px"></a>
#     <a href="https://bsky.app/profile/statmike.bsky.social"><img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Bluesky_Logo.svg" alt="BlueSky Logo" width="20px"></a>
#     <a href="https://x.com/statmike"><img src="https://upload.wikimedia.org/wikipedia/commons/5/5a/X_icon_2.svg" alt="X (Twitter) Logo" width="20px"></a>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Generate Documents For Project
#
# > This workflow is part of a series of workflows for the solution prototype: [Document Processing With Generative AI: Parse, Extract, Validate Authenticity, and More](./readme.md)
#
# We needs lots of documents for this project and generative AI makes a great tool for creating real world examples:
#
# Invoices
# - Mutiple vendors
# - Many Customers
# - Variable formatting
# - Samples that are anomolous - not exactly the same as the vendor true template
#
# The primarly tool used here is the [Google Gen AI SDK](https://github.com/googleapis/python-genai) which is covered in the Vertex AI documentation [here](https://cloud.google.com/vertex-ai/generative-ai/docs/sdks/overview).
# > Get more details with an [Overview of Generative AI on Vertex AI](https://cloud.google.com/vertex-ai/generative-ai/docs/overview)

# %% [markdown]
# ## Setup
#
# Note that this notebook expects to use a local virtual environment with the `./requirements.txt` installed.
#
# A potential workaround if using this notebook standalone is running:
#
# >```python
# >pip install -r requirements.txt
# >```
#
# And then restart the kernel.
#
# This notebook uses the package `pdfkit` which interacts with the command-line tool called `wkhtmltopdf` that needs to be installed in the environment:
# ```bash
# sudo apt-get update
# sudo apt-get install wkhtmltopdf
# ```

# %%
# package imports for this work
import subprocess, typing, datetime, json, asyncio, random, collections, os, shutil, glob, re, base64
from google import genai
import pydantic
import pdfkit
import fitz
from IPython.display import Image, display, IFrame, HTML

# %%
# what project are we working in?
PROJECT_ID = subprocess.run(['gcloud', 'config', 'get-value', 'project'], capture_output=True, text=True, check=True).stdout.strip()
PROJECT_ID
# Out:
# 'statmike-mlops-349915'

# %%
LOCATION = 'us-central1'

# %%
# setup google genai SDK
client = genai.Client(vertexai = True, project = PROJECT_ID, location = LOCATION)

# %% [markdown]
# ## Setup Schemas For Information
#
# These will be used to guide the generation and validate the response.

# %%
class Address(pydantic.BaseModel):
    street: str = pydantic.Field(description = 'The street address which might be across two lines.')
    city: str = pydantic.Field(description = 'The city part of an address with appropriate punctuation.')
    state: str = pydantic.Field(description = 'The state part of an address presented as a two letter abbreviation.')
    zip_code: str = pydantic.Field(description = 'The zip-5 or zip-9 code part of an address.')

    @pydantic.field_validator('state')
    def check_state_abbreviation(cls, value):
        if len(value) != 2:
            raise ValueError('State abbreviation must be two letters.')
        return value.upper()
    
    @pydantic.field_validator('zip_code')
    def check_zip_code(cls, value):
        if not (len(value) == 5 or len(value) == 10 and value[5] == '-'):
            raise ValueError('Zip code must be in the format XXXXX or XXXXX-XXXX.')
        return value

# %%
class Company(pydantic.BaseModel):
    company_name: str = pydantic.Field(description = 'The name of the company.')
    address: Address
    phone_number: typing.Optional[str] = pydantic.Field(description = 'The phone number of the company in the format XXX-XXX-XXXX.')
    email_address: pydantic.EmailStr = pydantic.Field(description = 'The email address of the company.')

    @pydantic.field_validator('phone_number')
    def check_phone_number(cls, value):
        if value is not None and len(value) != 12:
            raise ValueError('Phone number must be in the format XXX-XXX-XXXX.')
        return value

# %%
class LineItem(pydantic.BaseModel):
    item_sku: str = pydantic.Field(description="The Stock Keeping Unit (SKU) of the item.")
    item_description: str = pydantic.Field(description="A detailed description of the item.")
    unit_price: float = pydantic.Field(description="The price per unit of the item.")
    quantity: int = pydantic.Field(description="The number of units of the item.")
    list_price: float = pydantic.Field(description="The total price for the line item (unit_price * quantity).")
    currency: str = pydantic.Field(description="The currency code (e.g., USD, EUR).")
    discount_rate: typing.Optional[float] = pydantic.Field(default=0.0, description="The discount rate applied to the item, if any (e.g., 0.1 for 10%).")
    tax_rate: typing.Optional[float] = pydantic.Field(default=0.0, description="The tax rate applied to the item, if any (e.g., 0.08 for 8%).")
    item_id: typing.Optional[str] = pydantic.Field(default=None, description="A unique identifier for the line item.")

    # @pydantic.field_validator('quantity')
    # def check_quantity(cls, value):
    #     if value <= 0:
    #         raise ValueError('Quantity must be greater than zero.')
    #     return value

    # @pydantic.field_validator('unit_price', 'list_price')
    # def check_price(cls, value):
    #     if value < 0:
    #         raise ValueError('Price must be non-negative.')
    #     return value

    # @pydantic.field_validator('discount_rate', 'tax_rate')
    # def check_rate(cls, value):
    #     if not (0.0 <= value <= 1.0):
    #         raise ValueError('Rate must be between 0.0 and 1.0.')
    #     return value

    # @pydantic.model_validator(mode='after')
    # def check_list_price(self):
    #     calculated_list_price = self.unit_price * self.quantity
    #     if calculated_list_price != self.list_price:
    #         raise ValueError(f'List price ({self.list_price}) does not match calculated list price ({calculated_list_price}).')
    #     return self

# %%
class Invoice(pydantic.BaseModel):
    vendor: Company = pydantic.Field(description="The company that is the vendor for the invoice.")
    customer: Company = pydantic.Field(description="The company that is the customer for the invoice.")
    invoice_number: str = pydantic.Field(description="The unique identifier for the invoice.")
    invoice_date: datetime.date = pydantic.Field(description="The date the invoice was issued.")
    due_date: typing.Optional[datetime.date] = pydantic.Field(default=None, description="The date the invoice is due.")
    line_items: typing.List[LineItem] = pydantic.Field(description="The list of line items for the invoice.")
    subtotal: float = pydantic.Field(description="The sum of the list_price for all line items.")
    tax: float = pydantic.Field(description="The total tax for the invoice.")
    total: float = pydantic.Field(description="The total amount due for the invoice.")
    currency: str = pydantic.Field(description="The currency code for the invoice (e.g., USD, EUR).")

    # @pydantic.model_validator(mode='after')
    # def check_totals(self):
    #     calculated_subtotal = sum(item.list_price for item in self.line_items)
    #     if calculated_subtotal != self.subtotal:
    #         raise ValueError(f'Subtotal ({self.subtotal}) does not match calculated subtotal ({calculated_subtotal}).')

    #     calculated_tax = sum(item.list_price * item.tax_rate for item in self.line_items if item.tax_rate)
    #     if calculated_tax != self.tax:
    #         raise ValueError(f'Tax ({self.tax}) does not match calculated tax ({calculated_tax}).')

    #     calculated_total = self.subtotal + self.tax
    #     if calculated_total != self.total:
    #         raise ValueError(f'Total ({self.total}) does not match calculated total ({calculated_total}).')
        
    #     if any(item.currency != self.currency for item in self.line_items):
    #         raise ValueError(f'All line items must have the same currency as the invoice.')

    #     return self

# %%
class ListCompanies(pydantic.BaseModel):
    companies: typing.List[Company]

class Service(pydantic.BaseModel):
    name: str = pydantic.Field(description='The name of the product or service')
    description: str = pydantic.Field(description='The one sentence description of the product or service')

class ListServices(pydantic.BaseModel):
    services: typing.List[Service]

# %% [markdown]
# ## Generate Invoice Data

# %% [markdown]
# ### List of Vendors

# %%
response = client.models.generate_content(
    model = 'gemini-2.0-flash',
    contents = 'The industry of application development has many components.  Like consulting, creating plans, graphics design, application architecture, application development, testing, and more.  I need to create a list of potential vendors in this industry that do these services for a fee.  Please create 15 fake companies with fictitious information but USA based.',
    config = genai.types.GenerateContentConfig(
        temperature = 0,
        response_mime_type = 'application/json',
        response_schema = ListCompanies
    )
)

# %%
vendors = json.loads(response.text)['companies']

len(vendors), vendors[0]
# Out:
# (15,
#  {'company_name': 'Apex Digital Solutions',
#   'address': {'street': '123 Main Street',
#    'city': 'Anytown',
#    'state': 'CA',
#    'zip_code': '91234'},
#   'phone_number': '555-123-4567',
#   'email_address': 'info@apexdigitalsolutions.com'})

# %%
seen_vendor_names = set()
unique_vendors = []
duplicate_count = 0

for vendor in vendors:
    company_name = vendor.get('company_name')
    if company_name and company_name not in seen_vendor_names:
        seen_vendor_names.add(company_name)
        unique_vendors.append(vendor)
    elif company_name in seen_vendor_names:
        duplicate_count += 1

duplicate_count, len(unique_vendors)
# Out:
# (0, 15)

# %%
vendors = unique_vendors
vendors[0]
# Out:
# {'company_name': 'Apex Digital Solutions',
#  'address': {'street': '123 Main Street',
#   'city': 'Anytown',
#   'state': 'CA',
#   'zip_code': '91234'},
#  'phone_number': '555-123-4567',
#  'email_address': 'info@apexdigitalsolutions.com'}

# %% [markdown]
# ### List of Vendors Products
#
# A list of product each vendor offers.

# %%
async def generate_service_for_vendor(vendor, client, generation_config):
    """Generates services for a single vendor asynchronously."""
    company_name = vendor.get('company_name')
    print(f"[Task Start] Generating services for: {company_name}")

    prompt = f"""
    Generate a list of 10-15 typical software development and consulting services offered by a fictitious USA-based application development company named '{company_name}'.
    Focus on services like: Custom Software Development, Mobile App Development, Web Development, UI/UX Design, Cloud Consulting, QA & Testing, IT Strategy Consulting, Application Maintenance.
    Provide only the list of services matching the required schema.
    """

    try:
        # Use the asynchronous method generate_content_async
        response = await client.aio.models.generate_content(
            model='gemini-2.0-flash',
            contents=prompt,
            config=generation_config
        )

        # Parse the JSON response
        generated_services_list = json.loads(response.text)['services']

        # Create a copy to avoid modifying the original dict directly during async execution
        vendor_copy = vendor.copy()
        vendor_copy['services'] = generated_services_list
        print(f"  [Task Success] Generated {len(generated_services_list)} services for: {company_name}")
        return vendor_copy

    except Exception as e:
        # Handle potential errors during API call or parsing for this specific task
        print(f"  [Task Error] Failed generating services for {company_name}: {e}")
        # Return the vendor with an empty services list on error
        vendor_copy = vendor.copy()
        vendor_copy['services'] = []
        return vendor_copy

# %%
generation_config = genai.types.GenerateContentConfig(
    temperature=0.2,
    response_mime_type='application/json',
    response_schema=ListServices
)

tasks = [generate_service_for_vendor(vendor, client, generation_config) for vendor in vendors]
vendors_products = await asyncio.gather(*tasks)
# Out:
# [Task Start] Generating services for: Apex Digital Solutions
# [Task Start] Generating services for: BlueTech Innovations
# [Task Start] Generating services for: Cyberdyne Systems
# [Task Start] Generating services for: DataStream Analytics
# [Task Start] Generating services for: Eagle Eye Applications
# [Task Start] Generating services for: Future Forward Technologies
# [Task Start] Generating services for: Global Solutions Group
# [Task Start] Generating services for: Horizon Software Inc.
# [Task Start] Generating services for: Innovative Designs Co.
# [Task Start] Generating services for: Jupiter App Development
# [Task Start] Generating services for: Keystone Digital Agency
# [Task Start] Generating services for: LunarTech Solutions
# [Task Start] Generating services for: Nova Software Group
# [Task Start] Generating services for: Omni App Creators
# [Task Start] Generating services for: Pinnacle Digital Services
#   [Task Success] Generated 12 services for: Horizon Software Inc.
#   [Task Success] Generated 12 services for: Jupiter App Development
#   [Task Success] Generated 12 services for: Innovative Designs Co.
#   [Task Success] Generated 12 services for: Apex Digital Solutions
#   [Task Success] Generated 13 services for: Keystone Digital Agency
#   [Task Success] Generated 12 services for: Global Solutions Group
#   [Task Success] Generated 12 services for: Future Forward Technologies
#   [Task Success] Generated 12 services for: LunarTech Solutions
#   [Task Success] Generated 13 services for: Cyberdyne Systems
#   [Task Success] Generated 12 services for: BlueTech Innovations
#   [Task Success] Generated 12 services for: DataStream Analytics
#   [Task Success] Generated 13 services for: Pinnacle Digital Services
#   [Task Success] Generated 12 services for: Eagle Eye Applications
#   [Task Success] Generated 13 services for: Nova Software Group
#   [Task Success] Generated 13 services for: Omni App Creators

# %%
vendors_products[0]
# Out:
# {'company_name': 'Apex Digital Solutions',
#  'address': {'street': '123 Main Street',
#   'city': 'Anytown',
#   'state': 'CA',
#   'zip_code': '91234'},
#  'phone_number': '555-123-4567',
#  'email_address': 'info@apexdigitalsolutions.com',
#  'services': [{'name': 'Custom Software Development',
#    'description': 'Tailored software solutions designed and built to meet specific business needs.'},
#   {'name': 'Mobile App Development',
#    'description': 'Native and cross-platform mobile application development for iOS and Android.'},
#   {'name': 'Web Development',
#    'description': 'Responsive and scalable web application development using modern technologies.'},
#   {'name': 'UI/UX Design',
#    'description': 'User interface and user experience design services to create intuitive and engaging applications.'},
#   {'name': 'Cloud Consulting',
#    'description': 'Expert guidance on cloud adoption, migration, and optimization strategies.'},
#   {'name': 'QA & Testing',
#    'description': 'Comprehensive quality assurance and testing services to ensure software reliability.'},
#   {'name': 'IT Strategy Consulting',
#    'description': 'Strategic IT consulting services to align technology with business goals.'},
#   {'name': 'Application Maintenance',
#    'description': 'Ongoing maintenance and support services to keep applications running smoothly.'},
#   {'name': 'DevOps Consulting',
#    'description': 'DevOps strategy and implementation to streamline software development lifecycle.'},
#   {'name': 'Data Analytics & BI',
#    'description': 'Data analytics and business intelligence solutions to derive insights from data.'},
#   {'name': 'Enterprise Architecture',
#    'description': 'Design and implementation of robust and scalable enterprise architectures.'},
#   {'name': 'AI & Machine Learning',
#    'description': 'Development of AI-powered solutions and machine learning models.'}]}

# %% [markdown]
# ### List of Customers
#
# Create approximately 1200 customers of these vendors.

# %%
n_customers_batch = 10 # how many customer to generate in each request
n_batches = 240 # how many request to make
max_batches_async = 30 # how many requests can be manage simoultaneously

# %%
async def generate_customer_batch(batch_num, client, generation_config, semaphore):
    async with semaphore:
        prompt = f"""
        Generate a list of {n_customers_batch} distinct, fictitious potential customer companies based in the USA that would likely need application development or software consulting services.
        These companies should operate in diverse industries like Healthcare Tech, E-commerce, FinTech, Logistics, Education, Manufacturing Tech, SaaS, or Retail Tech.
        For each company, provide:
        - Company Name (fictitious)
        - Industry
        - Location (City, State)
        - Company Size (e.g., 1-50 employees, 51-200 employees, etc.)
        - Potential Need (1 sentence on why they might need app dev services)
        - Key Contact (Name, Title like CTO/VP Eng/IT Director, Email)

        Ensure all information is fictitious and diverse. Format the output as a list of customers according to the required schema.
        """

        try:
            response = await client.aio.models.generate_content(
                model='gemini-2.0-flash', 
                contents=prompt,
                config=generation_config
            )
            try:
                batch_result = json.loads(response.text)['companies']
                return batch_result
            except (json.JSONDecodeError, KeyError, TypeError) as json_e:
                print(json_e)
                return []
        except Exception as e:
            print(e)
            return []

# %%
generation_config = genai.types.GenerateContentConfig(
    temperature=2.0,
    response_mime_type='application/json',
    response_schema=ListCompanies
)

semaphore = asyncio.Semaphore(max_batches_async)
tasks = [generate_customer_batch(i+1, client, generation_config, semaphore) for i in range(n_batches)]
customers = await asyncio.gather(*tasks)
all_customers = [customer for batch_result in customers for customer in batch_result]

# %%
len(all_customers), all_customers[0]
# Out:
# (2398,
#  {'company_name': 'MediCloud Solutions',
#   'address': {'street': '123 Innovation Dr',
#    'city': 'San Francisco',
#    'state': 'CA',
#    'zip_code': '94107'},
#   'phone_number': '415-555-1212',
#   'email_address': 'info@medicloud.com'})

# %%
seen_company_names = set()
unique_customers = []
duplicate_count = 0

for customer in all_customers:
    company_name = customer.get('company_name')
    if company_name and company_name not in seen_company_names:
        seen_company_names.add(company_name)
        unique_customers.append(customer)
    elif company_name in seen_company_names:
        duplicate_count += 1

duplicate_count, len(unique_customers)
# Out:
# (1435, 963)

# %%
unique_customers[0]
# Out:
# {'company_name': 'MediCloud Solutions',
#  'address': {'street': '123 Innovation Dr',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'zip_code': '94107'},
#  'phone_number': '415-555-1212',
#  'email_address': 'info@medicloud.com'}

# %% [markdown]
# ### List of Invoices From Vendor To Customer
#
# For each vendor generate a list of invoices to a sample of the customers.  Some with a few invoices and some with many.

# %%
async def generate_invoice_async(vendor_info, customer_info, vendor_services, client, generation_config, semaphore):
    """Generates a single invoice asynchronously."""
    vendor_name = vendor_info.get('company_name', 'Unknown Vendor')
    customer_name = customer_info.get('company_name', 'Unknown Customer')

    async with semaphore:
        print(f"[Task Start] Generating invoice for Vendor: {vendor_name} | Customer: {customer_name}")

        # Prepare services list for the prompt
        services_prompt_list = "\n".join([f"- {s['name']}: {s['description']}" for s in vendor_services]) if vendor_services else "No services listed."

        prompt = f"""
        Generate a realistic, fictitious invoice based on the following details:

        **Vendor:**
        ```json
        {json.dumps(vendor_info, indent=2)}
        ```

        **Customer:**
        ```json
        {json.dumps(customer_info, indent=2)}
        ```

        **Available Vendor Services:**
        {services_prompt_list}

        **Instructions:**
        1. Create an invoice object strictly conforming to the provided Pydantic `Invoice` schema.
        2. Select 1 to 5 relevant services from the 'Available Vendor Services' list to include as line items.
        3. For each selected service/line item:
            - Generate a plausible item_sku.
            - Use the service name/description for item_description.
            - Determine a realistic quantity (e.g., hours for services like 10, 40, 80) and unit_price (e.g., hourly rate like 150.00, 200.00). Must be positive.
            - Calculate list_price (quantity * unit_price). Must be non-negative.
            - Set currency to USD.
            - Optionally apply a small discount_rate (0.0 to 0.1) or tax_rate (e.g., 0.0, 0.05, 0.08). Must be between 0.0 and 1.0.
        4. Generate a unique plausible invoice_number.
        5. Set the invoice_date to a random date within the year 2024.
        6. Set the due_date to be 15-30 days after the invoice_date, also within 2024.
        7. Calculate the subtotal (sum of all line item list_price).
        8. Calculate the total tax (sum of list_price * tax_rate for items with tax).
        9. Calculate the total (subtotal + tax).
        10. Ensure the top-level currency is USD and matches line item currency.
        11. VERY IMPORTANT: Respond *only* with the valid JSON object representing the Invoice, adhering precisely to the schema structure and types. Do not include any explanatory text before or after the JSON.
        """

        try:
            response = await client.aio.models.generate_content(
                model='gemini-2.0-flash',
                contents=prompt,
                config=generation_config
            )
            # Parse the JSON response directly into the Pydantic model for validation
            try:
                # Attempt to parse the JSON text first
                invoice_data = json.loads(response.text)
                # Then validate with Pydantic
                # validated_invoice = Invoice(**invoice_data) # Can enable for stricter validation
                print(f"  [Task Success] Generated invoice {invoice_data.get('invoice_number', 'N/A')} for {vendor_name} -> {customer_name}")
                # return validated_invoice # Return Pydantic object
                return invoice_data # Return raw dict for flexibility
            except (json.JSONDecodeError, pydantic.ValidationError, TypeError) as parse_error:
                 print(f"  [Task Error] Failed parsing/validating invoice for {vendor_name} -> {customer_name}: {parse_error}")
                 print(f"  Response Text (first 300 chars): {response.text[:300]}...")
                 return None

        except Exception as e:
            print(f"  [Task API Error] Failed generation for {vendor_name} -> {customer_name}: {e}")
            return None
        # Semaphore released automatically

# %%
services_map = {
    vendor['company_name']: vendor['services']
        for vendor in vendors_products if 'company_name' in vendor and 'services' in vendor
}

n_invoices = 300
max_async_requests = 20

generation_config = genai.types.GenerateContentConfig(
    temperature=0.6,
    response_mime_type='application/json',
    response_schema=Invoice
)
semaphore = asyncio.Semaphore(max_async_requests)

tasks = []
for i in range(n_invoices):
    vendor = random.choice(vendors)
    customer = random.choice(unique_customers)
    vendor_services = services_map.get(vendor.get('company_name'))
    if vendor_services is None:
        print(f"Warning: No services found for vendor '{vendor.get('company_name')}'. Skipping invoice generation for this pair.")
        continue # Skip if vendor has no services listed
    tasks.append(generate_invoice_async(vendor, customer, vendor_services, client, generation_config, semaphore))

print(f"Created {len(tasks)} invoice generation tasks. Running...")
generated_invoices = await asyncio.gather(*tasks)
# Out:
# Created 300 invoice generation tasks. Running...
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: FinanceForward Technologies
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: ShopStream Commerce
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: Learniverse Online
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Apex Fintech
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: CloudScale Software
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Clarity SaaS Platform
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Innovate Finance Group
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: GlobalHealth Analytics
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: LearnVerse
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Manufactured Future Tech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: LearnEd Technologies
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: FinTech Innovations LLC
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: GlobalMed Health
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: eCom Solutions Pro
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Urban Threads E-commerce
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: EcoCart Online
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: eCom Global Solutions
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Nova E-commerce Group
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: TrendStyle Retail
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: Nova Health Analytics
#   [Task Success] Generated invoice INV-2024-110 for Pinnacle Digital Services -> CloudScale Software
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: HealthFirst Mobile
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> Apex Fintech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: AgriFuture Technologies
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> ShopStream Commerce
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: QuickCart Technologies
#   [Task Success] Generated invoice INV-2024-110 for Future Forward Technologies -> Manufactured Future Tech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: Global Retail Technologies Inc
#   [Task Success] Generated invoice INV-2024-9876 for Horizon Software Inc. -> GlobalHealth Analytics
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: LogiStream Systems
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> Nova E-commerce Group
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Cloudify SaaS Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> GlobalMed Health
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Innovate Logistics Group
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> EcoCart Online
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: SmartPay Financials
#   [Task Success] Generated invoice INV-2024-0315 for Global Solutions Group -> Nova Health Analytics
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Trendify Ecom
#   [Task Success] Generated invoice INV-2024-0315 for Pinnacle Digital Services -> eCom Global Solutions
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Apex SaaS Platform
#   [Task Success] Generated invoice EEA-2024-110 for Eagle Eye Applications -> LearnVerse
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: LearnVerse Educational Systems
#   [Task Success] Generated invoice INV-2024-1023 for Apex Digital Solutions -> eCom Solutions Pro
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: EduLearn Systems
#   [Task Success] Generated invoice INV-2024-1122 for DataStream Analytics -> FinanceForward Technologies
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Global Tech Solutions
#   [Task Success] Generated invoice INV-2024-0722 for Cyberdyne Systems -> Innovate Finance Group
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Stellar FinTech Corp
#   [Task Success] Generated invoice INV-2024-1022 for Innovative Designs Co. -> FinTech Innovations LLC
#   [Task Success] Generated invoice INV-2024-1105 for Innovative Designs Co. -> TrendStyle Retail
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Manufactured Robotics
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Dynamic Retail Tech
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> Clarity SaaS Platform
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: eCommerce Nova
#   [Task Success] Generated invoice INV-2024-1122 for Global Solutions Group -> LearnEd Technologies
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: CloudHaven SaaS
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> Urban Threads E-commerce
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: CloudGenius SaaS
#   [Task Success] Generated invoice KD-2024-1103 for Keystone Digital Agency -> Learniverse Online
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: GreenTech Energy
#   [Task Success] Generated invoice INV-2024-7892 for LunarTech Solutions -> HealthFirst Mobile
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Manufacturing AI Group
#   [Task Success] Generated invoice INV-2024-1022 for Future Forward Technologies -> Apex SaaS Platform
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: FinTech Solutions Inc.
#   [Task Success] Generated invoice INV-2024-0715 for Global Solutions Group -> QuickCart Technologies
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: Swift Logistics
#   [Task Success] Generated invoice INV-2024-0315 for Global Solutions Group -> AgriFuture Technologies
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Renewable Energy Analytics
#   [Task Success] Generated invoice INV-2024-1022 for Global Solutions Group -> Global Retail Technologies Inc
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Nova E-commerce Group
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> Stellar FinTech Corp
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: EduTech Online Academy
#   [Task Success] Generated invoice FFT-2024-1105 for Future Forward Technologies -> LogiStream Systems
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: CloudBase SaaS
#   [Task Success] Generated invoice INV-2024-9876 for BlueTech Innovations -> CloudGenius SaaS
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: AgriSolutions AI
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> Trendify Ecom
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Secure Cyber Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Future Forward Technologies -> eCommerce Nova
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: eComVelocity
#   [Task Success] Generated invoice INV-2024-1102 for Jupiter App Development -> LearnVerse Educational Systems
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> SmartPay Financials
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: SwiftCart Logistics
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: HealthFlow Systems
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> Manufactured Robotics
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Sustainable Energy Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Omni App Creators -> EduLearn Systems
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: GlobalReach E-Commerce
#   [Task Success] Generated invoice INV-2024-1022 for Horizon Software Inc. -> Cloudify SaaS Solutions
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: StyleMine E-commerce
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> Innovate Logistics Group
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: CloudStream Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> Dynamic Retail Tech
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: GreenLeaf Agriculture Tech
#   [Task Success] Generated invoice INV-2024-1022 for Apex Digital Solutions -> Global Tech Solutions
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: RetailEdge Systems
#   [Task Success] Generated invoice INV-2024-1102 for Omni App Creators -> CloudHaven SaaS
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: RetailTech Dynamics
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> GreenTech Energy
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: CloudSprint Solutions
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> HealthFlow Systems
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: LearnOnline Platform
#   [Task Success] Generated invoice INV-2024-0315 for BlueTech Innovations -> Secure Cyber Solutions
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: DataNexus AI
#   [Task Success] Generated invoice INV-2024-1105 for Nova Software Group -> CloudBase SaaS
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Finwise Technologies
#   [Task Success] Generated invoice EEA-2024-110 for Eagle Eye Applications -> eComVelocity
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Logistics Direct
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> FinTech Solutions Inc.
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: GlobalChain Dynamics
#   [Task Success] Generated invoice INV-2024-0315 for Global Solutions Group -> EduTech Online Academy
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: Renewable Energy Systems Inc
#   [Task Success] Generated invoice OAC-2024-9876 for Omni App Creators -> Manufacturing AI Group
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: EcoTerra Energy Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> Sustainable Energy Solutions
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: SwiftRoute Logistics
#   [Task Success] Generated invoice FFT-2024-0315 for Future Forward Technologies -> GreenLeaf Agriculture Tech
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Nova Fintech
#   [Task Success] Generated invoice INV-2024-110 for Keystone Digital Agency -> Swift Logistics
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Agile Infrastructure Corp
#   [Task Success] Generated invoice INV-2024-0715 for Cyberdyne Systems -> Nova E-commerce Group
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: LearnVerse Digital
#   [Task Success] Generated invoice INV-2024-1105 for BlueTech Innovations -> RetailEdge Systems
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: LearnWell Educational Systems
#   [Task Success] Generated invoice INV-2024-0315 for DataStream Analytics -> Renewable Energy Analytics
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: SecureData Systems
#   [Task Success] Generated invoice INV-2024-0315 for Omni App Creators -> SwiftCart Logistics
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: RetailAI Technologies
#   [Task Success] Generated invoice INV-2024-777 for LunarTech Solutions -> AgriSolutions AI
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: GlobalSync Solutions
#   [Task Success] Generated invoice KD-2024-0315 for Keystone Digital Agency -> StyleMine E-commerce
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: CloudGenix SaaS
#   [Task Success] Generated invoice INV-2024-0315 for Nova Software Group -> GlobalReach E-Commerce
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: eComm Growth Solutions
#   [Task Success] Generated invoice INV-2024-110 for Innovative Designs Co. -> RetailTech Dynamics
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: HealthWise Solutions Inc.
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> CloudSprint Solutions
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Precision Agriculture
#   [Task Success] Generated invoice INV-2024-1122 for BlueTech Innovations -> CloudStream Solutions
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Global Link Translation Services
#   [Task Success] Generated invoice INV-2024-7712 for LunarTech Solutions -> Agile Infrastructure Corp
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Agile Learning Platforms
#   [Task Success] Generated invoice EEA-2024-1122 for Eagle Eye Applications -> Finwise Technologies
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: eCom Amplify
#   [Task Success] Generated invoice DSA-2024-1122 for DataStream Analytics -> LearnVerse Digital
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: SwiftLogistics Group
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> DataNexus AI
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: DataNexus AI
#   [Task Success] Generated invoice INV-2024-1105 for Future Forward Technologies -> CloudGenix SaaS
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: CyberGuard Security Systems
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> SecureData Systems
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Global Retail Technologies Inc
#   [Task Success] Generated invoice INV-2024-1105 for Pinnacle Digital Services -> Nova Fintech
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: RetailNext Innovations
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> LearnOnline Platform
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Cloudstream SaaS Solutions
#   [Task Success] Generated invoice INV-2024-7894 for Nova Software Group -> GlobalChain Dynamics
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: MediCare Innovations
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> EcoTerra Energy Solutions
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: FinServe Analytics
#   [Task Success] Generated invoice INV-2024-1122 for Eagle Eye Applications -> Logistics Direct
#   [Task Success] Generated invoice INV-2024-0315 for Future Forward Technologies -> LearnWell Educational Systems
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: SecureHealth Systems
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: ManuTech Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Global Solutions Group -> Renewable Energy Systems Inc
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: CloudSpring Solutions
#   [Task Success] Generated invoice INV-2024-1105 for Pinnacle Digital Services -> RetailAI Technologies
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: EcoChic Retail
#   [Task Success] Generated invoice INV-2024-1105 for Omni App Creators -> SwiftRoute Logistics
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: GlobalReach E-Commerce
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> eComm Growth Solutions
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: SustainaBuild Technologies
#   [Task Success] Generated invoice INV-2024-1022 for Global Solutions Group -> GlobalSync Solutions
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: CloudNine SaaS
#   [Task Success] Generated invoice INV-2024-1022 for Innovative Designs Co. -> HealthWise Solutions Inc.
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: ShopSphere Commerce
#   [Task Success] Generated invoice OAC-2024-9285 for Omni App Creators -> Precision Agriculture
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: ManufactureAI
#   [Task Success] Generated invoice INV-2024-0315 for Nova Software Group -> Global Link Translation Services
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: LearnWell Education Group
#   [Task Success] Generated invoice INV-2024-1022 for Future Forward Technologies -> Agile Learning Platforms
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: Trendify Ecom
#   [Task Success] Generated invoice FFT-2024-110 for Future Forward Technologies -> CyberGuard Security Systems
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: EduTech Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> FinServe Analytics
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Retail Dynamics Corp
#   [Task Success] Generated invoice INV-2024-7894 for Nova Software Group -> SwiftLogistics Group
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Global Fin Solutions
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> DataNexus AI
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudHaven SaaS
#   [Task Success] Generated invoice INV-2024-0715 for Horizon Software Inc. -> Cloudstream SaaS Solutions
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: GlobalTrans Logistics
#   [Task Success] Generated invoice INV-2024-1105 for BlueTech Innovations -> Global Retail Technologies Inc
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Global Tech Solutions
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> MediCare Innovations
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: GlobalChain Logistics
#   [Task Success] Generated invoice INV-2024-0722 for Horizon Software Inc. -> CloudSpring Solutions
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: BioTech Innovations Corp
#   [Task Success] Generated invoice INV-2024-1122 for Pinnacle Digital Services -> GlobalReach E-Commerce
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer:  الإنتاجية المتقدمة للصناعات
#   [Task Success] Generated invoice INV-2024-1022 for Keystone Digital Agency -> eCom Amplify
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: FinTech Prime
#   [Task Success] Generated invoice INV-2024-0315 for Cyberdyne Systems -> SecureHealth Systems
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: RetailFlow Systems
#   [Task Success] Generated invoice INV-2024-1105 for Eagle Eye Applications -> RetailNext Innovations
#   [Task Success] Generated invoice INV-2024-1022 for Apex Digital Solutions -> ManuTech Solutions
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Dynamic Retail Tech
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: CloudZenith SaaS
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> EcoChic Retail
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: AgriSmart Solutions
#   [Task Success] Generated invoice EEA-2024-1104 for Eagle Eye Applications -> SustainaBuild Technologies
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Swift Logistics Group
#   [Task Success] Generated invoice INV-2024-7891 for LunarTech Solutions -> LearnWell Education Group
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: Global Transit Logistics
#   [Task Success] Generated invoice INV-2024-0722 for BlueTech Innovations -> ManufactureAI
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: MedLink Pro
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> CloudNine SaaS
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: GlobalEats
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> ShopSphere Commerce
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: EcoBloom E-Commerce
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> EduTech Solutions
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Quantum Health Systems
#   [Task Success] Generated invoice INV-2024-1022 for Innovative Designs Co. -> Trendify Ecom
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: FinSecure Technologies
#   [Task Success] Generated invoice OAC-2024-1122 for Omni App Creators -> RetailFlow Systems
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: LearnVerse Inc.
#   [Task Success] Generated invoice INV-2024-7891 for LunarTech Solutions -> GlobalTrans Logistics
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Quantum Healthcare Data
#   [Task Success] Generated invoice DSA-2024-0315 for DataStream Analytics -> Retail Dynamics Corp
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: LearnBright Educational Systems
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> CloudHaven SaaS
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Digital Health Systems
#   [Task Success] Generated invoice INV-2024-1104 for Omni App Creators -> GlobalChain Logistics
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: LearnVerse Digital
#   [Task Success] Generated invoice DSA-2024-071 for DataStream Analytics -> Global Tech Solutions
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Cloud Solutions Pro
#   [Task Success] Generated invoice INV-2024-7891 for LunarTech Solutions -> Global Fin Solutions
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: NextGen Retail
#   [Task Success] Generated invoice INV-2024-0722 for BlueTech Innovations -> Swift Logistics Group
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Zenith Financial Innovations
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> FinTech Prime
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Swift Logistics LLC
#   [Task Success] Generated invoice DSA-2024-1122 for DataStream Analytics -> CloudZenith SaaS
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Modern Retail Tech
#   [Task Success] Generated invoice OAC-2024-110 for Omni App Creators -> Dynamic Retail Tech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: E-Comm Express
#   [Task Success] Generated invoice INV-2024-0315 for DataStream Analytics -> MedLink Pro
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: CloudApp Stream
#   [Task Success] Generated invoice INV-2024-1022 for Global Solutions Group -> Global Transit Logistics
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Zenith Financial AI
#   [Task Success] Generated invoice KD-2024-0315 for Keystone Digital Agency -> BioTech Innovations Corp
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Aether BioSolutions
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> AgriSmart Solutions
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Swift Logistics Systems
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> GlobalEats
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: BioNexus Healthcare
#   [Task Success] Generated invoice INV-2024-1105 for Future Forward Technologies -> EcoBloom E-Commerce
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Machina Dynamics
#   [Task Success] Generated invoice INV-2024-0715 for Horizon Software Inc. -> LearnVerse Inc.
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Global Retail Solutions LLC
#   [Task Success] Generated invoice INV-2024-1104 for Global Solutions Group -> FinSecure Technologies
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Global Green Innovations
#   [Task Success] Generated invoice INV-2024-9876 for BlueTech Innovations -> Quantum Healthcare Data
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: LearnForward Education
#   [Task Success] Generated invoice INV-2024-1022 for Keystone Digital Agency -> LearnVerse Digital
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: EcoTerra Farms
#   [Task Success] Generated invoice INV-2024-1023 for Apex Digital Solutions -> Quantum Health Systems
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: CloudSoft Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> Cloud Solutions Pro
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: EcoBloom E-commerce
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> Digital Health Systems
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: LogiTrack Systems
#   [Task Success] Generated invoice INV-2024-1022 for DataStream Analytics -> Zenith Financial Innovations
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: StyleTech E-commerce
#   [Task Success] Generated invoice INV-2024-1022 for Apex Digital Solutions -> LearnBright Educational Systems
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: HealthSync Technologies
#   [Task Success] Generated invoice INV-2024-1023 for Pinnacle Digital Services -> NextGen Retail
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: FarmToTable Supply
#   [Task Success] Generated invoice EEA-2024-0315 for Eagle Eye Applications -> Swift Logistics LLC
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Retail Revolution Technologies
#   [Task Success] Generated invoice INV-2024-7789 for LunarTech Solutions -> Zenith Financial AI
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Zenith SaaS Platform
#   [Task Success] Generated invoice INV-2024-1105 for Global Solutions Group -> E-Comm Express
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: EduSpark Academy
#   [Task Success] Generated invoice EEA-2024-110 for Eagle Eye Applications -> Modern Retail Tech
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: ShopFront AI
#   [Task Success] Generated invoice CS-2024-0722 for Cyberdyne Systems -> Swift Logistics Systems
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: SecurePay Technologies
#   [Task Success] Generated invoice INV-2024-1103 for Innovative Designs Co. -> BioNexus Healthcare
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: CloudWise Software
#   [Task Success] Generated invoice INV-2024-0322 for DataStream Analytics -> Machina Dynamics
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: LearnTech Dynamics
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> CloudApp Stream
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: MachinaTech Industries
#   [Task Success] Generated invoice INV-2024-7894 for Nova Software Group -> Aether BioSolutions
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Nova Health Analytics
#   [Task Success] Generated invoice INV-2024-1022 for Nova Software Group -> Global Retail Solutions LLC
#   [Task Success] Generated invoice INV-2024-0322 for Horizon Software Inc. -> LearnForward Education
#   [Task Success] Generated invoice INV-2024-9876 for Horizon Software Inc. -> EcoBloom E-commerce
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Streamline Transport
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: LearnScape Academy
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: LearnUp Education Systems
#   [Task Success] Generated invoice INV-2024-0722 for Global Solutions Group -> LogiTrack Systems
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: HealthCode AI
#   [Task Success] Generated invoice INV-2024-1022 for Future Forward Technologies -> Global Green Innovations
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> CloudSoft Solutions
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: EcoRenew Energy Systems
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: EcoFreight Systems
#   [Task Success] Generated invoice INV-2024-1122 for DataStream Analytics -> FarmToTable Supply
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Titan Manufacturing Systems
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> Retail Revolution Technologies
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: EcoFreight Logistics
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> StyleTech E-commerce
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: FinTech Dynamics LLC
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> HealthSync Technologies
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: ShopSmart Online
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> EcoTerra Farms
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: HealthFirst Systems
#   [Task Success] Generated invoice INV-2024-6789 for Nova Software Group -> ShopFront AI
#   [Task Success] Generated invoice INV-2024-0715 for Cyberdyne Systems -> EduSpark Academy
#   [Task Success] Generated invoice INV-2024-1022 for Future Forward Technologies -> Zenith SaaS Platform
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Healthify Solutions
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Energy Solutions Group
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: LearnTech Systems LLC
#   [Task Success] Generated invoice INV-2024-1022 for Horizon Software Inc. -> SecurePay Technologies
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: HealthLink Innovations
#   [Task Success] Generated invoice INV-2024-1102 for Innovative Designs Co. -> CloudWise Software
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: MachinaTech Solutions
#   [Task Success] Generated invoice KD-2024-1102 for Keystone Digital Agency -> MachinaTech Industries
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Precision Mfg Tech
#   [Task Success] Generated invoice INV-2024-1022 for Global Solutions Group -> LearnTech Dynamics
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Logistics Pro Systems
#   [Task Success] Generated invoice INV-2024-1105 for Pinnacle Digital Services -> Nova Health Analytics
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Bright Futures Education
#   [Task Success] Generated invoice INV-2024-1105 for Innovative Designs Co. -> LearnUp Education Systems
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Manufactured Future Tech
#   [Task Success] Generated invoice KD-2024-0315 for Keystone Digital Agency -> FinTech Dynamics LLC
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: FinTech Innovators Corp
#   [Task Success] Generated invoice INV-2024-1028 for Pinnacle Digital Services -> LearnScape Academy
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: SustainaBuild Technologies
#   [Task Success] Generated invoice INV-2024-3492 for Nova Software Group -> EcoFreight Logistics
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: ShopSwift Ecommerce
#   [Task Success] Generated invoice INV-2024-1022 for DataStream Analytics -> Streamline Transport
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: Swift Logistics Solutions
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> EcoFreight Systems
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: BioNexus Technologies
#   [Task Success] Generated invoice DSA-2024-0722 for DataStream Analytics -> ShopSmart Online
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: EcoCart Online
#   [Task Success] Generated invoice INV-2024-1105 for Innovative Designs Co. -> HealthCode AI
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: EcoBloom HealthTech
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> HealthFirst Systems
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudBase Analytics
#   [Task Success] Generated invoice INV-2024-1105 for Future Forward Technologies -> LearnTech Systems LLC
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: Logistics Leaps & Bounds
#   [Task Success] Generated invoice INV-2024-1105 for BlueTech Innovations -> HealthLink Innovations
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: CloudWave Solutions Inc
#   [Task Success] Generated invoice INV-2024-0315 for DataStream Analytics -> Healthify Solutions
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: E-Shoppe Innovations
#   [Task Success] Generated invoice INV-2024-0715 for Cyberdyne Systems -> MachinaTech Solutions
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: FabricTech Innovations
#   [Task Success] Generated invoice INV-2024-7777 for LunarTech Solutions -> EcoRenew Energy Systems
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Global Retail Solutions LLC
#   [Task Success] Generated invoice INV-2024-1022 for Nova Software Group -> Titan Manufacturing Systems
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: FinTech Innovations Corp
#   [Task Success] Generated invoice INV-2024-1105 for Eagle Eye Applications -> Energy Solutions Group
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: CoreForge Manufacturing
#   [Task Success] Generated invoice INV-2024-0315 for Cyberdyne Systems -> Precision Mfg Tech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: RetailAI Innovations
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> Logistics Pro Systems
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: OmniChannel Commerce Ltd
#   [Task Success] Generated invoice INV-2024-0722 for Nova Software Group -> Bright Futures Education
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: AgriValue AI
#   [Task Success] Generated invoice INV-2024-1105 for Future Forward Technologies -> Manufactured Future Tech
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: BioNexus Healthcare
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> EcoCart Online
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Nova Financial Technologies
#   [Task Success] Generated invoice INV-2024-1022 for BlueTech Innovations -> ShopSwift Ecommerce
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: SwiftRoute Logistics
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> BioNexus Technologies
#   [Task Success] Generated invoice KD-2024-0722 for Keystone Digital Agency -> Swift Logistics Solutions
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: CloudBoost Solutions
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: Innovate Finance Group
#   [Task Success] Generated invoice INV-2024-1105 for Pinnacle Digital Services -> SustainaBuild Technologies
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: NexGen Innovations Inc
#   [Task Success] Generated invoice INV-2024-1105 for Apex Digital Solutions -> EcoBloom HealthTech
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Precision Farming Solutions
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> FinTech Innovators Corp
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: EdTech Geniuses Corp.
#   [Task Success] Generated invoice EEA-2024-110 for Eagle Eye Applications -> CloudWave Solutions Inc
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: EcoCart Innovations
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> CloudBase Analytics
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Zenith SaaS Group
#   [Task Success] Generated invoice INV-2024-0722 for BlueTech Innovations -> Global Retail Solutions LLC
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: Global Retail Solutions LLC
#   [Task Success] Generated invoice INV-2024-0322 for Horizon Software Inc. -> CoreForge Manufacturing
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: CloudGenius Apps
#   [Task Success] Generated invoice EEA-2024-110 for Eagle Eye Applications -> E-Shoppe Innovations
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Global Defense System
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> FinTech Innovations Corp
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: ManufactureAI
#   [Task Success] Generated invoice LT-FTI-2024-072 for LunarTech Solutions -> FabricTech Innovations
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: QuickCart Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Global Solutions Group -> RetailAI Innovations
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudSource Solutions
#   [Task Success] Generated invoice KD-2024-0715 for Keystone Digital Agency -> Logistics Leaps & Bounds
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: SecureFin Technologies
#   [Task Success] Generated invoice JAD-2024-110 for Jupiter App Development -> OmniChannel Commerce Ltd
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: E-Comm Express
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> AgriValue AI
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: LogisticsPro
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> BioNexus Healthcare
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Manufacturing Tech Solutions
#   [Task Success] Generated invoice INV-2024-1122 for BlueTech Innovations -> Nova Financial Technologies
#   [Task Success] Generated invoice INV-2024-0315 for Horizon Software Inc. -> SwiftRoute Logistics
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Cybersecurity AI
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: AgriValue Tech
#   [Task Success] Generated invoice INV-2024-7890 for BlueTech Innovations -> EdTech Geniuses Corp.
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: Quantum Diagnostics Corp
#   [Task Success] Generated invoice INV-2024-1102 for Apex Digital Solutions -> NexGen Innovations Inc
#   [Task Success] Generated invoice INV-2024-1022 for Innovative Designs Co. -> Innovate Finance Group
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: CloudWave Solutions
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: eCom Solutions Inc.
#   [Task Success] Generated invoice INV-2024-1022 for Nova Software Group -> Precision Farming Solutions
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: ShopFront AI
#   [Task Success] Generated invoice EEA-2024-0015 for Eagle Eye Applications -> Zenith SaaS Group
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudNine SaaS
#   [Task Success] Generated invoice DSA-2024-1122 for DataStream Analytics -> QuickCart Solutions
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Manufactured Future Tech
#   [Task Success] Generated invoice INV-2024-0322 for Cyberdyne Systems -> EcoCart Innovations
#   [Task Success] Generated invoice INV-2024-0315 for Innovative Designs Co. -> Global Retail Solutions LLC
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudApp Solutions Inc.
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: LogisticsPro
#   [Task Success] Generated invoice INV-2024-110 for Future Forward Technologies -> Global Defense System
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: EcoStyle E-commerce
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> CloudGenius Apps
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: Global Ecom Solutions
#   [Task Success] Generated invoice INV-2024-0722 for BlueTech Innovations -> SecureFin Technologies
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Urban Retail Tech
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> CloudSource Solutions
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: EcoBloom Commerce
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> ManufactureAI
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Style Forward Retail
#   [Task Success] Generated invoice INV-2024-1105 for Omni App Creators -> CloudBoost Solutions
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: QuickCart Commerce
#   [Task Success] Generated invoice FFT-2024-110 for Future Forward Technologies -> E-Comm Express
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: Transcend Digital Media
#   [Task Success] Generated invoice INV-2024-1122 for BlueTech Innovations -> LogisticsPro
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: QuickCart E-Commerce
#   [Task Success] Generated invoice INV-2024-777 for LunarTech Solutions -> Manufacturing Tech Solutions
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: CloudScale Analytics
#   [Task Success] Generated invoice INV-2024-110 for Pinnacle Digital Services -> Cybersecurity AI
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: CloudCore Software
#   [Task Success] Generated invoice INV-2024-0315 for Cyberdyne Systems -> AgriValue Tech
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: EcoCart Online
#   [Task Success] Generated invoice INV-2024-789 for DataStream Analytics -> Global Ecom Solutions
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: CloudBase Analytics
#   [Task Success] Generated invoice DSA-2024-0315 for DataStream Analytics -> Manufactured Future Tech
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Logistics Edge Inc.
#   [Task Success] Generated invoice INV-2024-1023 for Apex Digital Solutions -> CloudApp Solutions Inc.
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Global eSolutions
#   [Task Success] Generated invoice INV-2024-1105 for Innovative Designs Co. -> Quantum Diagnostics Corp
#   [Task Success] Generated invoice EEA-2024-1122 for Eagle Eye Applications -> CloudWave Solutions
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: CloudGenius SaaS
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Zenith SaaS Platforms
#   [Task Success] Generated invoice INV-2024-1101 for Keystone Digital Agency -> eCom Solutions Inc.
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: EdTech Academy
#   [Task Success] Generated invoice INV-2024-7890 for Horizon Software Inc. -> QuickCart Commerce
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: MetalForge Innovations
#   [Task Success] Generated invoice INV-2024-0315 for Cyberdyne Systems -> EcoBloom Commerce
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: GlobalChain Dynamics
#   [Task Success] Generated invoice INV-2024-0315 for Future Forward Technologies -> Urban Retail Tech
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: SmartPay Financials
#   [Task Success] Generated invoice BT-2024-110 for BlueTech Innovations -> ShopFront AI
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Fintek Innovations
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> CloudNine SaaS
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Precision Agriculture
#   [Task Success] Generated invoice INV-2024-1105 for Omni App Creators -> Style Forward Retail
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: CloudCore SaaS
#   [Task Success] Generated invoice INV-2024-1022 for Horizon Software Inc. -> Transcend Digital Media
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: Logistics Direct
#   [Task Success] Generated invoice INV-2024-0715 for Horizon Software Inc. -> EcoStyle E-commerce
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: GlobalMed Health
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> LogisticsPro
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: FinServe Innovations
#   [Task Success] Generated invoice INV-2024-8795 for Nova Software Group -> QuickCart E-Commerce
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: FinServe Technologies
#   [Task Success] Generated invoice INV-2024-0789 for Apex Digital Solutions -> CloudScale Analytics
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Quantum Health Innovations
#   [Task Success] Generated invoice INV-2024-1022 for BlueTech Innovations -> CloudBase Analytics
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: EduTech Solutions Inc
#   [Task Success] Generated invoice INV-2024-1023 for Omni App Creators -> CloudCore Software
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: MediTech Innovations Inc.
#   [Task Success] Generated invoice INV-2024-1101 for Apex Digital Solutions -> Global eSolutions
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: HealthPulse Analytics
#   [Task Success] Generated invoice INV-2024-8765 for Nova Software Group -> Logistics Edge Inc.
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Stellar Cybernetics
#   [Task Success] Generated invoice EEA-2024-1122 for Eagle Eye Applications -> EcoCart Online
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: GlobalReach Marketplaces
#   [Task Success] Generated invoice FFT-2024-110 for Future Forward Technologies -> Zenith SaaS Platforms
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: TrendStyle Retail Tech
#   [Task Success] Generated invoice EEA-2024-1122 for Eagle Eye Applications -> MetalForge Innovations
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: LearnForward Educational Systems
#   [Task Success] Generated invoice INV-2024-9876 for Global Solutions Group -> SmartPay Financials
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: NextGen Retail
#   [Task Success] Generated invoice EEA-2024-1122 for Eagle Eye Applications -> CloudCore SaaS
# [Task Start] Generating invoice for Vendor: BlueTech Innovations | Customer: CloudWave Software
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> EdTech Academy
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: AgriCloud Innovations
#   [Task Success] Generated invoice INV-2024-110 for Jupiter App Development -> Precision Agriculture
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Velocity Logistics
#   [Task Success] Generated invoice INV-2024-1101 for Innovative Designs Co. -> CloudGenius SaaS
# [Task Start] Generating invoice for Vendor: Cyberdyne Systems | Customer: Retail Innovations LLC
#   [Task Success] Generated invoice INV-2024-0315 for Global Solutions Group -> GlobalChain Dynamics
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: Agile Infrastructure Corp
#   [Task Success] Generated invoice INV-2024-1122 for Pinnacle Digital Services -> Fintek Innovations
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Modern Retail Tech
#   [Task Success] Generated invoice INV-2024-8765 for BlueTech Innovations -> Logistics Direct
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: BioGenesis Therapeutics
#   [Task Success] Generated invoice INV-2024-1122 for Keystone Digital Agency -> GlobalMed Health
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: SaaS Summit
#   [Task Success] Generated invoice INV-2024-0315 for Innovative Designs Co. -> FinServe Innovations
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Energy Tech Corp
#   [Task Success] Generated invoice INV-2024-1022 for Jupiter App Development -> FinServe Technologies
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: EnergyGrid Dynamics
#   [Task Success] Generated invoice FFT-2024-1122 for Future Forward Technologies -> Quantum Health Innovations
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: Precision Automation Inc.
#   [Task Success] Generated invoice INV-2024-0315 for Global Solutions Group -> EduTech Solutions Inc
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: HealthAI Innovations
#   [Task Success] Generated invoice INV-2024-1105 for Eagle Eye Applications -> MediTech Innovations Inc.
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: NextGen Retail
#   [Task Success] Generated invoice INV-2024-1105 for Omni App Creators -> GlobalReach Marketplaces
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: CloudPeak SaaS
#   [Task Success] Generated invoice INV-2024-110 for Innovative Designs Co. -> LearnForward Educational Systems
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Precision Diagnostics
#   [Task Success] Generated invoice INV-2024-1122 for Jupiter App Development -> HealthPulse Analytics
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: SustainaBuild Materials
#   [Task Success] Generated invoice INV-2024-1102 for Pinnacle Digital Services -> Stellar Cybernetics
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: HealthChain Solutions
#   [Task Success] Generated invoice INV-2024-1122 for BlueTech Innovations -> CloudWave Software
# [Task Start] Generating invoice for Vendor: Horizon Software Inc. | Customer: EcoTerra Farms
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> TrendStyle Retail Tech
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Retail Edge Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Cyberdyne Systems -> Retail Innovations LLC
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: Global Retail Innovations
#   [Task Success] Generated invoice KD-2024-0315 for Keystone Digital Agency -> AgriCloud Innovations
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Prime Fintech Services
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> Velocity Logistics
# [Task Start] Generating invoice for Vendor: Eagle Eye Applications | Customer: ShopSphere
#   [Task Success] Generated invoice INV-2024-7894 for Nova Software Group -> NextGen Retail
# [Task Start] Generating invoice for Vendor: Pinnacle Digital Services | Customer: FinStrat Solutions LLC
#   [Task Success] Generated invoice INV-2024-9876 for Nova Software Group -> Energy Tech Corp
#   [Task Success] Generated invoice INV-2024-1122 for Pinnacle Digital Services -> Agile Infrastructure Corp
#   [Task Success] Generated invoice INV-2024-1105 for DataStream Analytics -> BioGenesis Therapeutics
#   [Task Success] Generated invoice OAC-2024-110 for Omni App Creators -> Modern Retail Tech
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: LearnNow Education
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: FinTech Frontier LLC
# [Task Start] Generating invoice for Vendor: DataStream Analytics | Customer: QuickCart Technologies
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: Agile Manufacturing
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> SaaS Summit
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: Apex Fintech
#   [Task Success] Generated invoice INV-2024-7782 for LunarTech Solutions -> EnergyGrid Dynamics
# [Task Start] Generating invoice for Vendor: Global Solutions Group | Customer: HealthPlus Digital
#   [Task Success] Generated invoice EEA-2024-1105 for Eagle Eye Applications -> Precision Automation Inc.
# [Task Start] Generating invoice for Vendor: Omni App Creators | Customer: Green Energy Analytics
#   [Task Success] Generated invoice DSA-2024-0315 for DataStream Analytics -> CloudPeak SaaS
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Manufacturing Tech Group
#   [Task Success] Generated invoice INV-2024-0722 for Horizon Software Inc. -> SustainaBuild Materials
# [Task Start] Generating invoice for Vendor: Future Forward Technologies | Customer: Logistics Ace
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> NextGen Retail
# [Task Start] Generating invoice for Vendor: Apex Digital Solutions | Customer: TrendStyle Retail
#   [Task Success] Generated invoice INV-2024-0315 for Keystone Digital Agency -> HealthAI Innovations
# [Task Start] Generating invoice for Vendor: Innovative Designs Co. | Customer: LearnVerse EdTech
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> HealthChain Solutions
# [Task Start] Generating invoice for Vendor: LunarTech Solutions | Customer: Apex Digital Health
#   [Task Success] Generated invoice INV-2024-7789 for LunarTech Solutions -> Precision Diagnostics
# [Task Start] Generating invoice for Vendor: Nova Software Group | Customer: Global Retail Innovations
#   [Task Success] Generated invoice INV-2024-1122 for Eagle Eye Applications -> ShopSphere
# [Task Start] Generating invoice for Vendor: Keystone Digital Agency | Customer: CloudServe Solutions
#   [Task Success] Generated invoice INV-2024-1022 for Keystone Digital Agency -> Global Retail Innovations
# [Task Start] Generating invoice for Vendor: Jupiter App Development | Customer: BioGenesis Therapeutics
#   [Task Error] Failed parsing/validating invoice for BlueTech Innovations ->  الإنتاجية المتقدمة للصناعات: Unterminated string starting at: line 14 column 21 (char 326)
#   Response Text (first 300 chars): {
#   "vendor": {
#     "company_name": "BlueTech Innovations",
#     "address": {
#       "street": "456 Oak Avenue",
#       "city": "Springfield",
#       "state": "IL",
#       "zip_code": "62704"
#     },
#     "phone_number": "555-987-6543",
#     "email_address": "contact@bluetechinnovations.com"
#   },
#   "custome...
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> Retail Edge Solutions
#   [Task Success] Generated invoice INV-2024-0315 for Pinnacle Digital Services -> FinStrat Solutions LLC
#   [Task Success] Generated invoice INV-2024-1022 for Horizon Software Inc. -> EcoTerra Farms
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> Prime Fintech Services
#   [Task Success] Generated invoice INV-2024-1122 for Innovative Designs Co. -> FinTech Frontier LLC
#   [Task Success] Generated invoice INV-2024-1122 for Future Forward Technologies -> LearnNow Education
#   [Task Success] Generated invoice INV-2024-0315 for Apex Digital Solutions -> Apex Fintech
#   [Task Success] Generated invoice INV-2024-1105 for Jupiter App Development -> Agile Manufacturing
#   [Task Success] Generated invoice INV-2024-1023 for DataStream Analytics -> QuickCart Technologies
#   [Task Success] Generated invoice INV-2024-9876 for Global Solutions Group -> HealthPlus Digital
#   [Task Success] Generated invoice INV-2024-1022 for Omni App Creators -> Green Energy Analytics
#   [Task Success] Generated invoice FFT-LA-2024-007 for Future Forward Technologies -> Logistics Ace
#   [Task Success] Generated invoice INV-2024-1022 for Nova Software Group -> Manufacturing Tech Group
#   [Task Success] Generated invoice INV-2024-1103 for Innovative Designs Co. -> LearnVerse EdTech
#   [Task Success] Generated invoice INV-2024-0322 for Apex Digital Solutions -> TrendStyle Retail
#   [Task Success] Generated invoice INV-2024-7890 for LunarTech Solutions -> Apex Digital Health
#   [Task Success] Generated invoice INV-2024-1105 for Jupiter App Development -> BioGenesis Therapeutics
#   [Task Success] Generated invoice INV-2024-0789 for Nova Software Group -> Global Retail Innovations
#   [Task Success] Generated invoice KD-2024-110 for Keystone Digital Agency -> CloudServe Solutions

# %%
invoices = [inv for inv in generated_invoices if inv is not None]

len(invoices), invoices[0]
# Out:
# (299,
#  {'vendor': {'company_name': 'DataStream Analytics',
#    'address': {'street': '101 Elm Street',
#     'city': 'Metropolis',
#     'state': 'NY',
#     'zip_code': '10001'},
#    'phone_number': '555-321-7890',
#    'email_address': 'support@datastreamanalytics.com'},
#   'customer': {'company_name': 'FinanceForward Technologies',
#    'address': {'street': '789 Market Street',
#     'city': 'New York',
#     'state': 'NY',
#     'zip_code': '10001'},
#    'phone_number': '212-555-5656',
#    'email_address': 'hello@financeforwardtech.com'},
#   'invoice_number': 'INV-2024-1122',
#   'invoice_date': '2024-03-15',
#   'due_date': '2024-04-09',
#   'line_items': [{'item_sku': 'CSD-001',
#     'item_description': 'Custom Software Development',
#     'unit_price': 150.0,
#     'quantity': 80,
#     'list_price': 12000.0,
#     'currency': 'USD',
#     'discount_rate': None,
#     'tax_rate': 0.08,
#     'item_id': 'LI-001'},
#    {'item_sku': 'UIUX-002',
#     'item_description': 'UI/UX Design',
#     'unit_price': 120.0,
#     'quantity': 40,
#     'list_price': 4800.0,
#     'currency': 'USD',
#     'discount_rate': None,
#     'tax_rate': 0.08,
#     'item_id': 'LI-002'},
#    {'item_sku': 'DACS-003',
#     'item_description': 'Data Analytics Consulting',
#     'unit_price': 200.0,
#     'quantity': 20,
#     'list_price': 4000.0,
#     'currency': 'USD',
#     'discount_rate': None,
#     'tax_rate': 0.08,
#     'item_id': 'LI-003'}],
#   'subtotal': 20800.0,
#   'tax': 1664.0,
#   'total': 22464.0,
#   'currency': 'USD'})

# %%
invoices_by_vendor = collections.defaultdict(list)
for invoice in invoices:
    invoices_by_vendor[invoice.get('vendor').get('company_name')].append(invoice)

# %%
for v in invoices_by_vendor:
    print(f"Found {len(invoices_by_vendor.get(v))} invoices for vendor: {v}")
# Out:
# Found 19 invoices for vendor: DataStream Analytics
# Found 24 invoices for vendor: Horizon Software Inc.
# Found 16 invoices for vendor: Keystone Digital Agency
# Found 19 invoices for vendor: Jupiter App Development
# Found 14 invoices for vendor: Pinnacle Digital Services
# Found 16 invoices for vendor: Cyberdyne Systems
# Found 19 invoices for vendor: Eagle Eye Applications
# Found 29 invoices for vendor: Future Forward Technologies
# Found 18 invoices for vendor: Global Solutions Group
# Found 23 invoices for vendor: Innovative Designs Co.
# Found 22 invoices for vendor: Apex Digital Solutions
# Found 21 invoices for vendor: LunarTech Solutions
# Found 22 invoices for vendor: Omni App Creators
# Found 19 invoices for vendor: BlueTech Innovations
# Found 18 invoices for vendor: Nova Software Group

# %% [markdown]
# ### Save And Reload Invoice Data
#
# Save the invoice data locally in folder for each vendor.  Then reload the data.

# %%
type(invoices_by_vendor)
# Out:
# collections.defaultdict

# %%
base_resource_dir = "./resources/documents/"

# %%
# the folder will be used to store the generated content, if it exists from a prior run then first delete to prevent overlapping content
if os.path.exists(base_resource_dir):
    shutil.rmtree(base_resource_dir)

for v, (vendor_name, list_of_invoices) in enumerate(invoices_by_vendor.items()):
    vendor_folder_name = f"vendor_{v}" #vendor_name.lower().replace(" ", "_")
    vendor_dir_path = os.path.join(base_resource_dir, vendor_folder_name, 'data')
    os.makedirs(vendor_dir_path, exist_ok=True)
    jsonl_file_path = os.path.join(vendor_dir_path, "invoices.jsonl")
    with open(jsonl_file_path, 'w', encoding='utf-8') as f_out:
        for invoice_dict in list_of_invoices:
            # Convert the invoice dictionary to a JSON string
            # default=str is important to handle non-serializable types like datetime.date
            json_line = json.dumps(invoice_dict, default=str)
            # Write the JSON string as a single line, followed by a newline
            f_out.write(json_line + '\n')

# %%
reloaded_invoices = collections.defaultdict(list)
search_pattern = os.path.join(base_resource_dir, "*", "data", "invoices.jsonl")
invoice_files = glob.glob(search_pattern)

for file_path in invoice_files:
    current_vendor_name = None
    invoices_from_this_file = []

    with open(file_path, 'r', encoding='utf-8') as f_in:
        for line_num, line in enumerate(f_in):
            line = line.strip()
            invoice_dict = json.loads(line)
            invoices_from_this_file.append(invoice_dict)
    reloaded_invoices[invoices_from_this_file[0].get('vendor').get('company_name')].extend(invoices_from_this_file)

# %%
type(reloaded_invoices)
# Out:
# collections.defaultdict

# %%
# verify same vendor list
reloaded_invoices.keys() == invoices_by_vendor.keys()
# Out:
# True

# %%
# verify the same number of invoices for each vendor
[len(invoices) for key, invoices in reloaded_invoices.items()] == [len(invoices) for key, invoices in invoices_by_vendor.items()]
# Out:
# True

# %%
# verify the same first invoice for each vendor
[json.dumps(invoices[0], default=str) for key, invoices in reloaded_invoices.items()] == [json.dumps(invoices[0], default=str) for key, invoices in invoices_by_vendor.items()]
# Out:
# True

# %% [markdown]
# ### Generate A Invoice Template for Each Vendor
#
# Use each vendors first invoice to create a template for the layout.

# %%
async def generate_invoice_template(vendor_name, invoice, client):
    
    print(f"[Task Start] Generating invoice template for: {vendor_name}")

    prompt = f"""
    Generate a realistic, fictitious invoice based on the following details:

    **Invoice:**
    ```json
    {json.dumps(invoice, indent=2)}
    ```

    **Instructions:**
    1. Create html for an invoice with typical but unique layout
    2. Select from the information provided
    3. Don't add information
    4. It is ok to leave information off that is not part of the invoice layout
    5. Make the layout specific to the vendor including the creation of a simple plain logo and/or layout format
    6. Feel free to use color for logos, headers, footers but it must remain formal for a business
    """

    for attempt in range(5):
        print(f"Try {attempt} for vendor: {vendor_name}")
        # Use the asynchronous method generate_content_async
        response = await client.aio.models.generate_content(
            model='gemini-2.0-flash',
            contents=prompt,
            config=genai.types.GenerateContentConfig(
                temperature=1.2,
            )
        )

        # find html in the response
        pattern = r'```(?:html|HTML)\n(.*?)```'  # Matches HTML code blocks
        matches = re.search(pattern, response.text, re.DOTALL)
        if matches:
            invoice_html = matches.group(1).strip()
            break

    # convert to pdf and save locally
    vendor_folder_name = vendor_name.lower().replace(" ", "_")
    vendor_dir_path = os.path.join(base_resource_dir, vendor_folder_name, 'template')
    os.makedirs(vendor_dir_path, exist_ok=True)
    template_file_path = os.path.join(vendor_dir_path, "template.pdf")
    pdfkit.from_string(invoice_html, template_file_path)

    # save a png version of the first page also: template.png
    doc = fitz.open(template_file_path)
    page = doc.load_page(0)
    pix = page.get_pixmap(dpi=150)
    pix.save(template_file_path.replace('.pdf', '.png'))

    # save the html version also: template.html
    with open(template_file_path.replace('.pdf', '.html'), 'w', encoding='utf-8') as f:
        f.write(invoice_html)

# %%
tasks = [generate_invoice_template(f'vendor_{v}', invoices[0], client) for v, (vendor, invoices) in enumerate(invoices_by_vendor.items())]
vendor_invoice_templates = await asyncio.gather(*tasks)
# Out:
# [Task Start] Generating invoice template for: vendor_0
# Try 0 for vendor: vendor_0
# [Task Start] Generating invoice template for: vendor_1
# Try 0 for vendor: vendor_1
# [Task Start] Generating invoice template for: vendor_2
# Try 0 for vendor: vendor_2
# [Task Start] Generating invoice template for: vendor_3
# Try 0 for vendor: vendor_3
# [Task Start] Generating invoice template for: vendor_4
# Try 0 for vendor: vendor_4
# [Task Start] Generating invoice template for: vendor_5
# Try 0 for vendor: vendor_5
# [Task Start] Generating invoice template for: vendor_6
# Try 0 for vendor: vendor_6
# [Task Start] Generating invoice template for: vendor_7
# Try 0 for vendor: vendor_7
# [Task Start] Generating invoice template for: vendor_8
# Try 0 for vendor: vendor_8
# [Task Start] Generating invoice template for: vendor_9
# Try 0 for vendor: vendor_9
# [Task Start] Generating invoice template for: vendor_10
# Try 0 for vendor: vendor_10
# [Task Start] Generating invoice template for: vendor_11
# Try 0 for vendor: vendor_11
# [Task Start] Generating invoice template for: vendor_12
# Try 0 for vendor: vendor_12
# [Task Start] Generating invoice template for: vendor_13
# Try 0 for vendor: vendor_13
# [Task Start] Generating invoice template for: vendor_14
# Try 0 for vendor: vendor_14

# %%
# Define the desired number of columns for the image grid
num_columns = 4  # Adjust as needed

print(f"Searching for PNG files in '{base_resource_dir}/*/template/*.png'...")

# --- Step 1: Find all PNG files ---
# Use glob to find PNG files within any vendor's 'data' subfolder
search_pattern = os.path.join(base_resource_dir, "*", "template", "*.png")
png_files = sorted(glob.glob(search_pattern)) # Sort the files for consistent order

if not png_files:
    print("No PNG files found in the expected subdirectories.")
else:
    print(f"Found {len(png_files)} PNG files. Generating grid display...")

    # --- Step 2: Generate HTML for the grid ---
    # We'll use an HTML table for the grid layout
    html_rows = []
    for i, img_path in enumerate(png_files):
        # Determine the start of a new row
        if i % num_columns == 0:
            html_rows.append("<tr>") # Start a new table row

        # Get the relevant subdirectory path for the caption
        try:
            # Get the directory containing the PNG file (e.g., ./resources/documents/vendor_x/data)
            img_dir = os.path.dirname(img_path)
            # Get the path relative to the base directory (e.g., vendor_x/data)
            relative_dir_path = os.path.relpath(img_dir, base_resource_dir)
            caption = f"{relative_dir_path}" # Use 'vendor_x/data' as caption
        except ValueError:
             # Fallback if relative path calculation fails (e.g., different drives on Windows)
            caption = os.path.dirname(img_path) # Use directory path as caption
        except Exception as e:
            caption = f"Error getting path: {e}"

        # Add a table cell (<td>) for this image and its caption
        # Using img src=filepath works well in most Jupyter environments
        # Setting width keeps the grid organized
        cell_html = f"""
        <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
            <img src="{img_path}" width="350" alt="{os.path.basename(img_path)}"><br>
            <small style="font-size: 10px;">{caption}</small>
        </td>
        """
        html_rows.append(cell_html)

        # Determine the end of a row
        if (i + 1) % num_columns == 0 or (i + 1) == len(png_files):
            # If it's the last column OR the very last image, close the row
            # Add empty cells if the last row isn't full
            if (i + 1) == len(png_files) and (i + 1) % num_columns != 0:
                 num_empty = num_columns - ((i + 1) % num_columns)
                 html_rows.append("<td></td>" * num_empty)
            html_rows.append("</tr>") # End the table row

    # Combine all parts into the final HTML table string
    final_html = f"<table>{''.join(html_rows)}</table>"

    # --- Step 3: Display the generated HTML in the notebook ---
    display(HTML(final_html))
# Out:
# Searching for PNG files in './resources/documents//*/template/*.png'...
# Found 15 PNG files. Generating grid display...
# <table><tr>
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_0/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_0/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_1/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_1/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_10/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_10/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_11/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_11/template</small>
#         </td>
#         </tr><tr>
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_12/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_12/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_13/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_13/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_14/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_14/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_2/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_2/template</small>
#         </td>
#         </tr><tr>
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_3/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_3/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_4/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_4/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_5/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_5/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_6/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_6/template</small>
#         </td>
#         </tr><tr>
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_7/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_7/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_8/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_8/template</small>
#         </td>
#
#         <td style="text-align: center; vertical-align: top; border: 1px solid #eee; padding: 5px;">
#             <img src="./resources/documents/vendor_9/template/template.png" width="350" alt="template.png"><br>
#             <small style="font-size: 10px;">vendor_9/template</small>
#         </td>
#         <td></td></tr></table>

# %% [markdown]
# ### Generate All invoices for Each Vendor

# %%
vendor_templates = {}
for v, vendor in enumerate(invoices_by_vendor.keys()):
    #template_path = os.path.join(base_resource_dir, vendor.lower().replace(' ', '_'), 'template', 'template.png')
    template_path = os.path.join(base_resource_dir, f'vendor_{v}', 'template', 'template.png')
    with open(template_path, 'rb') as f:
        template_read = f.read()
    document_inline = genai.types.Part.from_bytes(
        data = base64.b64encode(template_read).decode('utf_8'),
        mime_type = 'image/png'
    )
    with open(template_path.replace('.png', '.html'), 'r') as f:
        template_html = f.read()
    vendor_templates[f'vendor_{v}'] = dict(png = document_inline, html = template_html)

# %%
async def generate_invoice_files(vendor_name, invoice_number, invoice, client, semaphore):
    template = vendor_templates.get(vendor_name).get('html')
    async with semaphore:
        print(f"[Task Start] Generating invoice {invoice_number} for: {vendor_name}")

        prompt = f"""
        I need to create a new invoice in html format that matches the provided template perfectly.

        **New Invoice Data:**
        ```json
        {json.dumps(invoice, indent=2)}
        ```

        **Instructions:**
        1. Create html for an invoice with the same layout and formating as the provided template
        2. Select from the information provided
        3. Don't add information
        4. Recalculate any totals across all the line items
        5. Recalculate any discounts or taxes for lines items or invoice totals 
        6. It is ok to leave information off that is not part of the invoice layout
        7. Match the layout, lines, positioning, and formating of information include font sizes, font types, and colors
        """

        for attempt in range(5):
            if attempt>0:
                print(f"Attempt {attempt} for invoice {invoice_number} at vendor {vendor_name}")
            # Use the asynchronous method generate_content_async
            response = await client.aio.models.generate_content(
                model='gemini-2.0-flash',
                contents=[template, prompt],
                config=genai.types.GenerateContentConfig(
                    temperature=0,
                )
            )

            # find html in the response
            pattern = r'```(?:html|HTML)\n(.*?)```'  # Matches HTML code blocks
            matches = re.search(pattern, response.text, re.DOTALL)
            if matches:
                invoice_html = matches.group(1).strip()
                break
            
        try:
            # convert to pdf and save locally
            vendor_folder_name = vendor_name.lower().replace(" ", "_")
            vendor_dir_path = os.path.join(base_resource_dir, vendor_folder_name, 'invoices')
            os.makedirs(vendor_dir_path, exist_ok=True)
            template_file_path = os.path.join(vendor_dir_path, f"{vendor_name}_invoice_{invoice_number}.pdf")
            pdfkit.from_string(invoice_html, template_file_path)

            # save a png version of the first page also: template.png
            doc = fitz.open(template_file_path)
            page = doc.load_page(0)
            pix = page.get_pixmap(dpi=150)
            pix.save(template_file_path.replace('.pdf', '.png'))
            return True
        except Exception as e:
            print(e)
            return False

# %%
max_async_requests = 20
semaphore = asyncio.Semaphore(max_async_requests)

tasks = []
for v, (vendor_name, invoices) in enumerate(invoices_by_vendor.items()):
    for i, invoice in enumerate(invoices):
        tasks.append(generate_invoice_files(f'vendor_{v}', i, invoice, client, semaphore))

await asyncio.gather(*tasks)
# Out:
# [Task Start] Generating invoice 0 for: vendor_0
# [Task Start] Generating invoice 1 for: vendor_0
# [Task Start] Generating invoice 2 for: vendor_0
# [Task Start] Generating invoice 3 for: vendor_0
# [Task Start] Generating invoice 4 for: vendor_0
# [Task Start] Generating invoice 5 for: vendor_0
# [Task Start] Generating invoice 6 for: vendor_0
# [Task Start] Generating invoice 7 for: vendor_0
# [Task Start] Generating invoice 8 for: vendor_0
# [Task Start] Generating invoice 9 for: vendor_0
# [Task Start] Generating invoice 10 for: vendor_0
# [Task Start] Generating invoice 11 for: vendor_0
# [Task Start] Generating invoice 12 for: vendor_0
# [Task Start] Generating invoice 13 for: vendor_0
# [Task Start] Generating invoice 14 for: vendor_0
# [Task Start] Generating invoice 15 for: vendor_0
# [Task Start] Generating invoice 16 for: vendor_0
# [Task Start] Generating invoice 17 for: vendor_0
# [Task Start] Generating invoice 18 for: vendor_0
# [Task Start] Generating invoice 0 for: vendor_1
# [Task Start] Generating invoice 1 for: vendor_1
# [Task Start] Generating invoice 2 for: vendor_1
# [Task Start] Generating invoice 3 for: vendor_1
# [Task Start] Generating invoice 4 for: vendor_1
# [Task Start] Generating invoice 5 for: vendor_1
# [Task Start] Generating invoice 6 for: vendor_1
# [Task Start] Generating invoice 7 for: vendor_1
# [Task Start] Generating invoice 8 for: vendor_1
# [Task Start] Generating invoice 9 for: vendor_1
# [Task Start] Generating invoice 10 for: vendor_1
# [Task Start] Generating invoice 11 for: vendor_1
# [Task Start] Generating invoice 12 for: vendor_1
# [Task Start] Generating invoice 13 for: vendor_1
# [Task Start] Generating invoice 14 for: vendor_1
# [Task Start] Generating invoice 15 for: vendor_1
# [Task Start] Generating invoice 16 for: vendor_1
# [Task Start] Generating invoice 17 for: vendor_1
# [Task Start] Generating invoice 18 for: vendor_1
# [Task Start] Generating invoice 19 for: vendor_1
# [Task Start] Generating invoice 20 for: vendor_1
# [Task Start] Generating invoice 21 for: vendor_1
# [Task Start] Generating invoice 22 for: vendor_1
# [Task Start] Generating invoice 23 for: vendor_1
# [Task Start] Generating invoice 0 for: vendor_2
# [Task Start] Generating invoice 1 for: vendor_2
# [Task Start] Generating invoice 2 for: vendor_2
# [Task Start] Generating invoice 3 for: vendor_2
# [Task Start] Generating invoice 4 for: vendor_2
# [Task Start] Generating invoice 5 for: vendor_2
# [Task Start] Generating invoice 6 for: vendor_2
# [Task Start] Generating invoice 7 for: vendor_2
# [Task Start] Generating invoice 8 for: vendor_2
# [Task Start] Generating invoice 9 for: vendor_2
# [Task Start] Generating invoice 10 for: vendor_2
# [Task Start] Generating invoice 11 for: vendor_2
# [Task Start] Generating invoice 12 for: vendor_2
# [Task Start] Generating invoice 13 for: vendor_2
# [Task Start] Generating invoice 14 for: vendor_2
# [Task Start] Generating invoice 15 for: vendor_2
# [Task Start] Generating invoice 0 for: vendor_3
# [Task Start] Generating invoice 1 for: vendor_3
# [Task Start] Generating invoice 2 for: vendor_3
# [Task Start] Generating invoice 3 for: vendor_3
# [Task Start] Generating invoice 4 for: vendor_3
# [Task Start] Generating invoice 5 for: vendor_3
# [Task Start] Generating invoice 6 for: vendor_3
# [Task Start] Generating invoice 7 for: vendor_3
# [Task Start] Generating invoice 8 for: vendor_3
# [Task Start] Generating invoice 9 for: vendor_3
# [Task Start] Generating invoice 10 for: vendor_3
# [Task Start] Generating invoice 11 for: vendor_3
# [Task Start] Generating invoice 12 for: vendor_3
# [Task Start] Generating invoice 13 for: vendor_3
# [Task Start] Generating invoice 14 for: vendor_3
# [Task Start] Generating invoice 15 for: vendor_3
# [Task Start] Generating invoice 16 for: vendor_3
# [Task Start] Generating invoice 17 for: vendor_3
# [Task Start] Generating invoice 18 for: vendor_3
# [Task Start] Generating invoice 0 for: vendor_4
# [Task Start] Generating invoice 1 for: vendor_4
# [Task Start] Generating invoice 2 for: vendor_4
# [Task Start] Generating invoice 3 for: vendor_4
# [Task Start] Generating invoice 4 for: vendor_4
# [Task Start] Generating invoice 5 for: vendor_4
# [Task Start] Generating invoice 6 for: vendor_4
# [Task Start] Generating invoice 7 for: vendor_4
# [Task Start] Generating invoice 8 for: vendor_4
# [Task Start] Generating invoice 9 for: vendor_4
# [Task Start] Generating invoice 10 for: vendor_4
# [Task Start] Generating invoice 11 for: vendor_4
# [Task Start] Generating invoice 12 for: vendor_4
# [Task Start] Generating invoice 13 for: vendor_4
# [Task Start] Generating invoice 0 for: vendor_5
# [Task Start] Generating invoice 1 for: vendor_5
# [Task Start] Generating invoice 2 for: vendor_5
# [Task Start] Generating invoice 3 for: vendor_5
# [Task Start] Generating invoice 4 for: vendor_5
# [Task Start] Generating invoice 5 for: vendor_5
# [Task Start] Generating invoice 6 for: vendor_5
# [Task Start] Generating invoice 7 for: vendor_5
# [Task Start] Generating invoice 8 for: vendor_5
# [Task Start] Generating invoice 9 for: vendor_5
# [Task Start] Generating invoice 10 for: vendor_5
# [Task Start] Generating invoice 11 for: vendor_5
# [Task Start] Generating invoice 12 for: vendor_5
# [Task Start] Generating invoice 13 for: vendor_5
# [Task Start] Generating invoice 14 for: vendor_5
# [Task Start] Generating invoice 15 for: vendor_5
# [Task Start] Generating invoice 0 for: vendor_6
# [Task Start] Generating invoice 1 for: vendor_6
# [Task Start] Generating invoice 2 for: vendor_6
# [Task Start] Generating invoice 3 for: vendor_6
# [Task Start] Generating invoice 4 for: vendor_6
# [Task Start] Generating invoice 5 for: vendor_6
# [Task Start] Generating invoice 6 for: vendor_6
# [Task Start] Generating invoice 7 for: vendor_6
# [Task Start] Generating invoice 8 for: vendor_6
# [Task Start] Generating invoice 9 for: vendor_6
# [Task Start] Generating invoice 10 for: vendor_6
# [Task Start] Generating invoice 11 for: vendor_6
# [Task Start] Generating invoice 12 for: vendor_6
# [Task Start] Generating invoice 13 for: vendor_6
# [Task Start] Generating invoice 14 for: vendor_6
# [Task Start] Generating invoice 15 for: vendor_6
# [Task Start] Generating invoice 16 for: vendor_6
# [Task Start] Generating invoice 17 for: vendor_6
# [Task Start] Generating invoice 18 for: vendor_6
# [Task Start] Generating invoice 0 for: vendor_7
# [Task Start] Generating invoice 1 for: vendor_7
# [Task Start] Generating invoice 2 for: vendor_7
# [Task Start] Generating invoice 3 for: vendor_7
# [Task Start] Generating invoice 4 for: vendor_7
# [Task Start] Generating invoice 5 for: vendor_7
# [Task Start] Generating invoice 6 for: vendor_7
# [Task Start] Generating invoice 7 for: vendor_7
# [Task Start] Generating invoice 8 for: vendor_7
# [Task Start] Generating invoice 9 for: vendor_7
# [Task Start] Generating invoice 10 for: vendor_7
# [Task Start] Generating invoice 11 for: vendor_7
# [Task Start] Generating invoice 12 for: vendor_7
# [Task Start] Generating invoice 13 for: vendor_7
# [Task Start] Generating invoice 14 for: vendor_7
# [Task Start] Generating invoice 15 for: vendor_7
# [Task Start] Generating invoice 16 for: vendor_7
# [Task Start] Generating invoice 17 for: vendor_7
# [Task Start] Generating invoice 18 for: vendor_7
# [Task Start] Generating invoice 19 for: vendor_7
# [Task Start] Generating invoice 20 for: vendor_7
# [Task Start] Generating invoice 21 for: vendor_7
# [Task Start] Generating invoice 22 for: vendor_7
# [Task Start] Generating invoice 23 for: vendor_7
# [Task Start] Generating invoice 24 for: vendor_7
# [Task Start] Generating invoice 25 for: vendor_7
# [Task Start] Generating invoice 26 for: vendor_7
# [Task Start] Generating invoice 27 for: vendor_7
# [Task Start] Generating invoice 28 for: vendor_7
# [Task Start] Generating invoice 0 for: vendor_8
# [Task Start] Generating invoice 1 for: vendor_8
# [Task Start] Generating invoice 2 for: vendor_8
# [Task Start] Generating invoice 3 for: vendor_8
# [Task Start] Generating invoice 4 for: vendor_8
# [Task Start] Generating invoice 5 for: vendor_8
# [Task Start] Generating invoice 6 for: vendor_8
# [Task Start] Generating invoice 7 for: vendor_8
# [Task Start] Generating invoice 8 for: vendor_8
# [Task Start] Generating invoice 9 for: vendor_8
# [Task Start] Generating invoice 10 for: vendor_8
# [Task Start] Generating invoice 11 for: vendor_8
# [Task Start] Generating invoice 12 for: vendor_8
# [Task Start] Generating invoice 13 for: vendor_8
# [Task Start] Generating invoice 14 for: vendor_8
# [Task Start] Generating invoice 15 for: vendor_8
# [Task Start] Generating invoice 16 for: vendor_8
# [Task Start] Generating invoice 17 for: vendor_8
# [Task Start] Generating invoice 0 for: vendor_9
# [Task Start] Generating invoice 1 for: vendor_9
# [Task Start] Generating invoice 2 for: vendor_9
# [Task Start] Generating invoice 3 for: vendor_9
# [Task Start] Generating invoice 4 for: vendor_9
# [Task Start] Generating invoice 5 for: vendor_9
# [Task Start] Generating invoice 6 for: vendor_9
# [Task Start] Generating invoice 7 for: vendor_9
# [Task Start] Generating invoice 8 for: vendor_9
# [Task Start] Generating invoice 9 for: vendor_9
# [Task Start] Generating invoice 10 for: vendor_9
# [Task Start] Generating invoice 11 for: vendor_9
# [Task Start] Generating invoice 12 for: vendor_9
# [Task Start] Generating invoice 13 for: vendor_9
# [Task Start] Generating invoice 14 for: vendor_9
# [Task Start] Generating invoice 15 for: vendor_9
# [Task Start] Generating invoice 16 for: vendor_9
# [Task Start] Generating invoice 17 for: vendor_9
# [Task Start] Generating invoice 18 for: vendor_9
# [Task Start] Generating invoice 19 for: vendor_9
# [Task Start] Generating invoice 20 for: vendor_9
# [Task Start] Generating invoice 21 for: vendor_9
# [Task Start] Generating invoice 22 for: vendor_9
# [Task Start] Generating invoice 0 for: vendor_10
# [Task Start] Generating invoice 1 for: vendor_10
# [Task Start] Generating invoice 2 for: vendor_10
# [Task Start] Generating invoice 3 for: vendor_10
# [Task Start] Generating invoice 4 for: vendor_10
# [Task Start] Generating invoice 5 for: vendor_10
# [Task Start] Generating invoice 6 for: vendor_10
# [Task Start] Generating invoice 7 for: vendor_10
# [Task Start] Generating invoice 8 for: vendor_10
# [Task Start] Generating invoice 9 for: vendor_10
# [Task Start] Generating invoice 10 for: vendor_10
# [Task Start] Generating invoice 11 for: vendor_10
# [Task Start] Generating invoice 12 for: vendor_10
# [Task Start] Generating invoice 13 for: vendor_10
# [Task Start] Generating invoice 14 for: vendor_10
# [Task Start] Generating invoice 15 for: vendor_10
# [Task Start] Generating invoice 16 for: vendor_10
# [Task Start] Generating invoice 17 for: vendor_10
# [Task Start] Generating invoice 18 for: vendor_10
# [Task Start] Generating invoice 19 for: vendor_10
# [Task Start] Generating invoice 20 for: vendor_10
# [Task Start] Generating invoice 21 for: vendor_10
# [Task Start] Generating invoice 0 for: vendor_11
# [Task Start] Generating invoice 1 for: vendor_11
# [Task Start] Generating invoice 2 for: vendor_11
# [Task Start] Generating invoice 3 for: vendor_11
# [Task Start] Generating invoice 4 for: vendor_11
# [Task Start] Generating invoice 5 for: vendor_11
# [Task Start] Generating invoice 6 for: vendor_11
# [Task Start] Generating invoice 7 for: vendor_11
# [Task Start] Generating invoice 8 for: vendor_11
# [Task Start] Generating invoice 9 for: vendor_11
# [Task Start] Generating invoice 10 for: vendor_11
# [Task Start] Generating invoice 11 for: vendor_11
# [Task Start] Generating invoice 12 for: vendor_11
# [Task Start] Generating invoice 13 for: vendor_11
# [Task Start] Generating invoice 14 for: vendor_11
# [Task Start] Generating invoice 15 for: vendor_11
# [Task Start] Generating invoice 16 for: vendor_11
# [Task Start] Generating invoice 17 for: vendor_11
# [Task Start] Generating invoice 18 for: vendor_11
# [Task Start] Generating invoice 19 for: vendor_11
# [Task Start] Generating invoice 20 for: vendor_11
# [Task Start] Generating invoice 0 for: vendor_12
# [Task Start] Generating invoice 1 for: vendor_12
# [Task Start] Generating invoice 2 for: vendor_12
# [Task Start] Generating invoice 3 for: vendor_12
# [Task Start] Generating invoice 4 for: vendor_12
# [Task Start] Generating invoice 5 for: vendor_12
# [Task Start] Generating invoice 6 for: vendor_12
# [Task Start] Generating invoice 7 for: vendor_12
# [Task Start] Generating invoice 8 for: vendor_12
# [Task Start] Generating invoice 9 for: vendor_12
# [Task Start] Generating invoice 10 for: vendor_12
# [Task Start] Generating invoice 11 for: vendor_12
# [Task Start] Generating invoice 12 for: vendor_12
# [Task Start] Generating invoice 13 for: vendor_12
# [Task Start] Generating invoice 14 for: vendor_12
# [Task Start] Generating invoice 15 for: vendor_12
# [Task Start] Generating invoice 16 for: vendor_12
# [Task Start] Generating invoice 17 for: vendor_12
# [Task Start] Generating invoice 18 for: vendor_12
# [Task Start] Generating invoice 19 for: vendor_12
# [Task Start] Generating invoice 20 for: vendor_12
# [Task Start] Generating invoice 21 for: vendor_12
# [Task Start] Generating invoice 0 for: vendor_13
# [Task Start] Generating invoice 1 for: vendor_13
# [Task Start] Generating invoice 2 for: vendor_13
# [Task Start] Generating invoice 3 for: vendor_13
# [Task Start] Generating invoice 4 for: vendor_13
# [Task Start] Generating invoice 5 for: vendor_13
# [Task Start] Generating invoice 6 for: vendor_13
# [Task Start] Generating invoice 7 for: vendor_13
# [Task Start] Generating invoice 8 for: vendor_13
# [Task Start] Generating invoice 9 for: vendor_13
# [Task Start] Generating invoice 10 for: vendor_13
# [Task Start] Generating invoice 11 for: vendor_13
# [Task Start] Generating invoice 12 for: vendor_13
# [Task Start] Generating invoice 13 for: vendor_13
# [Task Start] Generating invoice 14 for: vendor_13
# [Task Start] Generating invoice 15 for: vendor_13
# [Task Start] Generating invoice 16 for: vendor_13
# [Task Start] Generating invoice 17 for: vendor_13
# [Task Start] Generating invoice 18 for: vendor_13
# [Task Start] Generating invoice 0 for: vendor_14
# [Task Start] Generating invoice 1 for: vendor_14
# [Task Start] Generating invoice 2 for: vendor_14
# [Task Start] Generating invoice 3 for: vendor_14
# [Task Start] Generating invoice 4 for: vendor_14
# [Task Start] Generating invoice 5 for: vendor_14
# [Task Start] Generating invoice 6 for: vendor_14
# [Task Start] Generating invoice 7 for: vendor_14
# [Task Start] Generating invoice 8 for: vendor_14
# [Task Start] Generating invoice 9 for: vendor_14
# [Task Start] Generating invoice 10 for: vendor_14
# [Task Start] Generating invoice 11 for: vendor_14
# [Task Start] Generating invoice 12 for: vendor_14
# [Task Start] Generating invoice 13 for: vendor_14
# [Task Start] Generating invoice 14 for: vendor_14
# [Task Start] Generating invoice 15 for: vendor_14
# [Task Start] Generating invoice 16 for: vendor_14
# [Task Start] Generating invoice 17 for: vendor_14
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# ### Anomalous Invoices
#
# Create an anomalous invoice version for each invoice by using Gemini to view an existing invoice and create a new one from it.  This results in a range of formatting and layout differences.

# %%
async def generate_fake_invoice_files(vendor_name, invoice_number, invoice, client, semaphore):
    template = vendor_templates.get(vendor_name).get('png')
    async with semaphore:
        print(f"[Task Start] Generating invoice {invoice_number} for: {vendor_name}")

        prompt = f"""
        I need to create a new invoice in html format that matches the provided template.

        **New Invoice Data:**
        ```json
        {json.dumps(invoice, indent=2)}
        ```

        **Instructions:**
        1. Create html for an invoice with the same layout and formating as the provided template
        2. Select from the information provided
        3. Don't add information
        4. Recalculate any totals across all the line items
        5. Recalculate any discounts or taxes for lines items or invoice totals 
        6. It is ok to leave information off that is not part of the invoice layout
        7. Match the layout, lines, positioning, and formating of information include font sizes, font types, and colors
        """

        for attempt in range(5):
            if attempt>0:
                print(f"Attempt {attempt} for invoice {invoice_number} at vendor {vendor_name}")
            # Use the asynchronous method generate_content_async
            response = await client.aio.models.generate_content(
                model='gemini-2.0-flash',
                contents=[template, prompt],
                config=genai.types.GenerateContentConfig(
                    temperature=0.5,
                )
            )

            # find html in the response
            pattern = r'```(?:html|HTML)\n(.*?)```'  # Matches HTML code blocks
            matches = re.search(pattern, response.text, re.DOTALL)
            if matches:
                invoice_html = matches.group(1).strip()
                break

        try:
            # convert to pdf and save locally
            vendor_folder_name = vendor_name.lower().replace(" ", "_")
            vendor_dir_path = os.path.join(base_resource_dir, vendor_folder_name, 'fake_invoices')
            os.makedirs(vendor_dir_path, exist_ok=True)
            template_file_path = os.path.join(vendor_dir_path, f"{vendor_name}_invoice_{invoice_number}.pdf")
            pdfkit.from_string(invoice_html, template_file_path)

            # save a png version of the first page also: template.png
            doc = fitz.open(template_file_path)
            page = doc.load_page(0)
            pix = page.get_pixmap(dpi=150)
            pix.save(template_file_path.replace('.pdf', '.png'))
            return True
        except Exception as e:
            print(e)
            return False

# %%
max_async_requests = 20
semaphore = asyncio.Semaphore(max_async_requests)

tasks = []
for v, (vendor_name, invoices) in enumerate(invoices_by_vendor.items()):
    for i, invoice in enumerate(invoices):
        #if i < 5:
        tasks.append(generate_fake_invoice_files(f'vendor_{v}', i, invoice, client, semaphore))

await asyncio.gather(*tasks)
# Out:
# [Task Start] Generating invoice 0 for: vendor_0
# [Task Start] Generating invoice 1 for: vendor_0
# [Task Start] Generating invoice 2 for: vendor_0
# [Task Start] Generating invoice 3 for: vendor_0
# [Task Start] Generating invoice 4 for: vendor_0
# [Task Start] Generating invoice 5 for: vendor_0
# [Task Start] Generating invoice 6 for: vendor_0
# [Task Start] Generating invoice 7 for: vendor_0
# [Task Start] Generating invoice 8 for: vendor_0
# [Task Start] Generating invoice 9 for: vendor_0
# [Task Start] Generating invoice 10 for: vendor_0
# [Task Start] Generating invoice 11 for: vendor_0
# [Task Start] Generating invoice 12 for: vendor_0
# [Task Start] Generating invoice 13 for: vendor_0
# [Task Start] Generating invoice 14 for: vendor_0
# [Task Start] Generating invoice 15 for: vendor_0
# [Task Start] Generating invoice 16 for: vendor_0
# [Task Start] Generating invoice 17 for: vendor_0
# [Task Start] Generating invoice 18 for: vendor_0
# [Task Start] Generating invoice 0 for: vendor_1
# [Task Start] Generating invoice 1 for: vendor_1
# [Task Start] Generating invoice 2 for: vendor_1
# [Task Start] Generating invoice 3 for: vendor_1
# [Task Start] Generating invoice 4 for: vendor_1
# [Task Start] Generating invoice 5 for: vendor_1
# [Task Start] Generating invoice 6 for: vendor_1
# [Task Start] Generating invoice 7 for: vendor_1
# [Task Start] Generating invoice 8 for: vendor_1
# [Task Start] Generating invoice 9 for: vendor_1
# [Task Start] Generating invoice 10 for: vendor_1
# [Task Start] Generating invoice 11 for: vendor_1
# [Task Start] Generating invoice 12 for: vendor_1
# [Task Start] Generating invoice 13 for: vendor_1
# [Task Start] Generating invoice 14 for: vendor_1
# [Task Start] Generating invoice 15 for: vendor_1
# [Task Start] Generating invoice 16 for: vendor_1
# [Task Start] Generating invoice 17 for: vendor_1
# [Task Start] Generating invoice 18 for: vendor_1
# [Task Start] Generating invoice 19 for: vendor_1
# [Task Start] Generating invoice 20 for: vendor_1
# [Task Start] Generating invoice 21 for: vendor_1
# [Task Start] Generating invoice 22 for: vendor_1
# [Task Start] Generating invoice 23 for: vendor_1
# [Task Start] Generating invoice 0 for: vendor_2
# [Task Start] Generating invoice 1 for: vendor_2
# [Task Start] Generating invoice 2 for: vendor_2
# [Task Start] Generating invoice 3 for: vendor_2
# [Task Start] Generating invoice 4 for: vendor_2
# [Task Start] Generating invoice 5 for: vendor_2
# [Task Start] Generating invoice 6 for: vendor_2
# [Task Start] Generating invoice 7 for: vendor_2
# [Task Start] Generating invoice 8 for: vendor_2
# [Task Start] Generating invoice 9 for: vendor_2
# [Task Start] Generating invoice 10 for: vendor_2
# [Task Start] Generating invoice 11 for: vendor_2
# [Task Start] Generating invoice 12 for: vendor_2
# [Task Start] Generating invoice 13 for: vendor_2
# [Task Start] Generating invoice 14 for: vendor_2
# [Task Start] Generating invoice 15 for: vendor_2
# [Task Start] Generating invoice 0 for: vendor_3
# [Task Start] Generating invoice 1 for: vendor_3
# [Task Start] Generating invoice 2 for: vendor_3
# [Task Start] Generating invoice 3 for: vendor_3
# [Task Start] Generating invoice 4 for: vendor_3
# [Task Start] Generating invoice 5 for: vendor_3
# [Task Start] Generating invoice 6 for: vendor_3
# [Task Start] Generating invoice 7 for: vendor_3
# [Task Start] Generating invoice 8 for: vendor_3
# [Task Start] Generating invoice 9 for: vendor_3
# [Task Start] Generating invoice 10 for: vendor_3
# [Task Start] Generating invoice 11 for: vendor_3
# [Task Start] Generating invoice 12 for: vendor_3
# [Task Start] Generating invoice 13 for: vendor_3
# [Task Start] Generating invoice 14 for: vendor_3
# [Task Start] Generating invoice 15 for: vendor_3
# [Task Start] Generating invoice 16 for: vendor_3
# [Task Start] Generating invoice 17 for: vendor_3
# [Task Start] Generating invoice 18 for: vendor_3
# [Task Start] Generating invoice 0 for: vendor_4
# [Task Start] Generating invoice 1 for: vendor_4
# [Task Start] Generating invoice 2 for: vendor_4
# [Task Start] Generating invoice 3 for: vendor_4
# [Task Start] Generating invoice 4 for: vendor_4
# [Task Start] Generating invoice 5 for: vendor_4
# [Task Start] Generating invoice 6 for: vendor_4
# [Task Start] Generating invoice 7 for: vendor_4
# [Task Start] Generating invoice 8 for: vendor_4
# [Task Start] Generating invoice 9 for: vendor_4
# [Task Start] Generating invoice 10 for: vendor_4
# [Task Start] Generating invoice 11 for: vendor_4
# [Task Start] Generating invoice 12 for: vendor_4
# [Task Start] Generating invoice 13 for: vendor_4
# [Task Start] Generating invoice 0 for: vendor_5
# [Task Start] Generating invoice 1 for: vendor_5
# [Task Start] Generating invoice 2 for: vendor_5
# [Task Start] Generating invoice 3 for: vendor_5
# [Task Start] Generating invoice 4 for: vendor_5
# [Task Start] Generating invoice 5 for: vendor_5
# [Task Start] Generating invoice 6 for: vendor_5
# [Task Start] Generating invoice 7 for: vendor_5
# [Task Start] Generating invoice 8 for: vendor_5
# [Task Start] Generating invoice 9 for: vendor_5
# [Task Start] Generating invoice 10 for: vendor_5
# [Task Start] Generating invoice 11 for: vendor_5
# [Task Start] Generating invoice 12 for: vendor_5
# [Task Start] Generating invoice 13 for: vendor_5
# [Task Start] Generating invoice 14 for: vendor_5
# [Task Start] Generating invoice 15 for: vendor_5
# [Task Start] Generating invoice 0 for: vendor_6
# [Task Start] Generating invoice 1 for: vendor_6
# [Task Start] Generating invoice 2 for: vendor_6
# [Task Start] Generating invoice 3 for: vendor_6
# [Task Start] Generating invoice 4 for: vendor_6
# [Task Start] Generating invoice 5 for: vendor_6
# [Task Start] Generating invoice 6 for: vendor_6
# [Task Start] Generating invoice 7 for: vendor_6
# [Task Start] Generating invoice 8 for: vendor_6
# [Task Start] Generating invoice 9 for: vendor_6
# [Task Start] Generating invoice 10 for: vendor_6
# [Task Start] Generating invoice 11 for: vendor_6
# [Task Start] Generating invoice 12 for: vendor_6
# [Task Start] Generating invoice 13 for: vendor_6
# [Task Start] Generating invoice 14 for: vendor_6
# [Task Start] Generating invoice 15 for: vendor_6
# [Task Start] Generating invoice 16 for: vendor_6
# [Task Start] Generating invoice 17 for: vendor_6
# [Task Start] Generating invoice 18 for: vendor_6
# [Task Start] Generating invoice 0 for: vendor_7
# [Task Start] Generating invoice 1 for: vendor_7
# [Task Start] Generating invoice 2 for: vendor_7
# [Task Start] Generating invoice 3 for: vendor_7
# [Task Start] Generating invoice 4 for: vendor_7
# [Task Start] Generating invoice 5 for: vendor_7
# [Task Start] Generating invoice 6 for: vendor_7
# [Task Start] Generating invoice 7 for: vendor_7
# [Task Start] Generating invoice 8 for: vendor_7
# [Task Start] Generating invoice 9 for: vendor_7
# [Task Start] Generating invoice 10 for: vendor_7
# [Task Start] Generating invoice 11 for: vendor_7
# [Task Start] Generating invoice 12 for: vendor_7
# [Task Start] Generating invoice 13 for: vendor_7
# [Task Start] Generating invoice 14 for: vendor_7
# [Task Start] Generating invoice 15 for: vendor_7
# [Task Start] Generating invoice 16 for: vendor_7
# [Task Start] Generating invoice 17 for: vendor_7
# [Task Start] Generating invoice 18 for: vendor_7
# [Task Start] Generating invoice 19 for: vendor_7
# [Task Start] Generating invoice 20 for: vendor_7
# [Task Start] Generating invoice 21 for: vendor_7
# [Task Start] Generating invoice 22 for: vendor_7
# [Task Start] Generating invoice 23 for: vendor_7
# [Task Start] Generating invoice 24 for: vendor_7
# [Task Start] Generating invoice 25 for: vendor_7
# [Task Start] Generating invoice 26 for: vendor_7
# [Task Start] Generating invoice 27 for: vendor_7
# Attempt 1 for invoice 8 at vendor vendor_5
# Attempt 1 for invoice 7 at vendor vendor_5
# Attempt 1 for invoice 11 at vendor vendor_5
# [Task Start] Generating invoice 28 for: vendor_7
# [Task Start] Generating invoice 0 for: vendor_8
# [Task Start] Generating invoice 1 for: vendor_8
# [Task Start] Generating invoice 2 for: vendor_8
# [Task Start] Generating invoice 3 for: vendor_8
# [Task Start] Generating invoice 4 for: vendor_8
# [Task Start] Generating invoice 5 for: vendor_8
# [Task Start] Generating invoice 6 for: vendor_8
# [Task Start] Generating invoice 7 for: vendor_8
# [Task Start] Generating invoice 8 for: vendor_8
# [Task Start] Generating invoice 9 for: vendor_8
# [Task Start] Generating invoice 10 for: vendor_8
# [Task Start] Generating invoice 11 for: vendor_8
# [Task Start] Generating invoice 12 for: vendor_8
# [Task Start] Generating invoice 13 for: vendor_8
# Attempt 1 for invoice 15 at vendor vendor_5
# [Task Start] Generating invoice 14 for: vendor_8
# [Task Start] Generating invoice 15 for: vendor_8
# [Task Start] Generating invoice 16 for: vendor_8
# [Task Start] Generating invoice 17 for: vendor_8
# [Task Start] Generating invoice 0 for: vendor_9
# [Task Start] Generating invoice 1 for: vendor_9
# [Task Start] Generating invoice 2 for: vendor_9
# [Task Start] Generating invoice 3 for: vendor_9
# [Task Start] Generating invoice 4 for: vendor_9
# [Task Start] Generating invoice 5 for: vendor_9
# [Task Start] Generating invoice 6 for: vendor_9
# [Task Start] Generating invoice 7 for: vendor_9
# [Task Start] Generating invoice 8 for: vendor_9
# [Task Start] Generating invoice 9 for: vendor_9
# [Task Start] Generating invoice 10 for: vendor_9
# Attempt 1 for invoice 3 at vendor vendor_7
# [Task Start] Generating invoice 11 for: vendor_9
# [Task Start] Generating invoice 12 for: vendor_9
# [Task Start] Generating invoice 13 for: vendor_9
# [Task Start] Generating invoice 14 for: vendor_9
# [Task Start] Generating invoice 15 for: vendor_9
# [Task Start] Generating invoice 16 for: vendor_9
# [Task Start] Generating invoice 17 for: vendor_9
# [Task Start] Generating invoice 18 for: vendor_9
# [Task Start] Generating invoice 19 for: vendor_9
# [Task Start] Generating invoice 20 for: vendor_9
# [Task Start] Generating invoice 21 for: vendor_9
# [Task Start] Generating invoice 22 for: vendor_9
# [Task Start] Generating invoice 0 for: vendor_10
# [Task Start] Generating invoice 1 for: vendor_10
# Attempt 1 for invoice 23 at vendor vendor_7
# Attempt 1 for invoice 17 at vendor vendor_7
# [Task Start] Generating invoice 2 for: vendor_10
# Attempt 1 for invoice 26 at vendor vendor_7
# [Task Start] Generating invoice 3 for: vendor_10
# [Task Start] Generating invoice 4 for: vendor_10
# [Task Start] Generating invoice 5 for: vendor_10
# [Task Start] Generating invoice 6 for: vendor_10
# [Task Start] Generating invoice 7 for: vendor_10
# [Task Start] Generating invoice 8 for: vendor_10
# [Task Start] Generating invoice 9 for: vendor_10
# [Task Start] Generating invoice 10 for: vendor_10
# [Task Start] Generating invoice 11 for: vendor_10
# [Task Start] Generating invoice 12 for: vendor_10
# [Task Start] Generating invoice 13 for: vendor_10
# [Task Start] Generating invoice 14 for: vendor_10
# [Task Start] Generating invoice 15 for: vendor_10
# [Task Start] Generating invoice 16 for: vendor_10
# [Task Start] Generating invoice 17 for: vendor_10
# [Task Start] Generating invoice 18 for: vendor_10
# [Task Start] Generating invoice 19 for: vendor_10
# [Task Start] Generating invoice 20 for: vendor_10
# [Task Start] Generating invoice 21 for: vendor_10
# [Task Start] Generating invoice 0 for: vendor_11
# Attempt 1 for invoice 4 at vendor vendor_8
# [Task Start] Generating invoice 1 for: vendor_11
# [Task Start] Generating invoice 2 for: vendor_11
# [Task Start] Generating invoice 3 for: vendor_11
# [Task Start] Generating invoice 4 for: vendor_11
# [Task Start] Generating invoice 5 for: vendor_11
# [Task Start] Generating invoice 6 for: vendor_11
# [Task Start] Generating invoice 7 for: vendor_11
# Attempt 2 for invoice 15 at vendor vendor_5
# [Task Start] Generating invoice 8 for: vendor_11
# [Task Start] Generating invoice 9 for: vendor_11
# [Task Start] Generating invoice 10 for: vendor_11
# [Task Start] Generating invoice 11 for: vendor_11
# [Task Start] Generating invoice 12 for: vendor_11
# [Task Start] Generating invoice 13 for: vendor_11
# [Task Start] Generating invoice 14 for: vendor_11
# [Task Start] Generating invoice 15 for: vendor_11
# [Task Start] Generating invoice 16 for: vendor_11
# [Task Start] Generating invoice 17 for: vendor_11
# [Task Start] Generating invoice 18 for: vendor_11
# [Task Start] Generating invoice 19 for: vendor_11
# [Task Start] Generating invoice 20 for: vendor_11
# [Task Start] Generating invoice 0 for: vendor_12
# [Task Start] Generating invoice 1 for: vendor_12
# [Task Start] Generating invoice 2 for: vendor_12
# [Task Start] Generating invoice 3 for: vendor_12
# [Task Start] Generating invoice 4 for: vendor_12
# [Task Start] Generating invoice 5 for: vendor_12
# [Task Start] Generating invoice 6 for: vendor_12
# [Task Start] Generating invoice 7 for: vendor_12
# [Task Start] Generating invoice 8 for: vendor_12
# [Task Start] Generating invoice 9 for: vendor_12
# [Task Start] Generating invoice 10 for: vendor_12
# [Task Start] Generating invoice 11 for: vendor_12
# [Task Start] Generating invoice 12 for: vendor_12
# [Task Start] Generating invoice 13 for: vendor_12
# [Task Start] Generating invoice 14 for: vendor_12
# [Task Start] Generating invoice 15 for: vendor_12
# [Task Start] Generating invoice 16 for: vendor_12
# Attempt 1 for invoice 17 at vendor vendor_9
# [Task Start] Generating invoice 17 for: vendor_12
# [Task Start] Generating invoice 18 for: vendor_12
# [Task Start] Generating invoice 19 for: vendor_12
# [Task Start] Generating invoice 20 for: vendor_12
# [Task Start] Generating invoice 21 for: vendor_12
# [Task Start] Generating invoice 0 for: vendor_13
# [Task Start] Generating invoice 1 for: vendor_13
# [Task Start] Generating invoice 2 for: vendor_13
# [Task Start] Generating invoice 3 for: vendor_13
# [Task Start] Generating invoice 4 for: vendor_13
# [Task Start] Generating invoice 5 for: vendor_13
# [Task Start] Generating invoice 6 for: vendor_13
# [Task Start] Generating invoice 7 for: vendor_13
# [Task Start] Generating invoice 8 for: vendor_13
# [Task Start] Generating invoice 9 for: vendor_13
# [Task Start] Generating invoice 10 for: vendor_13
# [Task Start] Generating invoice 11 for: vendor_13
# [Task Start] Generating invoice 12 for: vendor_13
# [Task Start] Generating invoice 13 for: vendor_13
# [Task Start] Generating invoice 14 for: vendor_13
# [Task Start] Generating invoice 15 for: vendor_13
# [Task Start] Generating invoice 16 for: vendor_13
# [Task Start] Generating invoice 17 for: vendor_13
# [Task Start] Generating invoice 18 for: vendor_13
# [Task Start] Generating invoice 0 for: vendor_14
# [Task Start] Generating invoice 1 for: vendor_14
# [Task Start] Generating invoice 2 for: vendor_14
# [Task Start] Generating invoice 3 for: vendor_14
# [Task Start] Generating invoice 4 for: vendor_14
# [Task Start] Generating invoice 5 for: vendor_14
# [Task Start] Generating invoice 6 for: vendor_14
# [Task Start] Generating invoice 7 for: vendor_14
# [Task Start] Generating invoice 8 for: vendor_14
# [Task Start] Generating invoice 9 for: vendor_14
# [Task Start] Generating invoice 10 for: vendor_14
# [Task Start] Generating invoice 11 for: vendor_14
# [Task Start] Generating invoice 12 for: vendor_14
# [Task Start] Generating invoice 13 for: vendor_14
# [Task Start] Generating invoice 14 for: vendor_14
# [Task Start] Generating invoice 15 for: vendor_14
# [Task Start] Generating invoice 16 for: vendor_14
# [Task Start] Generating invoice 17 for: vendor_14
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# ### Review Information
# Compare a real invoice to a fake invoice for each vendor - just use invoice 0 for this:

# %%
display(Image('./resources/documents/vendor_0/invoices/vendor_0_invoice_0.png', width=550))

# %%
display(Image('./resources/documents/vendor_0/fake_invoices/vendor_0_invoice_0.png', width=550))

# %% [markdown]
# ---
# ## Tried Multimodal Responses with Gemini - Not implemented.... Yet

# %%
prompt = f"""
Generate a realistic, fictitious invoice based on the following details:

**Invoice:**
```json
{json.dumps(invoices[0], indent=2)}
```

**Instructions:**
1. Create html for an invoice with typical but unique layout
2. Select from the information provided
3. Don't add information
4. It is ok to leave information off that is not part of the invoice layout
5. Make the layout specific to the vendor including the creation of a simple plain logo and/or layout format
6. Feel free to use color for logos, headers, footers but it must remain formal for a business
"""

# %%
#import base64

# imports for REST instead of Client Usage (genai)
#import requests
#import google.auth
#import google.auth.transport.requests

# %%
# response = client.models.generate_content(
#     model = 'gemini-2.0-flash-exp',
#     contents = prompt,
#     config = genai.types.GenerateContentConfig(
#         temperature = 1,
#         response_modalities = ['IMAGE']
#     )
# )

# %%
def generate_image(prompt):
  credentials, project_id_from_auth = google.auth.default(scopes=['https://www.googleapis.com/auth/cloud-platform'])
  auth_req = google.auth.transport.requests.Request()
  credentials.refresh(auth_req)
  access_token = credentials.token

  rest_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1/projects/{PROJECT_ID}/locations/{LOCATION}/publishers/google/models/gemini-2.0-flash-exp:generateContent"

  headers = {
      # Use the obtained access token
      "Authorization": f"Bearer {access_token}",
      "Content-Type": "application/json; charset=utf-8",
  }

  rest_payload = {
    "contents": [
      {
        "role": "user",
        "parts": [{"text": prompt}]
      }
    ],
    "generation_config": {
      "temperature": 1.0,
      "response_modalities": ["IMAGE", "TEXT"]
    }
  }

  try:
    response = requests.post(
        rest_url,
        headers=headers,
        json=rest_payload
    )
    response.raise_for_status()
    response_data = response.json()
  except requests.exceptions.RequestException as e:
    if e.response is not None:
      print(f"Status Code: {e.response.status_code}")
      try:
        print("Response Body:\n", json.dumps(e.response.json(), indent=2))
      except json.JSONDecodeError:
        print("Response Body:\n", e.response.text)
  except Exception as e:
    print('Unexpected Error: ', e)

  return response_data

# %%
response_data = generate_image(prompt)

# %%
response_data
# Out:
# {'candidates': [{'content': {'role': 'model',
#     'parts': [{'inlineData': {'mimeType': 'image/png',
#        'data': '...'}}]},
#    'finishReason': 'STOP'}],
#  'usageMetadata': {'promptTokenCount': 838,
#   'candidatesTokenCount': 258,
#   'totalTokenCount': 1096,
#   'trafficType': 'ON_DEMAND',
#   'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 838}],
#   'candidatesTokensDetails': [{'modality': 'IMAGE', 'tokenCount': 258}]},
#  'modelVersion': 'gemini-2.0-flash-exp',
#  'createTime': '2025-04-19T11:48:34.066257Z',
#  'responseId': 'ko0DaNGFBImThMIPgdDpqAQ'}

# %%
response_data.get('candidates')[0].get('content').get('parts')[0].get('inlineData')
# Out:
# {'mimeType': 'image/png',
#  'data': '...'}

# %%
def extract_decode(response_data):

    inline_data = None

    # extract
    try:
        # Navigate through the response structure using .get() for safety
        candidates = response_data.get('candidates', [])
        if not candidates:
            print("Warning: 'candidates' key not found or empty in the response data.")
            return None

        parts = candidates[0].get('content', {}).get('parts', [])
        if not parts:
            print("Warning: 'parts' key not found or empty in the first candidate's content.")
            return None

        inline_data = parts[0].get('inlineData')
        if inline_data is None:
            print("Warning: 'inlineData' key not found in the first part.")
            return None # Explicitly return None if not found

    except AttributeError as e:
        print(f"Error accessing nested data, check response structure: {e}")
        return None # Return None on unexpected structure
    except IndexError as e:
        print(f"Error accessing list elements (candidates/parts may be empty): {e}")
        return None # Return None if lists are empty/index out of bounds
    except Exception as e:
        # Catch any other unexpected errors during extraction
        print(f"An unexpected error occurred during data extraction: {e}")
        return None

    # decode
    if isinstance(inline_data, dict) and 'data' in inline_data:
        base64_data = inline_data.get('data')
        mime_type = inline_data.get('mimeType', 'unknown') # Optional: log mime type

        if not base64_data:
             print(f"Error: Found inlineData structure, but 'data' field is empty or missing.")
             return None

        try:
            # Decode the base64 string into image bytes
            image_bytes = base64.b64decode(base64_data)
            print(f"Successfully decoded image data ({mime_type}).") # You can remove this print if desired
            return image_bytes  # <<< Return the bytes on success

        except (base64.binascii.Error, ValueError) as e:
            # Handle potential errors during base64 decoding
            print(f"Error decoding base64 data: {e}")
            return None  # <<< Return None on decoding error
        except Exception as e:
            # Handle other potential errors during decoding
            print(f"An unexpected error occurred during decoding: {e}")
            return None # <<< Return None on other errors

    else:
        # Handle cases where inline_data wasn't a dict or lacked the 'data' key
        print("Error: 'inlineData' was found but is not a dictionary or lacks the 'data' key.")
        print(f"Value of inline_data: {inline_data}")
        return None # <<< Return None if structure is wrong

# %%
display(Image(extract_decode(response_data)))
# Out:
# Successfully decoded image data (image/png).
