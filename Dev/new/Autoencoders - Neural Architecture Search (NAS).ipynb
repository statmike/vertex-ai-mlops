# %% [markdown]
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2Fnew&dt=Autoencoders+-+Neural+Architecture+Search+%28NAS%29.ipynb)
#
# # Autoencoders - Neural Architecture Search (NAS)
#
# Use neural architecture search (NAS) to choose optimial architecture for an autoencoder.
