# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FApplied+GenAI%2Fresources&file=graphics.ipynb)
# <!--- header table --->
# <table align="left">
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/Applied%20GenAI/resources/graphics.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FApplied%2520GenAI%2Fresources%2Fgraphics.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20GenAI/resources/graphics.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/github-logo-32px.png" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20GenAI/resources/graphics.ipynb">
#       <img src="https://lh3.googleusercontent.com/UiNooY4LUgW_oTvpsNhPpQzsstV5W8F7rYgxgGBD85cWJoLmrOzhVs_ksK_vgx40SHs7jCqkTkCk=e14-rj-sc0xffffff-h130-w32" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# # Graphics For `./Applied GenAI`
#
# - Embed images with relative links and html within markdown like this:
# ```
# <p align="center"><center>
#     <img src="./resources/images/grounding/vs_app_preview.png" width="75%">
# </center><p>
# ```

# %% [markdown]
# ## Installation

# %%
#!npm install -g @mermaid-js/mermaid-cli

# %% [markdown]
# ## Setup

# %%
import os
import base64
import requests
from IPython.display import Image, display

# %%
mainpath = './images/created/'

# %% [markdown]
# ## Colors

# %%
gcolors = dict(
    blue = ['#E8F0FE','#D2E3FC','#AECBFA','#8AB4F8','#669DF6','#4285F4','#1A73E8','#1967D2','#185ABC','#174EA6'],
    red = ['#FCE8E6','#FAD2CF','#F6AEA9','#F28B82','#EE675C','#EA4335','#D93025','#C5221F','#B31412','#A50E0E'],
    yellow = ['#FEF7E0','#FEEFC3','#FDE293','#FDD663','#FCC934','#FBBC04','#F9AB00','#F29900','#EA8600','#E37400'],
    green = ['#E6F4EA','#CEEAD6','#A8DAB5','#81C995','#5BB974','#34A853','#1E8E3E','#188038','#137333','#0D652D'],
    grey = ['#F8F9FA','#F1F3F4','#E8EAED','#DADCE0','#BDC1C6','#9AA0A6','#80868B','#5F6368','#3C4043','#202124']
)

# %%
import IPython
def colorer(scheme, text):
    for colors in scheme.keys():
        IPython.display.display(
            IPython.display.Markdown(
                ' '.join(
                    f'<span style="font-family: monospace"><span style="color: {color}">{text}</span></span>'
                    for color in scheme[colors]
                )
            )
        )
colorer(gcolors, 'Vertex AI')
# Out:
# <span style="font-family: monospace"><span style="color: #E8F0FE">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #D2E3FC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #AECBFA">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #8AB4F8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #669DF6">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #4285F4">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1A73E8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1967D2">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #185ABC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #174EA6">Vertex AI</span></span>
# ...

# %% [markdown]
# ---
# ## Helper Funtions: For Mermaid Plots
#
# Designed to render plots from encoded strings sent to `https://mermaid.ink` after [this tutorial](https://mermaid.js.org/ecosystem/tutorials.html#jupyter-integration-with-mermaid-js)

# %%
def mermaid_render(graph, mainpath = mainpath, filepath = None, remote = True):
    if filepath:
        # verify director exists:
        fullpath = mainpath+filepath
        directory = os.path.dirname(fullpath)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)
    
    if remote: # use mermaid.ink/img to do the render
        encode = base64.b64encode(graph.encode('utf-8')).decode('ascii')
        response = requests.get('https://mermaid.ink/img/' + encode)
        if filepath:
            # save file
            with open(fullpath, 'wb') as f:
                f.write(response.content)
        return Image(response.content)
    else: # use local mermaid-cli (mmdc)
    #    if filepath:
    #        with open(fullpath+'.mdd', 'w') as f:
    #            f.write(graph)
    #        subprocess.run(["mmdc", "-i", fullpath+'.mdd', "-o", fullpath]) # -o is output to file, -t for theme, -b for background, -i is the input graph
    #        os.remove(fullpath+'.mdd')
    #    else: print('The `filepath` parameter is required for local processing (remote = False).')
        print('Still working on headless chrome in notebook')
        return #Image(fullpath)

# %% [markdown]
# ---
# ## Example: /example/example.png

# %%
filepath = 'example/example.png'

# %%
mermaid_render("""
graph LR;
    A--> B & C & D;
    B--> A & E;
    C--> A & E;
    D--> A & E;
    E--> B & C & D;
""")

# %%
mermaid_render("""
graph LR;
    A--> B & C & D;
    B--> A & E;
    C--> A & E;
    D--> A & E;
    E--> B & C & D;
""", filepath = filepath)

# %% [markdown]
# ---
# ## /grounding/overview.png

# %%
filepath = 'grounding/overview.png'

# %%
inits = '%%{init:{"flowchart":{"nodeSpacing": 10, "rankSpacing": 10}}}%%'

mermaid_render(f"""
{inits}
flowchart LR
    subgraph grounding [Grounding LLMs]
        client([Client])
        subgraph vertex [Vertex AI]
            vector([Vector Search])
            llama([LlamaIndex])
            fs([Feature Store])
            gemini([Gemini API])
            embed([Text Embeddings API])
        end
        subgraph agents [Vertex AI Agent Builder]
            vais([Vertex AI Search])
            rank([Ranking API])
            ground([Grounding API])
            check([Grounding Check API])
        end
        subgraph bq [BigQuery]
            search([Vector Search])
            index([Vector Index])
        end
        subgraph docai [Document AI]
            chunk([Layout Parser])
        end
    end
    
    style grounding fill:{gcolors['grey'][2]}, stroke-width:0px, rx:10, ry:10
    style vertex fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    style agents fill:{gcolors['red'][4]}, stroke-width:0px, rx:10, ry:10
    style bq fill:{gcolors['blue'][4]}, stroke-width:0px, rx:10, ry:10
    style docai fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
""", filepath = filepath)

# %% [markdown]
# ---
# ## /applied-genai/overview.png

# %%
filepath = 'applied-genai/overview.png'

inits = "%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20, 'subGraphTitleMargin': {'top': 15, 'bottom': 15}}}}%%"

mermaid_render(f"""
{inits}
flowchart LR
    classDef nodeClass fill:{gcolors['grey'][1]},stroke:{gcolors['grey'][5]},stroke-width:2px
    subgraph input [Information]
        direction TB
        input1([Images])
        input2([Files])
        input3([Data])
        input4([Video])
        input5([Audio])
        input1 ~~~ input2 ~~~ input3 ~~~ input4 ~~~ input5
    end
    subgraph retrieve [Retrieval Augmented Generation]
        direction TB
        subgraph build[Build]
            direction LR
            subgraph chunk ["Process (Chunk)"]

            end
            subgraph embed [Embeddings]

            end
            subgraph index [Index & Retrieve]

            end
            subgraph rank [Rank]

            end
            subgraph generate [Generate]

            end
            subgraph validate [Validate]

            end
            chunk --> embed --> index --> rank --> generate --> validate
        end
        subgraph tools [Customize]
            direction LR
            tune([Tuning])
            eval([Evaluation])
        end
        subgraph augment [Augment]
            direction LR
            function([Function Calling])
            extend([Extensions])
        end
        tools --> build
        augment --> build
        
    end
    subgraph output [Grounded Responses]
        output1([Summaries])
        output2([Search])
        output3([Q&A])
        output4([Classification])
        output5([Extraction])
        output1 ~~~ output2 ~~~ output3 ~~~ output4 ~~~ output5
    end
    input --> retrieve --> output

    style input fill:{gcolors['blue'][4]}, stroke-width:0px, rx:10, ry:10
    style retrieve fill:{gcolors['green'][4]}, stroke-width:0px, rx:10, ry:10
    style output fill:{gcolors['yellow'][4]}, stroke-width:0px, rx:10, ry:10
    style build fill:{gcolors['grey'][3]}, stroke-width:0px, rx:10, ry:10
    style tools fill:{gcolors['grey'][3]}, stroke-width:0px, rx:10, ry:10
    style augment fill:{gcolors['grey'][3]}, stroke-width:0px, rx:10, ry:10
    
    class input1,input2,input3,input4,input5,output1,output2,output3,output4,output5 nodeClass
    class tune,eval,function,extend,chunk,embed,index,rank,generate,validate nodeClass
    
    
""", filepath = filepath)

# %% [markdown]
# ---
# ## /applied-genai/overview-build.png

# %%
filepath = 'applied-genai/overview-build.png'

inits = "%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20, 'subGraphTitleMargin': {'top': 15, 'bottom': 15}}}}%%"

mermaid_render(f"""
{inits}
flowchart LR
    classDef nodeClass fill:{gcolors['grey'][1]},stroke:{gcolors['grey'][5]},stroke-width:2px

        subgraph build[Build]
            direction LR
            subgraph chunk ["Process (Chunk)"]

            end
            subgraph embed [Embeddings]

            end
            subgraph index [Index & Retrieve]

            end
            subgraph rank [Rank]

            end
            subgraph generate [Generate]

            end
            subgraph validate [Validate]

            end
            chunk --> embed --> index --> rank --> generate --> validate
        end

    style build fill:{gcolors['grey'][3]}, stroke-width:0px, rx:10, ry:10
    
    class chunk,embed,index,rank,generate,validate nodeClass
    
    
""", filepath = filepath)

# %%
nodes = ['chunk', 'embed', 'index', 'rank', 'generate', 'validate']
for node in nodes:

    filepath = f'applied-genai/overview-build-{node}.png'

    inits = "%%{init:{'flowchart': {'diagramPadding': 0, 'nodeSpacing': 20, 'rankSpacing': 20, 'subGraphTitleMargin': {'top': 15, 'bottom': 15}}}}%%"

    mermaid_render(f"""
    {inits}
    flowchart LR
        classDef nodeClass fill:{gcolors['grey'][1]},stroke:{gcolors['grey'][5]},stroke-width:2px
        classDef nodeClassG fill:{gcolors['green'][4]},stroke:{gcolors['grey'][5]},stroke-width:2px

            subgraph build[Build]
                direction LR
                subgraph chunk ["Process (Chunk)"]

                end
                subgraph embed [Embeddings]

                end
                subgraph index [Index & Retrieve]

                end
                subgraph rank [Rank]

                end
                subgraph generate [Generate]

                end
                subgraph validate [Validate]

                end
                chunk --> embed --> index --> rank --> generate --> validate
            end

        style build fill:{gcolors['grey'][3]}, stroke-width:0px, rx:10, ry:10

        class {','.join([w for w in nodes if w != node])} nodeClass
        class {node} nodeClassG


    """, filepath = filepath)

# %%
Image(mainpath+filepath)
