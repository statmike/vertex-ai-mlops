# %% [markdown]
# ![tracker](https://us-central1-vertex-ai-mlops-369716.cloudfunctions.net/pixel-tracking?path=statmike%2Fvertex-ai-mlops%2FApplied+GenAI%2Fresources%2Fimages%2Fcreated%2Fapplied-genai&file=compare_retrieval_systems.ipynb)
# <!--- header table --->
# <table align="left">
#   <td style="text-align: center">
#     <a href="https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20GenAI/resources/images/created/applied-genai/compare_retrieval_systems.ipynb">
#       <img width="32px" src="https://www.svgrepo.com/download/217753/github.svg" alt="GitHub logo">
#       <br>View on<br>GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/statmike/vertex-ai-mlops/blob/main/Applied%20GenAI/resources/images/created/applied-genai/compare_retrieval_systems.ipynb">
#       <img width="32px" src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo">
#       <br>Run in<br>Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https%3A%2F%2Fraw.githubusercontent.com%2Fstatmike%2Fvertex-ai-mlops%2Fmain%2FApplied%2520GenAI%2Fresources%2Fimages%2Fcreated%2Fapplied-genai%2Fcompare_retrieval_systems.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo">
#       <br>Run in<br>Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/bigquery/import?url=https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20GenAI/resources/images/created/applied-genai/compare_retrieval_systems.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/bigquery/v1/32px.svg" alt="BigQuery logo">
#       <br>Open in<br>BigQuery Studio
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/statmike/vertex-ai-mlops/main/Applied%20GenAI/resources/images/created/applied-genai/compare_retrieval_systems.ipynb">
#       <img width="32px" src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo">
#       <br>Open in<br>Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# # Plot
#
# Plot the data from the table in the retrival readme: [here](../../../../Retrieval/readme.md)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
metrics = [
    dict(database='Cloud SQL for MySQL', 
         min=0.0142, max=0.3064, mean=0.0194, median=0.0159, 
         std_dev=0.0288, p95=0.0212, p99=0.0238),
    dict(database='NumPy (local)', 
         min=0.0038, max=0.0129, mean=0.0042, median=0.0040, 
         std_dev=0.0011, p95=0.0054, p99=0.0079),
    dict(database='Cloud SQL for PostgreSQL', 
         min=0.0133, max=0.8231, mean=0.0229, median=0.0147, 
         std_dev=0.0800, p95=0.0172, p99=0.0198),
    dict(database='AlloyDB', 
         min=0.0053, max=0.0164, mean=0.0062, median=0.0058, 
         std_dev=0.0015, p95=0.0070, p99=0.0145),
    dict(database='BigQuery', 
         min=0.7869, max=1.3211, mean=0.9671, median=0.9480, 
         std_dev=0.1064, p95=1.1408, p99=1.2350),   
    dict(database='Vertex AI Feature Store', 
         min=0.0503, max=0.1832, mean=0.0810, median=0.0629, 
         std_dev=0.0289, p95=0.1226, p99=0.1423),
    dict(database='Vertex AI Vector Search', 
         min=0.0144, max=0.1282, mean=0.0281, median=0.0170, 
         std_dev=0.0222, p95=0.0681, p99=0.0945),
    dict(database='Spanner', 
         min=0.0374, max=2.2023, mean=0.0728, median=0.0414, 
         std_dev=0.2226, p95=0.1064, p99=0.6752),
    dict(database='Memorystore (Redis)', 
         min=0.0052, max=0.0305, mean=0.0068, median=0.0067, 
         std_dev=0.0025, p95=0.0076, p99=0.0108),
    dict(database='Firestore', 
         min=0.1388, max=1.7531, mean=0.2297, median=0.2286, 
         std_dev=0.1299, p95=0.2787, p99=0.5592),
    dict(database='Bigtable', 
         min=0.1362, max=0.2672, mean=0.1697, median=0.1652, 
         std_dev=0.0213, p95=0.2101, p99=0.2297)
]

# %%
databases = [d['database'] for d in metrics]
mins = [d['min'] for d in metrics]
maxs = [d['max'] for d in metrics]
means = [d['mean'] for d in metrics]
medians = [d['median'] for d in metrics]
std_devs = [d['std_dev'] for d in metrics]
p95s = [d['p95'] for d in metrics]
p99s = [d['p99'] for d in metrics]

# %%
plt.figure(figsize=(12, 6))  # Adjust figure size as needed

plt.plot(databases, mins, marker='o', linestyle='-', color='blue', label='Min')
plt.plot(databases, maxs, marker='s', linestyle='-', color='red', label='Max')
plt.plot(databases, means, marker='^', linestyle='-', color='green', label='Mean')
plt.plot(databases, medians, marker='D', linestyle='-', color='purple', label='Median')
plt.plot(databases, std_devs, marker='*', linestyle='-', color='orange', label='Std Dev')
plt.plot(databases, p95s, marker='x', linestyle='-', color='brown', label='P95')
plt.plot(databases, p99s, marker='+', linestyle='-', color='gray', label='P99')

plt.xlabel('Database')
plt.ylabel('Seconds')
plt.title('Profile: Sequential Retrieval Tries With Test Environment')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Create figure and subplots (order reversed)
fig, (ax2, ax1) = plt.subplots(2, 1, sharex=True, figsize=(12, 8),
                               gridspec_kw={'height_ratios': [1, 1]})

# Plotting on the first subplot (ax1) - range 0 to 0.4
ax1.plot(databases, mins, marker='o', linestyle='-', color='blue', label='Min')
ax1.plot(databases, maxs, marker='s', linestyle='-', color='red', label='Max')
ax1.plot(databases, means, marker='^', linestyle='-', color='green', label='Mean')
ax1.plot(databases, medians, marker='D', linestyle='-', color='purple', label='Median')
ax1.plot(databases, std_devs, marker='*', linestyle='-', color='orange', label='Std Dev')
ax1.plot(databases, p95s, marker='x', linestyle='-', color='brown', label='P95')
ax1.plot(databases, p99s, marker='+', linestyle='-', color='gray', label='P99')

ax1.set_ylim(0, 0.4)  # Set y-axis limits for ax1
ax1.spines['top'].set_visible(False)  # Hide top spine

# Plotting on the second subplot (ax2) - range 0.4 to 10
ax2.plot(databases, mins, marker='o', linestyle='-', color='blue', label='Min')
ax2.plot(databases, maxs, marker='s', linestyle='-', color='red', label='Max')
ax2.plot(databases, means, marker='^', linestyle='-', color='green', label='Mean')
ax2.plot(databases, medians, marker='D', linestyle='-', color='purple', label='Median')
ax2.plot(databases, std_devs, marker='*', linestyle='-', color='orange', label='Std Dev')
ax2.plot(databases, p95s, marker='x', linestyle='-', color='brown', label='P95')
ax2.plot(databases, p99s, marker='+', linestyle='-', color='gray', label='P99')

ax2.set_ylim(0.4, 10)  # Set y-axis limits for ax2
ax2.spines['bottom'].set_visible(False)  # Hide bottom spine

# Break effect (switched ax1 and ax2)
d = .015  # how big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax2.transAxes, color='k', clip_on=False)
ax2.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax2.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax1.transAxes)  # switch to the bottom axes
ax1.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax1.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

# Other plot elements
ax1.set_xlabel('Database')
ax2.set_ylabel('Seconds (0.4-10)')
ax1.set_ylabel('Seconds (0-0.4)')
ax2.set_title('Profile: Sequential Retrieval Tries With Test Environment')
plt.xticks(rotation=45, ha='right')
ax2.legend(loc='upper left')  # Legend for ax2 (now the top plot)
ax1.legend(loc='upper right') # Legend for ax1 (now the bottom plot)
plt.tight_layout()
plt.show()

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Candle stick-like bars for min to max range
plt.vlines(databases, mins, maxs, colors='black', label='Min-Max Range')

# Scatter plots for other metrics
plt.scatter(databases, means, marker='^', color='green', label='Mean', zorder=3)
plt.scatter(databases, medians, marker='D', color='purple', label='Median', zorder=3)
plt.scatter(databases, p95s, marker='x', color='brown', label='P95', zorder=3)
plt.scatter(databases, p99s, marker='+', color='gray', label='P99', zorder=3)

plt.xlabel('Database')
plt.ylabel('Seconds')
plt.title('Profile: Sequential Retrieval Tries With Test Environment')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.savefig('compare_retrieval_systems-zoom-0.png')
plt.show()

# %%
# Plotting - Second Plot (y-axis range 0-0.4)
plt.figure(figsize=(12, 6))

# Candle stick-like bars for min to max range
plt.vlines(databases, mins, maxs, colors='black', label='Min-Max Range')

# Scatter plots for other metrics
plt.scatter(databases, means, marker='^', color='green', label='Mean', zorder=3)
plt.scatter(databases, medians, marker='D', color='purple', label='Median', zorder=3)
plt.scatter(databases, p95s, marker='x', color='brown', label='P95', zorder=3)
plt.scatter(databases, p99s, marker='+', color='gray', label='P99', zorder=3)

plt.xlabel('Database')
plt.ylabel('Seconds')
plt.title('Profile: Sequential Retrieval Tries With Test Environment (Zoomed)')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 0.4)  # Set y-axis limit for the second plot
plt.legend()
plt.tight_layout()
plt.savefig('compare_retrieval_systems-zoom-1.png')
plt.show()

# %%
# Plotting - Second Plot (y-axis range 0-0.4)
plt.figure(figsize=(12, 6))

# Candle stick-like bars for min to max range
plt.vlines(databases, mins, maxs, colors='black', label='Min-Max Range')

# Scatter plots for other metrics
plt.scatter(databases, means, marker='^', color='green', label='Mean', zorder=3)
plt.scatter(databases, medians, marker='D', color='purple', label='Median', zorder=3)
plt.scatter(databases, p95s, marker='x', color='brown', label='P95', zorder=3)
plt.scatter(databases, p99s, marker='+', color='gray', label='P99', zorder=3)

plt.xlabel('Database')
plt.ylabel('Seconds')
plt.title('Profile: Sequential Retrieval Tries With Test Environment (Zoomed)')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 0.05)  # Set y-axis limit for the second plot
plt.legend()
plt.tight_layout()
plt.savefig('compare_retrieval_systems-zoom-2.png')
plt.show()
