# %% [markdown]
# # Adding GA4 Event (page_view) Tracking to all Repository Documents
#
# - Get list of all `.md` and `.ipynb` document in this repository
# - Create GA4 Measurment Protocol pixel link for each document
# - edit each document to contain an image load for the pixel

# %%
import os
import json
import urllib.parse

# %%
measurement_id = 'G-6VDTYWLKX6'

url = 'https://www.google-analytics.com/collect?v=2'
track_parms = f'&tid={measurement_id}&cid=1&en=page_view&sid=1'

# %%
# tested in: /home/jupyter/vertex-ai-mlops/architectures/tracking
for root, dirs, files in os.walk(r'/home/jupyter/vertex-ai-mlops'):
    for file in files:
        if file.endswith(('.md', '.ipynb')) and not root.endswith('.ipynb_checkpoints'):
            dl = urllib.parse.quote_plus(root.replace('/home/jupyter/', 'statmike/'))
            dt = urllib.parse.quote_plus(file)
            click = url + track_parms + f"&dl={dl}&dt={dt}"
            print('--------------------------------------------------------------------')
            print(os.path.join(root, file))
            print(click)
            if file.endswith('.md'):
                update = False
                print('Editing File Header...')
                
                # read file contents
                with open(os.path.join(root, file), 'r') as reader:
                    content = reader.readlines()
                before = content[0]
                
                # edit contents
                if content[0].startswith('![ga4](https://www.google-analytics.com'):
                    content[0] = f'![ga4]({click})\n'
                else:
                    content.insert(0, f'![ga4]({click})\n')
                after = content[0]
                if content[1] not in ('', '\n'):
                    update = True
                    content.insert(1, '\n')
                
                # write file contents (overwrite)
                if before != after or update:
                    print(f'Before:\n{before}')
                    print(f'After:\n{after}')
                    with open(os.path.join(root, file), 'w') as writer:
                        writer.writelines(content)
                else:
                    print(f'No change, existing value is:\n{before}')
                    
            elif not file == 'tracking_ga4_add.ipynb': # .ipynb are JSON files, dont read this file though
                update = False
                print('Editing File Header...')
                
                # read file contents
                with open(os.path.join(root, file), 'r') as reader:
                    content = json.loads(reader.read())
                    
                # edit contents
                for cell in content['cells']:
                    if cell['cell_type'] == 'markdown':
                        before = cell['source'][0]
                        if cell['source'][0].startswith('![ga4](https://www.google-analytics.com'):
                            cell['source'][0] = f'![ga4]({click})\n'
                        else:
                            cell['source'].insert(0, f'![ga4]({click})\n')
                        after = cell['source'][0]
                        
                        if cell['source'][1] not in ('', '\n'):
                            update = True
                            cell['source'].insert(1, '\n')
                        break
                
                # write file contents (overwrite)
                if before != after or update:
                    print(f'Before:\n{before}')
                    print(f'After:\n{after}')
                    with open(os.path.join(root, file), 'w') as writer:
                        writer.write(json.dumps(content))
                else:
                    print(f'No change, existing value is:\n{before}')
# Out:
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Vertex AI - Vizier Optimization Service.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=Vertex+AI+-+Vizier+Optimization+Service.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=Vertex+AI+-+Vizier+Optimization+Service.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/11 - Vertex AI > Features - Feature Store.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=11+-+Vertex+AI+%3E+Features+-+Feature+Store.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=11+-+Vertex+AI+%3E+Features+-+Feature+Store.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/99 - Cleanup/99 - Cleanup.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F99+-+Cleanup&dt=99+-+Cleanup.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F99+-+Cleanup&dt=99+-+Cleanup.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/99 - Cleanup/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F99+-+Cleanup&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F99+-+Cleanup&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Learn ML/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FLearn+ML&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FLearn+ML&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied AI Solutions/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+AI+Solutions&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+AI+Solutions&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Learn Bayes/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FLearn+Bayes&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FLearn+Bayes&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Autoencoders/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Autoencoders&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Autoencoders&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05c - Vertex AI Custom Model - TensorFlow - Custom Job With Custom Container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05c+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Custom+Container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05c+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Custom+Container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05a - Vertex AI Custom Model - TensorFlow - Custom Job With Python File.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05a+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Python+File.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05a+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Python+File.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05b - Vertex AI Custom Model - TensorFlow - Custom Job With Python Source Distribution.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05b+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Python+Source+Distribution.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05b+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Custom+Job+With+Python+Source+Distribution.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05 - Vertex AI Custom Model - TensorFlow - Notebook to Hyperparameter Tuning Script.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Notebook+to+Hyperparameter+Tuning+Script.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Notebook+to+Hyperparameter+Tuning+Script.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Prediction - Batch.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Batch.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Batch.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05h - Vertex AI Custom Model - TensorFlow - Hyperparameter Tuning Job With Python Source Distribution.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05h+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Python+Source+Distribution.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05h+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Python+Source+Distribution.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05f - Vertex AI Custom Model - TensorFlow - Training Pipeline With Custom Container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05f+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Custom+Container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05f+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Custom+Container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Distributed Training.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Distributed+Training.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Distributed+Training.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Monitoring.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Monitoring.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Monitoring.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Interpretability with LIT.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Interpretability+with+LIT.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Interpretability+with+LIT.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Prediction - Custom.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Custom.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Custom.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Experiments.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Experiments.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Experiments.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - ML Metadata.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+ML+Metadata.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+ML+Metadata.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Explainability - Feature-Based.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Explainability+-+Feature-Based.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Explainability+-+Feature-Based.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05g - Vertex AI Custom Model - TensorFlow - Hyperparameter Tuning Job With Python file.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05g+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Python+file.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05g+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Python+file.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Prediction - Online.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Online.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Online.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05i - Vertex AI Custom Model - TensorFlow - Hyperparameter Tuning Job With Custom Container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05i+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Custom+Container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05i+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Hyperparameter+Tuning+Job+With+Custom+Container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05e - Vertex AI Custom Model - TensorFlow - Training Pipeline With Python Source Distribution.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05e+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Python+Source+Distribution.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05e+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Python+Source+Distribution.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05d - Vertex AI Custom Model - TensorFlow - Training Pipeline With Python file.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05d+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Python+file.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05d+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Training+Pipeline+With+Python+file.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Explainability - Example-Based.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Explainability+-+Example-Based.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Explainability+-+Example-Based.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Prediction - Local.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Local.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Prediction+-+Local.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Interpretability with WIT.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Interpretability+with+WIT.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Interpretability+with+WIT.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Pipelines.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Pipelines.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Pipelines.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05 - Vertex AI Custom Model - TensorFlow - Notebook to Script.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Notebook+to+Script.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+Notebook+to+Script.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05 - Vertex AI Custom Model - TensorFlow - in Notebook.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+in+Notebook.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05+-+Vertex+AI+Custom+Model+-+TensorFlow+-+in+Notebook.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/05Tools - Automation.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Automation.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=05Tools+-+Automation.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/05 - TensorFlow/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F05+-+TensorFlow&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03f - BQML Logistic Regression With Hyperparameter Tuning.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03f+-+BQML+Logistic+Regression+With+Hyperparameter+Tuning.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03f+-+BQML+Logistic+Regression+With+Hyperparameter+Tuning.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03b - BQML Boosted Trees.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03b+-+BQML+Boosted+Trees.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03b+-+BQML+Boosted+Trees.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03d - BQML Deep Neural Network (DNN).ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03d+-+BQML+Deep+Neural+Network+%28DNN%29.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03d+-+BQML+Deep+Neural+Network+%28DNN%29.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03Tools - Pipelines Example 3.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+3.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+3.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/BQML Feature Engineering.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=BQML+Feature+Engineering.ipynb
# Editing File Header...
# Before:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=BQML+Feature+Engineering.ipynb)
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=BQML+Feature+Engineering.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03Tools - Predictions.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Predictions.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Predictions.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03i - BQML Autoencoder with Anomaly Detection.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03i+-+BQML+Autoencoder+with+Anomaly+Detection.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03i+-+BQML+Autoencoder+with+Anomaly+Detection.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03a - BQML Logistic Regression.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03a+-+BQML+Logistic+Regression.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03a+-+BQML+Logistic+Regression.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03Tools - Pipelines Example 2.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+2.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+2.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03e - BQML Wide-And-Deep Networks.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03e+-+BQML+Wide-And-Deep+Networks.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03e+-+BQML+Wide-And-Deep+Networks.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03c - BQML Random Forest.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03c+-+BQML+Random+Forest.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03c+-+BQML+Random+Forest.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03Tools - Pipelines Example 1.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+1.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03Tools+-+Pipelines+Example+1.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03 - Introduction to BigQuery ML (BQML).ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03+-+Introduction+to+BigQuery+ML+%28BQML%29.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03+-+Introduction+to+BigQuery+ML+%28BQML%29.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03h - BQML k-means with Anomaly Detection.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03h+-+BQML+k-means+with+Anomaly+Detection.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03h+-+BQML+k-means+with+Anomaly+Detection.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/03g - BQML - PCA with Anomaly Detection.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03g+-+BQML+-+PCA+with+Anomaly+Detection.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=03g+-+BQML+-+PCA+with+Anomaly+Detection.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/03 - BigQuery ML (BQML)/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F03+-+BigQuery+ML+%28BQML%29&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/AutoML to Cloud Run.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=AutoML+to+Cloud+Run.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=AutoML+to+Cloud+Run.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/CPR Endpoints That Train.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=CPR+Endpoints+That+Train.ipynb
# Editing File Header...
# Before:
# # Custom Prediction Routines for Endpoints That Train
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=CPR+Endpoints+That+Train.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Custom Managed Notebook.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Custom+Managed+Notebook.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Custom+Managed+Notebook.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/05 EBE TESTING.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=05+EBE+TESTING.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=05+EBE+TESTING.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/pyspark_ml_lr_dataproc.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=pyspark_ml_lr_dataproc.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=pyspark_ml_lr_dataproc.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Transfer_Learning_Fine_Tuning.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Transfer_Learning_Fine_Tuning.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=pyspark_ml_lr_dataproc.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/dataproc_gmm.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=dataproc_gmm.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=dataproc_gmm.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/dataproc_lr.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=dataproc_lr.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=dataproc_lr.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/aa - TFX on Vertex AI - Interactive.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=aa+-+TFX+on+Vertex+AI+-+Interactive.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=aa+-+TFX+on+Vertex+AI+-+Interactive.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/04g Notes Holder.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=04g+Notes+Holder.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=04g+Notes+Holder.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Notes - Just Notes.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Notes+-+Just+Notes.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Notes+-+Just+Notes.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Compare Scripts.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Compare+Scripts.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Compare+Scripts.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/08a - Vertex AI - Pipelines - BQML 02+03.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=08a+-+Vertex+AI+-+Pipelines+-+BQML+02%2B03.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=08a+-+Vertex+AI+-+Pipelines+-+BQML+02%2B03.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/sparkml gmm test.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=sparkml+gmm+test.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=08a+-+Vertex+AI+-+Pipelines+-+BQML+02%2B03.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Transfer_Learning_BaseModel.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=Transfer_Learning_BaseModel.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=08a+-+Vertex+AI+-+Pipelines+-+BQML+02%2B03.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/forecasting master.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=forecasting+master.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=forecasting+master.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/03c - model signature.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=03c+-+model+signature.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=03c+-+model+signature.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/transfer_learning/Untitled.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2Ftransfer_learning&dt=Untitled.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=03c+-+model+signature.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/transfer_learning/transfer_learning.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2Ftransfer_learning&dt=transfer_learning.ipynb
# Editing File Header...
# Before:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev&dt=transfer_learning.ipynb)
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2Ftransfer_learning&dt=transfer_learning.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Tools/dataproc-serverless-pyspark.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2FTools&dt=dataproc-serverless-pyspark.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2FTools&dt=dataproc-serverless-pyspark.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Dev/Tools/dataproc-serverless-pyspark-custom-container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2FTools&dt=dataproc-serverless-pyspark-custom-container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FDev%2FTools&dt=dataproc-serverless-pyspark-custom-container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Pre-Trained APIs/api-fun-demo.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Pre-Trained+APIs&dt=api-fun-demo.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Pre-Trained+APIs&dt=api-fun-demo.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Pre-Trained APIs/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Pre-Trained+APIs&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Pre-Trained+APIs&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/scripting/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Fscripting&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Fscripting&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/00 - Setup/00 - Environment Setup.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F00+-+Setup&dt=00+-+Environment+Setup.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F00+-+Setup&dt=00+-+Environment+Setup.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/00 - Setup/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F00+-+Setup&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F00+-+Setup&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/07 - PyTorch/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/06 - XGBoost/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F06+-+XGBoost&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F06+-+XGBoost&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/08 - R/08b_gcs Script - Vertex AI Custom Model - R - Notebook to Script.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08b_gcs+Script+-+Vertex+AI+Custom+Model+-+R+-+Notebook+to+Script.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08b_gcs+Script+-+Vertex+AI+Custom+Model+-+R+-+Notebook+to+Script.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/08 - R/08 - Vertex AI Custom Model - R - in Notebook.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08+-+Vertex+AI+Custom+Model+-+R+-+in+Notebook.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08+-+Vertex+AI+Custom+Model+-+R+-+in+Notebook.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/08 - R/08b_gcs Training Job - Vertex AI Custom Model - R - Training Pipeline With Custom Container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08b_gcs+Training+Job+-+Vertex+AI+Custom+Model+-+R+-+Training+Pipeline+With+Custom+Container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08b_gcs+Training+Job+-+Vertex+AI+Custom+Model+-+R+-+Training+Pipeline+With+Custom+Container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/08 - R/08Tools - Prediction - Custom.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08Tools+-+Prediction+-+Custom.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F08+-+R&dt=08Tools+-+Prediction+-+Custom.ipynb)
#
# ...
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/architectures/tracking/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Farchitectures%2Ftracking&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Farchitectures%2Ftracking&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Similarity Learning/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Similarity+Learning&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Similarity+Learning&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/04 - scikit-learn/04 - Vertex AI Custom Model - scikit-learn - Notebook to Script.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04+-+Vertex+AI+Custom+Model+-+scikit-learn+-+Notebook+to+Script.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04+-+Vertex+AI+Custom+Model+-+scikit-learn+-+Notebook+to+Script.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/04 - scikit-learn/04a - Vertex AI Custom Model - scikit-learn - Custom Job With Python File.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04a+-+Vertex+AI+Custom+Model+-+scikit-learn+-+Custom+Job+With+Python+File.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04a+-+Vertex+AI+Custom+Model+-+scikit-learn+-+Custom+Job+With+Python+File.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/04 - scikit-learn/04 - Vertex AI Custom Model - scikit-learn - in Notebook.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04+-+Vertex+AI+Custom+Model+-+scikit-learn+-+in+Notebook.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=04+-+Vertex+AI+Custom+Model+-+scikit-learn+-+in+Notebook.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/04 - scikit-learn/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F04+-+scikit-learn&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Job Parameters.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Job+Parameters.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Job+Parameters.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/BigQuery - R.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=BigQuery+-+R.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=BigQuery+-+R.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Packages.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Packages.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Packages.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Custom Containers.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Custom+Containers.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Custom+Containers.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/BigQuery - Python Client.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=BigQuery+-+Python+Client.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=BigQuery+-+Python+Client.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/DEV - KFP.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=DEV+-+KFP.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=DEV+-+KFP.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Client for GCS.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Client+for+GCS.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Client+for+GCS.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Training.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Training.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Training.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/Python Multiprocessing.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Multiprocessing.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=Python+Multiprocessing.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/aiplatform_notes.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=aiplatform_notes.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=aiplatform_notes.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Tips/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FTips&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Reinforcement Learning/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Reinforcement+Learning&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Reinforcement+Learning&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/8 - Vertex AI Pipelines - Forecasting Tournament - BQML + AutoML + Prophet.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=8+-+Vertex+AI+Pipelines+-+Forecasting+Tournament+-+BQML+%2B+AutoML+%2B+Prophet.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=8+-+Vertex+AI+Pipelines+-+Forecasting+Tournament+-+BQML+%2B+AutoML+%2B+Prophet.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/1 - BigQuery Time Series Forecasting Data Review and Preparation.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=1+-+BigQuery+Time+Series+Forecasting+Data+Review+and+Preparation.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=1+-+BigQuery+Time+Series+Forecasting+Data+Review+and+Preparation.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/6 - Vertex AI Custom Model - Forecasting with Prophet - In Notebook.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=6+-+Vertex+AI+Custom+Model+-+Forecasting+with+Prophet+-+In+Notebook.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=6+-+Vertex+AI+Custom+Model+-+Forecasting+with+Prophet+-+In+Notebook.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/4 - Vertex AI AutoML Forecasting - Python client.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=4+-+Vertex+AI+AutoML+Forecasting+-+Python+client.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=4+-+Vertex+AI+AutoML+Forecasting+-+Python+client.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/7 - Vertex AI Custom Model - Forecasting with Prophet - Custom Job With Custom Container.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=7+-+Vertex+AI+Custom+Model+-+Forecasting+with+Prophet+-+Custom+Job+With+Custom+Container.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=7+-+Vertex+AI+Custom+Model+-+Forecasting+with+Prophet+-+Custom+Job+With+Custom+Container.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/3 - Vertex AI AutoML Forecasting - GCP Console (no code).ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=3+-+Vertex+AI+AutoML+Forecasting+-+GCP+Console+%28no+code%29.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=3+-+Vertex+AI+AutoML+Forecasting+-+GCP+Console+%28no+code%29.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/2 - BQML Univariate Forecasting with ARIMA+.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=2+-+BQML+Univariate+Forecasting+with+ARIMA%2B.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=2+-+BQML+Univariate+Forecasting+with+ARIMA%2B.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/5 - Vertex AI AutoML Forecasting - multiple scenarios.ipynb
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=5+-+Vertex+AI+AutoML+Forecasting+-+multiple+scenarios.ipynb
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=5+-+Vertex+AI+AutoML+Forecasting+-+multiple+scenarios.ipynb)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Forecasting/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Forecasting&dt=readme.md)
#
# --------------------------------------------------------------------
# /home/jupyter/vertex-ai-mlops/Applied Recommender Systems/readme.md
# https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Recommender+Systems&dt=readme.md
# Editing File Header...
# No change, existing value is:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+Recommender+Systems&dt=readme.md)
