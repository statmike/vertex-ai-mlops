# %% [markdown]
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Farchitectures%2Ftracking%2Fsetup%2Fga4&dt=ga4_add.ipynb)
#
# # Adding GA4 Event (page_view) Tracking to all Repository Documents
#
# - Get list of all `.md` and `.ipynb` document in this repository
# - Create GA4 Measurment Protocol pixel link for each document
# - edit each document to contain an image load for the pixel
#
#
# Also see these File (in the same directory) that **list and remove** the GA4 links from all `.md` and `.ipynb` files in the repository:
# - list file with ga4: [ga4_list.py](./ga4_list.py)
# - remove ga4 tracking: [ga4_remove.py](./ga4_remove.py)

# %%
import os
import json
import urllib.parse

# %%
measurement_id = 'G-6VDTYWLKX6'

url = 'https://www.google-analytics.com/collect?v=2'
track_parms = f'&tid={measurement_id}&cid=1&en=page_view&sid=1'

# %%
# tested in: /home/jupyter/vertex-ai-mlops/architectures/tracking
for root, dirs, files in os.walk(r'/home/jupyter/vertex-ai-mlops'):
    for file in files:
        if file.endswith(('.md', '.ipynb')) and not root.endswith('.ipynb_checkpoints'):
            dl = urllib.parse.quote_plus(root.replace('/home/jupyter/', 'statmike/'))
            dt = urllib.parse.quote_plus(file)
            click = url + track_parms + f"&dl={dl}&dt={dt}"
            #print('--------------------------------------------------------------------')
            #print(os.path.join(root, file))
            #print(click)
            
            if file.endswith('.md'):
                update = False
                #print('Editing File Header...')
                
                # read file contents
                with open(os.path.join(root, file), 'r') as reader:
                    content = reader.readlines()
                before = content[0]
                
                # edit contents
                if content[0].startswith('![ga4](https://www.google-analytics.com'):
                    content[0] = f'![ga4]({click})\n'
                else:
                    content.insert(0, f'![ga4]({click})\n')
                after = content[0]
                
                # follow the ga4 line with a blank line
                if content[1] not in ('', '\n'):
                    update = True
                    content.insert(1, '\n')
                
                # write file contents (overwrite)
                if (before != after) or update:
                    print(f'Before:\n{before}')
                    print(f'After:\n{after}')
                    with open(os.path.join(root, file), 'w') as writer:
                        writer.writelines(content)
                #else:
                #    print(f'No change, existing value is:\n{before}')
                    
            elif not file == 'ga4_add.ipynb': # .ipynb are JSON files, dont read this current file though
                update = False
                #print('Editing File Header...')
                
                # read file contents
                with open(os.path.join(root, file), 'r') as reader:
                    content = json.loads(reader.read())
                    
                # edit contents: {'cells': [{'cell_type': 'markdown', 'source': ['', '', ...], ...}, ...]}
                for cell in content['cells']:
                    if cell['cell_type'] == 'markdown':
                        before = cell['source'][0]
                        if cell['source'][0].startswith('![ga4](https://www.google-analytics.com'):
                            cell['source'][0] = f'![ga4]({click})\n'
                        else:
                            cell['source'].insert(0, f'![ga4]({click})\n')
                        after = cell['source'][0]
                        
                        # follow the ga4 line with a blank line
                        if cell['source'][1] not in ('', '\n'):
                            update = True
                            cell['source'].insert(1, '\n')
                        break
                
                # write file contents (overwrite)
                if (before != after) or update:
                    print(f'Before:\n{before}')
                    print(f'After:\n{after}')
                    with open(os.path.join(root, file), 'w') as writer:
                        writer.write(json.dumps(content))
                #else:
                #    print(f'No change, existing value is:\n{before}')
# Out:
# Before:
# # Host Torchscript On Vertex Endpoint
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch&dt=YOLOv5+On+Vertex+AI+Endpoints+With+NVIDIA+Triton+Server.ipynb)
#
# Before:
# <div align="center">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5&dt=README.md)
#
# Before:
# <div align="center">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5&dt=README.zh-CN.md)
#
# Before:
# <div align="center">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5&dt=tutorial.ipynb)
#
# Before:
# ## Contributing to YOLOv5 🚀
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5&dt=CONTRIBUTING.md)
#
# Before:
# <!--
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2F.github&dt=PULL_REQUEST_TEMPLATE.md)
#
# Before:
# <div align="center">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2Fclassify&dt=tutorial.ipynb)
#
# Before:
# <div align="center">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2Fsegment&dt=tutorial.ipynb)
#
# Before:
# # Flask REST API
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2Futils%2Fflask_rest_api&dt=README.md)
#
# Before:
# <img src="https://cdn.comet.ml/img/notebook_logo.png">
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2Futils%2Floggers%2Fcomet&dt=README.md)
#
# Before:
# # ClearML Integration
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fyolov5%2Futils%2Floggers%2Fclearml&dt=README.md)
#
# Before:
# ##### **NOTE:** `dali_backend` is available in `tritonserver-20.11` and later
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend&dt=README.md)
#
# Before:
# The MIT License (MIT)
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend&dt=LICENSE.md)
#
# Before:
# ## Individual Contributor License Agreement (CLA)
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend&dt=CLA.md)
#
# Before:
# # DALI model configuration file
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs&dt=config.md)
#
# Before:
# # Triton Inference Server with DALI backend
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fresnet50_trt&dt=README.md)
#
# Before:
# # ResNet101 PyTorch segmentation example
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fsegmentation&dt=README.md)
#
# Before:
# # GPU-accelerated video processing in Triton using DALI
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fvideo_decode_remap&dt=README.md)
#
# Before:
# # DALI plugins with Triton
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fdali_plugin&dt=README.md)
#
# Before:
# # Identity model for DALI
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fidentity&dt=README.md)
#
# Before:
# # InceptionV3 inference using DALI
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Finception_ensemble&dt=README.md)
#
# Before:
# # Multi input model for DALI Backend
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fmulti_input&dt=README.md)
#
# Before:
# # Decoding video in DALI backend
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fvideo_decoding&dt=README.md)
#
# Before:
# # perf_analyzer example with DALI image decoder
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fdocs%2Fexamples%2Fperf_analyzer&dt=README.md)
#
# Before:
# The torchaudio based processing of audio files comes from NVIDIA Deep Learning Examples project:
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fbenchmarks%2Fdali_vs_python%2FBM_jasper&dt=README.md)
#
# Before:
# # Contributor Covenant Code of Conduct
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2&dt=CODE_OF_CONDUCT.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2&dt=README.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=deprecations.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=tostring.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=cmake-integration.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=list-of-examples.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=tutorial.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=ci-and-misc.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=Readme.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=benchmarks.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=slow-compiles.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=matchers.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=limitations.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=release-process.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=command-line.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=test-cases-and-sections.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=opensource-users.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=assertions.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=contributing.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=logging.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=configuration.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=other-macros.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=generators.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=test-fixtures.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=release-notes.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=why-catch.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=commercial-users.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=reporters.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=event-listeners.md)
#
# Before:
# <a id="top"></a>
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2Fdocs&dt=own-main.md)
#
# Before:
# <!--
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2F.github&dt=pull_request_template.md)
#
# Before:
# ---
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2F.github%2FISSUE_TEMPLATE&dt=feature_request.md)
#
# Before:
# ---
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2F07+-+PyTorch%2Ftemp%2Ftriton-serve%2Fdali_backend%2Fextern%2FCatch2%2F.github%2FISSUE_TEMPLATE&dt=bug_report.md)
#
# Before:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+GenAI&dt=Vertex+AI+GenAI+For+Document+Q%26A+-+Annual+Report.ipynb)
#
# After:
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2FApplied+GenAI&dt=Vertex+AI+GenAI+For+Document+Q%26A+-+Healthcare+Benefits+Member+Handbook.ipynb)

# %% [markdown]
# ## NOTES
# This edits files on disk.  If they are currently loaded in Jupyter then the opened version may look different. **THIS IS IMPORTANT**
#
# - Save all files
# - When a note pops up about the version on disk being different, choose **revert** while reload the file from the new version on disk that was created by this notebook.
