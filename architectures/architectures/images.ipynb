# %% [markdown]
# ![ga4](https://www.google-analytics.com/collect?v=2&tid=G-6VDTYWLKX6&cid=1&en=page_view&sid=1&dl=statmike%2Fvertex-ai-mlops%2Farchitectures%2Farchitectures&dt=images.ipynb)
#
# # Visuals

# %% [markdown]
# ---
# ## Colors

# %%
gcolors = dict(
    blue = ['#E8F0FE','#D2E3FC','#AECBFA','#8AB4F8','#669DF6','#4285F4','#1A73E8','#1967D2','#185ABC','#174EA6'],
    red = ['#FCE8E6','#FAD2CF','#F6AEA9','#F28B82','#EE675C','#EA4335','#D93025','#C5221F','#B31412','#A50E0E'],
    yellow = ['#FEF7E0','#FEEFC3','#FDE293','#FDD663','#FCC934','#FBBC04','#F9AB00','#F29900','#EA8600','#E37400'],
    green = ['#E6F4EA','#CEEAD6','#A8DAB5','#81C995','#5BB974','#34A853','#1E8E3E','#188038','#137333','#0D652D'],
    grey = ['#F8F9FA','#F1F3F4','#E8EAED','#DADCE0','#BDC1C6','#9AA0A6','#80868B','#5F6368','#3C4043','#202124']
)

# %%
import IPython
def colorer(scheme, text):
    for colors in scheme.keys():
        IPython.display.display(
            IPython.display.Markdown(
                ' '.join(
                    f'<span style="font-family: monospace"><span style="color: {color}">{text}</span></span>'
                    for color in scheme[colors]
                )
            )
        )
colorer(gcolors, 'Vertex AI')
# Out:
# <span style="font-family: monospace"><span style="color: #E8F0FE">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #D2E3FC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #AECBFA">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #8AB4F8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #669DF6">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #4285F4">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1A73E8">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #1967D2">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #185ABC">Vertex AI</span></span> <span style="font-family: monospace"><span style="color: #174EA6">Vertex AI</span></span>
# ...

# %% [markdown]
# ---
# ## Graphviz
#
# Use [graphviz](https://graphviz.readthedocs.io/en/stable/manual.html).
# - Which is a python interface to [Graphviz](https://www.graphviz.org/)
#     - Which uses an abstract languaged called [Dot Language](https://www.graphviz.org/doc/info/lang.html)
#
#
# Open These Reference Links When Writing Code:
# - [Graphviz Documentation](https://graphviz.org/doc/info/lang.html)
# - [Python Graphviz API](https://graphviz.readthedocs.io/en/stable/api.html)

# %%
#!sudo apt-get -qq install graphviz

# %%
#!pip install graphviz -q -U

# %%
import graphviz
from IPython.display import Image

# %% [markdown]
# ---
# ## Google Fonts
#
# - https://github.com/google/fonts/blob/main/README.md
# - https://fonts.google.com/

# %%
# get font for annotations: get fonts from fonts.google.com
#font_source_url = "https://fonts.googleapis.com/css2?family=Roboto+Mono&display=swap"
#font_source = requests.get(font_source_url).content.decode("utf-8")
#start_url = font_source.find('url(')+4
#end_url = font_source.find(')', start_url)
#font_url = font_source[start_url:end_url]
#font = PIL.ImageFont.truetype(io.BytesIO(requests.get(font_url).content), 35)

# %% [markdown]
# ---
# ## Example

# %%
# Create Digraph object
dot = graphviz.Digraph()

# Add nodes
dot.node('1')
dot.node('3')
dot.node('2')
dot.node('5')

# Add edges
dot.edges(['12', '13', '35'])

# save to file
dot.render(filename = 'dot', directory = './images', format = 'png')

# Visualize the graph in notebook
dot

# %%
# visualize the file
Image('./images/dot.png')

# %% [markdown]
# ## ./readme.md: code progression

# %%
file = 'code_progression'
path = 'images/readme'
# Create Digraph object
cp = graphviz.Digraph()
cp.attr(rankdir = 'LR')

# Add nodes
cp.node(name = 'a1', label = 'Explore', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['blue'][4])
cp.node(name = 'a2', label = 'Develop', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['yellow'][4])
cp.node(name = 'a3', label = 'Deploy', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['yellow'][4], fillcolor = gcolors['grey'][4])

# Add edges
cp.edge('a1', 'a2', color = gcolors['blue'][4], penwidth = '3')
cp.edge('a2', 'a3', color = gcolors['yellow'][4], penwidth = '3')

# save to file
cp.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
cp

# %%
# visualize the file
Image('./images/readme/code_progression.png')

# %%
file = 'code_progression_star'
path = 'images/readme'
# Create Digraph object
cp = graphviz.Digraph()
cp.attr(rankdir = 'LR')

# Add nodes
cp.node(name = 'a1', label = 'Explore', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['blue'][4])
cp.node(name = 'a2', label = 'Develop', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['yellow'][4])
cp.node(name = 'm', label = '', shape = 'star', style = 'filled,rounded', penwidth = '0', color = gcolors['red'][4], fillcolor = gcolors['red'][4], fixedsize = 'True', width = '.5', height = '.5')
cp.node(name = 'a3', label = 'Deploy', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['yellow'][4], fillcolor = gcolors['grey'][4])

# Add edges
cp.edge('a1', 'a2', color = gcolors['blue'][4], penwidth = '3')
cp.edge('a2', 'm', color = gcolors['yellow'][4], penwidth = '3', arrowhead = 'none')
cp.edge('m', 'a3', color = gcolors['yellow'][4], penwidth = '3')
#cp.edge('a2', 'a3', color = gcolors['blue'][4], penwidth = '3')

# save to file
cp.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
cp

# %%
# visualize the file
Image('./images/readme/code_progression_star.png')

# %% [markdown]
# ## ./readme.md: decision

# %%
file = 'decision_training'
path = 'images/readme'
# Create Digraph object
d = graphviz.Digraph()
d.attr(rankdir = 'LR', label = 'Starting Points For AI With ML', labelloc = 'top', fontsize = '20')

# Add Decision Nodes:
d.node(name = 'd0', label = 'Task Type:', 
       shape = 'diamond', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['blue'][4], 
       fixedsize = 'True', width = '1.5', height = '1.5')

d.node(name = 'g', label = 'Generative AI\nFoundation Models On Vertex AI', 
       shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['yellow'][4], fillcolor = gcolors['yellow'][4],)

d.node(name = 'd1', label = 'Do You\nHave Training\nData?', 
       shape = 'diamond', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['blue'][4], 
       fixedsize = 'True', width = '1.5', height = '1.5')
d.node(name = 'r1', label = 'Pre-trained APIs', 
       shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4],)

d.node(name = 'd2', label = 'Are You\nWriting\nTraining\nCode?', 
       shape = 'diamond', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['blue'][4], 
       fixedsize = 'True', width = '1.5', height = '1.5')
d.node(name = 'r2', label = 'Vertex AI AutoML', 
       shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4],)

d.node(name = 'd3', label = 'Framework\nChoice:', 
       shape = 'diamond', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['blue'][4], 
       fixedsize = 'True', width = '1.5', height = '1.5')
d.node(name = 'r3', label = 'BigQuery ML', 
       shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4],)
d.node(name = 'r4', label = 'Vertex AI', 
       shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4],)




# Add edges
d.edge('d0', 'd1', label = 'Prediction',
       color = gcolors['green'][4], penwidth = '3', )
d.edge('d0', 'g', label = 'Generative',
       color = gcolors['yellow'][4], penwidth = '3', )


d.edge('d1', 'r1', label = 'No',
       color = gcolors['green'][4], penwidth = '3', )
d.edge('d1', 'd2', label = 'Yes',
        color = gcolors['green'][4], penwidth = '3')
d.edge('d2', 'r2', label = 'No',
       color = gcolors['green'][4], penwidth = '3')
d.edge('d2', 'd3', label = 'Yes',
       color = gcolors['green'][4], penwidth = '3')
d.edge('d3', 'r3', label = 'SQL',
       color = gcolors['green'][4], penwidth = '3')
d.edge('d3', 'r4', label = 'Your Choice!',
       color = gcolors['green'][4], penwidth = '3')

#d.edge('d1', 'g', label = 'Your Choice!',
#       color = gcolors['green'][4], penwidth = '3')

# extra edges:
d.edge('r1', 'g', label = 'Including',
       color = gcolors['yellow'][4], penwidth = '3')


# save to file
d.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
d

# %%
# visualize the file
Image('./images/readme/decision_training.png')

# %% [markdown]
# ## ./working with/docai/readme.md: high_level

# %%
file = 'high_level'
path = 'images/working with/documentai/readme'
# Create Digraph object
cp = graphviz.Digraph()
cp.attr(rankdir = 'LR')

# Add nodes
cp.node(name = 'a1', label = 'Document', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['blue'][4])
with cp.subgraph(name='cluster_0') as c:
    c.attr(label = 'Client', style = 'filled', color = gcolors['grey'][4])
    c.node(name = 'a2', label = 'API', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['yellow'][4], fillcolor = gcolors['yellow'][4])
cp.node(name = 'a3', label = 'Processor', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4])
cp.node(name = 'a4', label = 'Response', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['red'][4], fillcolor = gcolors['red'][4])

# Add edges
cp.edge('a1', 'a2', color = gcolors['blue'][4], penwidth = '3')
cp.edge('a2', 'a3', color = gcolors['yellow'][4], penwidth = '3')
cp.edge('a3', 'a4', color = gcolors['green'][4], penwidth = '3')

           
# save to file
cp.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
cp

# %%
# visualize the file
Image('./images/working with/documentai/readme/high_level.png')

# %% [markdown]
# ## ./working with/docai: bigquery

# %%
file = 'bigquery'
path = 'images/working with/documentai'
# Create Digraph object
cp = graphviz.Digraph()
cp.attr(rankdir = 'LR')

# Add nodes
with cp.subgraph(name = 'cluster_bq') as bq:
    bq.attr(label = 'BigQuery', style = 'filled,rounded', color = gcolors['blue'][0])
    with bq.subgraph(name = 'cluster_bq_ot') as bq_ot:
        bq_ot.attr(label = 'Object Table', style = 'filled,rounded', color = gcolors['grey'][3])
        bq_ot.node(name = 'a1', label = 'Document', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['blue'][4], fillcolor = gcolors['blue'][4])
    with bq.subgraph(name = 'cluster_bq_ml') as bq_ml:
        bq_ml.attr(label = 'ML.PROCESS_DOCUMENT', style = 'filled,rounded', color = gcolors['grey'][3])
        bq_ml.node(name = 'a2', label = 'API', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['yellow'][4], fillcolor = gcolors['yellow'][4])
        bq_ml.node(name = 'a3', label = 'Processor', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['green'][4], fillcolor = gcolors['green'][4])
        bq_ml.node(name = 'a4', label = 'Response', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['red'][4], fillcolor = gcolors['red'][4])

# Add edges
cp.edge('a1', 'a2', color = gcolors['blue'][4], penwidth = '3')
cp.edge('a2', 'a3', color = gcolors['yellow'][4], penwidth = '3')
cp.edge('a3', 'a4', color = gcolors['green'][4], penwidth = '3')

           
# save to file
cp.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
cp

# %%
# visualize the file
Image('./images/working with/documentai/readme/high_level.png')

# %% [markdown]
# ## ./feature store/readme.md

# %%
file = 'overview'
path = 'images/feature store/readme'
# Create Digraph object
g = graphviz.Digraph()
g.attr(rankdir = 'LR')

with g.subgraph(name = 'cluster_0') as bq:
    bq.attr(label = 'BigQuery', style = 'filled', color = gcolors['blue'][4])
    bq.node(name = 'bq1', label = 'Table/View', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

with g.subgraph(name = 'cluster_1') as fs:
    fs.attr(label = 'Vertex AI Feature Store', style = 'filled', color = gcolors['green'][4])
    with fs.subgraph(name = 'cluster_2') as fr:
        fr.attr(label = 'Feature Registry', style = 'filled', color = gcolors['yellow'][4])
        fr.node(name = 'fr1', label = 'Feature Groups', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
        fr.node(name = 'fr2', label = 'Feature', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4] )
    
    with fs.subgraph(name = 'cluster_3') as os:
        os.attr(label = 'Online Store', style = 'filled', color = gcolors['red'][4])
        os.node(name = 'os1', label = 'Feature View', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
       
# add edges
g.edge('fr1', 'fr2', color = gcolors['grey'][7], penwidth = '3')
g.edge('fr2', 'os1', label = '(1 or more)', color = gcolors['grey'][7], penwidth = '3')
g.edge('bq1', 'fr1', label = '(1 to 1)', color = gcolors['grey'][7], penwidth = '3')
g.edge('bq1', 'os1', label = '1 row per entity', color = gcolors['grey'][7], penwidth = '3')
    
# save to file
g.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
g

# %%
# visualize the file
Image('./images/feature store/readme/overview.png')

# %% [markdown]
# ## ./custom training/a_job

# %%
file = 'a_job'
path = 'images/custom training'
# Create Digraph object
g = graphviz.Digraph()
g.attr(rankdir = 'LR')

        
with g.subgraph(name = 'cluster_vertex') as v:
    v.attr(label = 'Vertex AI Training', style = 'filled', color = gcolors['green'][4])
    
    with v.subgraph(name = 'cluster_train') as cj:
        cj.attr(label = 'Custom Job', style = 'filled', color = gcolors['green'][2])
        cj.node(name = 'cj3', label = 'Compute', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
        cj.node(name = 'cj2', label = 'Container', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
        cj.node(name = 'cj1', label = 'Code', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
    
    with v.subgraph(name = 'cluster_ar') as ar:
        ar.attr(label = 'Vertex AI Pre-Built Containers', style = 'filled', color = gcolors['green'][2])
        ar.node(name = 'ar', label = 'Framework/Version\nSpecific Container', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

with g.subgraph(name = 'cluster_gcs') as gcs:
    gcs.attr(label = 'Local (or GCS)', style = 'filled', color = gcolors['yellow'][4])
    gcs.node(name = 'gcs', label = 'Script', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

with g.subgraph(name = 'cluster_bq') as bq:
    bq.attr(label = 'BigQuery', style = 'filled', color = gcolors['blue'][4])
    bq.node(name = 'bq', label = 'Table', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
    
with g.subgraph(name = 'cluster_gcs2') as gcs2:
    gcs2.attr(label = 'GCS', style = 'filled', color = gcolors['yellow'][4])
    gcs2.node(name = 'gcs2', label = 'Model Save Files', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
       
# add edges
g.edge('ar', 'cj2', label = 'URI', color = gcolors['grey'][7], penwidth = '3')
g.edge('gcs', 'cj1', color = gcolors['grey'][7], penwidth = '3')
g.edge('cj1', 'gcs2', color = gcolors['grey'][7], penwidth = '3')
g.edge('bq', 'cj1', color = gcolors['grey'][7], penwidth = '3')
    
# save to file
g.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
g

# %%
# visualize the file
Image('./images/custom training/a_job.png')

# %% [markdown]
# ## ./custom training/a_workflow

# %%
file = 'a_workflow'
path = 'images/custom training'
# Create Digraph object
g = graphviz.Digraph()
g.attr(rankdir = 'LR')

    
with g.subgraph(name = 'cluster_vertex') as v:
    v.attr(label = 'Vertex AI', style = 'filled', color = gcolors['green'][6])
     
    with v.subgraph(name = 'cluster_vertex_training') as vt:
        vt.attr(label = 'Training', style = 'filled', color = gcolors['green'][4])

        with vt.subgraph(name = 'cluster_train') as cj:
            cj.attr(label = 'Custom Job', style = 'filled', color = gcolors['green'][2])
            cj.node(name = 'cj3', label = 'Compute', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
            cj.node(name = 'cj2', label = 'Container', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
            cj.node(name = 'cj1', label = 'Code', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

        with vt.subgraph(name = 'cluster_ar') as ar:
            ar.attr(label = 'Vertex AI Pre-Built Containers', style = 'filled', color = gcolors['green'][2])
            ar.node(name = 'ar', label = 'Framework/Version\nSpecific Container', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

    with v.subgraph(name = 'cluster_mr') as ar:
        ar.attr(label = 'Model Registry', style = 'filled', color = gcolors['green'][4])
        ar.node(name = 'model', label = 'Model', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

    with v.subgraph(name = 'cluster_online') as o:
        o.attr(label = 'Online Prediction', style = 'filled', color = gcolors['green'][4])
        
        with o.subgraph(name = 'cluster_endpoint') as ep:
            ep.attr(label = 'Endpoint', style = 'filled', color = gcolors['green'][2])
            ep.node(name = 'dmodel', label = 'Deployed Model', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
            
with g.subgraph(name = 'cluster_gcs') as gcs:
    gcs.attr(label = 'Local (or GCS)', style = 'filled', color = gcolors['yellow'][4])
    gcs.node(name = 'gcs', label = 'Script', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])

with g.subgraph(name = 'cluster_bq') as bq:
    bq.attr(label = 'BigQuery', style = 'filled', color = gcolors['blue'][4])
    bq.node(name = 'bq', label = 'Table', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
    
with g.subgraph(name = 'cluster_gcs2') as gcs2:
    gcs2.attr(label = 'GCS', style = 'filled', color = gcolors['yellow'][4])
    gcs2.node(name = 'gcs2', label = 'Model Save Files', shape = 'rectangle', style = 'filled,rounded', penwidth = '3', color = gcolors['grey'][4], fillcolor = gcolors['grey'][4])
       
# add edges
g.edge('ar', 'cj2', label = 'URI', color = gcolors['grey'][7], penwidth = '3')
g.edge('gcs', 'cj1', color = gcolors['grey'][7], penwidth = '3')
g.edge('cj1', 'model', style = 'invis')
g.edge('cj1', 'gcs2', color = gcolors['grey'][7], penwidth = '3')
g.edge('bq', 'cj1', color = gcolors['grey'][7], penwidth = '3')
g.edge('gcs2', 'model', color = gcolors['grey'][7], penwidth = '3')
g.edge('model', 'dmodel', color = gcolors['grey'][7], penwidth = '3')
    
# save to file
g.render(filename = f'{file}', directory = f'./{path}', format = 'png')

# Visualize the graph in notebook
g

# %%
# visualize the file
Image('./images/custom training/a_workflow.png')
